# %% [markdown]
# # 準備

# %%
import random
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

#Jupyterでインライン表示するための宣言
# %matplotlib inline 
import os
import shutil
from tqdm import tqdm
import base64
import json
from requests import Request, Session
from io import BytesIO
from PIL import Image
import pandas as pd
import jaconv
import re
import cv2
import numpy as np
from symspellpy.symspellpy import SymSpell, Verbosity
import pickle
from pykakasi import kakasi
import Levenshtein
from collections import OrderedDict
import itertools

from statistics import mode
import time

import os
import sys
import requests
# If you are using a Jupyter notebook, uncomment the following line.
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO

# %% [markdown]
# # 探索

# %% [markdown]
# # 切り取って保存

# %%
#とりあえず試し

num=1
start=0
goal=3
n_part=10
url="/Users/obara/Downloads/prescription_data_jpeg/photo-"+str(num)+".jpeg"
img = cv2.imread(url)
#img = plt.imread(url)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#plt.imshow(img)
input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,img.shape[1]*2//7:img.shape[1]*6//7]
#plt.figure(figsize=[50,50])
#plt.imshow(input_image)
plt.imsave("/Users/obara/Downloads/prescription_data_jpeg_3/photo-"+str(num)+".jpeg",input_image)

# %%
#関数化
def image_check(url,n_part,start,goal):
    img = cv2.imread(url)
    #img = plt.imread(url)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    #plt.imshow(img)
    #input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,0:img.shape[1]//2]
    input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,img.shape[1]*3//7:img.shape[1]]
    #plt.figure(figsize=[50,50])
    #plt.imshow(input_image)
    plt.imsave("/Users/obara/Downloads/prescription_data_jpeg_3/photo-"+str(num)+".jpeg",input_image)
    return

# %%
import pickle
with open('text_dic2.pickle', 'rb') as web:
    df = pickle.load(web)
    
num_list=[int(x[6:][:-5]) for x in list(df.keys())]
num_list.sort()
num_list
#35は除外
# Out:
# [2,
#  35,
#  40,
#  85,
#  93,
#  110,
#  148,
#  301,
#  326,
#  339,
#  366,
#  435,
#  456,
#  504,
#  519,
#  524,
#  548,
#  630,
#  655,
#  721,
#  770,
#  775,
#  786,
#  793,
#  806,
#  879,
#  885,
#  1011,
#  1110,
#  1137]

# %%
#for文

for num in tqdm(num_list):
    url="/Users/obara/Downloads/prescription_data_jpeg/photo-"+str(num)+".jpeg"
    image_check(url,10,0,4)
# Out:
# 100%|██████████| 30/30 [00:12<00:00,  2.33it/s]

# %% [markdown]
# ## OCR結果を保存

# %%
info_list=[]
for i in tqdm(num_list):
    try:
        dic={"file_name":"","result(10,0,10)":""}
        url="/Users/obara/Downloads/prescription_data_jpeg_3/photo-"+str(i)+".jpeg"
        dic["file_name"]="photo-"+str(i)+".jpeg"
        dic["result(10,0,10)"]=recognize5(url,10,0,10)
        info_list.append(dic)
        print(dic)
    except:
        print("photo-"+str(i)+".jpeg")
        print("ミスーーーーーーーーーーーーーーーーーーーー")
        pass

#csvに保存
df=pd.DataFrame(info_list)
df.to_csv("ocr_result_3.csv",encoding="utf_8_sig")

#pickleファイルに保存
with open('ocr_result_3.pickle', 'wb') as web:
    pickle.dump(df , web)
# Out:
#   3%|▎         | 1/30 [00:03<01:30,  3.14s/it]
# API終了までにかかった時間:2.994349956512451[sec]
# for文を回し終わるまでにかかった時間:3.0522968769073486[sec]
# elapsed_time:3.125890016555786[sec]
# {'file_name': 'photo-2.jpeg', 'result(10,0,10)': [['P. 1'], ['方', '箋', 'O'], ['の保険薬局でも有効です。)'], ['保険者番号 011301012'], ['被保険者証・被保険'], ['1080912 347', '・'], ['者手帳の記号・番号'], ['保険医療機 東京都千代田区飯田橋4-6-9 STビル2階'], ['愛医療法人社団 高典会 飯田橋クリニック'], ['分 電話番号 03-3222-6461'], ['保険医氏名 高橋 典大'], ['首', 'í', '都道府県', '番号11', '3', '番号', '1', '点数表 医療機関', 'コード', '0', '1', '1', '2', '9', '1', '4 | 8'], ['処方箋の', '特に記載のある場合を除き、'], ['使用期間', '年月', 'MT', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['ジェネリック医薬品)への変更に差し支えがあると判断した場合 ]'], ['」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]}
#   7%|▋         | 2/30 [00:06<01:29,  3.19s/it]
# API終了までにかかった時間:3.30963397026062[sec]
# for文を回し終わるまでにかかった時間:3.3105320930480957[sec]
# elapsed_time:3.321908950805664[sec]
# {'file_name': 'photo-35.jpeg', 'result(10,0,10)': [['Date'], ['IKE'], ['tre', 'A']]}
# ...

# %%
text_list=list(df["result(10,0,10)"])

# %%
text_list[0]
# Out:
# [['P. 1'],
#  ['方', '箋', 'O'],
#  ['の保険薬局でも有効です。)'],
#  ['保険者番号 011301012'],
#  ['被保険者証・被保険'],
#  ['1080912 347', '・'],
#  ['者手帳の記号・番号'],
#  ['保険医療機 東京都千代田区飯田橋4-6-9 STビル2階'],
#  ['愛医療法人社団 高典会 飯田橋クリニック'],
#  ['分 電話番号 03-3222-6461'],
#  ['保険医氏名 高橋 典大'],
#  ['首',
#   'í',
#   '都道府県',
#   '番号11',
#   '3',
#   '番号',
#   '1',
#   '点数表 医療機関',
#   'コード',
#   '0',
#   '1',
#   '1',
#   '2',
#   '9',
#   '1',
#   '4 | 8'],
#  ['処方箋の', '特に記載のある場合を除き、'],
#  ['使用期間', '年月', 'MT', '保険薬局に提出すること。', '交付の日を含めて4日以内に'],
#  ['ジェネリック医薬品)への変更に差し支えがあると判断した場合 ]'],
#  ['」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]

# %%
#上を関数化　ある単語を含んでいたら、それ以降全てを取得（その単語は含まない）
def word_check_list(words_list,check_word):
    word=check_word
    candidate_list=[]
    for num in range(len(words_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            candidate1=[]
            candidate2=[]
            candidate3=[]
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][s+1:])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)
#1,15が二回,18,19,20

# %%
#上を関数化　ある単語を含んでいたら、それ以降全てを取得（その単語は含む）
def word_check_list2(words_list,check_word):
    word=check_word
    candidate_list=[]
    for num in range(len(words_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            candidate1=[]
            candidate2=[]
            candidate3=[]
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][s:])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)
#1,15が二回,18,19,20

# %%
#上を関数化　ある単語を含んでいたら、それより前を全てを取得（その単語は含まない）
def word_check_list_before(words_list,check_word):
    word=check_word
    candidate_list=[]
    for num in range(len(words_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            candidate1=[]
            candidate2=[]
            candidate3=[]
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][:s])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)
#1,15が二回,18,19,20

# %%
text_list=list(df["result(10,0,10)"])
text_list=word_check_list_before(text_list,"所在地")
text_list=word_check_list_before(text_list,"電話番号")
text_list=word_check_list_before(text_list,"保険医療")
text_list=word_check_list_before(text_list,"医療機")
text_list=word_check_list_before(text_list,"〒")
text_list=word_check_list_before(text_list,"東京都")
text_list=word_check_list_before(text_list,"町")
text_list=word_check_list_before(text_list,"区")
text_list=word_check_list(text_list,"険者番号")
text_list=word_check_list2(text_list,"被保険")
# # text_list=word_check_list_before(text_list,"所在地")
# text_list=word_check_list_before(text_list,"電話番号")

info_list=[]
sum_=0
for i in text_list:
    print(sum_)
    #print(i)
    word_list=["-".join(s) for s in i]#.replace("・","-").replace(".","-")
    word_list2=("-".join(word_list))
    print(word_list2)
    word_list3=word_list2.replace("・","-").replace(".","-").replace("•","-")
    word_list4=word_list3.split("-")
    word_list5=[]
    for word in word_list4:
        if word.count(' ')==1:
            word_list5.append(word.split(" ")[0])
            word_list5.append(word.split(" ")[1])
        else:
            word_list5.append(word)
    print(word_list5)
    sum_+=1
#     for word in word_list5:
        
#         print(re.sub('[^0-9]','',word))
    word_list6=[re.sub('[^0-9]','',word) for word in word_list5]
    #print("-".join(word_list6))
    print(re.sub('-+', '-', "-".join(word_list6).strip("-")))
    info_list.append(re.sub('-+', '-', "-".join(word_list6).strip("-")))
    #print([re.sub('[^0-9]','', ("-".join(s)).replace("・","").replace(".",""))for s in i])
    #print("-".join([re.sub('[^0-9]','', ("-".join(s)))for s in i]))
    #print("".join(["-".join(s) for s in i]))
#     print(re.sub('[^0-9]','', ("".join(["-".join(s) for s in i]))))
    #print("".join(i))
    #print( re.sub('[0-9]','', i))
    print("----------------")
# Out:
# 0
# 被保険者証・被保険-1080912 347-・-者手帳の記号・番号
# ['被保険者証', '被保険', '1080912', '347', '', '', '者手帳の記号', '番号']
# 1080912-347
# ----------------
# 1
# Date-IKE-tre-A
# ['Date', 'IKE', 'tre', 'A']
#
# ----------------
# 2
# 被保険者証・被保険|1910-者手帳の記号・番号|1336373
# ['被保険者証', '被保険|1910', '者手帳の記号', '番号|1336373']
# 1910-1336373
# ----------------
# 3
# 被保険者証・被保険-者手帳の記号・番号-12.5900516
# ['被保険者証', '被保険', '者手帳の記号', '番号', '12', '5900516']
# 12-5900516
# ----------------
# 4
# 被保険者証・被保険-50000013-109420-者手帳の記号・番号
# ['被保険者証', '被保険', '50000013', '109420', '者手帳の記号', '番号']
# 50000013-109420
# ----------------
# 5
# 被保険者証・被保険-9 2 4 2 0 7 09.97 5-者手帳の記号・番号
# ['被保険者証', '被保険', '9 2 4 2 0 7 09', '97', '5', '者手帳の記号', '番号']
# 92420709-97-5
# ----------------
# 6
# 18.-被保険者証・被保険-者手帳の記号・番号
# ['18', '', '被保険者証', '被保険', '者手帳の記号', '番号']
# 18
# ----------------
# 7
# 被保険者証・被保険-3230・6408-者手帳の記号・番号
# ['被保険者証', '被保険', '3230', '6408', '者手帳の記号', '番号']
# 3230-6408
# ----------------
# 8
# 概険者証・被保険 4851-手帳の記号・番号|267
# ...

# %%
"---------".replace("--","-")
re.sub('-+', '-', "---------")
# Out:
# '-'

# %%
info_list
# Out:
# ['1080912-347',
#  '',
#  '1910-1336373',
#  '12-5900516',
#  '50000013-109420',
#  '92420709-97-5',
#  '18',
#  '3230-6408',
#  '4851-267',
#  '7410435-12',
#  '13580774',
#  '26-38-5209',
#  '927-16-0375',
#  '1324-508',
#  '30-6137087-36536',
#  '39272125-10403475',
#  '59160232-7',
#  '42362412-18',
#  '03-335-2943-9',
#  '100-99744',
#  '01964204',
#  '1322316-5',
#  '3226851',
#  '10428159',
#  '11843562',
#  '532-6175',
#  '572802041-1750',
#  '21350726-212',
#  '04354858',
#  '01-48-5039']

# %%
a = 'lkdfhisoe78347834 (())&/&745  '
result = re.sub('[^0-9]','', a)
result
# Out:
# '78347834745'

# %%
#答え合わせ
f = open('result.txt',encoding="shift-jis")
lines2 = f.readlines() # 1行毎にファイル終端まで全て読む(改行文字も含まれる)
f.close()

# %%
for i in range(len(lines2)):
    print(i)
    if lines2[i].replace("\n","")==info_list[i]:
        print("あってる")
    else:
        print("間違ってる")
        print("正解:"+str(lines2[i].replace("\n","")))
        print("予想:"+str(info_list[i]))
    print("--------------")
# Out:
# 0
# あってる
# --------------
# 1
# あってる
# --------------
# 2
# あってる
# --------------
# 3
# あってる
# --------------
# 4
# あってる
# --------------
# 5
# 間違ってる
# 正解:92420709-975
# 予想:92420709-97-5
# --------------
# 6
# 間違ってる
# 正解:
# 予想:18
# --------------
# 7
# あってる
# --------------
# 8
# あってる
# --------------
# 9
# 間違ってる
# 正解:7410435-2
# 予想:7410435-12
# --------------
# 10
# あってる
# --------------
# 11
# あってる
# --------------
# 12
# 間違ってる
# 正解:27-16-0375
# 予想:927-16-0375
# --------------
# 13
# あってる
# --------------
# 14
# 間違ってる
# 正解:36-536
# 予想:36536
# --------------
# 15
# あってる
# --------------
# 16
# あってる
# --------------
# 17
# あってる
# --------------
# 18
# あってる
# --------------
# 19
# あってる
# --------------
# 20
# あってる
# --------------
# 21
# あってる
# --------------
# 22
# あってる
# --------------
# 23
# あってる
# --------------
# 24
# あってる
# --------------
# 25
# あってる
# --------------
# 26
# 間違ってる
# 正解:57280204-1750
# 予想:572802041-1750
# --------------
# 27
# あってる
# --------------
# 28
# あってる
# ...

# %%
# Azureパターン
recognize_azure(url)
# Out:
# ['の保険薬局でも有効です。)', '保険者', '被保険者証・被保険', '者手帳の記号・番号']

# %%
info_list=[]
for i in tqdm(num_list):
    try:
        dic={"file_name":"","result(10,0,10)":""}
        url="/Users/obara/Downloads/prescription_data_jpeg_3/photo-"+str(i)+".jpeg"
        dic["file_name"]="photo-"+str(i)+".jpeg"
        dic["result(10,0,10)"]=recognize_azure(url)
        info_list.append(dic)
        print(dic)
    except:
        print("photo-"+str(i)+".jpeg")
        print("ミスーーーーーーーーーーーーーーーーーーーー")
        pass

#csvに保存
df=pd.DataFrame(info_list)
df.to_csv("ocr_result_azure.csv",encoding="utf_8_sig")

#pickleファイルに保存
with open('ocr_result_azure.pickle', 'wb') as web:
    pickle.dump(df , web)
# Out:
#   3%|▎         | 1/30 [00:02<01:11,  2.46s/it]
# {'file_name': 'photo-2.jpeg', 'result(10,0,10)': ['り保険薬局でも有効です。)', '保険者番号01130012', '被保険者証・被保険', '1080912・347', '者手帳の記号・番号', '保険医療機東京都千代田区飯田橋4ー6ー9STビル2階', '関の所在地', '及び名称医療法人社団高典会飯田橋クリニック', '電話番号03ー3222ー6461', '保険医氏名高橋典大', 'ジェネリック医薬品)への変更に差し支えがあると判断した場合', '都道府県', '番号', '処方箋の', '使用期間', '点数表', '番号', '医療機関', '0129148', 'コード', '年月', '特に記載のある場合を除き、', '日交付の日を含めて4日以内に', '保険薬局に提出すること。', '」を記載し、「保険医署名」欄に署名又は記名・押印すること。']}
#   7%|▋         | 2/30 [00:03<01:00,  2.14s/it]
# {'file_name': 'photo-35.jpeg', 'result(10,0,10)': []}
#  10%|█         | 3/30 [00:05<00:57,  2.12s/it]
# ...

# %%
text_list=df["result(10,0,10)"]

# %%
text_list[0]
# Out:
# ['り保険薬局でも有効です。)',
#  '保険者番号01130012',
#  '被保険者証・被保険',
#  '1080912・347',
#  '者手帳の記号・番号',
#  '保険医療機東京都千代田区飯田橋4ー6ー9STビル2階',
#  '関の所在地',
#  '及び名称医療法人社団高典会飯田橋クリニック',
#  '電話番号03ー3222ー6461',
#  '保険医氏名高橋典大',
#  'ジェネリック医薬品)への変更に差し支えがあると判断した場合',
#  '都道府県',
#  '番号',
#  '処方箋の',
#  '使用期間',
#  '点数表',
#  '番号',
#  '医療機関',
#  '0129148',
#  'コード',
#  '年月',
#  '特に記載のある場合を除き、',
#  '日交付の日を含めて4日以内に',
#  '保険薬局に提出すること。',
#  '」を記載し、「保険医署名」欄に署名又は記名・押印すること。']

# %%
text_list=word_check_list_before(text_list,"所在地")
text_list=word_check_list_before(text_list,"電話番号")
text_list=word_check_list_before(text_list,"保険医療")
text_list=word_check_list_before(text_list,"医療機")
text_list=word_check_list_before(text_list,"〒")
text_list=word_check_list_before(text_list,"東京都")
text_list=word_check_list_before(text_list,"町")
text_list=word_check_list_before(text_list,"区")
text_list=word_check_list(text_list,"険者番号")
text_list=word_check_list2(text_list,"被保険")

# %%
text_list[9]
# Out:
# ['処方箋2019年09月27日12:07発行',
#  'どの保険薬局でも有効です。)',
#  '保険者番号0123のの10',
#  '・呆険7410435',
#  '.)記号・・番号2',
#  '保険医鴃物実下ロ西89番地の1',
#  '及び名称上林記念病院',
#  '電話番号0586ー61ー0110',
#  '保険医氏名原大',
#  '都道府県',
#  '点数表',
#  '医療機関',
#  '番号1',
#  'ド220',
#  '者番号',
#  '0"新令、0、年0000粤,,',
#  '着(ジェネリック医薬品)の変更に差し支えがあると判断した場合',
#  'ま「x」を記載し、「保険医署名」欄に署名又は記名・押印すること',
#  '症20mg',
#  '1T',
#  '1><夕食後',
#  '45日分',
#  '-(以下余白)ー']

# %%
info_list=[]
text_num=0
for text in text_list:
    result_list=text
    result_list=azure_before(result_list,"所在地")
    result_list=azure_before(result_list,"電話番号")
    result_list=azure_before(result_list,"保険医療")
    result_list=azure_before(result_list,"医療機")
    result_list=azure_before(result_list,"〒")
    result_list=azure_before(result_list,"東京都")
    result_list=azure_before(result_list,"町")
    result_list=azure_before(result_list,"区")
    result_list=azure_before(result_list,"及び")
    result_list=azure_before(result_list,"番地")
    result_list=azure_after1(result_list,"有効です")
    result_list=azure_after2(result_list,"被保険")
    result_list=azure_after1(result_list,"険者番号")
    


    
    text_num+=1
    info_list.append(result_list)
    print(text_num)
    print(result_list)
    print("-----------------")
# Out:
# 1
# ['被保険者証・被保険', '1080912・347', '者手帳の記号・番号']
# -----------------
# 2
# []
# -----------------
# 3
# ['保険者証・被保険1910', '手帳の記号・番号1336373']
# -----------------
# 4
# ['被保険者証・被保険', '12・5900516', '者手帳の記号・番号']
# -----------------
# 5
# ['被保険者証・被保険', '50000013・109420', '者手帳の記号・番号']
# -----------------
# 6
# ['被保険者証・被保険', '92420709・975', '者手帳の記号・番号']
# -----------------
# 7
# ['被保険者証・被保険', '者手帳の記号・番号']
# -----------------
# 8
# ['被保険者証・被保険', '者手帳の記号・番号', 'Page.1', '06139117', '3230・6408', '男・〇']
# -----------------
# 9
# ['623靏題', '・番号267']
# -----------------
# 10
# ['・呆険7410435', '.)記号・・番号2']
# -----------------
# 11
# ['被保険者証・被保険13580774', '③提出を希望されない方一', '者手帳の記号・番号']
# -----------------
# 12
# ['被保険者証・被保険26ー38', '5209', '者手帳の記号・番号']
# -----------------
# 13
# ['138・2.71', '尉縮証・', '者′)記号・番27ー16', '・0375']
# -----------------
# 14
# ['こ険者証・被保険', '1324・508', '!帳の記号・番号']
# -----------------
# 15
# ['被イ者証・被', '36・536', '者手帳の記号・番ロ']
# -----------------
# 16
# ...

# %%
info_list
# Out:
# [['被保険者証・被保険', '1080912・347', '者手帳の記号・番号'],
#  [],
#  ['保険者証・被保険1910', '手帳の記号・番号1336373'],
#  ['被保険者証・被保険', '12・5900516', '者手帳の記号・番号'],
#  ['被保険者証・被保険', '50000013・109420', '者手帳の記号・番号'],
#  ['被保険者証・被保険', '92420709・975', '者手帳の記号・番号'],
#  ['被保険者証・被保険', '者手帳の記号・番号'],
#  ['被保険者証・被保険', '者手帳の記号・番号', 'Page.1', '06139117', '3230・6408', '男・〇'],
#  ['623靏題', '・番号267'],
#  ['・呆険7410435', '.)記号・・番号2'],
#  ['被保険者証・被保険13580774', '③提出を希望されない方一', '者手帳の記号・番号'],
#  ['被保険者証・被保険26ー38', '5209', '者手帳の記号・番号'],
#  ['138・2.71', '尉縮証・', '者′)記号・番27ー16', '・0375'],
#  ['こ険者証・被保険', '1324・508', '!帳の記号・番号'],
#  ['被イ者証・被', '36・536', '者手帳の記号・番ロ'],
#  ['被保険者証・被保険10403475', '者手帳の記号・番号'],
#  ['被保険者証・被保険59160232・7', '者手帳の記号・番号'],
#  ['被保険者証・被保険', '者手帳の記号・番号', 'Page.1', '01130012', '42362412・18'],
#  ['被保険者証・被保険者', '手帳の記号・番号', '分割指示に係る一分割の一回目', '1003', '335ー2943ー9', '03'],
#  ['被保険者証・被保険', '者手帳の記号・番号', '100'],
#  ['・01964204', 'f手張の記号・番'],
#  ['被保険者証・被保険', '1322316・5', '者手帳の記号・番号'],
#  ['・番号3226851'],
# ...

# %%
results_list2=[]
for i in info_list:
    result_list2=[]
    for result in i:
        if len(re.sub('[^0-9]','',result))==0:
            pass
        else:
            result_list2.append(result)
    results_list2.append(result_list2)
        #print(re.sub('[^0-9-・.ー]','',result))

# %%
results_list2
# Out:
# [['1080912・347'],
#  [],
#  ['保険者証・被保険1910', '手帳の記号・番号1336373'],
#  ['12・5900516'],
#  ['50000013・109420'],
#  ['92420709・975'],
#  [],
#  ['Page.1', '06139117', '3230・6408'],
#  ['623靏題', '・番号267'],
#  ['・呆険7410435', '.)記号・・番号2'],
#  ['被保険者証・被保険13580774'],
#  ['被保険者証・被保険26ー38', '5209'],
#  ['138・2.71', '者′)記号・番27ー16', '・0375'],
#  ['1324・508'],
#  ['36・536'],
#  ['被保険者証・被保険10403475'],
#  ['被保険者証・被保険59160232・7'],
#  ['Page.1', '01130012', '42362412・18'],
#  ['1003', '335ー2943ー9', '03'],
#  ['100'],
#  ['・01964204'],
#  ['1322316・5'],
#  ['・番号3226851'],
#  ['被保険者証・被保険10428159'],
#  ['被保険者証・被保険11843562'],
#  ['532・6175'],
#  ['保険者証・被保険57280204・', '者手帳の記号・番号1750'],
#  ['21350726・212'],
#  ['号39131156', '04354858'],
#  ['01ー48・5039', '1三38き0:16', '7']]

# %%
result_list2
# Out:
# ['01ー48・5039', '1三38き0:16', '7']

# %%
result="1,,-22・ー2"
re.sub('[^0-9-・.ー]','',result)
# Out:
# '1-22・ー2'

# %%
num=0
for i in text_list[0]:
    if "被保険者" in i:
        print(num)
        break
    num=num+1

# %% [markdown]
# # 関数置き場

# %%
# 基本は最頻値をとる。最頻値がない時は平均をとる。numsが空の時は0にする。
def mode_average(nums):
    try:
        return mode(nums)
    except:
        if len(nums)!=0:
            return round(sum(nums) / len(nums))
        else:
            try:
                return nums[0]
            except:
                return 0  #これは危ないかも

# %%
#一部のみしか選択しないタイプ 画像を表示しない場合
def recognize5(url,n_part,start,goal):
    start_time = time.time()
    #pathからbase64にする場合
    def pil_image_to_base64(img_path):###ここは最後に消す
        pil_image = Image.open(img_path)
        buffered = BytesIO()
        pil_image.save(buffered, format="PNG")
        str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
        return str_encode_file

    #arrayからbase64にする場合
    def array_to_base64(img_array):
        pil_image = Image.fromarray(np.uint8(img_array))
        buffered = BytesIO()
        pil_image.save(buffered, format="PNG")
        str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
        return str_encode_file 

    def get_fullTextAnnotation(json_data):
        text_dict = json.loads(json_data)
        try:
            text = text_dict["responses"][0]["fullTextAnnotation"]["text"]
            return text
        except:
            print(None)
            return None

    #str_encode_file = pil_image_to_base64(url)  
    
    img = cv2.imread(url)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,0::]
#     plt.figure(figsize=[50,50])
#     plt.imshow(input_image)
    
    str_encode_file = array_to_base64(input_image)# input_imageがarrayの時
    str_url = "https://vision.googleapis.com/v1/images:annotate?key="
    str_api_key = "AIzaSyDlRRYrHEdjParsfRmh96_3xfafOo1crWY"
    str_headers = {'Content-Type': 'application/json'}
    str_json_data = {
        'requests': [
            {
                'image': {
                    'content': str_encode_file
                },
                'features': [
                    {
                        'type': "DOCUMENT_TEXT_DETECTION",
                        'maxResults': 1
                    }
                ],"imageContext": {
        "languageHints": ["ja"]
      },
            }
        ]
    }

    obj_session = Session()
    obj_request = Request("POST",
                            str_url + str_api_key,
                            data=json.dumps(str_json_data),
                            headers=str_headers
                            )
    obj_prepped = obj_session.prepare_request(obj_request)
    obj_response = obj_session.send(obj_prepped,
                                    verify=True,
                                    timeout=60
                                    )
    #もとの出力
    if obj_response.status_code == 200:
        text = get_fullTextAnnotation(obj_response.text)
        
    elapsed_time = time.time() - start_time
    print ("API終了までにかかった時間:{0}".format(elapsed_time) + "[sec]")
    #行ごとの出力    
    text_dict = json.loads(obj_response.text)
    word_list=text_dict["responses"][0]["textAnnotations"][0]["description"].split("\n")

    len_sum=0
    now_num=0
    left=[]
    right=[]
    top=[]
    bottom=[]
    dic_list=[]

    for i in range(1,len(text_dict["responses"][0]["textAnnotations"])):
        len_sum+=len(text_dict["responses"][0]["textAnnotations"][i]["description"].replace(" ",""))
        try:
            left.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["x"])
        except:
            pass
        try:
            right.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][1]["x"])
        except:
            pass
        try:
            right.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][2]["x"])
        except:
            pass
        try:
            left.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][3]["x"])
        except:
            pass

        try:
            bottom.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["y"])
        except:
            pass
        try:
            bottom.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][1]["y"])
        except:
            pass
        try:
            top.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][2]["y"])
        except:
            pass
        try:
            top.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][3]["y"])
        except:
            pass

        if len_sum==len(word_list[now_num].replace(" ","")):
            len_sum=0
            #print("word:   "+word_list[now_num])
            dic={"word":word_list[now_num],"文字の縦幅":mode_average(top)-mode_average(bottom),"x":round(mode_average(left)+mode_average(right)),"y":round(mode_average(top)+mode_average(bottom))}
            dic_list.append(dic)
            now_num+=1
            left=[]
            right=[]
            top=[]
            bottom=[]
    elapsed_time = time.time() - start_time
    print ("for文を回し終わるまでにかかった時間:{0}".format(elapsed_time) + "[sec]")
    df = pd.DataFrame(dic_list)
    df=df.sort_values('y')
    df.reset_index()
    tate_mean=df["文字の縦幅"].mean()

    diff_list=df["y"].diff()
    a_=0
    y_list=[]
    for a,b in zip(df["y"],diff_list):
        #print(a,b)
        if b<tate_mean:
            a=a_
        a_=a
        y_list.append(a)

    df["diff"]=diff_list
    df.loc[0,"diff"]=0
    df["y"]=y_list
    df=df.sort_values(["y","x"])
    grouped_df = df.groupby('y')
    grouped_list = [list(grouped_df["word"].get_group(word)) for word in grouped_df.groups]
    elapsed_time = time.time() - start_time
    print ("elapsed_time:{0}".format(elapsed_time) + "[sec]")
    return grouped_list

# %%
# azureのAPI   inputはURL

def recognize_azure(url):
    subscription_key="92fb4480fac54c5b87f52508f863fb8d"
    endpoint="https://test-ocr-prescription.cognitiveservices.azure.com/"

    analyze_url = endpoint + "vision/v3.0/ocr"
    image_path = url
    # Read the image into a byte array
    image_data = open(image_path, "rb").read()
    headers = {'Ocp-Apim-Subscription-Key': subscription_key,
               'Content-Type': 'application/octet-stream'}
    params = {'visualFeatures': 'Categories,Description,Color'}
    response = requests.post(
        analyze_url, headers=headers, params=params, data=image_data)
    response.raise_for_status()

    # The 'analysis' object contains various fields that describe the image. The most
    # relevant caption for the image is obtained from the 'description' property.
    analysis = response.json()
    words_list=[]
    for i in analysis["regions"]:
        for t in i["lines"]:
            word_list=[]
            for s in t["words"]:
                word_list.append(s["text"])
            text="".join(word_list)
            words_list.append(text)


            
            
    return words_list

# %%
# azureのAPI   #inputはarray

def recognize_azure2(image_array):
    subscription_key="92fb4480fac54c5b87f52508f863fb8d"
    endpoint="https://test-ocr-prescription.cognitiveservices.azure.com/"

    analyze_url = endpoint + "vision/v3.0/ocr"
#     image_path = url
#     # Read the image into a byte array
#     image_data = open(image_path, "rb").read()

    #arrayからbase64にする場合
    def array_to_base64(img_array):
        pil_image = Image.fromarray(np.uint8(img_array))
        buffered = BytesIO()
        pil_image.save(buffered, format="PNG")
        str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
        return str_encode_file 
    
    image_data=array_to_base64(image_array)
    headers = {'Ocp-Apim-Subscription-Key': subscription_key,
               'Content-Type': 'application/octet-stream'}
    params = {'visualFeatures': 'Categories,Description,Color'}
    response = requests.post(
        analyze_url, headers=headers, params=params, data=image_data)
    response.raise_for_status()

    # The 'analysis' object contains various fields that describe the image. The most
    # relevant caption for the image is obtained from the 'description' property.
    analysis = response.json()
    words_list=[]
    for i in analysis["regions"]:
        for t in i["lines"]:
            word_list=[]
            for s in t["words"]:
                word_list.append(s["text"])
            text="".join(word_list)
            words_list.append(text)


            
            
    return words_list

# %%
plt.imshow(waku("/Users/obara/Downloads/prescription_data_jpeg_3/photo-1137.jpeg")[1])
waku("/Users/obara/Downloads/prescription_data_jpeg_3/photo-1137.jpeg")[1]
#print(recognize_azure(waku("/Users/obara/Downloads/prescription_data_jpeg_3/photo-1137.jpeg")[1]))
#print(recognize_azure(waku("/Users/obara/Downloads/kigou.png")[1]))
print(recognize_azure("/Users/obara/Downloads/kigou.png"))
# Out:
# ['—48•', '5039']

# %%
"/Users/obara/Downloads/prescription_data_jpeg_3/photo-1137.jpeg"
# Out:
# '/Users/obara/Downloads/prescription_data_jpeg_3/photo-1137.jpeg'

# %%
subscription_key="92fb4480fac54c5b87f52508f863fb8d"
endpoint="https://test-ocr-prescription.cognitiveservices.azure.com/"

analyze_url = endpoint + "vision/v3.0/ocr"
image_path = url
# Read the image into a byte array
image_data = open(image_path, "rb").read()
headers = {'Ocp-Apim-Subscription-Key': subscription_key,
           'Content-Type': 'application/octet-stream'}
params = {'visualFeatures': 'Categories,Description,Color'}
response = requests.post(
    analyze_url, headers=headers, params=params, data=image_data)
response.raise_for_status()

# The 'analysis' object contains various fields that describe the image. The most
# relevant caption for the image is obtained from the 'description' property.
analysis = response.json()
words_list=[]
for i in analysis["regions"][0]["lines"]:
    word_list=[]
    for t in i["words"]:
        word_list.append(t["text"])
    text="".join(word_list)
    words_list.append(text)
# Out:
#   File "<ipython-input-16-f84758ba02bb>", line 28
#     return words_list
#                      ^
# SyntaxError: 'return' outside function

# %%
analysis
# Out:
# {'language': 'ja',
#  'textAngle': 0.0,
#  'orientation': 'Up',
#  'regions': [{'boundingBox': '3,593,396,308',
#    'lines': [{'boundingBox': '3,593,396,34',
#      'words': [{'boundingBox': '3,599,29,24', 'text': 'の'},
#       {'boundingBox': '33,595,32,32', 'text': '保'},
#       {'boundingBox': '67,593,32,33', 'text': '険'},
#       {'boundingBox': '98,593,33,33', 'text': '薬'},
#       {'boundingBox': '132,595,30,31', 'text': '局'},
#       {'boundingBox': '165,596,30,28', 'text': 'で'},
#       {'boundingBox': '200,594,24,31', 'text': 'も'},
#       {'boundingBox': '229,593,32,32', 'text': '有'},
#       {'boundingBox': '261,593,32,33', 'text': '効'},
#       {'boundingBox': '295,596,30,28', 'text': 'で'},
#       {'boundingBox': '325,593,32,32', 'text': 'す'},
#       {'boundingBox': '356,616,11,10', 'text': '。'},
#       {'boundingBox': '390,593,9,33', 'text': ')'}]},
#     {'boundingBox': '199,747,197,38',
#      'words': [{'boundingBox': '199,748,38,37', 'text': '保'},
# ...

# %%
for i in analysis["regions"]:
    for t in i["lines"]:
        word_list=[]
        for s in t["words"]:
            word_list.append(s["text"])
        text="".join(word_list)
        words_list.append(text)

# %%
words_list
# Out:
# ['の保険薬局でも有効です。)',
#  '保険者',
#  '被保険者証・被保険',
#  '者手帳の記号・番号',
#  'の保険薬局でも有効です。)',
#  '保険者',
#  '被保険者証・被保険',
#  '者手帳の記号・番号',
#  '方',
#  '」を記載し、「保険医署名」欄に署名又は記名・押印すること。',
#  '箋',
#  '亡月',
#  '後',
#  '発',
#  '番',
#  '号',
#  '01ー48・5039',
#  '1三38き0:16',
#  '7',
#  '保険医療機東京都千代田区飯田橋4ー4ー',
#  '関の所在地',
#  '及び名称医療法人社団慈仁会飯田橋小池クリーック',
#  '女',
#  '電話番号03ー3221ー8858',
#  '保険医氏名小池美由紀',
#  '都道府県',
#  '点数表',
#  '1',
#  '3',
#  '番号',
#  '番号',
#  '処方箋の',
#  '使用期間',
#  'ノエいック',
#  'ロロへの/、一こ',
#  '医療機関',
#  '1',
#  '0',
#  'コード',
#  '年月',
#  'しんがる',
#  '1',
#  '34551',
#  '特に記載のある場合を除き、',
#  '交付の日を含めて4日以内に',
#  '保険薬局に提出すること。']

# %%
analysis["regions"][1]
# Out:
# {'boundingBox': '5,491,994,1046',
#  'lines': [{'boundingBox': '37,491,61,64',
#    'words': [{'boundingBox': '37,491,61,64', 'text': '方'}]},
#   {'boundingBox': '5,1501,994,36',
#    'words': [{'boundingBox': '5,1507,9,27', 'text': '」'},
#     {'boundingBox': '42,1502,27,30', 'text': 'を'},
#     {'boundingBox': '73,1502,33,31', 'text': '記'},
#     {'boundingBox': '108,1501,33,33', 'text': '載'},
#     {'boundingBox': '150,1504,24,28', 'text': 'し'},
#     {'boundingBox': '179,1525,9,11', 'text': '、'},
#     {'boundingBox': '234,1501,9,27', 'text': '「'},
#     {'boundingBox': '246,1503,33,32', 'text': '保'},
#     {'boundingBox': '283,1502,31,33', 'text': '険'},
#     {'boundingBox': '318,1504,30,31', 'text': '医'},
#     {'boundingBox': '352,1503,31,33', 'text': '署'},
#     {'boundingBox': '386,1504,28,33', 'text': '名'},
#     {'boundingBox': '422,1510,10,26', 'text': '」'},
#     {'boundingBox': '455,1503,33,33', 'text': '欄'},
#     {'boundingBox': '494,1505,28,29', 'text': 'に'},
# ...

# %%
def azure_before(result_list,word):
    num=0
    num1=0
    for i in result_list:
        if word in i:
            #print(num)
            num1=1
            break
        num=num+1
    if num1==1:
        result_list=result_list[:num]
    else:
        pass
    return result_list

# %%
def azure_after1(result_list,word):#含まない
    num=0
    num1=0
    for i in result_list:
        if word in i:
            num1=1
            #print(num)
            break
        num=num+1
    if num1==1:
        result_list=result_list[num+1:]
    else:
        pass
    return result_list

# %%
def azure_after2(result_list,word):#含む
    num=0
    num1=0
    for i in result_list:
        if word in i:
            num1=1
            #print(num)
            break
        num=num+1
    if num1==1:
        result_list=result_list[num:]
    else:
        pass
    return result_list

# %%
result_list=text_list[19]
print(result_list)
result_list=azure_before(result_list,"所在地")
# Out:
# ['・は、どの保険薬局でも有効です。)', '061', '保険者番号', '亡月', '後発希', '3946', '99744', '3', '被保険者証・被保険', '者手帳の記号・番号', '100', '保健医療機関の東京都千代田区飯田橋4ー5ー16コアビル3F', '所在地及び名称', '飯田橋歯科クリニック', '電話番号03ー3288ー5253', '保険医氏名竹内均']

# %%
result_list
# Out:
# ['・は、どの保険薬局でも有効です。)',
#  '061',
#  '保険者番号',
#  '亡月',
#  '後発希',
#  '3946',
#  '99744',
#  '3',
#  '被保険者証・被保険',
#  '者手帳の記号・番号',
#  '100',
#  '保健医療機関の東京都千代田区飯田橋4ー5ー16コアビル3F']

# %%
plt.imshow(waku("/Users/obara/Downloads/prescription_data_jpeg_3/photo-1137.jpeg")[1])

print(recognize_azure(waku("/Users/obara/Downloads/prescription_data_jpeg_3/photo-1137.jpeg")[1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-4471ae8c0e32> in <module>
#       1 plt.imshow(waku("/Users/obara/Downloads/prescription_data_jpeg_3/photo-1137.jpeg")[1])
#       2
# ----> 3 print(recognize_azure(waku("/Users/obara/Downloads/prescription_data_jpeg_3/photo-1137.jpeg")[1]))
#       4
#
# <ipython-input-25-1affc4dc1ee7> in recognize_azure(url)
#       8     image_path = url
#       9     # Read the image into a byte array
# ---> 10     image_data = open(image_path, "rb").read()
#      11     headers = {'Ocp-Apim-Subscription-Key': subscription_key,
#      12                'Content-Type': 'application/octet-stream'}
#
# TypeError: expected str, bytes or os.PathLike object, not numpy.ndarray

# %%
#切り出す作業。返り値は、保険者番号、記号、基本情報の部分、左下（PHCでは不要）、右下（PHCでは不要）、下全部
def waku(image):
    #arrayになっているものをもどす
    #img = Image.fromarray(np.uint8(image))
    #画像を読み込む（arrayに）
    image = cv2.imread(image)
    
    #画像をグレースケール化 入れるのはarray
    img_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

    #閾値を180にして2値化
    # threshold = 10
    # ret, img_thresh = cv2.threshold(img_gray, threshold, 255, cv2.THRESH_BINARY)

    #2値化後を表示
#     plt.imshow( img_gray)
#     plt.gray()

    height=img_gray.shape[0]
    width=img_gray.shape[1]
    #切り出し
    img2=image
    #img2=image[0:612*height//2340,width//2:width]              
                     
    # BGR -> グレースケール
    gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
    
    # エッジ抽出 (Canny)
    edges = cv2.Canny(gray, 50, 190, apertureSize=3)
    #cv2.imwrite('wakuedges.png', edges)
    # 膨張処理
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    edges = cv2.dilate(edges, kernel)


    # 輪郭抽出
    _, contours, hierarchy = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    # 面積でフィルタリング
    rects = []
    mensekilist=[]
    for cnt, hrchy in zip(contours, hierarchy[0]):
        if cv2.contourArea(cnt) < 30:
            continue  # 面積が小さいものは除く
        if hrchy[3] == -1:
            continue  # ルートノードは除く
        # 輪郭を囲む長方形を計算する。
        rect = cv2.minAreaRect(cnt)
        rect_points = cv2.boxPoints(rect).astype(int)
        rects.append(rect_points)
        mensekilist.append(cv2.contourArea(cnt) )

    indexnum=mensekilist.index(max(mensekilist))

    # x-y 順でソート
    #rects = sorted(rects, key=lambda x: (x[0][1], x[0][0]))

    # 描画する。
    for i, rect in enumerate(rects):
        color = np.random.randint(0, 255, 3).tolist()
        #cv2.drawContours(img, rects, i, color, 2)
        #cv2.putText(img, str(i), tuple(rect[0]), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 3)

        #print('rect:\n', rect)

    i=indexnum
    x=[rects[i][0][0],rects[i][1][0],rects[i][2][0],rects[i][3][0]]
    x1=sorted(x)
    y=[rects[i][0][1],rects[i][1][1],rects[i][2][1],rects[i][3][1]]
    y1=sorted(y)
    smallx=round((x1[1] +x1[0])//2)
    largex=round((x1[-1]+x1[-2])//2)
    smally=round((y1[0]+y1[1])//2)
    largey=round((y1[-1]+y1[-2])//2)
    sitanum=img2[smally:largey,smallx:largex]
    #cv2.imwrite('sitanum2/'+str(num)+'.png', sitanum)

    #以下PHCverのパラメータ       
    img_list=[]
    for i in range(8):
        n=i
        height1=largey-smally
        width1=int(round((largex-smallx)/8))
        difference=int(round((height1-width1)/3))
        difference2=width1//7

        if n<4:
            img3=img2[smally-height1+3*difference:largey-height1-difference,(smallx+width1*n)+0*difference2:smallx+width1*(n+1)-2*difference2]

        else:
            img3=img2[smally-height1+3*difference:largey-height1-difference,(largex-width1*(8-n))+0*difference2:largex-width1*(7-n)-2*difference2]
        img_list.append(img3)

    im_h = cv2.hconcat(img_list)

    #以下矢澤先生verのパラメータ
    img_list2=[]
    for i in range(8):
        n=i
        height1=largey-smally
        width1=int(round((largex-smallx)/8))
        difference=int(round((height1-width1)/3))
        difference2=width1//7

        if n<4:
            img3=img2[smally-height1+1*difference:largey-height1-difference,(smallx+width1*n)+1*difference2:smallx+width1*(n+1)-0*difference2]

        else:
            img3=img2[smally-height1+1*difference:largey-height1-difference,(largex-width1*(8-n))+1*difference2:largex-width1*(7-n)-0*difference2]
        img_list2.append(img3)

    im_h2 = cv2.hconcat(img_list2)


    #記号番号の上のところを取得する
    img4 = img2[smally - height1 + 3 * difference : largey - height1 - difference, smallx:largex]
    
    #矢澤先生の処方箋の時
    # top = image[0: 900 * height // 2340, 0 :width]
    # bottom1 = image[900 * height // 2340 :height, 0 :width//2]
    # bottom2 = image[900 * height // 2340 :height, width // 2 :width]
    # bottom_all=image[900 * height // 2340 :height, 0 :width]

    #PHCの処方箋の時・・・topを少し広めに取り、境界領域の情報を掬えるようにする
    top = image[0: 400 * height // 1030, 0 :width]
    bottom1 = image[300 * height // 1030 :height, 0 :width//2]
    bottom2 = image[300 * height // 1030 :height, width // 2 :width]
    bottom_all = image[300 * height // 1030 :height, 0:width]


    #保険者番号、記号、基本情報の部分、左下（PHCでは不要）、右下（PHCでは不要）、下全部、縦線消去したやつ(img4)、
    return im_h, sitanum,top,bottom1,bottom2,bottom_all,img4,im_h2
