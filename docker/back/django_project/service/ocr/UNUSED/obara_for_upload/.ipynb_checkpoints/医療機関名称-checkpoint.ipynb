# %% [markdown]
# # 準備

# %%
import random
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

#Jupyterでインライン表示するための宣言
# %matplotlib inline 
import os
import shutil
from tqdm import tqdm
import base64
import json
from requests import Request, Session
from io import BytesIO
from PIL import Image
import pandas as pd
import jaconv
import re
import cv2
import numpy as np
from symspellpy.symspellpy import SymSpell, Verbosity
import pickle
from pykakasi import kakasi
import Levenshtein
from collections import OrderedDict
import itertools

from statistics import mode
import time
from janome.tokenizer import Tokenizer

# %% [markdown]
# # 探索

# %% [markdown]
# # 切り取って保存

# %%
#とりあえず試し

num=1
start=0
goal=3
n_part=10
url="/Users/obara/Downloads/prescription_data_jpeg/photo-"+str(num)+".jpeg"
img = cv2.imread(url)
#img = plt.imread(url)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#plt.imshow(img)
input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,img.shape[1]*2//7:img.shape[1]*6//7]
#plt.figure(figsize=[50,50])
#plt.imshow(input_image)
plt.imsave("/Users/obara/Downloads/prescription_data_jpeg_4/photo-"+str(num)+".jpeg",input_image)

# %%
#関数化
def image_check(url,n_part,start,goal):
    img = cv2.imread(url)
    #img = plt.imread(url)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    #plt.imshow(img)
    #input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,0:img.shape[1]//2]
    input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,img.shape[1]*2//7:img.shape[1]]
    #plt.figure(figsize=[50,50])
    #plt.imshow(input_image)
    plt.imsave("/Users/obara/Downloads/prescription_data_jpeg_4/photo-"+str(num)+".jpeg",input_image)
    return

# %%
import pickle
with open('text_dic2.pickle', 'rb') as web:
    df = pickle.load(web)
    
num_list=[int(x[6:][:-5]) for x in list(df.keys())]
num_list.sort()
num_list
#35は除外
# Out:
# [2,
#  35,
#  40,
#  85,
#  93,
#  110,
#  148,
#  301,
#  326,
#  339,
#  366,
#  435,
#  456,
#  504,
#  519,
#  524,
#  548,
#  630,
#  655,
#  721,
#  770,
#  775,
#  786,
#  793,
#  806,
#  879,
#  885,
#  1011,
#  1110,
#  1137]

# %%
#for文

for num in tqdm(num_list):
    url="/Users/obara/Downloads/prescription_data_jpeg/photo-"+str(num)+".jpeg"
    image_check(url,10,0,4)
# Out:
# 100%|██████████| 30/30 [00:14<00:00,  2.06it/s]

# %% [markdown]
# ## OCR結果を保存

# %%
info_list=[]
for i in tqdm(num_list):
    try:
        dic={"file_name":"","result(10,0,10)":""}
        url="/Users/obara/Downloads/prescription_data_jpeg_4/photo-"+str(i)+".jpeg"
        dic["file_name"]="photo-"+str(i)+".jpeg"
        dic["result(10,0,10)"]=recognize5(url,10,0,10)
        info_list.append(dic)
        print(dic)
    except:
        print("photo-"+str(i)+".jpeg")
        print("ミスーーーーーーーーーーーーーーーーーーーー")
        pass

#csvに保存
df=pd.DataFrame(info_list)
df.to_csv("ocr_result_4.csv",encoding="utf_8_sig")

#pickleファイルに保存
with open('ocr_result_4.pickle', 'wb') as web:
    pickle.dump(df , web)
# Out:
#   3%|▎         | 1/30 [00:03<01:44,  3.60s/it]
# API終了までにかかった時間:3.5632479190826416[sec]
# for文を回し終わるまでにかかった時間:3.5728278160095215[sec]
# elapsed_time:3.590301990509033[sec]
# {'file_name': 'photo-2.jpeg', 'result(10,0,10)': [['P. 1'], ['処', '方', '箋', 'O'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号', '01130012'], ['被保険者証・被保険'], ['1 0 8 0 9 1 2 3 4 7'], ['者手帳の記号・番号'], ['っ', '保険医療機', '東京都千代田区飯田橋4-6-9 STビル2階'], ['幸子'], ['及び名称 医療法人社団 高典会 飯田橋クリニック'], ['56才'], ['7ヶ月男の 電話番号 03-3222-6461'], ['9月 22日生', '保険医氏名 高橋 典大'], ['険者', '被扶養者', '都道府県', '1', '3', '番号', '点数表', '1', '医療機関', '0', '1', '1', '1', '2 9 4. 8'], ['処方箋の', '特に記載のある場合を除き、'], ['1年 5月', '13日', '年 月', '日交付の日を含めて4日以内に'], ['使用期間', '保険薬局に提出すること。'], ['処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合、'], ['変更不可」欄に「」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]}
#   7%|▋         | 2/30 [00:07<01:43,  3.70s/it]
# API終了までにかかった時間:3.9103331565856934[sec]
# for文を回し終わるまでにかかった時間:3.9110610485076904[sec]
# elapsed_time:3.919351100921631[sec]
# {'file_name': 'photo-35.jpeg', 'result(10,0,10)': [['Date'], ['.'], ['人0'], ['Os']]}
#  10%|█         | 3/30 [00:11<01:41,  3.77s/it]
# API終了までにかかった時間:3.928049325942993[sec]
# for文を回し終わるまでにかかった時間:3.937465190887451[sec]
# elapsed_time:3.9503071308135986[sec]
# {'file_name': 'photo-40.jpeg', 'result(10,0,10)': [['171'], ['外来処方箋'], ['(この処方箋はどの保険薬局でも有効です)'], ['216016', '保険者番号 0|61|38|150'], ['1633', '被保険者証・被保険|1910'], ['者手帳の記号・番号|1336373'], ['2', '東京都武蔵野市吉祥寺本町1-30-12'], ['保険医療機'], ['関の所在地 医療法人社団 東仁会 吉祥寺あさひ病院'], ['U'], ['雅子', '電話番号 0422-22-1120'], ['診療科', '膠原病内科'], ['性別 女保険医氏名 有村義宏', 'ED'], ['年9月22日(50才)'], ['被扶養者', '番号', '113', '都道府県 点数表 医療機関', '番号 コード', '1', '31317|0|129'], ['特に記載のある場合を除き、'], ['処方箋の', '交付の日を含めて4日以内に'], ['0年5月18日', '使用期間', '保険薬局に提出すること。'], ['日々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】ミゾリビン錠50mg', '3錠'], ['35日分'], ['1日1回朝食前']]}
#  13%|█▎        | 4/30 [00:15<01:38,  3.80s/it]
# API終了までにかかった時間:3.7550361156463623[sec]
# for文を回し終わるまでにかかった時間:3.8354332447052[sec]
# elapsed_time:3.8499040603637695[sec]
# {'file_name': 'photo-85.jpeg', 'result(10,0,10)': [['処', '方', 'P. 1'], ['N', 'ge'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['割'], ['保険者番号 061 386613'], ['被保険者証・被保険'], ['者手帳の記号・番号', '12.5900516'], ['ガワミツヒロ', '保険医療機 東京都千代田区外神田5-2-3'], ['谷川 光洋', '関の所在地', '及び名称"アソルティ末広町ビル1F'], ['大昭平 40才', '末広町ヒライ耳鼻咽喉科'], ['1ヶ月男女 電話番号03-3836-3387'], ['53年11月 9日生', '保険医氏名平井 良治'], ['被保険者、被扶養者', '番号', '都道府県', '1', '3', '番号', '点数表', '1', '医療機関', 'コード', '0', '1', '1 3', '5', 'o', '38'], ['処方箋の', '特に記載のある場合を除き、'], ['平成30年', '12月 26日', '使用期間', '平成 年月 日', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['こは、「変更不可」欄に「」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】カルボシステイン錠'], ['5 0 0 mg', '3 錠'], ['1日3回 朝・昼・夕食後', '14日分']]}
#  17%|█▋        | 5/30 [00:19<01:34,  3.77s/it]
# API終了までにかかった時間:3.6544740200042725[sec]
# for文を回し終わるまでにかかった時間:3.664755344390869[sec]
# elapsed_time:3.678230047225952[sec]
# {'file_name': 'photo-93.jpeg', 'result(10,0,10)': [['O', 'P. 1'], ['処', '方', '箋'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号', '011 1 300112'], ['被保険者証・被保険', '50000013.109420'], ['者手帳の記号・番号'], ['保険医療機 東京都千代田区飯田橋4-4-7'], ["'", '及び名称 医療法人社団慈仁会 飯田橋小池クリニック'], ['43才'], ['4ヶ月男の 電話番号 03-3221-8858'], ['.', '4日生', '保険医氏名 小池 美由紀'], ['者', '被扶養者', '番号', '都道府県', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0', '1', '3', '415 51', '特に記載のある場合を除き、'], ['111', '5月 13日', '使用期間', '処方箋の', '年月日', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['キソプロフェンNa錠'], ['3. 錠'], ['g'], ['30日分'], ['食後服用'], ['バミピド錠 100mg', '3', '錠'], ['30日分'], ['食後服用'], ['帰四逆加呉茱萸生姜湯エキス顆粒']]}
#  20%|██        | 6/30 [00:22<01:28,  3.69s/it]
# API終了までにかかった時間:3.464254140853882[sec]
# for文を回し終わるまでにかかった時間:3.476135015487671[sec]
# elapsed_time:3.4894440174102783[sec]
# {'file_name': 'photo-110.jpeg', 'result(10,0,10)': [['P. 1'], ['処', '方'], ['G'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['11316012', '保険者番号 01 400019'], ['3175 018', '者手帳の記号・番号', '被保険者証・被保険', '92420709.975'], ['ュンコ', '保険医療機 東京都千代田区外神田5-2-3'], ['子', '関の所在地', '及び名称、アソルティ末広町ビル1F'], ['平', '36才', '末広町ヒライ耳鼻咽喉科'], ['3ヶ月男の', '電話番号03-3836-3387'], ['9月', '27日生', '保険医氏平井 良治'], ['被扶養者', '来日', '都道府県', '3', '東日', '1', '点数表 医療機関', '-', 'Q11', '3', '5', '0 13', '8']]}
#  23%|██▎       | 7/30 [00:26<01:25,  3.71s/it]
# API終了までにかかった時間:3.6491799354553223[sec]
# for文を回し終わるまでにかかった時間:3.701417922973633[sec]
# elapsed_time:3.7469940185546875[sec]
# {'file_name': 'photo-148.jpeg', 'result(10,0,10)': [['処', '方'], ['1/1ページ'], ['(この処方箋はどの保険薬局でも有効です)'], ['12|27|1243) 保険者番号'], ['0 0 2 3 7/8', '被保険者証・被保険'], ['者手帳の記号・番号'], ['ウラノチッ', '埜 知津子', '所在地及び名称', '保険医療機関の', 'Fine F', '上西クリニック', '大阪市平野区平野西3-9-21 コーポ常'], ['年', '3月26日 女', '電話番号', '(06)6760-5630'], ['保険医氏名', '上西 正明'], ['番号', '都道府県', '27', '番号', '1', '点数表 医療機関', 'コード', '5807943'], ['30年 12月18日 処方箋 の 平成 年 月 日(特に記載のある場合を除き、'], ['に差し支えある場合「レ」又は「×」を記載 使用期間 交付の日を含め4日以内に保険薬局に提出すること)'], ['セミド錠30mg', '2錠', '1日1回朝食後', '14日分'], ['ロノラクトン錠25'], ['1錠', '1日1回朝食後', '14日分'], ['- 1 mo']]}
#  27%|██▋       | 8/30 [00:30<01:22,  3.73s/it]
# API終了までにかかった時間:3.7502691745758057[sec]
# for文を回し終わるまでにかかった時間:3.7616400718688965[sec]
# elapsed_time:3.7782509326934814[sec]
# {'file_name': 'photo-301.jpeg', 'result(10,0,10)': [['30分後もどる'], ['a'], ['処', '方'], ['(この処方箋はどの保険薬局でも有効です)', 'Page. 1'], ['保険者番号 0 6 1 3 19 1 117'], ['被保険者証・被保険', '3 2 30 · 64 0 8'], ['者手帳の記号・番号'], ['〒101-0021'], ['保険医療機', '東京都千代田区外神田六丁目14番2号'], ['山口', 'グチカナコ', '桂奈子', '関の所在地', '及び名称', 'サカイ末広ビル7階B室', '雪月花メディカルクリニック 秋葉原診療所'], ['電話番号 03-5812-5301'], ['2和50年07月26日', '男', '保険医氏名 大道雅文'], ['被保険者', '被扶養者', '番号', '都道府県', '113', '1', '番号 コード', '点数表 医療機関', '特に記載のある場合', '011/337 110'], ['を除き、交付の日を'], ['平成30年12月28日', '使用期間', '処方箋の', '平成年月日', '含めて4日以内に保険', '薬局に提出すること。'], ['LA']]}
#  30%|███       | 9/30 [00:33<01:14,  3.53s/it]
# API終了までにかかった時間:3.0428662300109863[sec]
# for文を回し終わるまでにかかった時間:3.0529801845550537[sec]
# elapsed_time:3.0662362575531006[sec]
# {'file_name': 'photo-326.jpeg', 'result(10,0,10)': [['院外', '処', '方', '箋 2013年09月30日 11:44 発行'], ['(この処方箋は、 どの保険薬局でも有効です。)'], ['保険者番号1062315118'], ['被保険者証・被保険]4851'], ['手帳の記号・番号|267'], ['保険医療機愛知県一宮市奥町字下口西89番地の1'], ['関の所在地 社会医療法人杏嶺会'], ['浩二', '及び名称 上林記念病院'], ['電話番号0586-61-0110', '中'], ['男女、保険医氏名', '中原保裕', '原'], ['09月28日生', '賞者 ==被扶養者==', '都道府県', '号', '213', '点数表', '号', '1', '医療機関', 'ド', '2 2 0 2 1 2 6', '特に記載のある場合を除き、'], ['01年09月 30日', '使用期間', '処方箋の', '令和 1年10月3日 榮<薬に進出すること。'], ['つ処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', ']'], ['「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること'], ['2 T'], ['【般】 リルマザホン塩酸塩錠1mg'], ['不眠時', '20回分'], ['(以下余白)']]}
#  33%|███▎      | 10/30 [00:36<01:07,  3.38s/it]
# API終了までにかかった時間:2.989309310913086[sec]
# for文を回し終わるまでにかかった時間:3.0035083293914795[sec]
# elapsed_time:3.021700143814087[sec]
# {'file_name': 'photo-339.jpeg', 'result(10,0,10)': [['院外処方', '箋 2019年09月27日 12:07 発行'], ['(この処方箋は,どの保険薬局でも有効です。)'], ['保険者番号101 2 3 0 0 1 0'], ['被保険者証・被験7410435'], ['者手帳の記号・番号12'], ['保険医療機愛知県一宮市奥町字下口西89番地の1'], ['智子', '関の所在地 社会医療法人杏嶺会'], ['及び名称 上林記念病院'], ['電話番号0586-61-0110'], ['10月11日生', '男・の保険医氏名 原 大', '印'], ['被扶養者', '番', '都道府県', '号', '213', '番', '点数表', '号', '1', '医療機関', 'ド', '2 202 12 6'], ['01年 09月 27日', 'の日夢内に'], ['処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること'], ['設】パロキセチン錠20mg'], ['1 T'], ['1×夕食後', '45日分'], ['(以下余白)']]}
#  37%|███▋      | 11/30 [00:39<01:03,  3.34s/it]
# API終了までにかかった時間:3.2105908393859863[sec]
# for文を回し終わるまでにかかった時間:3.2229747772216797[sec]
# elapsed_time:3.235473871231079[sec]
# {'file_name': 'photo-366.jpeg', 'result(10,0,10)': [['処方箋'], ['部茂'], ['1:82011230-2'], ['(この処方箋は、どの保険薬局でも有効です。)', '24', '①ここには薬に関連する'], ['保険薬局に提出してく'], ['旦者番号'], ['町村番号', '保険者番号', '3 92 71 2 67', '②検査値情報をご提供い'], ['医療又は', '受給者番号', '|者手帳の記号・番号', '被保険者証・被保険13580774', '③提出を希望されない方'], ['ナオコ', '男', '所在地及び名称', '保険医療機関の〒546-0002', '大阪府大阪市東住吉区杭全', '④検査値は過去3か月間以'], ['井', '直子', '仁真会', '白鷺診療所', '⑤処方せんの有効期限は'], ['TEL. 06-6714-1661', '場合,保険薬局でお薬'], ['保険者 被扶養者', '和 15年 1月 3日生 保険医氏名', '1割', '番号', '都道府県', '|2|7', '1', '番号 コード', '点数表 医療機関', '田部 茂', 'ポ', '0805785', 'FI', 'ID:82011230', 'ヨコイ ナオコ'], ['年月日', '平成30年12月20日 | 使用期限', '処方箋の', '平成年月 日', '特に記載のある場合を除き、交付の日付を含め', '氏名:横井直子 性別', '生年月日:昭和15年1月3'], ['4日以内に保険薬局に提出してください。']]}
#  40%|████      | 12/30 [00:43<01:03,  3.52s/it]
# API終了までにかかった時間:3.857180118560791[sec]
# for文を回し終わるまでにかかった時間:3.8723082542419434[sec]
# elapsed_time:3.906266212463379[sec]
# {'file_name': 'photo-435.jpeg', 'result(10,0,10)': [['処', '方'], ['1/1ページ'], ['(この処方箋はどの保険薬局でも有効です)'], ['|13|6015) 保険者番号'], ['|13|8263'], ['8 2 8 37', '被保険者証・被保険 26-38 5209'], ['者手帳の記号・番号'], ['ブチルエ', '保険医療機関の', '東京都武蔵野市吉祥寺本町1-35-14'], ['H晴生', '所在地及び名称', 'おざき心のクリニック'], ['11月13日', '女', '電話番号', '保険医氏名', '(0422)20-5587', '尾崎純子', '尾', 've'], ['保険者', '都道府県', '番号', '13', '点数表 医療機関', '番号 コード', '3325248'], ['年5月18日 処方箋の平成 年 月 日(特に記載のある場合を除き、'], ['支えある場合「レ」又は「×」を記載 使用期間 交付の日を含め4日以内に保険薬局に提出すること)'], ['15 mg', '0.5錠'], ['20%', '0.26 mg', '分1夕食後', '28日分'], ['ng', '0.5錠', '分1就寝前', '28日分']]}
#  43%|████▎     | 13/30 [00:46<01:00,  3.56s/it]
# API終了までにかかった時間:3.600536823272705[sec]
# for文を回し終わるまでにかかった時間:3.6123969554901123[sec]
# elapsed_time:3.628598928451538[sec]
# {'file_name': 'photo-456.jpeg', 'result(10,0,10)': [['処方箋正', '11'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['国7-本'], ['保険者番号', '3', '8', '2', '1'], ['|域保険者証・滅険'], ['者手帳の記号・翻27-16', '• 0 3 7 5'], ['保険医療機関 武蔵野市吉祥寺本町1-33-6'], ['の所在地'], ['及び名称、 木下循環器呼吸器内科クリニック'], ['16日男 ・ 女「電話番号 0422-22-8300'], ['CD'], ['者 2.0 割「保険医氏名 木下陽'], ['5月18日', '都道府県', '番号', '13', '番号', '点数表', '1', '医療機関', 'コード', '313|2|3|8|9|6'], ['月', 'DET', '特に記載のある場合を除き、交付の日を含めて4日以内に保険薬局に提出すること。'], ['いて、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['間に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['アロプリノール錠100mg', '1', '錠'], ['ストール錠5mg', '1', '錠'], ['朝食後服用'], ['30日分'], ['ムロ配合錠AP', '1', '錠'], ['朝食後服用']]}
#  47%|████▋     | 14/30 [00:50<00:56,  3.53s/it]
# API終了までにかかった時間:3.444812774658203[sec]
# for文を回し終わるまでにかかった時間:3.45491099357605[sec]
# elapsed_time:3.470231056213379[sec]
# {'file_name': 'photo-504.jpeg', 'result(10,0,10)': [['処', '方', 'P. 1'], ['箋'], ['(この処方箋は、どの保険薬局でも有効です。)', 'O'], ['保険者番号', '06132948'], ['被保険者証・被保険'], ['1 3 2 4 • 5 0 8'], ['者手帳の記号・番号'], ['保険医旅機 東京都千代田区飯田橋4-6-9 STビル2階'], ['及び名称 医療法人社団 高典会 飯田橋クリニック'], ['26才'], ['8ヶ月男の 電話番号03-3222-6461', '高'], ['JIT', '10日生', '保険医氏名 高橋 典大'], ['被扶養者', '都道府県', '1', '3', '番号', '1', '点数表 医療機関', 'コード', 'N', '0 1 9 4. 8', '1'], ['5月13日', '使用期間', '処方箋の', '年月 交付の日を含めて4日以内に', '保険薬局に提出すること。', '特に記載のある場合を除き、'], ['について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['5 mg', '1', '錠'], ['夕食後'], ['なら寝る前', '30日分'], ['ィカプセル100'], ['3', 'C']]}
#  50%|█████     | 15/30 [00:54<00:54,  3.60s/it]
# API終了までにかかった時間:3.743975877761841[sec]
# for文を回し終わるまでにかかった時間:3.7504429817199707[sec]
# elapsed_time:3.762104034423828[sec]
# {'file_name': 'photo-519.jpeg', 'result(10,0,10)': [['処', '方', '箋', '負担:30%'], ['(この処方察はどの保険薬局でも有効です。', 'Tom'], ['保 険 者番号 06137087'], ['|被保険者証・被保険'], ['36 · 536'], ['者手帳の記号・番号'], ['ト', '保険医療機関の', '新宿区四谷1-2-4 クニヤビル3F'], ['所在地及び名称'], ['みどりの森ひふ科クリニック'], [')。平'], ['12日 「男女', '電話番号', '03-3352-4100'], ['保険医氏名 矢澤 徳仁'], ['被扶養者', '番号', '都道府県 点数表 医療機関', '1/3|番号|1', 'コード10|4|3|7|6|7|3'], ['特に記載のある場合を除き、交付の日を含めて'], ['10日 19日', '処方箋の 4日以内に保険薬局に提出すること。']]}
#  53%|█████▎    | 16/30 [00:57<00:50,  3.58s/it]
# API終了までにかかった時間:3.4554319381713867[sec]
# for文を回し終わるまでにかかった時間:3.501258134841919[sec]
# elapsed_time:3.5130271911621094[sec]
# {'file_name': 'photo-524.jpeg', 'result(10,0,10)': [['処方箋'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['08', '①ここには薬に関連する検査値情'], ['保険薬局に提出してください。'], ['保険者番号'], ['3 92 72 1 2 5', '②検査値情報をご提供いただくと'], ['被保険者証・被保険10403475'], ['者手帳の記号・番号', '-', '③提出を希望されない方は処方せ'], ['保険医療機関の〒546-0002'], ['男', '所在地及び名称', '七丁目十番十九等', '大阪府大阪市東住吉区杭全', '④検査値は過去3か月間以内に測:'], ['仁真会'], ['白鷺診療所', '⑤処方せんの有効期限は発行日を'], ['7月', '26日生', '保険医氏名 三橋', 'TEL. 06-6714-1661', '誠', '場合、保険薬局でお薬を受け取'], ['夫養者', '1割', '番号', '都道府県', '27', '品', '1', '点数表、 医療機関', 'lo slo 51718151', 'ID: 87012068']]}
#  57%|█████▋    | 17/30 [01:01<00:45,  3.54s/it]
# API終了までにかかった時間:3.4047110080718994[sec]
# for文を回し終わるまでにかかった時間:3.416616916656494[sec]
# elapsed_time:3.430040121078491[sec]
# {'file_name': 'photo-548.jpeg', 'result(10,0,10)': [['処方せん'], ['(この処方せんは、どの保険薬局でも有効です)'], ['(処方せん番号: 20171228-000074)'], ['保険者番号 01 1 2 0 0 1'], ['被保険者証・被保険 159160232・7'], ['者手帳の記号・番号'], ['保険医療機関 埼玉県さいたま市桜区上大久保'], ['チ', '様」の所在地及び 884'], ['名称', '医療法人聖仁会西部総合病院'], ['月12日 |年齢 39歳 1ヶ月 「性別 男性', '電話番号 048-854-1111'], ['保険医氏名西郷嘉一郎'], ['麻薬免許番号'], ['「患者負担', '30% 番号', '11', '111', '都道府県 点数表 医療機関', '番号 コード', '1', '特に記載のある場合を除き', '01 04 000', '4,000'], ['平成29年12月28日', '使用期間', '処方せんの', '平成29年12月31日', 'に保険薬局に提出すること。', '交付の日を含めて4日以内'], ['ユ方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['三更不可」欄に「い」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['-1 【般】ロキソプロフェンNa錠60mg', '3錠', '14日分'], ['3錠 14日分'], ['【般レバミピド錠100mg'], ['分3/毎食後', '12/28から14日分'], ['・.2 【般】ケトプロフェンテープ40mg(10×14cm非温感)', '5袋'], ['1日1枚、', '12/28から'], ['部位 :胸部']]}
#  60%|██████    | 18/30 [01:04<00:41,  3.47s/it]
# API終了までにかかった時間:3.2948219776153564[sec]
# for文を回し終わるまでにかかった時間:3.306245803833008[sec]
# elapsed_time:3.3198788166046143[sec]
# {'file_name': 'photo-630.jpeg', 'result(10,0,10)': [['18:15="}'], ['処', '方', 'XIPRXIGE'], ['(この処方変はどの保険薬局でも有効です)', 'Page 1'], ['保険者番号', '0 11 3 0 0 1 2'], ['被保険者証・被保険', '4 2 3 6 2 4 1 2 • 18'], ['者手帳の記号・番号'], ['〒101-0021'], ['保険医療機', '東京都千代田区外神田六丁目14番2号'], ['カタマコト', '関の所在地', 'サカイ末広ビル7階B室'], ['保方誠', '及び名称', '雪月花メディカルクリニック秋葉原診療所'], ['電話番号 03-5812-5301'], ['和53年10月17日', '(', '男女', '保険医氏名 大道雅文', '(EL'], ['被保険者', '被扶養者', '番号', '都道府県', '113', '1', '番号 コード', '点数表 医療機関', '0|11313171110'], ['特に記載のある場合'], ['平成30年12月12日', '使用期間', '処方箋の', '平成年月日', 'を除き、交付の日を', '含めて4日以内に保険', '薬局に提出すること。'], ['個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', '4'], ['には、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】アロプリノール錠100mg', '3錠'], ['分3毎食後', '28日分'], ['及】*', '【般】ロキソプロフェンNa錠60mg', '3錠']]}
#  63%|██████▎   | 19/30 [01:07<00:36,  3.34s/it]
# API終了までにかかった時間:3.0032529830932617[sec]
# for文を回し終わるまでにかかった時間:3.012009859085083[sec]
# elapsed_time:3.0241987705230713[sec]
# {'file_name': 'photo-655.jpeg', 'result(10,0,10)': [['IÀ Gta'], ['処方せん', '~373)'], ['どの保険薬局でも有効です。)', '分割指示に係る分割の回目'], ['保険者番号', '4100', '14 00:38'], ['被保険者証・被保険者', '03', '335-2943-9'], ['手帳の記号・番号'], ['かわごえ むねき', '医療機関の', '東京都千代田区外神田5丁目2-7'], ['川越宗紀', '所在地及び'], ['名称'], ['明神下診療所'], ['電話番号 03-5816-3110'], ['999/09/13', '男', '保険医氏名 米田衆介', 'VON'], ['被保険者'], ['18/12/28', '処方せ県番号', '都道府113', '番', '数表', '1', '関コード', '医療機、', '011/3 4 4 3 7'], ['んの使', '用期間 平成年月日 特に記載のある場合を除き、交付の'], ['日から4日以内に保険薬局に提出す'], ['ること'], ['て、後発医薬品(ジェネリック)への変更に差し支えが判断した場合には「変更不可」欄に「レ」又は']]}
#  67%|██████▋   | 20/30 [01:11<00:33,  3.38s/it]
# API終了までにかかった時間:3.450183868408203[sec]
# for文を回し終わるまでにかかった時間:3.455782890319824[sec]
# elapsed_time:3.4684829711914062[sec]
# {'file_name': 'photo-721.jpeg', 'result(10,0,10)': [['処', '方', 'せ', '3'], ['(後発希望'], ['(この処方せんは、どの保険薬局でも有効です。)'], ['保険者番号', '0 6 1 3 9 4', '6 3'], ['被保険者証・被保険', '100', '99744'], ['者手帳の記号・番号'], ['保健医療機関の東京都千代田区飯田橋4-5-16 コアビル3F'], ['介', '殿', '所在地及び名称'], ['飯田橋歯科クリニック'], ['電話番号 03-3288-5253'], ['年1月16日', '(男・女'], ['保険医氏名竹内均']]}
#  70%|███████   | 21/30 [01:14<00:31,  3.48s/it]
# API終了までにかかった時間:3.6923370361328125[sec]
# for文を回し終わるまでにかかった時間:3.7017760276794434[sec]
# elapsed_time:3.715696096420288[sec]
# {'file_name': 'photo-770.jpeg', 'result(10,0,10)': [['Po dl". X. GE'], ['方', '箋かか21'], ['(この処方類はどの保険薬局でも有効です。)', '負担:30%'], ['保険者番号 39122072'], ['被保険者証・被保険'], ['• 019 64204'], ['者手帳の記号・番号'], ['東京都台東区上野3-16-4 文行堂ビル2F'], ['ロウ', '保険医療機関の'], ['郡', '所在地及び名称'], ['医療法人社団雄翔会あさひ上野クリニック'], ['・平'], ['29日', '男女', '電話番号', '森田 秀和', '03-5818-7070'], ['保険医氏名', 'ED'], ['被扶養者', '番号 1/3|番号|1 コード06/301219', '都道府県 点数表 医療機関'], ['特に記載のある場合を除き、交付の日を含めて'], ['処方箋の 4日以内に保険薬局に提出すること。'], ['2月14日', '使用期間 平成 年月日'], ['(ジェネリック医薬品)への変更に差し支えがあると判断した場合には、'], ['」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['変更不可'], ['【内服】'], ['ン塩酸塩錠1', '【般】プラバスタチンナトリウム']]}
#  73%|███████▎  | 22/30 [01:18<00:27,  3.45s/it]
# API終了までにかかった時間:3.3580851554870605[sec]
# for文を回し終わるまでにかかった時間:3.3667609691619873[sec]
# elapsed_time:3.3794400691986084[sec]
# {'file_name': 'photo-775.jpeg', 'result(10,0,10)': [['処', '方', '箋', 'l', 'P. 1'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号', '01111301012'], ['被保険者証・被保険'], ['1322316.5'], ['者手帳の記号・番号'], ['保険医療機 東京都千代田区飯田橋4-6-9 STビル2階'], ['及び名様 医療法人社団 高典会 飯田橋クリニック'], ['47才'], ['5ヶ月 男の 電話番号 03-3222-6461'], ['7日生', '保険医氏名 高橋 典大'], ['音', '被扶養者', '|都道府県', '番号', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0', '1', '1', '2', '911 8', '4'], ['年', '5月', '13日', '使用期間', '処方箋の', '年月日', '保険薬局に提出すること。', '交付の日を含めて4日以内に', '特に記載のある場合を除き、'], ['について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['-可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['ィカプセル100']]}
#  77%|███████▋  | 23/30 [01:21<00:24,  3.54s/it]
# API終了までにかかった時間:3.6992950439453125[sec]
# for文を回し終わるまでにかかった時間:3.710732936859131[sec]
# elapsed_time:3.723552942276001[sec]
# {'file_name': 'photo-786.jpeg', 'result(10,0,10)': [['笑 2013年09月27日 12:54 発行'], ['院外 処方'], ['(この処方箋は,どの保険薬局でも有効です。)'], ['保険者番号 2 310 0 4 5'], ['被保険者証・被保険'], ['手帳の記号・番号|3226851'], ['保険医療機愛知県一宮市奥町字下口西89番地の1'], ['関の所在地 社会医療法人杏嶺会'], ['春子', '及び名称 上林記念病院'], ['電話番号 0586-61-0110'], ['男。 保険医氏名', '市橋佳世子', '養'], ['F 02月20日生', '都道府県|2|3', '2 3 *** 1 212102111216', '医療機関', 'ド'], ['険者 ==被扶養者== 番'], ['処方箋の', '令和 1年9月30日 業業に進出すること。'], ['和 01年 09月 27日', '使用期間'], ['日々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', ')'], ['は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること', 'O. 5 T'], ['エビリファイ錠3mg', '1 T'], ['【般】アムロジピン口腔内崩壊錠2.5mg', '1xEVE', '28日分'], ['2 T'], ['リフレックス錠15mg', '1×夕食後', '28日分']]}
#  80%|████████  | 24/30 [01:26<00:24,  4.00s/it]
# API終了までにかかった時間:5.052948951721191[sec]
# for文を回し終わるまでにかかった時間:5.064063787460327[sec]
# elapsed_time:5.076608896255493[sec]
# {'file_name': 'photo-793.jpeg', 'result(10,0,10)': [['処方箋'], ['Page 1'], ['の処方箋は、どの保険薬局でも有効です。)'], ['02 長'], ['2', '7', '4 2', '5', '1', '保険者番号', '39', '2', '7 11 2 6 7'], ['被保険者証・被保険 10428159'], ['5', '6', '3 4 1'], ['者手帳の記号・番号'], ['<同姓同名有り> 保険医療機関の 〒546-0002'], ['(男)', '所在地及び名称', '大阪府大阪市東住吉区杭全'], ['七丁目十番十九号'], ['様', '仁真会 白鷺診療所'], ['女', 'TEL. 06-6714-1661'], ['6月', '1日生', '保険医氏名 岡崎久宜', '所'], ['扶養者', '都道府県', '番号', '27', '1', '番号 コード', '点数表 医療機関', '08015|7185'], ['処方箋の 平成 30年 12月23日'], ['30年 12月20日', '使用期間', '4日以内に保険薬局に提出してください。', '特に記載のある場合を除き、交付の日付を含め'], ['雪々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合に', 'に]'], ['「変更不可」欄に「」または「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]}
#  83%|████████▎ | 25/30 [01:33<00:24,  4.85s/it]
# API終了までにかかった時間:6.779211044311523[sec]
# for文を回し終わるまでにかかった時間:6.791145086288452[sec]
# elapsed_time:6.808765172958374[sec]
# {'file_name': 'photo-806.jpeg', 'result(10,0,10)': [['2809 第01版'], ['0481', '処方'], ['箋'], ['1:19 この処方箋は、どの薬局でも有効です。(コピーは無効です。)', '1/1'], ['号'], ['号', '保険者番号|39|2|3|2|0|318'], ['は', '被保険者証・被保険|11843562'], ['番号', '者手帳の記号・番号'], ['00748 耳鼻咽喉科', 'の所在地', '保険医療機関 〒494-0001 愛知県一宮市開明字平1番地'], ['ユリコ', '及 び 名称 一 宮西病院'], ['百合子'], ['様電 話 番 号 0586-48-0077(代)'], ['年08月09日 79才女性保険 医氏名 宮田英雄'], ['Lone'], ['弁者', '負担割合 1割', '都道府県', '番号', '2 3', '番号', '点数表', '1', '医療機関', 'ド', '2|20| 3| 2|72|'], ['令和1年09月27日', '使用期限', '処方箋の', '令和1年09月30日'], ['[', '個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['には、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】 パロキセチン錠10mg', '2錠'], ['1回1錠 (1日2錠)'], ['・1日2回 朝・夕食後', '21日分'], ['2010 con 107']]}
#  87%|████████▋ | 26/30 [01:38<00:19,  4.86s/it]
# API終了までにかかった時間:4.860499858856201[sec]
# for文を回し終わるまでにかかった時間:4.870249032974243[sec]
# elapsed_time:4.883002042770386[sec]
# {'file_name': 'photo-879.jpeg', 'result(10,0,10)': [['P. 1'], ['処', '方', '箋', 'GE'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['割'], ['保険者番号', '0 61 34803'], ['被保険者証・被保険', '.', '532 6175'], ['者手帳の記号・番号'], ['フラメグミ', '保険医療機 東京都千代田区外神田5-2-3'], ['倉めぐみ', '関の所在地', '及び名称 アソルティ末広町ビル1F'], ['大昭平 48才', '末広町ヒライ耳鼻咽喉科'], ['9ヶ月男女 電話番号 03-3836-3387'], ['15年 3月 9日生', '保険医氏名平井 良治'], ['保険者、被扶養者', '番号', '都道府県', '1', '3', '番号', '点数表', '1', '医療機関', 'コード', '0 1 3 5110° 1.38', '特に記載のある場合を除き、'], ['処方箋の', '交付の日を含めて4日以内に'], ['平成 30年 12月', '26日', '使用期間 平成 年月', '保険薬局に提出すること。'], ['個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['ニは、「変更不可」欄に「」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]}
#  90%|█████████ | 27/30 [01:43<00:14,  4.97s/it]
# API終了までにかかった時間:5.085760831832886[sec]
# for文を回し終わるまでにかかった時間:5.120459794998169[sec]
# elapsed_time:5.211035966873169[sec]
# {'file_name': 'photo-885.jpeg', 'result(10,0,10)': [['Guard'], ['Copy', 'per Copy G'], ['Guard Paper', 'opy Guard', 'jard Paper', 'Copy Guard', 'aper Copy', 'hard Paper', 'per Copy Guard', 'uard Paper Copy', 'Copy Guard Paper', 'Paper Copy Guard', 'Guard Paper Copy', 'Copy Guard Paper', 'Guar laper Cody', 'pyyuard Paper'], ['Paper Copy Guard', 'by Guard Paper Copy', 'fropy Guard Paper', 'dos Jaded', 'Copy Guard Paper Co'], ['てる方はどの保険薬局でも有効です)', 'Copard Paper Copy Gear'], ['38009', 'Co Pape', 'De 011300127 Paper Copy Guard', '保険者番号'], ['6 V Copy Guard Papa'], ['Caro y Gual', '被保険者証・被保険| 57280204'], ['9 1'], ['者手帳の記号・番号 1750', 'Lapes'], ['37', 'GUNO er opy Vaper Com', 'er cuard Woer opy Guard/', '保険医療機 opyを', '東京都武蔵野市吉祥寺本町1-30-12', 'Copy Guard Page Copy Guard Paper Cor'], ['Paper Copy Già Paper Copy Gray'], ['機地', 'Guard PT', '医療法人社団 東仁会Garam'], ['Evans paper CBS Guard Pape'], ['ne Paper Copy Sard)', 'py Guard Paper Cox'], ['0422-221120'], ['孝典', 'Paper Copy Guar'], ['ord Pa/', '診療科', 's Paper', 'Copy 人工透析内!', 'Guäm aper'], ['三8月22日(513) py Guard Paper VIK', 'Co Gual Paper Copy Gu', '性別 男 保険医氏名 笠原仁', 'Zer Copy Guard Pace'], ['被保険者', 'con', 'Pap', '\\/', '13', '都道府県 無数表 医療機関', '番号', 'コード|3|37|0|1|2|9'], ['wa Pap'], ['特に記載のある場合を除き、'], ['年5月17日', 'CO', '使用期間', '処方箋の', 'V Gud', 'per CO', 'jard Pais', 'opy Gus', 'perc', 'vard', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['ROLTIN', 'は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること、any py Guard Paper Cons', '後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', 'Guard per Copy ✓rd Paper Copy Guar', 'Estander Copy Guard Pape', 'y Guard Paper Copy'], ['-ツムラ芍薬甘草湯エキス顆粒(医療用)(2.5g) "'], ['I aper', 'Grd Paper Copy Guar'], ['er Copy Gu TV', 'x per', '下肢つり時1包', 'Paper ca', 'opy Guard PT', 'per Copy G', 'xrd Paper', 'opy Guard P', 'er Copy G', 'zard Paper Copy', 'opy Guest', 'aper Copy Guard', 'jard Paper Copy', 'Copy Guard Paper', 'aper Copy Guard', 'co', 'Copy Guard Pape', 'Paper Cop', 'Guar'], ['ELT']]}
# API終了までにかかった時間:4.411003112792969[sec]
# for文を回し終わるまでにかかった時間:4.633635997772217[sec]
#  93%|█████████▎| 28/30 [01:48<00:09,  4.90s/it]
# elapsed_time:4.709389925003052[sec]
# {'file_name': 'photo-1011.jpeg', 'result(10,0,10)': [['処', '方', 'P. 1'], ['箋'], ['(この処方箋は、どの保険薬局でも有効です。)', '後発希望'], ['保険者番号', '0 1 1 4 0011'], ['被保険者証・被保険'], ['者手帳の記号・番号', '2 1 3 5 0 7 2 6 • 2 1 2'], ['保険医療機 東京都千代田区飯田橋4-4-7'], ['関の所在地'], ['及び名称 医療法人社団慈仁会 飯田橋小池クリニック'], ['22才'], ['5ヶ月男の 電話番号03-3221-8858'], ['6日生', '保険医氏名 小池 美由紀'], ['被扶養者', '|都道府県', '番号', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0 1', '3', 'SR', '4 5 5 1'], ['処方箋の', '特に記載のある場合を除き、'], ['5月13日', '使用期間', '年月 日', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['いて、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['欄に「1」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['ジン錠', '3 mg', '2 錠'], ['食後服用', '5日分']]}
#  97%|█████████▋| 29/30 [01:52<00:04,  4.72s/it]
# API終了までにかかった時間:4.283455848693848[sec]
# for文を回し終わるまでにかかった時間:4.294160842895508[sec]
# elapsed_time:4.308790922164917[sec]
# {'file_name': 'photo-1110.jpeg', 'result(10,0,10)': [['処方箋'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号31911131111516'], ['被保険者証・被保険者', '04354858'], ['手帳の記号・番号'], ['39'], ['保険医療機関の東京都杉並区上荻2-42-11'], ['所在地及び名称 一般社団法人衛生文化協会'], ['園子', '城西病院'], ['電話番号 03-3390-4166', '矢'], ['2年2月27日 女', '保険医氏名 矢吹里香子', 'ED'], ['険者 負担割 1割'], ['都道府県番号137点数表番号1医療機関コード1570928'], ['平成30年5月18日', '処方度の', 'の日を含めて4日以内に保険薬局', '特に記載のある場合を除き交付'], ['使用期間 平成30年5月21日 に提出すること。'], ['日々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['薬'], ['・ヌビア錠50mg', '1'], ['1錠'], ['ロジンOD錠5mg'], ['(朝)'], ['1日1回 14日分']]}
# 100%|██████████| 30/30 [01:56<00:00,  3.89s/it]
# API終了までにかかった時間:3.648853063583374[sec]
# for文を回し終わるまでにかかった時間:3.6584889888763428[sec]
# elapsed_time:3.6707749366760254[sec]
# {'file_name': 'photo-1137.jpeg', 'result(10,0,10)': [['P. 1'], ['処', '方', '箋', 'a'], ['(この処方箋は、どの保険薬局でも有効です。)', '後発希望'], ['保険者番号', '138016'], ['被保険者証・被保険'], ['者手帳の記号・番号', '01-48.5039'], ['ョウイチ', '保険医療機 東京都千代田区飯田橋4-4-7'], ['関の所在地'], ['及び名称一医療法人社団慈仁会 飯田橋小池クリニック'], ['63才'], ['池'], ['8ヶ月)女 電話番号03-3221-8858'], ['9月 14日生', '保険医氏名 小池 美由紀', '印'], ['弁者 被扶養者', '番号', '都道府県', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0', '1', '3 4 5 5', '1'], ['処方箋の', '特に記載のある場合を除き、'], ['1年', '5月', '24日', '使用期間', '年月 月日', '保険薬局に提出すること。', '交付の日を含めて4日以内に!'], ['う薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['更不可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['アムロジピン錠2', '2. 5 mg', '1', '4.']]}

# %%
def pickle_file_open(pickle_file_path):
    '''
    pickleファイルをロードする
    input:pickleファイルのpath
    output:ロード済みのファイル
    '''
    with open(pickle_file_path, 'rb') as web:
        df = pickle.load(web)
    return df

df=pickle_file_open('ocr_result_4.pickle')

# %%
#住所の後、電話番号の前
#所在地及び名称より後ろ
#クリニック、医療法人、

# %%
text_list=list(df["result(10,0,10)"])

# %%
#上を関数化　ある単語を含んでいたら、それ以降全てを取得（その単語は含まない）
def word_check_list(words_list,check_word):
    word=check_word
    candidate_list=[]
    for num in range(len(words_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            candidate1=[]
            candidate2=[]
            candidate3=[]
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][s+1:])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)
#1,15が二回,18,19,20

# %%
#上を関数化　ある単語を含んでいたら、それ以降全てを取得（その単語は含む）
def word_check_list2(words_list,check_word):
    word=check_word
    candidate_list=[]
    for num in range(len(words_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            candidate1=[]
            candidate2=[]
            candidate3=[]
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][s:])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)
#1,15が二回,18,19,20

# %%
#上を関数化　ある単語を含んでいたら、それより前を全てを取得（その単語は含まない）
def word_check_list_before(words_list,check_word):
    word=check_word
    candidate_list=[]
    for num in range(len(words_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            candidate1=[]
            candidate2=[]
            candidate3=[]
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][:s])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)
#1,15が二回,18,19,20

# %%
text_list=list(df["result(10,0,10)"])
text_list=word_check_list_before(text_list,"話番号")
text_list=word_check_list2(text_list,"所在地")
text_list=word_check_list2(text_list,"及び名称")
text_list=word_check_list(text_list,"記号・番号")
text_list=word_check_list_before(text_list,"都道府県")




# for text in text_list:
#     print(text)
# print("--------------------------------")
# print("--------------------------------")
# print("--------------------------------")
# print("--------------------------------")

hos_list=[]
for text in text_list:
    t_list=[]
    for t in text:
        t_list.extend(t)
        #print(t)
    print(t_list)
    hos_list.append(t_list)
# Out:
# ['及び名称 医療法人社団 高典会 飯田橋クリニック', '56才']
# ['Date', '.', '人0', 'Os']
# ['関の所在地 医療法人社団 東仁会 吉祥寺あさひ病院', 'U']
# ['谷川 光洋', '関の所在地', '及び名称"アソルティ末広町ビル1F', '大昭平 40才', '末広町ヒライ耳鼻咽喉科']
# ["'", '及び名称 医療法人社団慈仁会 飯田橋小池クリニック', '43才']
# ['子', '関の所在地', '及び名称、アソルティ末広町ビル1F', '平', '36才', '末広町ヒライ耳鼻咽喉科']
# ['ウラノチッ', '埜 知津子', '所在地及び名称', '保険医療機関の', 'Fine F', '上西クリニック', '大阪市平野区平野西3-9-21 コーポ常']
# ['山口', 'グチカナコ', '桂奈子', '関の所在地', '及び名称', 'サカイ末広ビル7階B室', '雪月花メディカルクリニック 秋葉原診療所']
# ['浩二', '及び名称 上林記念病院']
# ['及び名称 上林記念病院']
# ['ナオコ', '男', '所在地及び名称', '保険医療機関の〒546-0002', '大阪府大阪市東住吉区杭全', '④検査値は過去3か月間以', '井', '直子', '仁真会', '白鷺診療所', '⑤処方せんの有効期限は', 'TEL. 06-6714-1661', '場合,保険薬局でお薬']
# ['H晴生', '所在地及び名称', 'おざき心のクリニック']
# ['及び名称、 木下循環器呼吸器内科クリニック']
# ['及び名称 医療法人社団 高典会 飯田橋クリニック', '26才']
# ['所在地及び名称', 'みどりの森ひふ科クリニック', ')。平']
# ['男', '所在地及び名称', '七丁目十番十九等', '大阪府大阪市東住吉区杭全', '④検査値は過去3か月間以内に測:', '仁真会', '白鷺診療所', '⑤処方せんの有効期限は発行日を', '7月', '26日生', '保険医氏名 三橋', 'TEL. 06-6714-1661', '誠', '場合、保険薬局でお薬を受け取']
# ['チ', '様」の所在地及び 884', '名称', '医療法人聖仁会西部総合病院']
# ['保方誠', '及び名称', '雪月花メディカルクリニック秋葉原診療所']
# ['川越宗紀', '所在地及び', '名称', '明神下診療所']
# ['介', '殿', '所在地及び名称', '飯田橋歯科クリニック']
# ['郡', '所在地及び名称', '医療法人社団雄翔会あさひ上野クリニック', '・平']
# ['保険医療機 東京都千代田区飯田橋4-6-9 STビル2階', '及び名様 医療法人社団 高典会 飯田橋クリニック', '47才']
# ['春子', '及び名称 上林記念病院']
# ['(男)', '所在地及び名称', '大阪府大阪市東住吉区杭全', '七丁目十番十九号', '様', '仁真会 白鷺診療所', '女', 'TEL. 06-6714-1661', '6月', '1日生', '保険医氏名 岡崎久宜', '所']
# ['ユリコ', '及 び 名称 一 宮西病院', '百合子']
# ['倉めぐみ', '関の所在地', '及び名称 アソルティ末広町ビル1F', '大昭平 48才', '末広町ヒライ耳鼻咽喉科']
# ['37', 'GUNO er opy Vaper Com', 'er cuard Woer opy Guard/', '保険医療機 opyを', '東京都武蔵野市吉祥寺本町1-30-12', 'Copy Guard Page Copy Guard Paper Cor', 'Paper Copy Già Paper Copy Gray', '機地', 'Guard PT', '医療法人社団 東仁会Garam', 'Evans paper CBS Guard Pape', 'ne Paper Copy Sard)', 'py Guard Paper Cox', '0422-221120', '孝典', 'Paper Copy Guar', 'ord Pa/', '診療科', 's Paper', 'Copy 人工透析内!', 'Guäm aper', '三8月22日(513) py Guard Paper VIK', 'Co Gual Paper Copy Gu', '性別 男 保険医氏名 笠原仁', 'Zer Copy Guard Pace']
# ['及び名称 医療法人社団慈仁会 飯田橋小池クリニック', '22才']
# ['所在地及び名称 一般社団法人衛生文化協会', '園子', '城西病院']
# ['及び名称一医療法人社団慈仁会 飯田橋小池クリニック', '63才', '池']

# %%
result_list=[]
for word_list in hos_list:
    result=[]
    #print(word)
    for word in word_list:
        #print("[処理前]")
        #print(word)
        word=text_replace(word)
        if not_hospital(word.replace(" ",""))==True:
            if len(word)>3:
                #print("[--処理後--]")
                print(word)
                result.append(word)
    result_list.append(result)
    print("-------------------")
# Out:
# 医療法人社団高典会飯田橋クリニック
# -------------------
# -------------------
# 医療法人社団東仁会吉祥寺あさひ病院
# -------------------
# 谷川光洋
# アソルティ末広町ビル1F
# 末広町ヒライ耳鼻咽喉科
# -------------------
# 医療法人社団慈仁会飯田橋小池クリニック
# -------------------
# アソルティ末広町ビル1F
# 末広町ヒライ耳鼻咽喉科
# -------------------
# 埜知津子
# 保険医療機
# 上西クリニック
# 大阪市平野区平野西3921コーポ常
# -------------------
# サカイ末広ビル7階B室
# 雪月花メディカルクリニック秋葉原診療所
# -------------------
# 上林記念病院
# -------------------
# 上林記念病院
# -------------------
# 保険医療機5460002
# 大阪府大阪市東住吉区杭全
# ④検査値は過去3か月間以
# 白鷺診療所
# ⑤処方せんの有効期限は
# 場合保険薬局でお薬
# -------------------
# おざき心のクリニック
# -------------------
# 木下循環器呼吸器内科クリニック
# -------------------
# 医療法人社団高典会飯田橋クリニック
# -------------------
# みどりの森ひふ科クリニック
# -------------------
# 七丁目十番十九等
# 大阪府大阪市東住吉区杭全
# ④検査値は過去3か月間以内に測
# 白鷺診療所
# ⑤処方せんの有効期限は発行日を
# 26日生
# 保険医氏名三橋
# 場合保険薬局でお薬を受け取
# -------------------
# 様の884
# 医療法人聖仁会西部総合病院
# -------------------
# 雪月花メディカルクリニック秋葉原診療所
# -------------------
# 川越宗紀
# 明神下診療所
# -------------------
# 飯田橋歯科クリニック
# -------------------
# 医療法人社団雄翔会あさひ上野クリニック
# -------------------
# 保険医療機東京都千代田区飯田橋469STビル2階
# 名様医療法人社団高典会飯田橋クリニック
# -------------------
# 上林記念病院
# -------------------
# 大阪府大阪市東住吉区杭全
# 七丁目十番十九号
# 仁真会白鷺診療所
# 保険医氏名岡崎久宜
# -------------------
# 一宮西病院
# -------------------
# 倉めぐみ
# アソルティ末広町ビル1F
# 末広町ヒライ耳鼻咽喉科
# -------------------
# 保険医療機opyを
# 東京都武蔵野市吉祥寺本町13012
# PaperCopyGiàPaperCopyGray
# 医療法人社団東仁会Garam
# Copy人工透析内
# Guämaper
# 三8月22日513pyGuardPaperVIK
# 性別男保険医氏名笠原仁
# -------------------
# 医療法人社団慈仁会飯田橋小池クリニック
# -------------------
# 一般社団法人衛生文化協会
# 城西病院
# -------------------
# 一医療法人社団慈仁会飯田橋小池クリニック
# -------------------

# %%
result_list
# Out:
# [['医療法人社団高典会飯田橋クリニック'],
#  [],
#  ['医療法人社団東仁会吉祥寺あさひ病院'],
#  ['谷川光洋', 'アソルティ末広町ビル1F', '末広町ヒライ耳鼻咽喉科'],
#  ['医療法人社団慈仁会飯田橋小池クリニック'],
#  ['アソルティ末広町ビル1F', '末広町ヒライ耳鼻咽喉科'],
#  ['埜知津子', '保険医療機', '上西クリニック', '大阪市平野区平野西3921コーポ常'],
#  ['サカイ末広ビル7階B室', '雪月花メディカルクリニック秋葉原診療所'],
#  ['上林記念病院'],
#  ['上林記念病院'],
#  ['保険医療機5460002',
#   '大阪府大阪市東住吉区杭全',
#   '④検査値は過去3か月間以',
#   '白鷺診療所',
#   '⑤処方せんの有効期限は',
#   '場合保険薬局でお薬'],
#  ['おざき心のクリニック'],
#  ['木下循環器呼吸器内科クリニック'],
#  ['医療法人社団高典会飯田橋クリニック'],
#  ['みどりの森ひふ科クリニック'],
#  ['七丁目十番十九等',
#   '大阪府大阪市東住吉区杭全',
#   '④検査値は過去3か月間以内に測',
#   '白鷺診療所',
#   '⑤処方せんの有効期限は発行日を',
#   '26日生',
#   '保険医氏名三橋',
#   '場合保険薬局でお薬を受け取'],
#  ['様の884', '医療法人聖仁会西部総合病院'],
#  ['雪月花メディカルクリニック秋葉原診療所'],
#  ['川越宗紀', '明神下診療所'],
#  ['飯田橋歯科クリニック'],
#  ['医療法人社団雄翔会あさひ上野クリニック'],
#  ['保険医療機東京都千代田区飯田橋469STビル2階', '名様医療法人社団高典会飯田橋クリニック'],
#  ['上林記念病院'],
#  ['大阪府大阪市東住吉区杭全', '七丁目十番十九号', '仁真会白鷺診療所', '保険医氏名岡崎久宜'],
#  ['一宮西病院'],
#  ['倉めぐみ', 'アソルティ末広町ビル1F', '末広町ヒライ耳鼻咽喉科'],
#  ['保険医療機opyを',
#   '東京都武蔵野市吉祥寺本町13012',
#   'PaperCopyGiàPaperCopyGray',
#   '医療法人社団東仁会Garam',
#   'Copy人工透析内',
#   'Guämaper',
#   '三8月22日513pyGuardPaperVIK',
#   '性別男保険医氏名笠原仁'],
#  ['医療法人社団慈仁会飯田橋小池クリニック'],
#  ['一般社団法人衛生文化協会', '城西病院'],
#  ['一医療法人社団慈仁会飯田橋小池クリニック']]

# %%
not_hospital("0422221120")
# Out:
# False

# %%
def kata(text):
    '''
    入力が全てカタカナかどうかを判断する
    input:テキスト
    output:もし全部カタカナならTrue、違うならFalse
    '''
    re_katakana = re.compile(r'[\u30A1-\u30F4]+')
    if re_katakana.fullmatch(text):
        return True
    else:
        return False

# %%
import re

s = 'aaa@xxx.com.@@@, bbb@yyy.com, ccc@zzz.net'

m = re.match(r'([a-z]+)@([a-z]+)\.com', s)
print(m)
# <re.Match object; span=(0, 11), match='aaa@xxx.com'>

result = re.sub(r'([a-z]+)@([a-z]+)\.com', 'new-address', s)
print(result)
# Out:
# <_sre.SRE_Match object; span=(0, 11), match='aaa@xxx.com'>
# new-address.@@@, new-address, ccc@zzz.net

# %%
import re
#raw_abc = r'[0-9]+才'[ァ-ン]
raw_abc = r'[ぁ-んｦ-ﾟァ-ン0-9Ａ-ＺA-Zａ-ｚa-z]+'
text = "0422221120"

matchobj = re.fullmatch(raw_abc, text)

try:
    answer=matchobj.group()
    print
except:
    answer=True

# %%
def not_hospital(text):
    raw_abc = r'[ぁ-んｦ-ﾟァ-ン0-9Ａ-ＺA-Zａ-ｚa-z]+'
    raw_abc2 = r'大?昭?平?令?[0-9]+才'
    matchobj = re.fullmatch(raw_abc, text.replace(" ",""))
    matchobj2 = re.fullmatch(raw_abc2, text.replace(" ",""))
    try:
        answer=matchobj.group()
    except:
        answer=False
        
    try:
        answer2=matchobj2.group()
    except:
        answer2=False
    
    if answer==False and answer2==False:
        return True
    else:
        return False

# %%
print(not_hospital("ercuardWoeropyGuard"))
# Out:
# False

# %%
#置換
def text_replace(text):
    
    text=text.replace(" ","")
    text = text.replace('及び','')
    text = text.replace('名称','')
    text = text.replace('所在地','')
    text = text.replace('関の','')
    text = text.replace('保険医師','')
    text = text.replace('','')
    text = text.replace('','')
    text = text.replace('','')
    text=re.sub('\W+','', text)
    

    return text

# %%
text_replace("、アソルティ末aa広町ビ・ル1F及び一宮西病院")
# Out:
# 'アソルティ末aa広町ビル1F一宮西病院'

# %%
for i in text_list:
    for s in i:
        for s_ in s.split(" "):
            if s_ in list(df_hospital.keys()):
                print(s_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-1f37b8f848fd> in <module>
#       1 for i in text_list:
#       2     for s in i:
# ----> 3         for s_ in s.split(" "):
#       4             if s_ in list(df_hospital.keys()):
#       5                 print(s_)
#
# AttributeError: 'list' object has no attribute 'split'

# %%
for i in text_list:
    for s in i:
        for s_ in s.split(" "):
            if s_ in list(df_hospital.keys()):
                print(s_)

# %%
t = Tokenizer("merge.csv", udic_enc="utf-8")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a2984eec731e> in <module>
# ----> 1 t = Tokenizer("merge.csv", udic_enc="utf-8")
#
# NameError: name 'Tokenizer' is not defined

# %%
t = Tokenizer("merge.csv", udic_enc="utf-8")
def wakati(text):
    sei=""
    mei=""
    for token in t.tokenize(text):
        if token.part_of_speech.split(",")[2]=="人名" and (token.part_of_speech.split(",")[3]=="姓" or token.part_of_speech.split(",")[3]=="性"):
            sei=token.surface
        if token.part_of_speech.split(",")[2]=="人名" and token.part_of_speech.split(",")[3]=="名":
            mei=token.surface
    return sei,mei

# %%
for token in t.tokenize("東大病院及び名称一医療法人社団慈仁会 飯田橋小池クリニック"):
    print(token)
# Out:
# 東大	名詞,固有名詞,組織,*,*,*,東大,トウダイ,トーダイ
# 病院	名詞,一般,*,*,*,*,病院,ビョウイン,ビョーイン
# 及び	接続詞,*,*,*,*,*,及び,オヨビ,オヨビ
# 名称	名詞,一般,*,*,*,*,名称,メイショウ,メイショー
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# 医療	名詞,一般,*,*,*,*,医療,イリョウ,イリョー
# 法人	名詞,一般,*,*,*,*,法人,ホウジン,ホージン
# 社団	名詞,一般,*,*,*,*,社団,シャダン,シャダン
# 慈仁会	名詞,一般,*,*,*,*,慈仁会,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 飯田橋	名詞,固有名詞,地域,一般,*,*,飯田橋,イイダバシ,イーダバシ
# 小池	名詞,固有名詞,組織,*,*,*,小池,コイケ,コイケ
# クリニック	名詞,一般,*,*,*,*,クリニック,クリニック,クリニック

# %%
import pickle
with open('dict_hospitalInfo.pickle', 'rb') as web:
    df_hospital = pickle.load(web)

# %%
len(df_hospital)
# Out:
# 50427

# %%
for i in list(df_hospital.keys()):
    if "みどりの森" in i:
        print(i)
# Out:
# 芝山みどりの森クリニック
# みどりの森ひふ科クリニック
# 医療法人財団 真和会 みどりの森デンタルクリニック町田
# 医療法人財団真和会 みどりの森デンタルクリニック高座渋谷
# 医療法人財団真和会 みどりの森デンタルクリニック

# %%
df_hospital
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-210-650d70b2d7ae> in <module>
# ----> 1 df_hospital
#
# NameError: name 'df_hospital' is not defined

# %%
c=[i.split(",")[1]+",-1,-1,10000,名詞,固有名詞,医療機関名,,*,*,"+i.split(",")[0]+","+jaconv.hira2kata(i.split(",")[0])+","+jaconv.hira2kata(i.split(",")[0]) for i in lines3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-833ae1f6055b> in <module>
# ----> 1 c=[i.split(",")[1]+",-1,-1,10000,名詞,固有名詞,医療機関名,,*,*,*"+i.split(",")[0]+","+jaconv.hira2kata(i.split(",")[0])+","+jaconv.hira2kata(i.split(",")[0]) for i in lines3]
#       2
#       3
#       4
#
# NameError: name 'lines3' is not defined

# %%
c=[i+",-1,-1,10000,名詞,固有名詞,*,*,*,*,*,*,*" for i in df_hospital.keys()]


#ポリフェノール,-1,-1,1000,名詞,固有名詞,一般,*,*,*,ポリフェノール,ポリフェノール,ポリフェノール

# %%
c[0]
# Out:
# '千葉県がんセンター,-1,-1,10000,名詞,固有名詞,*,*,*,*,*,*,*'

# %%
with open('hospital.csv', 'w', encoding='utf-8') as f:
#     f.write('ロスマリン,-1,-1,1000,名詞,固有名詞,一般,*,*,*,ロスマリン,ロスマリン,ロスマリン\n')
#     f.write('ポリフェノール,-1,-1,1000,名詞,固有名詞,一般,*,*,*,ポリフェノール,ポリフェノール,ポリフェノール\n')
#     f.write('機序,-1,-1,1000,名詞,サ変接続,*,*,*,*,機序,キジョ,キジョ\n')
    for i in c:
        f.write(i+"\n")

# %%
from janome.tokenizer import Tokenizer
t = Tokenizer("hospital.csv", udic_enc="utf-8")

line = '藍磯 飯田橋小池クリニック小原大智ロスマリン酸摂取後の脳内ドーパミンがアルツハイマー病を予防する  ポリフェノールの新たな作用機序'

for token in t.tokenize(line):
    print(token)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-d5634188e602> in <module>
#       1 from janome.tokenizer import Tokenizer
# ----> 2 t = Tokenizer("hospital.csv", udic_enc="utf-8")
#       3
#       4 line = '藍磯 飯田橋小池クリニック小原大智ロスマリン酸摂取後の脳内ドーパミンがアルツハイマー病を予防する  ポリフェノールの新たな作用機序'
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/janome/tokenizer.py in __init__(self, udic, udic_enc, udic_type, max_unknown_length, wakati, mmap, dotfile)
#     166             if udic.endswith('.csv'):
#     167                 # build user dictionary from CSV
# --> 168                 self.user_dic = UserDictionary(udic, udic_enc, udic_type, connections)
#     169             elif os.path.isdir(udic):
#     170                 # load compiled user dictionary
#
# ~/anaconda3/lib/python3.6/site-packages/janome/dic.py in __init__(self, user_dict, enc, type, connections)
#     404         """
#     405         build_method = getattr(self, 'build' + type)
# --> 406         compiledFST, entries = build_method(user_dict, enc)
#     407         Dictionary.__init__(self, [compiledFST], entries, connections)
#     408
#
# ~/anaconda3/lib/python3.6/site-packages/janome/dic.py in buildipadic(self, user_dict, enc)
#     416                 pos_major, pos_minor1, pos_minor2, pos_minor3, \
#     417                 infl_type, infl_form, base_form, reading, phonetic = \
# --> 418                     line.split(',')
#     419                 part_of_speech = ','.join([pos_major, pos_minor1, pos_minor2, pos_minor3])
#     420                 morph_id = len(surfaces)
#
# ValueError: too many values to unpack (expected 13)

# %%
text_list=list(df["result(10,0,10)"])
text_list=word_check_list_before(text_list,"所在地")
text_list=word_check_list_before(text_list,"電話番号")
text_list=word_check_list_before(text_list,"保険医療")
text_list=word_check_list_before(text_list,"医療機")
text_list=word_check_list_before(text_list,"〒")
text_list=word_check_list_before(text_list,"東京都")
text_list=word_check_list_before(text_list,"町")
text_list=word_check_list_before(text_list,"区")
text_list=word_check_list(text_list,"険者番号")
text_list=word_check_list2(text_list,"被保険")
# # text_list=word_check_list_before(text_list,"所在地")
# text_list=word_check_list_before(text_list,"電話番号")

info_list=[]
sum_=0
for i in text_list:
    print(sum_)
    #print(i)
    word_list=["-".join(s) for s in i]#.replace("・","-").replace(".","-")
    word_list2=("-".join(word_list))
    print(word_list2)
    word_list3=word_list2.replace("・","-").replace(".","-").replace("•","-")
    word_list4=word_list3.split("-")
    word_list5=[]
    for word in word_list4:
        if word.count(' ')==1:
            word_list5.append(word.split(" ")[0])
            word_list5.append(word.split(" ")[1])
        else:
            word_list5.append(word)
    print(word_list5)
    sum_+=1
#     for word in word_list5:
        
#         print(re.sub('[^0-9]','',word))
    word_list6=[re.sub('[^0-9]','',word) for word in word_list5]
    #print("-".join(word_list6))
    print(re.sub('-+', '-', "-".join(word_list6).strip("-")))
    info_list.append(re.sub('-+', '-', "-".join(word_list6).strip("-")))
    #print([re.sub('[^0-9]','', ("-".join(s)).replace("・","").replace(".",""))for s in i])
    #print("-".join([re.sub('[^0-9]','', ("-".join(s)))for s in i]))
    #print("".join(["-".join(s) for s in i]))
#     print(re.sub('[^0-9]','', ("".join(["-".join(s) for s in i]))))
    #print("".join(i))
    #print( re.sub('[0-9]','', i))
    print("----------------")
# Out:
# 0
# 被保険者証・被保険-1080912 347-・-者手帳の記号・番号
# ['被保険者証', '被保険', '1080912', '347', '', '', '者手帳の記号', '番号']
# 1080912-347
# ----------------
# 1
# Date-IKE-tre-A
# ['Date', 'IKE', 'tre', 'A']
#
# ----------------
# 2
# 被保険者証・被保険|1910-者手帳の記号・番号|1336373
# ['被保険者証', '被保険|1910', '者手帳の記号', '番号|1336373']
# 1910-1336373
# ----------------
# 3
# 被保険者証・被保険-者手帳の記号・番号-12.5900516
# ['被保険者証', '被保険', '者手帳の記号', '番号', '12', '5900516']
# 12-5900516
# ----------------
# 4
# 被保険者証・被保険-50000013-109420-者手帳の記号・番号
# ['被保険者証', '被保険', '50000013', '109420', '者手帳の記号', '番号']
# 50000013-109420
# ----------------
# 5
# 被保険者証・被保険-9 2 4 2 0 7 09.97 5-者手帳の記号・番号
# ['被保険者証', '被保険', '9 2 4 2 0 7 09', '97', '5', '者手帳の記号', '番号']
# 92420709-97-5
# ----------------
# 6
# 18.-被保険者証・被保険-者手帳の記号・番号
# ['18', '', '被保険者証', '被保険', '者手帳の記号', '番号']
# 18
# ----------------
# 7
# 被保険者証・被保険-3230・6408-者手帳の記号・番号
# ['被保険者証', '被保険', '3230', '6408', '者手帳の記号', '番号']
# 3230-6408
# ----------------
# 8
# 概険者証・被保険 4851-手帳の記号・番号|267
# ['概険者証', '被保険', '4851', '手帳の記号', '番号|267']
# 4851-267
# ----------------
# 9
# 被保険者証・被験7410435-手帳の記号・番号12
# ['被保険者証', '被験7410435', '手帳の記号', '番号12']
# 7410435-12
# ----------------
# 10
# 被保険者証・被保険 13580774-③提出を希望されない方-|者手帳の記号・番号
# ['被保険者証', '被保険', '13580774', '③提出を希望されない方', '|者手帳の記号', '番号']
# 13580774
# ----------------
# 11
# 被保険者証・被保険 26-38. 5209-者手帳の記号・番号
# ['被保険者証', '被保険', '26', '38', '', '5209', '者手帳の記号', '番号']
# 26-38-5209
# ----------------
# 12
# 被保険者証・械-者手帳の記号・927-16-• 0 3 7 5
# ['被保険者証', '械', '者手帳の記号', '927', '16', '', ' 0 3 7 5']
# 927-16-0375
# ----------------
# 13
# 険者証・被保険-1 3 2 4 • 5 0 8-三帳の記号・番号
# ['険者証', '被保険', '1 3 2 4 ', ' 5 0 8', '三帳の記号', '番号']
# 1324-508
# ----------------
# 14
# |被保険者証・被保険-36 · 536-者手帳の記号・番号
# ['|被保険者証', '被保険', '36 · 536', '者手帳の記号', '番号']
# 36536
# ----------------
# 15
# 被保険者証・被保険10403475-者手帳の記号・番号---③提出を希望されない方は処方せ
# ['被保険者証', '被保険10403475', '者手帳の記号', '番号', '', '', '③提出を希望されない方は処方せ']
# 10403475
# ----------------
# 16
# 被保険者証・被保険 | 59160232・7-者手帳の記号・番号
# ['被保険者証', '被保険 | 59160232', '7', '者手帳の記号', '番号']
# 59160232-7
# ----------------
# 17
# 被保険者証・被保険-4 2 3 6 2 4 1 2 • 18-者手帳の記号・番号
# ['被保険者証', '被保険', '4 2 3 6 2 4 1 2 ', '', '18', '者手帳の記号', '番号']
# 42362412-18
# ----------------
# 18
# 被保険者証・被保険者-03-・-335-2943-9-手帳の記号・番号
# ['被保険者証', '被保険者', '03', '', '', '335', '2943', '9', '手帳の記号', '番号']
# 03-335-2943-9
# ----------------
# 19
# 被保険者証・被保険-100-99744-者手帳の記号・番号
# ['被保険者証', '被保険', '100', '99744', '者手帳の記号', '番号']
# 100-99744
# ----------------
# 20
# 保険者証・被保険-・01964204-手帳の記号・番号
# ['保険者証', '被保険', '', '01964204', '手帳の記号', '番号']
# 01964204
# ----------------
# 21
# 被保険者証・被保険-1 3 2 2 3 1 6.5-者手帳の記号・番号
# ['被保険者証', '被保険', '1 3 2 2 3 1 6', '5', '者手帳の記号', '番号']
# 1322316-5
# ----------------
# 22
# 被保険者証・被保険-手帳の記号・番号|3226851
# ['被保険者証', '被保険', '手帳の記号', '番号|3226851']
# 3226851
# ----------------
# 23
# 被保険者証・被保険 10428159-者手帳の記号・番号
# ['被保険者証', '被保険', '10428159', '者手帳の記号', '番号']
# 10428159
# ----------------
# 24
# 被保険者証・被保険|11843562-者手帳の記号・番号
# ['被保険者証', '被保険|11843562', '者手帳の記号', '番号']
# 11843562
# ----------------
# 25
# 被保険者証・被保険-5 3 2.61 7 5-者手帳の記号・番号
# ['被保険者証', '被保険', '5 3 2', '61 7 5', '者手帳の記号', '番号']
# 532-6175
# ----------------
# 26
# Copy Guar/-被保険者証・被保険-B-572802041-者手帳の記号・番号 1750-vard per-ger-opy-Copy Guard Pascopy Guard Paper Cor-Cor
# ['Copy', 'Guar/', '被保険者証', '被保険', 'B', '572802041', '者手帳の記号', '番号', '1750', 'vard', 'per', 'ger', 'opy', 'Copy Guard Pascopy Guard Paper Cor', 'Cor']
# 572802041-1750
# ----------------
# 27
# 保険者証・被保険」-手帳の記号・番号-2 1 3 5 0 7 2 6 • 2 1 2
# ['保険者証', '被保険」', '手帳の記号', '番号', '2 1 3 5 0 7 2 6 ', ' 2 1 2']
# 21350726-212
# ----------------
# 28
# 手帳の記号・番号-被保険者証・被保険者-.-・04354858
# ['手帳の記号', '番号', '被保険者証', '被保険者', '', '', '', '04354858']
# 04354858
# ----------------
# 29
# 被保険者証・被保険-者手帳の記号・番号-01-48.5039
# ['被保険者証', '被保険', '者手帳の記号', '番号', '01', '48', '5039']
# 01-48-5039
# ----------------

# %%
"---------".replace("--","-")
re.sub('-+', '-', "---------")
# Out:
# '-'

# %%
info_list
# Out:
# ['1080912-347',
#  '',
#  '1910-1336373',
#  '12-5900516',
#  '50000013-109420',
#  '92420709-97-5',
#  '18',
#  '3230-6408',
#  '4851-267',
#  '7410435-12',
#  '13580774',
#  '26-38-5209',
#  '927-16-0375',
#  '1324-508',
#  '30-6137087-36536',
#  '39272125-10403475',
#  '59160232-7',
#  '42362412-18',
#  '03-335-2943-9',
#  '100-99744',
#  '01964204',
#  '1322316-5',
#  '3226851',
#  '10428159',
#  '11843562',
#  '532-6175',
#  '572802041-1750',
#  '21350726-212',
#  '04354858',
#  '01-48-5039']

# %%
a = 'lkdfhisoe78347834 (())&/&745  '
result = re.sub('[^0-9]','', a)
result
# Out:
# '78347834745'

# %%
#答え合わせ
f = open('result.txt',encoding="shift-jis")
lines2 = f.readlines() # 1行毎にファイル終端まで全て読む(改行文字も含まれる)
f.close()

# %%
for i in range(len(lines2)):
    print(i)
    if lines2[i].replace("\n","")==info_list[i]:
        print("あってる")
    else:
        print("間違ってる")
        print("正解:"+str(lines2[i].replace("\n","")))
        print("予想:"+str(info_list[i]))
    print("--------------")
# Out:
# 0
# あってる
# --------------
# 1
# あってる
# --------------
# 2
# あってる
# --------------
# 3
# あってる
# --------------
# 4
# あってる
# --------------
# 5
# 間違ってる
# 正解:92420709-975
# 予想:92420709-97-5
# --------------
# 6
# 間違ってる
# 正解:
# 予想:18
# --------------
# 7
# あってる
# --------------
# 8
# あってる
# --------------
# 9
# 間違ってる
# 正解:7410435-2
# 予想:7410435-12
# --------------
# 10
# あってる
# --------------
# 11
# あってる
# --------------
# 12
# 間違ってる
# 正解:27-16-0375
# 予想:927-16-0375
# --------------
# 13
# あってる
# --------------
# 14
# 間違ってる
# 正解:36-536
# 予想:36536
# --------------
# 15
# あってる
# --------------
# 16
# あってる
# --------------
# 17
# あってる
# --------------
# 18
# あってる
# --------------
# 19
# あってる
# --------------
# 20
# あってる
# --------------
# 21
# あってる
# --------------
# 22
# あってる
# --------------
# 23
# あってる
# --------------
# 24
# あってる
# --------------
# 25
# あってる
# --------------
# 26
# 間違ってる
# 正解:57280204-1750
# 予想:572802041-1750
# --------------
# 27
# あってる
# --------------
# 28
# あってる
# --------------
# 29
# あってる
# --------------

# %%
dict_hospitalInfo_base
# Out:
# {'千葉県がんセンター': ['1', '0110684', '12'],
#  '医療法人社団福寿会 鷲見医院': ['1', '0112300', '12'],
#  '医療法人緑栄会 三愛記念そが病院': ['1', '0116814', '12'],
#  '千葉市 千葉市立青葉病院': ['1', '0118687', '12'],
#  'クリニックあしたば': ['1', '0117911', '12'],
#  '医療法人社団誠馨会 千葉メディカルセンター': ['1', '0123091', '12'],
#  '医療法人社団 大樹 大賀医院': ['1', '0123554', '12'],
#  '一般社団法人 巨樹の会 千葉みなとリハビリテーション病院': ['1', '0122895', '12'],
#  '独立行政法人国立病院機構 千葉医療センター': ['1', '9110016', '12'],
#  '国立大学法人 千葉大学医学部附属病院': ['1', '9210014', '12'],
#  '独立行政法人国立病院機構 千葉東病院': ['1', '9510058', '12'],
#  '医療法人社団翠明会 山王病院': ['1', '0113241', '12'],
#  '国立研究開発法人 量子科学技術研究開発機構 QST病院': ['1', '9110040', '12'],
#  '清和園多部田診療所': ['1', '0111070', '12'],
#  '医療法人社団創進会 みつわ台総合病院': ['1', '0116384', '12'],
#  '社会福祉法人千葉県身体障害者福祉事業団 千葉県千葉リハビリテーションセンター': ['1', '0111799', '12'],
#  '千葉県こども病院': ['1', '0113191', '12'],
#  'しののめ元山医院': ['1', '0117549', '12'],
#  '医療法人社団圭恵会 すずらんクリニック': ['1', '0123356', '12'],
#  '独立行政法人国立病院機構 下総精神医療センター': ['1', '9510066', '12'],
#  '千葉市休日救急診療所': ['1', '0114561', '12'],
#  '医療法人社団 千葉白報会 総合クリニック ドクターランド幕張': ['1', '0122697', '12'],
#  '医療法人社団究美会 肌と歯のクリニック 東京ベイ幕張': ['1', '0123539', '12'],
#  '医療法人財団みさき会 たむら記念病院': ['1', '1310713', '12'],
#  '東京歯科大学市川総合病院': ['1', '2712404', '12'],
#  '医療法人社団 瑞鶴会 鶴木クリニック医科・歯科': ['1', '2714400', '12'],
#  'タムス市川リハビリテーション病院': ['1', '2716975', '12'],
#  '国立研究開発法人国立国際医療研究センター国府台病院': ['1', '9110024', '12'],
#  '独立行政法人地域医療機能推進機構船橋中央病院': ['1', '2810018', '12'],
#  '医療法人同和会 千葉病院': ['1', '2810117', '12'],
#  '芝山医科歯科クリニック': ['1', '2813533', '12'],
#  '医療法人社団三松会 さくらクリニック': ['1', '2813863', '12'],
#  '医療法人社団誠馨会 セコメディック病院': ['1', '2814945', '12'],
#  'いけだハートクリニック 船橋駅前診療所': ['1', '2816148', '12'],
#  '船橋市立医療センター': ['1', '2811214', '12'],
#  '医療法人社団千葉白報会 総合クリニック ドクターランド船橋': ['1', '2816627', '12'],
#  '医療法人社団慈善会 ぜんり歯科内科クリニック': ['1', '2812527', '12'],
#  '医療法人社団協和会 滝不動病院': ['1', '2812204', '12'],
#  '医療法人鉄蕉会 亀田ファミリークリニック館山': ['1', '3610870', '12'],
#  '医療法人沖縄徳洲会 館山病院': ['1', '3611001', '12'],
#  '国保直営総合病院 君津中央病院': ['1', '1010149', '12'],
#  '医療法人社団志仁会 薬丸病院': ['1', '1010156', '12'],
#  '日本大学松戸歯学部付属病院': ['1', '2410546', '12'],
#  '医療法人社団慈朋会 金子医院': ['1', '2411486', '12'],
#  '医療法人沖縄徳洲会 千葉西総合病院': ['1', '2412484', '12'],
#  '松戸市立総合医療センター': ['1', '2416527', '12'],
#  '医療法人社団真療会 野田病院': ['1', '2010833', '12'],
#  '医療法人社団天榮会 茂原機能クリニック': ['1', '3111184', '12'],
#  '医療法人社団 剛裕会 須田外科・歯科医院': ['1', '3111309', '12'],
#  '医療法人社団聖母会 聖マリア記念病院': ['1', '4310322', '12'],
#  '日本赤十字社 成田赤十字病院': ['1', '4310041', '12'],
#  '成田病院': ['1', '4310058', '12'],
#  '成田市急病診療所': ['1', '4310983', '12'],
#  '医療法人社団心和会 成田リハビリテーション病院': ['1', '4312492', '12'],
#  '日本医科大学成田国際空港クリニック': ['1', '4310462', '12'],
#  '国際医療福祉大学成田病院': ['1', '4312591', '12'],
#  '佐倉市休日夜間急病診療所': ['1', '4210167', '12'],
#  '和田診療所': ['1', '4210472', '12'],
#  '医療法人静和会 浅井病院': ['1', '0810036', '12'],
#  '東千葉メディカルセンター': ['1', '0810630', '12'],
#  '夢屋診療所': ['1', '1410273', '12'],
#  '重症心身障害児施設 聖母療育園': ['1', '1410182', '12'],
#  '総合病院国保旭中央病院': ['1', '1411255', '12'],
#  '社会医療法人社団菊田会 習志野第一病院': ['1', '0210047', '12'],
#  '社会福祉法人恩賜財団済生会支部千葉県済生会 千葉県済生会 習志野病院': ['1', '0210971', '12'],
#  '医療法人社団柏水会 初石病院': ['1', '2110062', '12'],
#  '医療法人社団秀和会 秀和会クリニック': ['1', '2111995', '12'],
#  '医療法人社団天宣会 北柏リハビリ総合病院': ['1', '2112423', '12'],
#  '医療法人社団協友会 柏厚生総合病院': ['1', '2114866', '12'],
#  '公益財団法人柏市医療公社 医療センター': ['1', '2115095', '12'],
#  '社会医療法人社団蛍水会 名戸ケ谷病院付属名戸ケ谷診療所': ['1', '2112258', '12'],
#  '社会医療法人社団蛍水会 名戸ヶ谷病院': ['1', '2116259', '12'],
#  '国立研究開発法人国立がん研究センター東病院': ['1', '9110057', '12'],
#  '千葉県循環器病センター': ['1', '0610162', '12'],
#  '独立行政法人 労働者健康安全機構 千葉労災病院': ['1', '0610147', '12'],
#  '市原市急病センター': ['1', '0610774', '12'],
#  '帝京大学ちば総合医療センター': ['1', '0610634', '12'],
#  '流山市平日夜間・休日診療所': ['1', '2310431', '12'],
#  '医療法人社団心和会 新八千代病院': ['1', '0410308', '12'],
#  '医療法人社団心和会 八千代病院': ['1', '0410464', '12'],
#  '東京女子医科大学附属八千代医療センター': ['1', '0411736', '12'],
#  '我孫子市休日診療所': ['1', '2510725', '12'],
#  '医療法人緑生会 あびこクリニック': ['1', '2510840', '12'],
#  '天龍堂クリニック': ['1', '2511178', '12'],
#  '医療法人社団聖仁会 我孫子聖仁会病院': ['1', '2511087', '12'],
#  '医療法人鉄蕉会 亀田総合病院': ['1', '3910221', '12'],
#  '亀田クリニック': ['1', '3910270', '12'],
#  '鴨川市立国保病院': ['1', '3911021', '12'],
#  '医療法人社団宏和会 エビハラ病院': ['1', '3910163', '12'],
#  '医療法人梨香会 秋元病院': ['1', '2610335', '12'],
#  '医療法人沖縄徳洲会 鎌ケ谷総合病院': ['1', '2610889', '12'],
#  '医療法人社団君津あすなろ会 あすなろクリニック': ['1', '1110717', '12'],
#  'あさひクリニック': ['1', '4410643', '12'],
#  '医療法人沖縄徳洲会 四街道徳洲会病院': ['1', '4410833', '12'],
#  '独立行政法人国立病院機構 下志津病院': ['1', '9510033', '12'],
#  '千葉県袖ヶ浦福祉センター': ['1', '0910240', '12'],
#  '東京都千葉福祉園診療所': ['1', '0910265', '12'],
#  '医療法人社団良康会 福王台皮膚科歯科': ['1', '0910653', '12'],
#  '医療法人みつや会 新八街総合病院': ['1', '4510079', '12'],
#  '日本医科大学千葉北総病院': ['1', '4111134', '12'],
#  '医療法人社団 昭桜会 桜台メディカルクリニック': ['1', '4710463', '12'],
#  '千葉県立佐原病院': ['1', '5210067', '12'],
#  '香取おみがわ医療センター': ['1', '5210703', '12'],
#  'さんむ医療センター': ['1', '5310354', '12'],
#  '医療法人社団仁和会 睦岡クリニック': ['1', '5310347', '12'],
#  '髙根病院': ['1', '0711358', '12'],
#  '長谷川医院': ['1', '0100602', '12'],
#  '松本医院': ['1', '0101980', '12'],
#  '医療法人グリーンエミネンス 中村古峡記念病院': ['1', '0110163', '12'],
#  '医療法人社団普照会 井上記念病院': ['1', '0110171', '12'],
#  '医療法人柏葉会 柏戸病院': ['1', '0110197', '12'],
#  '医療法人 三橋病院': ['1', '0110262', '12'],
#  '医療法人学而会 木村病院': ['1', '0110304', '12'],
#  '医療法人 石郷岡病院': ['1', '0110502', '12'],
#  '千葉県精神保健福祉センター': ['1', '0110627', '12'],
#  '独立行政法人地域医療機能推進機構 千葉病院': ['1', '0110635', '12'],
#  '一般社団法人千葉衛生福祉協会 千葉診療所': ['1', '0110668', '12'],
#  '医療法人社団福生会 斎藤労災病院': ['1', '0110700', '12'],
#  '千葉セントラル神経科クリニック': ['1', '0111674', '12'],
#  '新千葉医院': ['1', '0111773', '12'],
#  '山崎皮膚科医院': ['1', '0112763', '12'],
#  '浜田小児科医院': ['1', '0112854', '12'],
#  '医療法人 椎名内科医院': ['1', '0112979', '12'],
#  '西千葉眼科医院': ['1', '0113076', '12'],
#  '医療法人社団一陽会 髙部内科医院': ['1', '0113175', '12'],
#  '林内科医院': ['1', '0113209', '12'],
#  '髙木整形外科': ['1', '0113423', '12'],
#  '医療法人社団仁静堂 平山整形外科・外科医院': ['1', '0113522', '12'],
#  '医療法人社団伸幸会 登戸クリニック': ['1', '0113571', '12'],
#  '山崎整形外科医院': ['1', '0113910', '12'],
#  '医療法人社団有馬会 有馬外科胃腸科': ['1', '0114025', '12'],
#  '木村整形外科': ['1', '0114108', '12'],
#  '医療法人社団翔葉会 今井医院': ['1', '0114389', '12'],
#  '医療法人社団峰明会 青木内科医院': ['1', '0114413', '12'],
#  '医療法人社団巖会 あさひ眼科医院': ['1', '0114504', '12'],
#  '久保小児科内科': ['1', '0114512', '12'],
#  '医療法人社団清弘会 神田内科医院': ['1', '0114520', '12'],
#  '医療法人社団青光会 今井町診療所': ['1', '0114553', '12'],
#  '医療法人社団仁威会 実川外科医院': ['1', '0114603', '12'],
#  '医療法人社団望葉会 日下医院': ['1', '0114710', '12'],
#  '医療法人社団柏陽会 柏木産婦人科': ['1', '0114751', '12'],
#  '新宿外科医院': ['1', '0114793', '12'],
#  '医療法人社団博洋会 大濱医院': ['1', '0114801', '12'],
#  '医療法人社団椿森会 椿森クリニック': ['1', '0114868', '12'],
#  'わたなべ整形外科': ['1', '0114942', '12'],
#  'もり内科クリニック': ['1', '0115014', '12'],
#  '千葉眼科': ['1', '0115105', '12'],
#  '医療法人社団春光会 千葉市役所前クリニック': ['1', '0115410', '12'],
#  '榎本医院': ['1', '0115972', '12'],
#  '医療法人緑栄会 三愛記念病院': ['1', '0115980', '12'],
#  '医療法人社団細川会 えりやま内科皮膚科医院': ['1', '0116020', '12'],
#  '医療法人社団宗仙会 山口耳鼻咽喉科': ['1', '0116095', '12'],
#  'ちば宇津木皮膚科': ['1', '0116129', '12'],
#  '医療法人志方記念会 三木クリニック': ['1', '0116228', '12'],
#  '医療法人社団ヘルスアンドスポーツ会 鍋島整形外科': ['1', '0116269', '12'],
#  '医療法人社団生実会 ホタカ整形外科': ['1', '0116319', '12'],
#  '亘内科医院': ['1', '0116442', '12'],
#  '千葉クリニック': ['1', '0116822', '12'],
#  '青柳内科クリニック': ['1', '0116939', '12'],
#  '武本眼科医院': ['1', '0116996', '12'],
#  '医療法人社団澤泉会 矢澤内科医院': ['1', '0117317', '12'],
#  'ジツカワ眼科': ['1', '0117507', '12'],
#  '医療法人社団 和田医院': ['1', '0117515', '12'],
#  'しまだ医院': ['1', '0117614', '12'],
#  '本千葉メンタルクリニック': ['1', '0117770', '12'],
#  '小野寺産婦人科': ['1', '0117879', '12'],
#  '医療法人社団 喜美会 自由が丘クリニックソフィア': ['1', '0117887', '12'],
#  '医療法人社団 至心会 田那村内科小児科医院': ['1', '0118000', '12'],
#  '医療法人社団 煌和会 國分クリニック': ['1', '0118018', '12'],
#  '島野眼科医院': ['1', '0118083', '12'],
#  'るみえ内科小児科': ['1', '0118109', '12'],
#  '医療法人社団 惇友会 荒井眼科': ['1', '0118265', '12'],
#  '医療法人社団 豊賀會 吉井耳鼻咽喉科医院': ['1', '0118281', '12'],
#  'ヒロ耳鼻科クリニック': ['1', '0118364', '12'],
#  '和康会産婦人科健康診断クリニック': ['1', '0118398', '12'],
#  '千葉寺駅前眼科': ['1', '0118414', '12'],
#  '医療法人社団桐和会 桐原クリニック': ['1', '0118497', '12'],
#  '公益財団法人ちば県民保健予防財団 千葉県庁医務室': ['1', '0118620', '12'],
#  '小松﨑耳鼻咽喉科': ['1', '0118679', '12'],
#  '社会医療法人社団同仁会 そが西口クリニック': ['1', '0118877', '12'],
#  '医療法人社団 松石会 松石内科医院': ['1', '0118927', '12'],
#  '岡田医院': ['1', '0119149', '12'],
#  'つばきこどもクリニック': ['1', '0119206', '12'],
#  '医療法人社団春鈴会 寺田クリニック': ['1', '0119404', '12'],
#  '医療法人社団晃知会 小浜内科外科クリニック': ['1', '0119438', '12'],
#  '医療法人社団豊流会 ツチダクリニック': ['1', '0119461', '12'],
#  '山口内科外科クリニック': ['1', '0119487', '12'],
#  '西川泌尿器科クリニック': ['1', '0119560', '12'],
#  '東千葉クリニック': ['1', '0119776', '12'],
#  '長谷川胃腸科クリニック': ['1', '0119818', '12'],
#  '医療法人社団青稜会 そが皮膚科': ['1', '0119875', '12'],
#  'こいで内科消化器科クリニック': ['1', '0119917', '12'],
#  '一般財団法人柏戸記念財団 ポートスクエア柏戸クリニック': ['1', '0119933', '12'],
#  '中野耳鼻咽喉科医院': ['1', '0120022', '12'],
#  '千葉そごう眼科診療所': ['1', '0120048', '12'],
#  'くすの木クリニック': ['1', '0120220', '12'],
#  '医療法人社団恵昭会 千葉駅前クリニック': ['1', '0120345', '12'],
#  '西千葉クリニック': ['1', '0120386', '12'],
#  '医療法人社団鎮誠会 千葉きぼーるクリニック': ['1', '0120667', '12'],
#  '医療法人社団 のわび会 医療法人社団 のわび会 そがこどもクリニック': ['1', '0120915', '12'],
#  '医療法人社団英正会 けやき眼科クリニック': ['1', '0120998', '12'],
#  '千葉中央こころのクリニック': ['1', '0121004', '12'],
#  '医療法人社団 貴祥会 耳鼻咽喉科なかのクリニック': ['1', '0121277', '12'],
#  '医療法人社団桃李会 なかしまクリニック': ['1', '0121335', '12'],
#  '医療法人社団 ゆう ゆうクリニック': ['1', '0121459', '12'],
#  '医療法人社団 西千葉皮膚科クリニック': ['1', '0121608', '12'],
#  '本千葉小児科': ['1', '0121616', '12'],
#  '医療法人社団あい 増田病院': ['1', '0121632', '12'],
#  '社会福祉法人淑徳福祉会 淑徳おゆみ診療所': ['1', '0121772', '12'],
#  '上田医院': ['1', '0121889', '12'],
#  'ちば美容・形成外科クリニック': ['1', '0121996', '12'],
#  '医療法人社団 千葉中央クリニック': ['1', '0122028', '12'],
#  '医療法人社団 とのおか眼科': ['1', '0122176', '12'],
#  '菫ホームクリニック': ['1', '0122317', '12'],
#  '千葉駅前心療内科': ['1', '0122424', '12'],
#  '医療法人同和会 脳神経内科千葉': ['1', '0122440', '12'],
#  '医療法人 学而会 弁天メンタルクリニック': ['1', '0122465', '12'],
#  '医療法人社団爽風会 心の風クリニック千葉': ['1', '0122473', '12'],
#  '医療法人社団純衛会 越川内科医院': ['1', '0122523', '12'],
#  '医療法人社団 彤柱会 みやこ整形外科クリニック': ['1', '0122549', '12'],
#  'すみれ眼科': ['1', '0122556', '12'],
#  '千葉シーサイドクリニック': ['1', '0122564', '12'],
#  '医療法人社団 千葉寺駅前整形外科': ['1', '0122572', '12'],
#  '医療法人社団飛鵬会 わかばクリニック': ['1', '0122598', '12'],
#  '医療法人社団双寿 ちぐさ会クリニック': ['1', '0122614', '12'],
#  '医療法人社団春日会 椎名内科': ['1', '0122689', '12'],
#  '西千葉麻酔科クリニック': ['1', '0122713', '12'],
#  '医療法人健志会 白旗整形外科内科': ['1', '0122739', '12'],
#  '医療法人社団 中村内科クリニック': ['1', '0122754', '12'],
#  'みなとこどもクリニック': ['1', '0122846', '12'],
#  '千葉訪問皮膚科': ['1', '0122853', '12'],
#  '医療法人社団報徳会 報徳千葉診療所': ['1', '0122887', '12'],
#  '医療法人社団琴誠会 いそのメディカルクリニック': ['1', '0122929', '12'],
#  '医療法人社団 米満内科医院': ['1', '0122978', '12'],
#  '医療法人財団 明理会 千葉ロイヤルクリニック': ['1', '0122986', '12'],
#  'そがメンタルクリニック': ['1', '0123059', '12'],
#  '医療法人社団 桜治会 赤坂皮フ科クリニック': ['1', '0123067', '12'],
#  '医療法人社団壮和会 ゆりの木クリニック': ['1', '0123075', '12'],
#  '旭町診療所': ['1', '0123166', '12'],
#  '千葉あおばクリニック': ['1', '0123174', '12'],
#  '医療法人社団瑛美会 千葉スキンケアクリニック': ['1', '0123208', '12'],
#  'そがリウマチ・整形外科': ['1', '0123232', '12'],
#  '千葉静脈瘤クリニック': ['1', '0123257', '12'],
#  '医療法人社団 緑萌会 高橋ウイメンズクリニック': ['1', '0123265', '12'],
#  'ゆかわクリニック': ['1', '0123273', '12'],
#  '医療法人社団 千葉中央ひかりクリニック': ['1', '0123331', '12'],
#  '医療法人社団マザー・キー なのはなクリニック': ['1', '0123364', '12'],
#  '医療法人社団童心会 若杉こどもクリニック': ['1', '0123398', '12'],
#  'ふたば訪問クリニック': ['1', '0123489', '12'],
#  '医療法人社団日敏会 浜野長嶋内科': ['1', '0123505', '12'],
#  '鍋嶋眼科医院': ['1', '0123513', '12'],
#  '千葉あおぞらクリニック': ['1', '0123638', '12'],
#  'ちばの根岸眼科': ['1', '0123646', '12'],
#  '医療法人社団 雄恵会 こもだクリニック': ['1', '0123661', '12'],
#  'にへい脳外科': ['1', '0123729', '12'],
#  '医療法人浄光会 千葉みなと病院': ['1', '0123794', '12'],
#  'HSクリニック': ['1', '0123828', '12'],
#  '医療法人社団水野胃腸科・内科': ['1', '0123885', '12'],
#  'アイクリニック千葉': ['1', '0123893', '12'],
#  '医療法人社団だいだい 千葉駅すばるクリニック': ['1', '0123927', '12'],
#  '医療法人社団城東桐和会 千葉駅総合クリニック': ['1', '0123935', '12'],
#  '医療法人社団純英会 赤井町クリニック': ['1', '0123968', '12'],
#  '千葉レディースクリニック': ['1', '0123976', '12'],
#  '医療法人社団弘恵会 そが内科小児科クリニック': ['1', '0124024', '12'],
#  '医療法人社団Blue Bird 青い鳥クリニック千葉': ['1', '0124123', '12'],
#  'りべるたすクリニック': ['1', '0124131', '12'],
#  'みらいクリニック': ['1', '0124198', '12'],
#  '医療法人社団青水会 ふくろうアイクリニック': ['1', '0124222', '12'],
#  'いそむら内科': ['1', '0124248', '12'],
#  '野井レディースクリニック': ['1', '0124263', '12'],
#  '東京ビジネスクリニックペリエ千葉エキナカ': ['1', '0124297', '12'],
#  '千葉汐見丘メンタルクリニック': ['1', '0124347', '12'],
#  '医療法人社団 千心会 市川クリニック': ['1', '0124370', '12'],
#  '山田整形外科医院': ['1', '0124438', '12'],
#  '医療法人社団夢双会 千葉中央スタークリニック': ['1', '0124461', '12'],
#  'メディカルスキャニング千葉': ['1', '0124529', '12'],
#  '霜整形外科医院': ['1', '0124537', '12'],
#  'さくさべ坂通り診療所': ['1', '0124628', '12'],
#  'ちば下肢静脈瘤クリニック': ['1', '0124636', '12'],
#  '医療法人社団響心会 東千葉ホームクリニック': ['1', '0124644', '12'],
#  'みんなのライフサポートクリニック蘇我': ['1', '0124669', '12'],
#  '奈良内科医院': ['1', '0103085', '12'],
#  '田井耳鼻咽喉科アレルギー科': ['1', '0103218', '12'],
#  '田井小児科眼科心療内科': ['1', '0103226', '12'],
#  '諏訪部産婦人科': ['1', '0103283', '12'],
#  '脊尾内科小児科': ['1', '0103382', '12'],
#  '医療法人社団晴山会 平山病院': ['1', '0110767', '12'],
#  '社会医療法人社団千葉県勤労者医療協会 花園診療所': ['1', '0110791', '12'],
#  '石橋内科小児科医院': ['1', '0111450', '12'],
#  '善利医院': ['1', '0112060', '12'],
#  '袖ヶ浦外科': ['1', '0112243', '12'],
#  '向井医院': ['1', '0112409', '12'],
#  '伊東内科医院': ['1', '0112953', '12'],
#  '医療法人社団幸有会 幸有会記念病院 ': ['1', '0113050', '12'],
#  '医療法人社団津田会 津田胃腸科医院': ['1', '0113563', '12'],
#  '医療法人社団敬仁会 神田耳鼻咽喉科医院': ['1', '0113720', '12'],
#  '医療法人社団隆陽会 さつきが丘医院': ['1', '0114017', '12'],
#  '医療法人社団悠啓会 いまにし医院': ['1', '0114124', '12'],
#  '眞清クリニック': ['1', '0114314', '12'],
#  '小池医院': ['1', '0114371', '12'],
#  '医療法人社団信和会 小泉医院': ['1', '0114611', '12'],
#  '医療法人社団 伯野外科胃腸科': ['1', '0114843', '12'],
#  'さこう医院': ['1', '0115089', '12'],
#  '幕張台クリニック': ['1', '0115162', '12'],
#  '三上眼科医院': ['1', '0115170', '12'],
#  'ちぐさ診療所': ['1', '0115246', '12'],
#  '本郷内科': ['1', '0115253', '12'],
#  '医療法人社団有相会 最成病院': ['1', '0115675', '12'],
#  '医療法人社団なのはな会 幕張本郷クリニック': ['1', '0116012', '12'],
#  '安久津眼科': ['1', '0116558', '12'],
#  '医療法人社団竹田会 武藤医院': ['1', '0117150', '12'],
#  'ちば整形外科クリニック': ['1', '0117192', '12'],
#  '幕張本郷耳鼻咽喉科医院': ['1', '0117747', '12'],
#  '医療法人社団栗田会 栗田皮フ科': ['1', '0117812', '12'],
#  '古川医院': ['1', '0118141', '12'],
#  '医療法人社団 恵佑会 元山医院': ['1', '0118273', '12'],
#  'おざきクリニック': ['1', '0118380', '12'],
#  '医療法人社団 小羊会 千葉横戸クリニック': ['1', '0118471', '12'],
#  '医療法人社団 善秀会 朝日ヶ丘医院': ['1', '0118992', '12'],
#  '千葉健生病院付属まくはり診療所': ['1', '0119172', '12'],
#  '社会医療法人社団千葉県勤労者医療協会 千葉健生病院': ['1', '0119180', '12'],
#  'ひらおか内科クリニック': ['1', '0119255', '12'],
#  '医療法人社団千秋双葉会 幕張耳鼻咽喉科': ['1', '0119453', '12'],
#  '医療法人社団 あおやぎ眼科': ['1', '0119545', '12'],
#  'メンタルクリニック とみた': ['1', '0119594', '12'],
#  '医療法人社団誠徳会 藤森小児科': ['1', '0119602', '12'],
#  '坂口医院': ['1', '0120089', '12'],
#  '幕張あんず医院': ['1', '0120261', '12'],
#  '医療法人静和会 新検見川メンタルクリニック': ['1', '0120337', '12'],
#  '医療法人杏会 松本クリニック': ['1', '0120451', '12'],
#  '医療法人社団咲心会 和久整形外科': ['1', '0120535', '12'],
#  'いけだメディカルクリニック': ['1', '0120584', '12'],
#  '水野医院': ['1', '0120626', '12'],
#  '医療法人社団 素心館 小林こどもクリニック': ['1', '0120634', '12'],
#  '医療法人社団 正心会 正岡クリニック': ['1', '0120691', '12'],
#  '医療法人社団 花也会 Wクリニックフォーマザーズ幕張': ['1', '0120790', '12'],
#  '本郷眼科': ['1', '0121194', '12'],
#  '信愛クリニック': ['1', '0121319', '12'],
#  '医療法人社団 紫陽花会 落合皮膚科': ['1', '0121392', '12'],
#  '医療法人社団オー・エフ・シー 大森ファミリークリニック': ['1', '0121426', '12'],
#  '医療法人社団聖鳥会 しらゆり眼科': ['1', '0121442', '12'],
#  '本郷並木通り内科': ['1', '0121475', '12'],
#  '宇田川婦人科': ['1', '0121517', '12'],
#  '田村ゆみこ内科クリニック': ['1', '0121525', '12'],
#  '幕張整形外科': ['1', '0121574', '12'],
#  '医療法人社団あおぞら 野瀬はなぞのクリニック': ['1', '0121673', '12'],
#  '幕張おおで眼科': ['1', '0121723', '12'],
#  'たかクリニック': ['1', '0121731', '12'],
#  '医療法人社団MSC 幕張本郷しぶやクリニック': ['1', '0122010', '12'],
#  '医療法人社団 貴駿 幕張本郷整形外科内科': ['1', '0122200', '12'],
#  '医療法人社団 ゆかり会 幕張胃腸クリニック': ['1', '0122499', '12'],
#  '医療法人社団千秋双葉会 幕張キッズクリニック': ['1', '0122622', '12'],
#  '医療法人社団彩心会 花見川ひかり整形外科': ['1', '0122655', '12'],
#  '医療法人健志会 検見川整形外科内科': ['1', '0122770', '12'],
#  '医療法人社団 有光会 花見川眼科': ['1', '0122788', '12'],
#  '医療法人社団江楓会 あかいし脳神経外科クリニック': ['1', '0122812', '12'],
#  '医療法人社団晴山会 平山病院附属 花見川腎クリニック': ['1', '0122838', '12'],
#  'ひろ内科クリニック': ['1', '0122952', '12'],
#  '医療法人社団 福医会 たなか内科クリニック': ['1', '0123034', '12'],
#  '医療法人社団 順啓会 ほしなが耳鼻咽喉科': ['1', '0123125', '12'],
#  '医療法人社団旺仁会 東山整形外科': ['1', '0123182', '12'],
#  '医療法人社団オリーブ会 いとう新検見川クリニック': ['1', '0123190', '12'],
#  '幕張あいけいクリニック': ['1', '0123224', '12'],
#  '医療法人社団恵翔会 岩田こどもクリニック': ['1', '0123612', '12'],
#  '医療法人社団恵翔会 アリス耳鼻咽喉科': ['1', '0123620', '12'],
#  '花見川中央クリニック': ['1', '0123653', '12'],
#  '医療法人社団緑隆会 みどり耳鼻咽喉科': ['1', '0123703', '12'],
#  '石川小児科医院': ['1', '0123711', '12'],
#  '一般社団法人共進会 まくはり南クリニック': ['1', '0123745', '12'],
#  '入江眼科医院': ['1', '0123760', '12'],
#  '社会福祉法人 煌徳会 般若クリニック': ['1', '0123786', '12'],
#  '検見川ウィメンズクリニック': ['1', '0124032', '12'],
#  'えじま 医院': ['1', '0124156', '12'],
#  '医療法人社団三水会 北千葉整形外科幕張クリニック': ['1', '0124164', '12'],
#  '南花園クリニック': ['1', '0124255', '12'],
#  '医療法人社団桜誠会 桜並木心療医院': ['1', '0124305', '12'],
#  'あつみ眼科': ['1', '0124586', '12'],
#  'いちのせ耳鼻咽喉科': ['1', '0124610', '12'],
#  '幕張不整脈クリニック': ['1', '0124677', '12'],
#  '医療法人社団恵佑会 宮野木台クリニック': ['1', '0124685', '12'],
#  '柴田医院': ['1', '0103895', '12'],
#  '社会医療法人社団千葉県勤労者医療協会 北部診療所': ['1', '0111039', '12'],
#  '小林眼科医院': ['1', '0111310', '12'],
#  '谷口眼科クリニック': ['1', '0111658', '12'],
#  '三枝整形外科医院': ['1', '0112631', '12'],
#  '鈴木眼科': ['1', '0113043', '12'],
#  '大塚クリニック': ['1', '0113340', '12'],
#  'たじま産婦人科': ['1', '0113480', '12'],
#  '医療法人社団薬王会 緑町診療所': ['1', '0113506', '12'],
#  '黒砂皮膚科医院': ['1', '0114041', '12'],
#  '医療法人社団光知会 千葉健康クリニック': ['1', '0114298', '12'],
#  '医療法人社団光正会 川島医院': ['1', '0114454', '12'],
#  '医療法人社団仁正会 神津医院': ['1', '0114629', '12'],
#  '医療法人社団山紫会 谷嶋医院': ['1', '0114637', '12'],
#  '医療法人社団以仁会 稲毛サティクリニック': ['1', '0114918', '12'],
#  'にしちば心和クリニック': ['1', '0115451', '12'],
#  '医療法人社団北滋会 中川産婦人科': ['1', '0115469', '12'],
#  '医療法人社団東伸会 井原医院': ['1', '0115634', '12'],
#  '医療法人社団清雄会 宇井内科クリニック': ['1', '0115741', '12'],
#  '社会医療法人社団健脳会 千葉脳神経外科病院': ['1', '0115758', '12'],
#  '医療法人社団 みうらクリニック': ['1', '0116236', '12'],
#  '鈴木内科クリニック': ['1', '0116491', '12'],
#  '岡本皮膚科': ['1', '0116970', '12'],
#  'しんわクリニック・稲毛': ['1', '0117119', '12'],
#  '勝又内科医院': ['1', '0117267', '12'],
#  '稲毛整形外科': ['1', '0117622', '12'],
#  '髙橋こどもクリニック': ['1', '0117796', '12'],
#  '栄光クリニック': ['1', '0117861', '12'],
#  '医療法人社団ふけ会 富家千葉病院': ['1', '0118042', '12'],
#  'けいよう内科クリニック': ['1', '0118059', '12'],
#  '愛和クリニック': ['1', '0118356', '12'],
#  '医療法人社団 三康会 田中クリニック': ['1', '0118521', '12'],
#  '池上内科医院': ['1', '0118588', '12'],
#  '医療法人社団 三水会 北千葉整形外科稲毛クリニック': ['1', '0118836', '12'],
#  '露崎こどもクリニック': ['1', '0118968', '12'],
#  '木内クリニック': ['1', '0119107', '12'],
#  '山田医院': ['1', '0119115', '12'],
#  '近藤医院': ['1', '0119131', '12'],
#  'なかむら泌尿器科': ['1', '0119230', '12'],
#  'のむら耳鼻咽喉科': ['1', '0119305', '12'],
#  '医療法人社団至峰会 千草台なかむらクリニック': ['1', '0119529', '12'],
#  '赤塚小児科医院': ['1', '0119578', '12'],
#  '武田クリニック': ['1', '0119586', '12'],
#  '水上医院': ['1', '0119719', '12'],
#  '医療法人社団Vision Quest Japan 吉田眼科': ['1', '0119826', '12'],
#  'ちば生活習慣病内科クリニック': ['1', '0119867', '12'],
#  '菅沼医院': ['1', '0120055', '12'],
#  '医療法人社団 稲毛皮フ科クリニック': ['1', '0120097', '12'],
#  '武久レディースクリニック': ['1', '0120121', '12'],
#  '医療法人社団遊山会 耳鼻咽喉科サージセンターちば': ['1', '0120329', '12'],
#  '長沼眼科': ['1', '0120360', '12'],
#  '医療法人社団親月会 千葉中央外科内科': ['1', '0120378', '12'],
#  '医療法人社団元志会 いなげ耳鼻咽喉科': ['1', '0120428', '12'],
#  '医療法人社団明香会 カヤマ内科泌尿器科': ['1', '0120444', '12'],
#  'せんげん通りクリニック': ['1', '0121020', '12'],
#  '林医院': ['1', '0121046', '12'],
#  '医療法人社団康葉会 稲毛整形外科クリニック': ['1', '0121129', '12'],
#  '千葉メンタルクリニック': ['1', '0121137', '12'],
#  '稲毛中央外科医院': ['1', '0121145', '12'],
#  '医療法人社団 千葉糖尿病内科会 しいなクリニック': ['1', '0121186', '12'],
#  '医療法人社団松育会 むらまつクリニック': ['1', '0121244', '12'],
#  '医療法人社団 幸葉会 西千葉整形外科': ['1', '0121434', '12'],
#  '医療法人社団三育会 宮野木外科・内科': ['1', '0121467', '12'],
#  '稲毛バースクリニック': ['1', '0121756', '12'],
#  '医療法人社団マリヤ・クリニック': ['1', '0121855', '12'],
#  '社会福祉法人生活クラブ 生活クラブ風の村園生診療所': ['1', '0121970', '12'],
#  '医療法人社団 新藤医院': ['1', '0122234', '12'],
#  '医療法人社団ティ&ケイ くろさきこどもクリニック': ['1', '0122242', '12'],
#  '医療法人社団 翠明会 山王整形クリニック': ['1', '0122275', '12'],
#  '稲毛むらさき内科クリニック': ['1', '0122309', '12'],
#  'たけだ眼科': ['1', '0122341', '12'],
#  '医療法人社団 公伸会 黒砂台診療所': ['1', '0122457', '12'],
#  '医療法人社団亮山会 わかば皮膚科': ['1', '0122648', '12'],
#  '医療法人社団ガラテア ぴあーすクリニック': ['1', '0122994', '12'],
#  'あおきこどもクリニック': ['1', '0123141', '12'],
#  'スラージュ内科クリニック': ['1', '0123281', '12'],
#  'かまだ皮フ科': ['1', '0123307', '12'],
#  '医療法人社団AZMEDICAL 小中台クリニック': ['1', '0123406', '12'],
#  '稲毛神経内科・メモリークリニック': ['1', '0123596', '12'],
#  '医療法人社団 十誠会 川上診療所': ['1', '0123687', '12'],
#  '医療法人社団 永福会 永井クリニック': ['1', '0123919', '12'],
#  '石川医院': ['1', '0123943', '12'],
#  '医療法人社団駿心会 いなげ西病院': ['1', '0124107', '12'],
#  '医療法人社団幸訪会 いなげファミリー内科クリニック': ['1', '0124115', '12'],
#  '医療法人社団駿心会 いなげ腎クリニック': ['1', '0124180', '12'],
#  '医療法人社団駿心会 稲毛病院': ['1', '0124206', '12'],
#  '医療法人社団福寿会 千葉北眼科': ['1', '0124271', '12'],
#  '医療法人社団千葉ハート 千葉ハートクリニック': ['1', '0124289', '12'],
#  '医療法人社団ことら会 稲毛とらのこ産婦人科': ['1', '0124313', '12'],
#  '医療法人社団十誠会 川上診療所分院': ['1', '0124321', '12'],
#  '医療法人社団佐々木記念会 千葉北佐々木クリニック': ['1', '0124362', '12'],
#  '医療法人社団修生会 大岩眼科': ['1', '0124453', '12'],
#  '医療法人社団 直心会 轟クリニック': ['1', '0124503', '12'],
#  '千葉在宅診療クリニック': ['1', '0124560', '12'],
#  '医療法人社団響心会 稲毛駅前ホームクリニック': ['1', '0124578', '12'],
#  '都賀診療所': ['1', '0102863', '12'],
#  '工藤内科医院': ['1', '0103671', '12'],
#  '平沢小児科': ['1', '0103853', '12'],
#  'みつわ台中央診療所': ['1', '0111047', '12'],
#  '出口眼科医院': ['1', '0111971', '12'],
#  '都賀眼科クリニック': ['1', '0113019', '12'],
#  '勝俣内科小児科': ['1', '0113100', '12'],
#  '高品クリニック': ['1', '0113126', '12'],
#  '前田皮膚科医院': ['1', '0113316', '12'],
#  '水野内科循環器科医院': ['1', '0113365', '12'],
#  '医療法人社団聖洋会 みつわ台クリニック': ['1', '0113621', '12'],
#  '医療法人社団誠馨会 総泉病院': ['1', '0113654', '12'],
#  '医療法人社団六治会 石渡内科': ['1', '0113779', '12'],
#  '医療法人社団 こま内科・呼吸器内科': ['1', '0113803', '12'],
#  '医療法人社団亮山会 つが皮膚科医院': ['1', '0114363', '12'],
#  '高圓内科医院': ['1', '0114702', '12'],
#  '医療法人社団誠馨会 千葉中央メディカルセンター': ['1', '0114728', '12'],
#  '医療法人社団興仁会 板谷内科クリニック': ['1', '0114926', '12'],
#  '高根町整形外科': ['1', '0115279', '12'],
#  'なかむら医院': ['1', '0115394', '12'],
#  '医療法人社団青草会 篠﨑病院': ['1', '0115824', '12'],
#  '医療法人社団明生会 東葉クリニック千葉': ['1', '0115832', '12'],
#  '医療法人社団邦葉会 小山内科': ['1', '0115949', '12'],
#  'あべひろきこどもクリニック': ['1', '0115956', '12'],
#  '医療法人社団 中山内科クリニック': ['1', '0116053', '12'],
#  '千葉内科クリニック': ['1', '0116251', '12'],
#  '医療法人社団鳳仁会 若林皮膚科医院': ['1', '0117374', '12'],
#  '一般財団法人柏戸記念財団 小倉台柏戸クリニック': ['1', '0117424', '12'],
#  '医療法人社団 祐紀会 小松耳鼻咽喉科医院': ['1', '0117457', '12'],
#  '医療法人社団若竹会宮内泌尿器科医院': ['1', '0117481', '12'],
#  'ちしろ台眼科': ['1', '0117713', '12'],
#  '医療法人社団謙和会 高品内科婦人科医院': ['1', '0117820', '12'],
#  '医療法人社団 榎会 千城台クリニック': ['1', '0118182', '12'],
#  '医療法人社団芳旭会 小関医院': ['1', '0118216', '12'],
#  '医療法人社団 都賀内科クリニック': ['1', '0118513', '12'],
#  'つがクリニック': ['1', '0118828', '12'],
#  '千葉市大宮学園': ['1', '0119198', '12'],
#  '医療法人社団長寿会 長谷川整形外科': ['1', '0119370', '12'],
#  '久保田医院': ['1', '0119396', '12'],
#  '医療法人社団若葉会 若葉整形外科クリニック': ['1', '0119511', '12'],
#  '堀田医院': ['1', '0119628', '12'],
#  '医療法人社団颯晃会 御成台整形外科': ['1', '0119958', '12'],
#  '千葉市桜木園': ['1', '0120154', '12'],
#  '医療法人社団志栄会 都賀レディースクリニック': ['1', '0120162', '12'],
#  '松永クリニック小児科・小児外科': ['1', '0120196', '12'],
#  '篠クリニック': ['1', '0120295', '12'],
#  '医療法人社団千葉いずみ会 泉中央病院': ['1', '0120543', '12'],
#  '医療法人社団 クレド 医療法人社団 クレド さとうクリニック': ['1', '0120873', '12'],
#  '清宮医院': ['1', '0120931', '12'],
#  'ふるかわクリニック': ['1', '0121327', '12'],
#  '医療法人社団 ひよこ会 ぬまざわ小児科・耳鼻咽喉科クリニック': ['1', '0121343', '12'],
#  '伊予クリニック': ['1', '0121376', '12'],
#  '西都賀クリニック': ['1', '0121533', '12'],
#  '医療法人社団慈徳会 つがメンタルクリニック': ['1', '0121657', '12'],
#  'たて産婦人科': ['1', '0121921', '12'],
#  'あおばクリニック': ['1', '0122002', '12'],
#  '医療法人社団淳朋会 都賀さいとう整形外科': ['1', '0122044', '12'],
#  '医療法人社団桐伸会 藤井クリニック': ['1', '0122168', '12'],
#  '医療法人社団岩鷲会 つばめ耳鼻咽喉科': ['1', '0122218', '12'],
#  '医療法人社団 みぞぶち眼科': ['1', '0122382', '12'],
#  '医療法人社団 世恵会 小倉台福田医院': ['1', '0123000', '12'],
#  '楽多クリニック': ['1', '0123018', '12'],
#  'らいむらクリニック': ['1', '0123083', '12'],
#  '医療法人社団 斎真会 古川医院': ['1', '0123109', '12'],
#  '内田耳鼻咽喉科': ['1', '0123299', '12'],
#  '医療法人社団 邦潤会 わかば宮本医院': ['1', '0123455', '12'],
#  '医療法人社団千城台耳鼻咽喉科 千城台耳鼻咽喉科医院': ['1', '0123588', '12'],
#  '医療法人社団匡仁会 梶田医院': ['1', '0124008', '12'],
#  '木下婦人科医院': ['1', '0124016', '12'],
#  '若松町ひまわりクリニック': ['1', '0124099', '12'],
#  '千野整形外科': ['1', '0124214', '12'],
#  '医療法人社団しょうじ しょうじ内科': ['1', '0124412', '12'],
#  '土屋内科医院': ['1', '0124446', '12'],
#  '忍足小児科': ['1', '0103077', '12'],
#  '大木戸整形外科': ['1', '0112102', '12'],
#  'あすなろ皮膚科': ['1', '0114009', '12'],
#  '医療法人社団 角栄団地診療所': ['1', '0114736', '12'],
#  '医療法人社団阿 の会 坂の上外科': ['1', '0115378', '12'],
#  '医療法人社団九陵会 小渋医院': ['1', '0115444', '12'],
#  'みどり泌尿器科皮フ科医院': ['1', '0115519', '12'],
#  '山本医院': ['1', '0115527', '12'],
#  '医療法人社団総和会 武村内科医院': ['1', '0115659', '12'],
#  'やまもとクリニック': ['1', '0115774', '12'],
#  '医療法人社団櫻佑会 昭和の森クリニック': ['1', '0115857', '12'],
#  '医療法人社団本郷会 鎌取内科': ['1', '0115865', '12'],
#  '医療法人社団千秋双葉会 双葉耳鼻咽喉科': ['1', '0116186', '12'],
#  '医療法人社団 令和会 鎌取駅前クリニック': ['1', '0116194', '12'],
#  '医療法人社団至玄清秀会 篠崎医院': ['1', '0116293', '12'],
#  '医療法人社団緑真会 学園前クリニック': ['1', '0116301', '12'],
#  '医療法人社団五月会 とけレディースクリニック': ['1', '0116343', '12'],
#  '田宮クリニック': ['1', '0116368', '12'],
#  'あすみが丘内科クリニック': ['1', '0116418', '12'],
#  'おゆみの整形外科クリニック': ['1', '0116517', '12'],
#  'にこにこ胃腸科・整形外科': ['1', '0116566', '12'],
#  'おゆみの耳鼻咽喉科': ['1', '0116590', '12'],
#  '医療法人社団裕仁会 かまとり医院': ['1', '0116608', '12'],
#  'かまとり皮ふ科': ['1', '0116699', '12'],
#  '医療法人社団誠心会 あすみが丘耳鼻咽喉科気管食道科': ['1', '0116798', '12'],
#  '医療法人社団芳友会 大久保クリニック': ['1', '0116806', '12'],
#  '医療法人社団紫雲会 千葉南病院': ['1', '0116855', '12'],
#  '医療法人社団あすみ会 あすみが丘佐野眼科': ['1', '0116947', '12'],
#  '医療法人社団緑生会 あらい整形外科': ['1', '0117069', '12'],
#  '医療法人社団明康会 かない内科': ['1', '0117135', '12'],
#  '川村クリニック': ['1', '0117176', '12'],
#  '若新医院': ['1', '0117242', '12'],
#  '鎌取メンタルクリニック': ['1', '0117382', '12'],
#  'こんだこども医院': ['1', '0117390', '12'],
#  'ひらた内科・小児科クリニック': ['1', '0117689', '12'],
#  '医療法人社団 夢の樹会 のせこどもクリニック': ['1', '0118075', '12'],
#  '医療法人社団 二葉会 かまとり眼科クリニック': ['1', '0118372', '12'],
#  '医療法人社団 詠冴会 千葉整形外科内科': ['1', '0118422', '12'],
#  'あすみが丘メンタルクリニック': ['1', '0118661', '12'],
#  '医療法人社団 三敬会 忍足眼科医院': ['1', '0118703', '12'],
#  '医療法人社団 淳英会 おゆみの診療所': ['1', '0118778', '12'],
#  '鈴木脳神経外科クリニック': ['1', '0118810', '12'],
#  '医療法人社団 幸樹会 おゆみのクリニック': ['1', '0118885', '12'],
#  '医療法人社団 鏡一会 鏡戸病院': ['1', '0118935', '12'],
#  '小池皮膚科': ['1', '0119313', '12'],
#  'ゲートウェイクリニックおゆみ野中央': ['1', '0119743', '12'],
#  '医療法人社団星瞳会 まなこどもクリニック': ['1', '0119792', '12'],
#  '西郡整形外科': ['1', '0119925', '12'],
#  '医療法人社団健育会 さとう小児科医院': ['1', '0119982', '12'],
#  '医療法人社団武田会 かまとり武田肛門科': ['1', '0120188', '12'],
#  'おがわ医院': ['1', '0120410', '12'],
#  '医療法人社団恵信会おゆみ野南医院': ['1', '0120501', '12'],
#  '医療法人社団廣和会おりはら耳鼻咽喉科': ['1', '0120519', '12'],
#  '土気駅前皮膚科': ['1', '0120576', '12'],
#  '佐野クリニック': ['1', '0120659', '12'],
#  '医療法人社団 豊心会 中野内科クリニック': ['1', '0120766', '12'],
#  '昭和の森耳鼻咽喉科': ['1', '0120865', '12'],
#  '内科・循環器内科 やまだクリニック': ['1', '0120881', '12'],
#  '医療法人社団 錦昌会 千葉こどもとおとなの整形外科': ['1', '0121160', '12'],
#  '医療法人社団 寄命会 椎名崎クリニック': ['1', '0121178', '12'],
#  '緑こころのクリニック': ['1', '0121509', '12'],
#  '福元クリニック': ['1', '0121624', '12'],
#  'いやしのメンタルクリニック誉田': ['1', '0121780', '12'],
#  '医療法人社団ファーティル みやけウィメンズクリニック': ['1', '0121913', '12'],
#  '医療法人社団アンダンテ きくちこどもクリニック': ['1', '0121947', '12'],
#  '医療法人社団錦昌会 みどりのは 葉記念病院': ['1', '0122143', '12'],
#  '吉原クリニック': ['1', '0122366', '12'],
#  '花レディースクリニック': ['1', '0122721', '12'],
#  '医療法人社団 みどりクリニック': ['1', '0122747', '12'],
#  '医療法人社団淳英会 おゆみの中央病院': ['1', '0122820', '12'],
#  '医療法人社団 史輝会 おゆみ野レインボー皮ふ科': ['1', '0122879', '12'],
#  'みねた婦人科クリニック': ['1', '0123315', '12'],
#  '医療法人社団 賢仁会 あすみが丘医院': ['1', '0123349', '12'],
#  '医療法人社団 大志会 ちばグリーン整形外科': ['1', '0123414', '12'],
#  '医療法人社団寄命会 土気腎クリニック': ['1', '0123737', '12'],
#  '医療法人社団房総武田会ながしまクリニック': ['1', '0123810', '12'],
#  'あずま腎クリニック': ['1', '0123984', '12'],
#  'ドクターケンクリニック': ['1', '0124040', '12'],
#  "K'sクリニックおゆみ野": ['1', '0124354', '12'],
#  '医療法人社団賢仁会 こどもの森クリニック': ['1', '0124420', '12'],
#  '医療法人社団祐会 おゆみ野眼科クリニック': ['1', '0124495', '12'],
#  '医療法人社団 圭恵会 すずらんクリニックあすみが丘': ['1', '0124693', '12'],
#  'たなべ小児科医院': ['1', '0103523', '12'],
#  'ガーデンタウンクリニック': ['1', '0103630', '12'],
#  '高根産科婦人科医院': ['1', '0103861', '12'],
#  '稲毛診療所': ['1', '0110734', '12'],
#  '関根整形外科医院': ['1', '0111518', '12'],
#  'いそべ利伊医院': ['1', '0111534', '12'],
#  '千葉市心身障害児総合通園センター': ['1', '0111831', '12'],
#  '福山医院': ['1', '0112110', '12'],
#  '千葉市立海浜病院': ['1', '0112524', '12'],
#  '千葉県精神科医療センター': ['1', '0112672', '12'],
#  '由宇クリニック': ['1', '0112730', '12'],
#  '千葉県救急医療センター': ['1', '0113274', '12'],
#  '医療法人社団慈洲会 瀨古医院': ['1', '0113456', '12'],
#  '医療法人社団光静会 成田医院': ['1', '0113589', '12'],
#  '医療法人社団四輝会 伊藤小児科': ['1', '0113613', '12'],
#  '医療法人鉄蕉会 亀田総合病院附属 幕張クリニック': ['1', '0113811', '12'],
#  '高洲中央医院': ['1', '0113928', '12'],
#  'たみたに小児科': ['1', '0113993', '12'],
#  '医療法人社団協和会 稲浜クリニック': ['1', '0114132', '12'],
#  'たかた眼科': ['1', '0114215', '12'],
#  'たかた整形外科': ['1', '0114223', '12'],
#  '美浜ひふクリニック': ['1', '0114991', '12'],
#  '医療法人社団地山会 海浜整形外科': ['1', '0115196', '12'],
#  '医療法人社団順風会 杉田耳鼻咽喉科': ['1', '0115204', '12'],
#  '医療法人社団 沼野胃腸科内科': ['1', '0115543', '12'],
#  '新美浜整形外科': ['1', '0115667', '12'],
#  'いなげ海岸クリニック': ['1', '0115790', '12'],
#  '京葉眼科医院': ['1', '0115931', '12'],
#  '医療法人社団 森整形外科クリニック': ['1', '0116137', '12'],
#  '幕張ベイクリニック': ['1', '0116152', '12'],
#  '医療法人社団樹徳会 眼科美浜クリニック': ['1', '0116392', '12'],
#  '深浦内科クリニック': ['1', '0116624', '12'],
#  '稲毛海岸神経科クリニック': ['1', '0117051', '12'],
#  '医療法人社団 赤尾クリニック': ['1', '0117143', '12'],
#  '医療法人社団恒心会 遠藤クリニック': ['1', '0117697', '12'],
#  '医療法人社団桃舞会 たかはし医院': ['1', '0117754', '12'],
#  '愛光クリニック': ['1', '0118133', '12'],
#  '医療法人社団 けやき会 なつめ皮ふ科': ['1', '0118158', '12'],
#  '幸町中央診療所': ['1', '0118570', '12'],
#  '医療法人社団 誠馨会 自動車事故対策機構 千葉療護センター': ['1', '0118646', '12'],
#  '美浜神経内科': ['1', '0118653', '12'],
#  '海浜パーククリニック': ['1', '0118802', '12'],
#  'いの皮フ科': ['1', '0119214', '12'],
#  'おおた小児科': ['1', '0119297', '12'],
#  '公益財団法人ちば県民保健予防財団 総合健診センター': ['1', '0119479', '12'],
#  '医療法人社団樹徳会 海浜幕張眼科': ['1', '0119503', '12'],
#  '医療法人社団 うたせ耳鼻咽喉科・アレルギー科': ['1', '0119552', '12'],
#  '小林整形外科': ['1', '0119610', '12'],
#  'ささき整形リハビリテーションクリニック': ['1', '0119669', '12'],
#  'あかねこどもクリニック': ['1', '0119834', '12'],
#  '医療法人社団祥孝会 幕張西クリニック': ['1', '0119842', '12'],
#  'ぴあ心療クリニック': ['1', '0119966', '12'],
#  '医療法人社団和則会 玉井こどもクリニック': ['1', '0120253', '12'],
#  '医療法人社団扇心会 幕張マリブクリニック': ['1', '0120352', '12'],
#  '医療法人社団滋聡会 うたせメディカルクリニック': ['1', '0120527', '12'],
#  '医療法人社団 前田記念 まえだ耳鼻咽喉科': ['1', '0120618', '12'],
#  '医療法人 鉄蕉会 亀田MTGクリニック': ['1', '0120824', '12'],
#  '医療法人社団 嘉泉会 うたせ眼科': ['1', '0121228', '12'],
#  '医療法人社団 聖史会 高洲公園心療医院': ['1', '0121285', '12'],
#  '医療法人社団 健輝会 八木内科クリニック': ['1', '0121293', '12'],
#  '池田クリニック': ['1', '0121558', '12'],
#  '打瀬並木道クリニック': ['1', '0121798', '12'],
#  '幕張ハートクリニック': ['1', '0121806', '12'],
#  '医療法人社団三水会 北千葉整形外科美浜クリニック': ['1', '0121830', '12'],
#  '医療法人社団魁芙会 千葉ポートメディカルクリニック': ['1', '0121939', '12'],
#  '医療法人社団誠仁会 みはま病院': ['1', '0121988', '12'],
#  '医療法人社団創志会 千葉マリンクリニック': ['1', '0122077', '12'],
#  '髙柳耳鼻咽喉科': ['1', '0122127', '12'],
#  'ふじた耳鼻咽喉科': ['1', '0122150', '12'],
#  '医療法人グリーンエミネンス 古峡みはまクリニック': ['1', '0122259', '12'],
#  '医療法人社団THY とくやまクリニック': ['1', '0122283', '12'],
#  '医療法人社団小羊会 高洲訪問クリニック': ['1', '0122531', '12'],
#  '東京ベイ先端医療・幕張クリニック': ['1', '0122663', '12'],
#  'ヘルスケアクリニック川島内科・婦人科': ['1', '0122911', '12'],
#  '社会福祉法人 兼愛会 しょうじゅクリニック': ['1', '0122937', '12'],
#  'うたせ内科・呼吸器内科': ['1', '0122945', '12'],
#  '医療法人社団明順会 瀬古眼科': ['1', '0123042', '12'],
#  '医療法人社団 千種会 あいおいクリニック': ['1', '0123133', '12'],
#  '舘野医院': ['1', '0123323', '12'],
#  '医療法人社団 裕恵会 とおやま医院': ['1', '0123372', '12'],
#  '医療法人社団 三和会 わらがいこどもクリニック': ['1', '0123380', '12'],
#  '幕張ベイタウン整形': ['1', '0123471', '12'],
#  '医療法人鉄蕉会 亀田IVFクリニック幕張': ['1', '0123547', '12'],
#  '医療法人社団汐風 きむらクリニック': ['1', '0123851', '12'],
#  '医療法人社団哲昇会 山﨑内科': ['1', '0123950', '12'],
#  '医療法人社団柏義会 こん内科クリニック': ['1', '0124149', '12'],
#  'Mスキンクリニック': ['1', '0124388', '12'],
#  '医療法人社団創志会 千葉マリンこどもクリニック': ['1', '0124396', '12'],
#  'Sleep Rest Clinic 幕張': ['1', '0124479', '12'],
#  '美浜ホームクリニック': ['1', '0124487', '12'],
#  '医療法人社団彩翔会あそうクリニック': ['1', '0124545', '12'],
#  '真砂クリニック': ['1', '0124594', '12'],
#  '医療法人社団響心会 稲毛ベイサイドホームクリニック ': ['1', '0124651', '12'],
#  '稲毛海岸脳神経外科クリニック': ['1', '0124701', '12'],
#  '野口胃腸科外科医院': ['1', '1300805', '12'],
#  '医療法人厚仁会 内田病院': ['1', '1310044', '12'],
#  '銚子市立病院': ['1', '1310051', '12'],
#  '医療法人積仁会 島田総合病院': ['1', '1310119', '12'],
#  '医療法人芳仁会 海村医院本院': ['1', '1310291', '12'],
#  '宮内内科小児科医院': ['1', '1310309', '12'],
#  '力武医院': ['1', '1310366', '12'],
#  '医療法人寿徳会 加瀬外科医院': ['1', '1310374', '12'],
#  '大野眼科': ['1', '1310457', '12'],
#  '医療法人社団延寿会 西原医院': ['1', '1310473', '12'],
#  '医療法人社団圭寿会 兒玉病院': ['1', '1310499', '12'],
#  '医療法人社団寿康会 宇野沢医院': ['1', '1310507', '12'],
#  '医療法人社団耳鼻咽喉科髙津医院': ['1', '1310523', '12'],
#  '医療法人社団今村医院': ['1', '1310531', '12'],
#  '医療法人社団昭仁会 安藤医院': ['1', '1310564', '12'],
#  '関谷医院': ['1', '1310572', '12'],
#  '医療法人社団双葉会 宮内医院': ['1', '1310580', '12'],
#  '医療法人社団 石井皮膚科診療所': ['1', '1310598', '12'],
#  'いしがみ小児科': ['1', '1310622', '12'],
#  '片倉外科医院': ['1', '1310630', '12'],
#  '吉野クリニック': ['1', '1310655', '12'],
#  '医療法人社団廣仁会 東京堂クリニック': ['1', '1310663', '12'],
#  '浅利クリニック': ['1', '1310671', '12'],
#  '海村医院分院': ['1', '1310689', '12'],
#  '野口皮膚科クリニック': ['1', '1310721', '12'],
#  'たせい耳鼻咽喉科クリニック': ['1', '1310762', '12'],
#  '医療法人社団 聡誠会 なゆきクリニック': ['1', '1310788', '12'],
#  '児玉メディカルクリニック': ['1', '1310804', '12'],
#  '医療法人社団 新生会 医療法人社団 新生会 新生産婦人科': ['1', '1310838', '12'],
#  'くぼたこどもクリニック': ['1', '1310853', '12'],
#  'さいとう眼科クリニック': ['1', '1310879', '12'],
#  '医療法人社団徳清会 三枝整形外科医院': ['1', '1310895', '12'],
#  '医療法人社団洋光会 協和医院': ['1', '1310911', '12'],
#  '須藤医院': ['1', '1310937', '12'],
#  '医療法人社団 恒友会 銚子こころクリニック': ['1', '1310945', '12'],
#  '江里川医院': ['1', '2701183', '12'],
#  '岳医院': ['1', '2701571', '12'],
#  '大倉内科小児科医院': ['1', '2702264', '12'],
#  '坂井小児科医院': ['1', '2702397', '12'],
#  '藤巻クリニック': ['1', '2702595', '12'],
#  '貝田クリニック': ['1', '2702611', '12'],
#  '吉田耳鼻咽喉科医院': ['1', '2702637', '12'],
#  '医療法人静和会 中山病院': ['1', '2710036', '12'],
#  '医療法人 式場病院': ['1', '2710176', '12'],
#  '医療法人社団一条会 一条会病院': ['1', '2710218', '12'],
#  '国府台眼科': ['1', '2710358', '12'],
#  '石黒医院': ['1', '2710515', '12'],
#  '船津整形外科内科小児科医院': ['1', '2710598', '12'],
#  '尾林内科医院': ['1', '2710622', '12'],
#  '安藤病院': ['1', '2710655', '12'],
#  '山本内科小児科医院': ['1', '2710705', '12'],
#  '石森整形外科皮膚科医院': ['1', '2710739', '12'],
#  '市川市おひさまキッズ': ['1', '2710796', '12'],
#  '小林呼吸器科外科医院': ['1', '2710853', '12'],
#  '内科行徳診療所': ['1', '2710945', '12'],
#  '池田神経内科クリニック': ['1', '2710960', '12'],
#  '成毛医院': ['1', '2710978', '12'],
#  '斎藤産婦人科眼科': ['1', '2711158', '12'],
#  '寺島医院': ['1', '2711224', '12'],
#  '両総医院': ['1', '2711364', '12'],
#  '近藤小児科': ['1', '2711422', '12'],
#  '土橋医院': ['1', '2711448', '12'],
#  '篠塚医院': ['1', '2711521', '12'],
#  '滝沢医院': ['1', '2711554', '12'],
#  '廣瀬医院': ['1', '2711711', '12'],
#  '二階堂医院': ['1', '2711802', '12'],
#  '門田整形外科医院': ['1', '2711836', '12'],
#  '宏成医院': ['1', '2711919', '12'],
#  '伊藤眼科医院': ['1', '2711935', '12'],
#  '医療法人社団健医会 セントラル眼科クリニック': ['1', '2711943', '12'],
#  '医療法人社団朋正会 熊谷外科整形外科医院': ['1', '2712032', '12'],
#  '吉田小児科医院': ['1', '2712040', '12'],
#  '医療法人社団 高仁堂医院': ['1', '2712107', '12'],
#  '高中医院': ['1', '2712123', '12'],
#  '三本松クリニック': ['1', '2712156', '12'],
#  '古谷皮膚科クリニック': ['1', '2712172', '12'],
#  '大塚医院': ['1', '2712313', '12'],
#  '中村耳鼻咽喉科医院': ['1', '2712347', '12'],
#  '相之川慶信会医院': ['1', '2712370', '12'],
#  '医療法人社団調和会 南行徳眼科クリニック': ['1', '2712487', '12'],
#  '医療法人社団悠水会 うちだ内科クリニック': ['1', '2712495', '12'],
#  '医療法人社団平静会 大村病院': ['1', '2712503', '12'],
#  '竜崎医院': ['1', '2712511', '12'],
#  '医療法人社団 市川クリニック': ['1', '2712537', '12'],
#  '医療法人社団慈恩会 吉岡医院': ['1', '2712545', '12'],
#  '医療法人社団恩明会 塩浜宮崎医院': ['1', '2712560', '12'],
#  '医療法人社団則由会 水島耳鼻咽喉科': ['1', '2712586', '12'],
#  '大谷医院': ['1', '2712610', '12'],
#  'すみや耳鼻咽喉科': ['1', '2712636', '12'],
#  '医療法人社団万美会 津田眼科医院': ['1', '2712644', '12'],
#  '医療法人社団 木暮医院': ['1', '2712651', '12'],
#  '竹内クリニック': ['1', '2712719', '12'],
#  '医療法人社団 小菅医院': ['1', '2712727', '12'],
#  '医療法人社団 国井整形外科': ['1', '2712735', '12'],
#  '医療法人社団徳山会 東菅野診療所': ['1', '2712768', '12'],
#  '仁整形外科': ['1', '2712776', '12'],
#  '医療法人社団明誠会 ありもと耳鼻咽喉科医院': ['1', '2712826', '12'],
#  '医療法人社団 菊池外科医院': ['1', '2712875', '12'],
#  '医療法人社団順心会 まえだ小児科医院': ['1', '2712883', '12'],
#  '社会医療法人社団千葉県勤労者医療協会 市川市民診療所': ['1', '2712891', '12'],
#  '伊藤内科医院': ['1', '2712917', '12'],
#  '医療法人社団 吉岡産婦人科医院': ['1', '2712925', '12'],
#  '医療法人社団三世会 大高医院': ['1', '2712933', '12'],
#  '上井内科胃腸科医院': ['1', '2712941', '12'],
#  '半沢クリニック': ['1', '2712966', '12'],
#  '白石整形外科クリニック': ['1', '2712990', '12'],
#  '医療法人社団新友会 本八幡腎クリニック': ['1', '2713014', '12'],
#  '北沢眼科医院': ['1', '2713055', '12'],
#  '慶友整形外科医院': ['1', '2713089', '12'],
#  '医療法人社団凌雲会 根本産婦人科医院': ['1', '2713097', '12'],
#  '医療法人社団信道会 姚医院': ['1', '2713105', '12'],
#  '医療法人社団慈正会 日比医院': ['1', '2713113', '12'],
#  '加藤外科内科クリニック': ['1', '2713121', '12'],
#  '医療法人社団恵愛会 小谷整形外科': ['1', '2713154', '12'],
#  '医療法人社団式場記念会 式場隆三郎記念クリニック': ['1', '2713162', '12'],
#  '医療法人社団吉田医院': ['1', '2713204', '12'],
#  '医療法人社団ゆうゆう舎 岩川小児科': ['1', '2713220', '12'],
#  '医療法人社団ゆうゆう舎 伊藤医院': ['1', '2713246', '12'],
#  '田﨑クリニック': ['1', '2713253', '12'],
#  'めめ眼科': ['1', '2713261', '12'],
#  '安田整形外科医院': ['1', '2713279', '12'],
#  'サトウ眼科クリニック': ['1', '2713295', '12'],
#  '小林医院': ['1', '2713303', '12'],
#  '野口クリニック': ['1', '2713345', '12'],
#  '加藤医院': ['1', '2713352', '12'],
#  '大沢医院': ['1', '2713360', '12'],
#  '岩沢医院': ['1', '2713378', '12'],
#  '清仁会行徳クリニック': ['1', '2713402', '12'],
#  '市川医院': ['1', '2713410', '12'],
#  '医療法人社団慶桜会 かねこ医院': ['1', '2713428', '12'],
#  '山下耳鼻咽喉科クリニック': ['1', '2713451', '12'],
#  'いわせ医院': ['1', '2713493', '12'],
#  '星耳鼻咽喉科医院': ['1', '2713527', '12'],
#  '湯本皮膚科クリニック': ['1', '2713535', '12'],
#  '医療法人社団 岩田クリニック': ['1', '2713543', '12'],
#  '大原ファミリークリニック': ['1', '2713592', '12'],
#  '医療法人社団さわやか会 茆原内科医院': ['1', '2713600', '12'],
#  '藤田耳鼻咽喉科医院': ['1', '2713642', '12'],
#  'ましずクリニック': ['1', '2713667', '12'],
#  '中島整形外科': ['1', '2713675', '12'],
#  'ひらかわクリニック': ['1', '2713691', '12'],
#  'いなだクリニック': ['1', '2713709', '12'],
#  '栗原皮フ科クリニック': ['1', '2713733', '12'],
#  '皮膚科KSクリニック': ['1', '2713758', '12'],
#  '渡辺医院': ['1', '2713808', '12'],
#  '大町植竹医院': ['1', '2713816', '12'],
#  '南八幡眼科': ['1', '2713832', '12'],
#  '越田医院内科外科ペインクリニック': ['1', '2713881', '12'],
#  'いわはらキッズクリニック': ['1', '2713964', '12'],
#  'とつか内科クリニック': ['1', '2714012', '12'],
#  '医療法人社団 あきつ会 鈴木医院': ['1', '2714061', '12'],
#  '医療法人社団 恵隆会 浮谷クリニック': ['1', '2714079', '12'],
#  'こまきクリニック': ['1', '2714111', '12'],
#  '本八幡南口眼科クリニック': ['1', '2714129', '12'],
#  '山口皮膚科医院': ['1', '2714145', '12'],
#  'ふくざわ内科クリニック': ['1', '2714152', '12'],
#  '医療法人社団 みずほ会 つやま眼科医院': ['1', '2714186', '12'],
#  '医療法人社団 藤巻耳鼻咽喉科医院': ['1', '2714194', '12'],
#  '医療法人社団 紫苑会 たかはしクリニック': ['1', '2714228', '12'],
#  '福谷内科医院': ['1', '2714244', '12'],
#  '川嶋レディースクリニック': ['1', '2714285', '12'],
#  '医療法人社団慈宏会 まさき整形外科': ['1', '2714293', '12'],
#  'いまいクリニック': ['1', '2714319', '12'],
#  '師岡医院': ['1', '2714327', '12'],
#  'たていし内科': ['1', '2714335', '12'],
#  '医療法人社団 能登クリニック': ['1', '2714343', '12'],
#  '医療法人社団 市川肛門科胃腸科クリニック': ['1', '2714368', '12'],
#  '松宮クリニック': ['1', '2714376', '12'],
#  '木下内科クリニック': ['1', '2714384', '12'],
#  '医療法人社団 北国分内科・皮膚科クリニック': ['1', '2714392', '12'],
#  '市川いけだクリニック': ['1', '2714418', '12'],
#  '玉井医院': ['1', '2714442', '12'],
#  '井上医院': ['1', '2714459', '12'],
#  '上白土ハートクリニック': ['1', '2714517', '12'],
#  '医療法人社団嵐川 大野中央病院': ['1', '2714533', '12'],
#  '市川市急病診療所': ['1', '2714558', '12'],
#  '床島耳鼻咽喉科医院': ['1', '2714566', '12'],
#  'えんぴつ公園こどもクリニック': ['1', '2714590', '12'],
#  '医療法人社団泰正会 大町成光堂クリニック': ['1', '2714657', '12'],
#  'いそべ整形外科': ['1', '2714673', '12'],
#  '本八幡クリニック': ['1', '2714681', '12'],
#  '長浜クリニック': ['1', '2714715', '12'],
#  '医療法人社団鴻翠会 柏の森クリニック': ['1', '2714731', '12'],
#  '医療法人社団みずき会 さとう整形外科': ['1', '2714749', '12'],
#  '医療法人社団安誠会 やすはら内科クリニック': ['1', '2714806', '12'],
#  '医療法人社団新友会 新南行徳クリニック': ['1', '2714848', '12'],
#  '医療法人社団聖進会 市川東病院': ['1', '2714855', '12'],
#  '医療法人友康会 行徳中央病院': ['1', '2714863', '12'],
#  '医療法人友康会 行徳中央クリニック': ['1', '2714871', '12'],
#  '医療法人社団 みつはしクリニック': ['1', '2714889', '12'],
#  '医療法人社団 誠安会 あべ内科クリニック': ['1', '2714921', '12'],
#  'ベリークリニック': ['1', '2714939', '12'],
#  '医療法人社団 吉田こどもクリニック': ['1', '2714947', '12'],
#  '医療法人社団八心会 上田医院': ['1', '2715027', '12'],
#  '仁和医院': ['1', '2715035', '12'],
#  '医療法人社団森メンタルクリニック': ['1', '2715043', '12'],
#  'あらたこどもクリニック': ['1', '2715068', '12'],
#  '医療法人社団徳明会 行徳駅前クリニック': ['1', '2715092', '12'],
#  '医療法人社団銀帆会 いいだ眼科': ['1', '2715100', '12'],
#  '医療法人社団馨仁会 妙典内科クリニック': ['1', '2715134', '12'],
#  '医療法人社団恵眼会 滝澤眼科': ['1', '2715142', '12'],
#  '北国分診療所': ['1', '2715167', '12'],
#  'ひかり耳鼻咽喉科': ['1', '2715209', '12'],
#  '若葉クリニック': ['1', '2715258', '12'],
#  '島田クリニック': ['1', '2715266', '12'],
#  'アストラル八幡クリニック': ['1', '2715274', '12'],
#  '竹林眼科': ['1', '2715282', '12'],
#  '清水クリニック': ['1', '2715290', '12'],
#  '医療法人社団 康照会 みやお整形外科': ['1', '2715316', '12'],
#  '医療法人社団 芳英会 医療法人社団 芳英会 吉野内科・神経内科医院': ['1', '2715365', '12'],
#  '医療法人社団幸留会 市川スキンクリニック': ['1', '2715407', '12'],
#  '医療法人社団優佑会 市川ケアクリニック': ['1', '2715456', '12'],
#  '西川クリニック': ['1', '2715464', '12'],
#  '藤巻眼科クリニック': ['1', '2715472', '12'],
#  'らいおんハートクリニック押切': ['1', '2715522', '12'],
#  '斎藤医院': ['1', '2715548', '12'],
#  'ふみ浜耳鼻咽喉科医院': ['1', '2715597', '12'],
#  '医療法人社団 青峯会 医聖よろずクリニック いちかわ院': ['1', '2715613', '12'],
#  'いざなぎクリニック': ['1', '2715621', '12'],
#  '行徳皮膚科クリニック': ['1', '2715639', '12'],
#  '医療法人社団互仁会 スマイル眼科': ['1', '2715647', '12'],
#  '小坂整形外科': ['1', '2715654', '12'],
#  '医療法人社団豊永会 市川駅前眼科': ['1', '2715662', '12'],
#  '医療法人社団市和会 東\ue0a1クリニック市川': ['1', '2715670', '12'],
#  'みずの皮フ科医院': ['1', '2715688', '12'],
#  '日下部クリニック': ['1', '2715696', '12'],
#  '医療法人社団 あいおいクリニック': ['1', '2715753', '12'],
#  'やなぎはら皮ふ科クリニック': ['1', '2715761', '12'],
#  '医療法人社団育明会 市川Rio皮膚科': ['1', '2715787', '12'],
#  '医療法人社団優希会 市川駅前おがわ内科': ['1', '2715803', '12'],
#  '八幡ファミリークリニック': ['1', '2715829', '12'],
#  'ながさか皮膚科クリニック': ['1', '2715837', '12'],
#  '金沢皮フ科医院': ['1', '2715845', '12'],
#  'たきあ胃腸科クリニック': ['1', '2715852', '12'],
#  'ねもとメンタルクリニック': ['1', '2715860', '12'],
#  '医療法人社団涼風会 かわしま皮膚科': ['1', '2715878', '12'],
#  '行徳じんクリニック': ['1', '2715886', '12'],
#  '福田医院': ['1', '2715894', '12'],
#  '森クリニック': ['1', '2715910', '12'],
#  '医療法人社団青和会 やまびこクリニック': ['1', '2715928', '12'],
#  'わたなべ糖内科クリニック': ['1', '2715936', '12'],
#  '医療法人社団靱生会 メディカルプラザ市川駅': ['1', '2715969', '12'],
#  '医療法人社団 緑友会 らいおんハート整形外科リハビリクリニック': ['1', '2715985', '12'],
#  '八幡眼科医院': ['1', '2716017', '12'],
#  'なかさこ医院': ['1', '2716058', '12'],
#  '医療法人社団 わたなべ医院': ['1', '2716082', '12'],
#  '医療法人健志会 行徳整形外科内科': ['1', '2716090', '12'],
#  '医療法人社団 康友会 おおわだ佐多クリニック': ['1', '2716124', '12'],
#  '市川整形外科内科': ['1', '2716132', '12'],
#  '医療法人社団 長谷川眼科クリニック': ['1', '2716140', '12'],
#  '佐々木内科医院': ['1', '2716157', '12'],
#  '医療法人社団 康友会 原田耳鼻咽喉科': ['1', '2716173', '12'],
#  '吉田クリニック': ['1', '2716199', '12'],
#  'もとやわた駅前整形外科': ['1', '2716215', '12'],
#  '藤田小児科医院': ['1', '2716231', '12'],
#  '医療法人財団 明理会 行徳総合病院': ['1', '2716249', '12'],
#  'メンタルヘルス診療所しっぽふぁーれ': ['1', '2716256', '12'],
#  '市川フォレストクリニック': ['1', '2716280', '12'],
#  '医療法人社団 長伸会 市川南クリニック': ['1', '2716306', '12'],
#  '医療法人社団健森会 まごころクリニック行徳': ['1', '2716314', '12'],
#  'ふるや内科クリニック': ['1', '2716348', '12'],
#  '市川東ヘルスクリニック': ['1', '2716355', '12'],
#  '医療法人社団 薫友会 藤井皮膚科クリニック': ['1', '2716363', '12'],
#  'あいこう耳鼻いんこう科': ['1', '2716371', '12'],
#  '本八幡セントラル放射線科クリニック': ['1', '2716405', '12'],
#  '医療法人社団 iーメンタルクリニック': ['1', '2716421', '12'],
#  '医療法人社団 泰陽会 本八幡耳鼻咽喉科': ['1', '2716439', '12'],
#  '金子皮フ科クリニック': ['1', '2716447', '12'],
#  '市川ひふ科形成外科クリニック': ['1', '2716470', '12'],
#  '医療法人社団弘豊会 本八幡皮ふ科クリニック': ['1', '2716504', '12'],
#  '医療法人社団 南行徳整形外科内科': ['1', '2716512', '12'],
#  '医療法人社団伯則会 原木医院': ['1', '2716538', '12'],
#  '医療法人社団 おひさまの会 サンサンこどもクリニック': ['1', '2716546', '12'],
#  'さくらライフ市川クリニック': ['1', '2716553', '12'],
#  '医療法人社団御波会面野医院': ['1', '2716579', '12'],
#  '医療法人社団順誠会 妙典さいとう耳鼻咽喉科': ['1', '2716587', '12'],
#  ...}

# %%
for i in list(dict_hospitalInfo_base.values()):
    if i[1]=="4224481":
        print(i)
# Out:
# ['1', '4224481', '13']

# %% [markdown]
# # symspellで行う

# %%
with open('hospital3_8.pickle', 'rb') as f:
    sym_spell_hospital = pickle.load(f)

def symspell_hospital(_query,_max_edit_distance_lookup):
    answer=[]
    answer_distance=[]
    input_term =_query
    _max_edit_distance_lookup = _max_edit_distance_lookup
    suggestion_verbosity = Verbosity.CLOSEST  # TOP, CLOSEST, ALL
    
    suggestions = sym_spell_hospital.lookup(input_term, suggestion_verbosity,
                               _max_edit_distance_lookup)
    for suggestion in suggestions:
        answer.append(suggestion.term)
        answer_distance.append(suggestion.distance)
    return(answer,answer_distance)

#病院データベースのインポート(subは医科・歯科が併設されているケースの、sub側の医療機関のコードを格納したもの)
with open('dict_hospitalInfo.pickle', 'rb') as f:
    dict_hospitalInfo_base = pickle.load(f)
#with open('dict_hospitalInfo_sub.pickle', 'rb') as f:
#    dict_hospitalInfo_sub_base = pickle.load(f)

#病院名の表記揺れ修正してdict,listを生成
dict_hospitalInfo,l_hospital = {},[]
for key in dict_hospitalInfo_base.keys():
    normed = jaconv.normalize(key)
    dict_hospitalInfo[normed] = dict_hospitalInfo_base[key]
    l_hospital.append(normed)

#文字列長情報を付与してあげる
s_hospital_withLen = pd.Series(l_hospital, index=[len(i) for i in l_hospital])


def not_hospital(text):
    '''
    医療機関っぽくない単語かどうかを判定する
    input:text
    output:医療機関っぽくない場合はFalseを返す、その他はTrue
    '''
    raw_abc = r'[ぁ-んｦ-ﾟァ-ン0-9Ａ-ＺA-Zａ-ｚa-z]+'
    raw_abc2 = r'大?昭?平?令?[0-9]+才'
    matchobj = re.fullmatch(raw_abc, text.replace(" ",""))
    matchobj2 = re.fullmatch(raw_abc2, text.replace(" ",""))
    try:
        answer=matchobj.group()
    except:
        answer=False
        
    try:
        answer2=matchobj2.group()
    except:
        answer2=False
    
    if answer==False and answer2==False:
        return True
    else:
        return False


def text_replace(text):
    '''
    医療機関名称に関係なさそうな文字を削除
    input:text
    output:text
    '''
    text=text.replace(" ","")
    text = text.replace('及び','')
    text = text.replace('名称','')
    text = text.replace('所在地','')
    text = text.replace('関の','')
    text = text.replace('保険医師','')
    text=re.sub('\W+','', text)

    return text

# %%
#以後、ブロック一つずつ確認していく

raw_str=['保険医療機東京都千代田区飯田橋469STビル2階', '飯田橋クリニック']
_1_hospital_name=""
_1_hospital_code_type=""
_1_hosipital_code=""
_1_hospital_place_code=""

for num in range(len(raw_str)):
    val = raw_str[num]    

    #1_医療機関レコード
    if (_1_hospital_name is None) and (len(val)>4 and len(val)<24):#lenの閾値はテキトーなので今後調整
        #new
        symspell_results_2=symspell_hospital(val, 10)#symspell_results_2にはふたつのリストが入っている
        print(symspell_results_2)
        hospital = symspell_results_2[0]
        hospital2 = symspell_results_2[1]
        #hospital2_list.append(hospital2) ... この情報は取らないfor the time being

        if hospital != []:
            l_hospital,l_symspell_dist=[],[]
            #hospital_symspell_results.append(hospital[0]) ... この情報は取らないfor the time being
            for j in range(len(hospital)):
                hospital_name = hospital[j]
                symspell_dist = hospital2[j]
                l_hospital_search = s_hospital_withLen[s_hospital_withLen.index>=len(hospital_name)].values.tolist()
                for i in l_hospital_search:
                    if hospital_name in i:
                        l_hospital.append(i)
                        l_symspell_dist.append(symspell_dist)

            #l_hospitalの値をvalの値の編集距離を取得して、それに応じて並び替え. valが最長病院名より長かったらvalを短くする.
            l_leven=[]
            max_len = max([len(i) for i in l_hospital])
            if len(val)>max_len:
                compare = val[:max_len]
            else:
                compare = val
            for i in l_hospital:
                l_leven.append(Levenshtein.distance(compare,i))         
            l_hospital_sorted = pd.Series(l_hospital,index=[l_symspell_dist,l_leven]).sort_index(ascending=False).values.tolist()

            #一番近しいやつを決め打ちで出力
            _1_hospital_name = l_hospital_sorted[len(l_hospital_sorted)-1]
            _1_hospital_code_type,_1_hosipital_code,_1_hospital_place_code = dict_hospitalInfo[_1_hospital_name]

# %%
print(_1_hospital_name)

# %%
result_list
# Out:
# [['医療法人社団高典会飯田橋クリニック'],
#  [],
#  ['医療法人社団東仁会吉祥寺あさひ病院'],
#  ['谷川光洋', 'アソルティ末広町ビル1F', '末広町ヒライ耳鼻咽喉科'],
#  ['医療法人社団慈仁会飯田橋小池クリニック'],
#  ['アソルティ末広町ビル1F', '末広町ヒライ耳鼻咽喉科'],
#  ['埜知津子', '保険医療機', '上西クリニック', '大阪市平野区平野西3921コーポ常'],
#  ['サカイ末広ビル7階B室', '雪月花メディカルクリニック秋葉原診療所'],
#  ['上林記念病院'],
#  ['上林記念病院'],
#  ['保険医療機5460002',
#   '大阪府大阪市東住吉区杭全',
#   '④検査値は過去3か月間以',
#   '白鷺診療所',
#   '⑤処方せんの有効期限は',
#   '場合保険薬局でお薬'],
#  ['おざき心のクリニック'],
#  ['木下循環器呼吸器内科クリニック'],
#  ['医療法人社団高典会飯田橋クリニック'],
#  ['みどりの森ひふ科クリニック'],
#  ['七丁目十番十九等',
#   '大阪府大阪市東住吉区杭全',
#   '④検査値は過去3か月間以内に測',
#   '白鷺診療所',
#   '⑤処方せんの有効期限は発行日を',
#   '26日生',
#   '保険医氏名三橋',
#   '場合保険薬局でお薬を受け取'],
#  ['様の884', '医療法人聖仁会西部総合病院'],
#  ['雪月花メディカルクリニック秋葉原診療所'],
#  ['川越宗紀', '明神下診療所'],
#  ['飯田橋歯科クリニック'],
#  ['医療法人社団雄翔会あさひ上野クリニック'],
#  ['保険医療機東京都千代田区飯田橋469STビル2階', '名様医療法人社団高典会飯田橋クリニック'],
#  ['上林記念病院'],
#  ['大阪府大阪市東住吉区杭全', '七丁目十番十九号', '仁真会白鷺診療所', '保険医氏名岡崎久宜'],
#  ['一宮西病院'],
#  ['倉めぐみ', 'アソルティ末広町ビル1F', '末広町ヒライ耳鼻咽喉科'],
#  ['保険医療機opyを',
#   '東京都武蔵野市吉祥寺本町13012',
#   'PaperCopyGiàPaperCopyGray',
#   '医療法人社団東仁会Garam',
#   'Copy人工透析内',
#   'Guämaper',
#   '三8月22日513pyGuardPaperVIK',
#   '性別男保険医氏名笠原仁'],
#  ['医療法人社団慈仁会飯田橋小池クリニック'],
#  ['一般社団法人衛生文化協会', '城西病院'],
#  ['一医療法人社団慈仁会飯田橋小池クリニック']]

# %%
word="鈴木クリニック"
for hos_name in list(dict_hospitalInfo_base.keys()):
    if word in hos_name:
        print( hos_name)
# Out:
# 北柏鈴木クリニック
# 鈴木クリニック
# 医療法人社団 将恵会 鈴木クリニック
# 医療法人社団 志鈴会 鈴木クリニック
# 医療法人社団 敬水会 江戸川橋鈴木クリニック
# 自然堂鈴木クリニック
# 医療法人社団 加納会 鈴木クリニック
# 医療法人社団 潤明会 鈴木クリニック
# 歯科鈴木クリニック
# 医療法人社団横浜健康医学会 関内鈴木クリニック
# 医療法人新医会 鈴木クリニック
# 医療法人 鈴成会 鈴木クリニック
# 医療法人悠有会 鈴木クリニック

# %%
dict_hospitalInfo_base
# Out:
# {'千葉県がんセンター': ['1', '0110684', '12'],
#  '医療法人社団福寿会 鷲見医院': ['1', '0112300', '12'],
#  '医療法人緑栄会 三愛記念そが病院': ['1', '0116814', '12'],
#  '千葉市 千葉市立青葉病院': ['1', '0118687', '12'],
#  'クリニックあしたば': ['1', '0117911', '12'],
#  '医療法人社団誠馨会 千葉メディカルセンター': ['1', '0123091', '12'],
#  '医療法人社団 大樹 大賀医院': ['1', '0123554', '12'],
#  '一般社団法人 巨樹の会 千葉みなとリハビリテーション病院': ['1', '0122895', '12'],
#  '独立行政法人国立病院機構 千葉医療センター': ['1', '9110016', '12'],
#  '国立大学法人 千葉大学医学部附属病院': ['1', '9210014', '12'],
#  '独立行政法人国立病院機構 千葉東病院': ['1', '9510058', '12'],
#  '医療法人社団翠明会 山王病院': ['1', '0113241', '12'],
#  '国立研究開発法人 量子科学技術研究開発機構 QST病院': ['1', '9110040', '12'],
#  '清和園多部田診療所': ['1', '0111070', '12'],
#  '医療法人社団創進会 みつわ台総合病院': ['1', '0116384', '12'],
#  '社会福祉法人千葉県身体障害者福祉事業団 千葉県千葉リハビリテーションセンター': ['1', '0111799', '12'],
#  '千葉県こども病院': ['1', '0113191', '12'],
#  'しののめ元山医院': ['1', '0117549', '12'],
#  '医療法人社団圭恵会 すずらんクリニック': ['1', '0123356', '12'],
#  '独立行政法人国立病院機構 下総精神医療センター': ['1', '9510066', '12'],
#  '千葉市休日救急診療所': ['1', '0114561', '12'],
#  '医療法人社団 千葉白報会 総合クリニック ドクターランド幕張': ['1', '0122697', '12'],
#  '医療法人社団究美会 肌と歯のクリニック 東京ベイ幕張': ['1', '0123539', '12'],
#  '医療法人財団みさき会 たむら記念病院': ['1', '1310713', '12'],
#  '東京歯科大学市川総合病院': ['1', '2712404', '12'],
#  '医療法人社団 瑞鶴会 鶴木クリニック医科・歯科': ['1', '2714400', '12'],
#  'タムス市川リハビリテーション病院': ['1', '2716975', '12'],
#  '国立研究開発法人国立国際医療研究センター国府台病院': ['1', '9110024', '12'],
#  '独立行政法人地域医療機能推進機構船橋中央病院': ['1', '2810018', '12'],
#  '医療法人同和会 千葉病院': ['1', '2810117', '12'],
#  '芝山医科歯科クリニック': ['1', '2813533', '12'],
#  '医療法人社団三松会 さくらクリニック': ['1', '2813863', '12'],
#  '医療法人社団誠馨会 セコメディック病院': ['1', '2814945', '12'],
#  'いけだハートクリニック 船橋駅前診療所': ['1', '2816148', '12'],
#  '船橋市立医療センター': ['1', '2811214', '12'],
#  '医療法人社団千葉白報会 総合クリニック ドクターランド船橋': ['1', '2816627', '12'],
#  '医療法人社団慈善会 ぜんり歯科内科クリニック': ['1', '2812527', '12'],
#  '医療法人社団協和会 滝不動病院': ['1', '2812204', '12'],
#  '医療法人鉄蕉会 亀田ファミリークリニック館山': ['1', '3610870', '12'],
#  '医療法人沖縄徳洲会 館山病院': ['1', '3611001', '12'],
#  '国保直営総合病院 君津中央病院': ['1', '1010149', '12'],
#  '医療法人社団志仁会 薬丸病院': ['1', '1010156', '12'],
#  '日本大学松戸歯学部付属病院': ['1', '2410546', '12'],
#  '医療法人社団慈朋会 金子医院': ['1', '2411486', '12'],
#  '医療法人沖縄徳洲会 千葉西総合病院': ['1', '2412484', '12'],
#  '松戸市立総合医療センター': ['1', '2416527', '12'],
#  '医療法人社団真療会 野田病院': ['1', '2010833', '12'],
#  '医療法人社団天榮会 茂原機能クリニック': ['1', '3111184', '12'],
#  '医療法人社団 剛裕会 須田外科・歯科医院': ['1', '3111309', '12'],
#  '医療法人社団聖母会 聖マリア記念病院': ['1', '4310322', '12'],
#  '日本赤十字社 成田赤十字病院': ['1', '4310041', '12'],
#  '成田病院': ['1', '4310058', '12'],
#  '成田市急病診療所': ['1', '4310983', '12'],
#  '医療法人社団心和会 成田リハビリテーション病院': ['1', '4312492', '12'],
#  '日本医科大学成田国際空港クリニック': ['1', '4310462', '12'],
#  '国際医療福祉大学成田病院': ['1', '4312591', '12'],
#  '佐倉市休日夜間急病診療所': ['1', '4210167', '12'],
#  '和田診療所': ['1', '4210472', '12'],
#  '医療法人静和会 浅井病院': ['1', '0810036', '12'],
#  '東千葉メディカルセンター': ['1', '0810630', '12'],
#  '夢屋診療所': ['1', '1410273', '12'],
#  '重症心身障害児施設 聖母療育園': ['1', '1410182', '12'],
#  '総合病院国保旭中央病院': ['1', '1411255', '12'],
#  '社会医療法人社団菊田会 習志野第一病院': ['1', '0210047', '12'],
#  '社会福祉法人恩賜財団済生会支部千葉県済生会 千葉県済生会 習志野病院': ['1', '0210971', '12'],
#  '医療法人社団柏水会 初石病院': ['1', '2110062', '12'],
#  '医療法人社団秀和会 秀和会クリニック': ['1', '2111995', '12'],
#  '医療法人社団天宣会 北柏リハビリ総合病院': ['1', '2112423', '12'],
#  '医療法人社団協友会 柏厚生総合病院': ['1', '2114866', '12'],
#  '公益財団法人柏市医療公社 医療センター': ['1', '2115095', '12'],
#  '社会医療法人社団蛍水会 名戸ケ谷病院付属名戸ケ谷診療所': ['1', '2112258', '12'],
#  '社会医療法人社団蛍水会 名戸ヶ谷病院': ['1', '2116259', '12'],
#  '国立研究開発法人国立がん研究センター東病院': ['1', '9110057', '12'],
#  '千葉県循環器病センター': ['1', '0610162', '12'],
#  '独立行政法人 労働者健康安全機構 千葉労災病院': ['1', '0610147', '12'],
#  '市原市急病センター': ['1', '0610774', '12'],
#  '帝京大学ちば総合医療センター': ['1', '0610634', '12'],
#  '流山市平日夜間・休日診療所': ['1', '2310431', '12'],
#  '医療法人社団心和会 新八千代病院': ['1', '0410308', '12'],
#  '医療法人社団心和会 八千代病院': ['1', '0410464', '12'],
#  '東京女子医科大学附属八千代医療センター': ['1', '0411736', '12'],
#  '我孫子市休日診療所': ['1', '2510725', '12'],
#  '医療法人緑生会 あびこクリニック': ['1', '2510840', '12'],
#  '天龍堂クリニック': ['1', '2511178', '12'],
#  '医療法人社団聖仁会 我孫子聖仁会病院': ['1', '2511087', '12'],
#  '医療法人鉄蕉会 亀田総合病院': ['1', '3910221', '12'],
#  '亀田クリニック': ['1', '3910270', '12'],
#  '鴨川市立国保病院': ['1', '3911021', '12'],
#  '医療法人社団宏和会 エビハラ病院': ['1', '3910163', '12'],
#  '医療法人梨香会 秋元病院': ['1', '2610335', '12'],
#  '医療法人沖縄徳洲会 鎌ケ谷総合病院': ['1', '2610889', '12'],
#  '医療法人社団君津あすなろ会 あすなろクリニック': ['1', '1110717', '12'],
#  'あさひクリニック': ['1', '4410643', '12'],
#  '医療法人沖縄徳洲会 四街道徳洲会病院': ['1', '4410833', '12'],
#  '独立行政法人国立病院機構 下志津病院': ['1', '9510033', '12'],
#  '千葉県袖ヶ浦福祉センター': ['1', '0910240', '12'],
#  '東京都千葉福祉園診療所': ['1', '0910265', '12'],
#  '医療法人社団良康会 福王台皮膚科歯科': ['1', '0910653', '12'],
#  '医療法人みつや会 新八街総合病院': ['1', '4510079', '12'],
#  '日本医科大学千葉北総病院': ['1', '4111134', '12'],
#  '医療法人社団 昭桜会 桜台メディカルクリニック': ['1', '4710463', '12'],
#  '千葉県立佐原病院': ['1', '5210067', '12'],
#  '香取おみがわ医療センター': ['1', '5210703', '12'],
#  'さんむ医療センター': ['1', '5310354', '12'],
#  '医療法人社団仁和会 睦岡クリニック': ['1', '5310347', '12'],
#  '髙根病院': ['1', '0711358', '12'],
#  '長谷川医院': ['1', '0100602', '12'],
#  '松本医院': ['1', '0101980', '12'],
#  '医療法人グリーンエミネンス 中村古峡記念病院': ['1', '0110163', '12'],
#  '医療法人社団普照会 井上記念病院': ['1', '0110171', '12'],
#  '医療法人柏葉会 柏戸病院': ['1', '0110197', '12'],
#  '医療法人 三橋病院': ['1', '0110262', '12'],
#  '医療法人学而会 木村病院': ['1', '0110304', '12'],
#  '医療法人 石郷岡病院': ['1', '0110502', '12'],
#  '千葉県精神保健福祉センター': ['1', '0110627', '12'],
#  '独立行政法人地域医療機能推進機構 千葉病院': ['1', '0110635', '12'],
#  '一般社団法人千葉衛生福祉協会 千葉診療所': ['1', '0110668', '12'],
#  '医療法人社団福生会 斎藤労災病院': ['1', '0110700', '12'],
#  '千葉セントラル神経科クリニック': ['1', '0111674', '12'],
#  '新千葉医院': ['1', '0111773', '12'],
#  '山崎皮膚科医院': ['1', '0112763', '12'],
#  '浜田小児科医院': ['1', '0112854', '12'],
#  '医療法人 椎名内科医院': ['1', '0112979', '12'],
#  '西千葉眼科医院': ['1', '0113076', '12'],
#  '医療法人社団一陽会 髙部内科医院': ['1', '0113175', '12'],
#  '林内科医院': ['1', '0113209', '12'],
#  '髙木整形外科': ['1', '0113423', '12'],
#  '医療法人社団仁静堂 平山整形外科・外科医院': ['1', '0113522', '12'],
#  '医療法人社団伸幸会 登戸クリニック': ['1', '0113571', '12'],
#  '山崎整形外科医院': ['1', '0113910', '12'],
#  '医療法人社団有馬会 有馬外科胃腸科': ['1', '0114025', '12'],
#  '木村整形外科': ['1', '0114108', '12'],
#  '医療法人社団翔葉会 今井医院': ['1', '0114389', '12'],
#  '医療法人社団峰明会 青木内科医院': ['1', '0114413', '12'],
#  '医療法人社団巖会 あさひ眼科医院': ['1', '0114504', '12'],
#  '久保小児科内科': ['1', '0114512', '12'],
#  '医療法人社団清弘会 神田内科医院': ['1', '0114520', '12'],
#  '医療法人社団青光会 今井町診療所': ['1', '0114553', '12'],
#  '医療法人社団仁威会 実川外科医院': ['1', '0114603', '12'],
#  '医療法人社団望葉会 日下医院': ['1', '0114710', '12'],
#  '医療法人社団柏陽会 柏木産婦人科': ['1', '0114751', '12'],
#  '新宿外科医院': ['1', '0114793', '12'],
#  '医療法人社団博洋会 大濱医院': ['1', '0114801', '12'],
#  '医療法人社団椿森会 椿森クリニック': ['1', '0114868', '12'],
#  'わたなべ整形外科': ['1', '0114942', '12'],
#  'もり内科クリニック': ['1', '0115014', '12'],
#  '千葉眼科': ['1', '0115105', '12'],
#  '医療法人社団春光会 千葉市役所前クリニック': ['1', '0115410', '12'],
#  '榎本医院': ['1', '0115972', '12'],
#  '医療法人緑栄会 三愛記念病院': ['1', '0115980', '12'],
#  '医療法人社団細川会 えりやま内科皮膚科医院': ['1', '0116020', '12'],
#  '医療法人社団宗仙会 山口耳鼻咽喉科': ['1', '0116095', '12'],
#  'ちば宇津木皮膚科': ['1', '0116129', '12'],
#  '医療法人志方記念会 三木クリニック': ['1', '0116228', '12'],
#  '医療法人社団ヘルスアンドスポーツ会 鍋島整形外科': ['1', '0116269', '12'],
#  '医療法人社団生実会 ホタカ整形外科': ['1', '0116319', '12'],
#  '亘内科医院': ['1', '0116442', '12'],
#  '千葉クリニック': ['1', '0116822', '12'],
#  '青柳内科クリニック': ['1', '0116939', '12'],
#  '武本眼科医院': ['1', '0116996', '12'],
#  '医療法人社団澤泉会 矢澤内科医院': ['1', '0117317', '12'],
#  'ジツカワ眼科': ['1', '0117507', '12'],
#  '医療法人社団 和田医院': ['1', '0117515', '12'],
#  'しまだ医院': ['1', '0117614', '12'],
#  '本千葉メンタルクリニック': ['1', '0117770', '12'],
#  '小野寺産婦人科': ['1', '0117879', '12'],
#  '医療法人社団 喜美会 自由が丘クリニックソフィア': ['1', '0117887', '12'],
#  '医療法人社団 至心会 田那村内科小児科医院': ['1', '0118000', '12'],
#  '医療法人社団 煌和会 國分クリニック': ['1', '0118018', '12'],
#  '島野眼科医院': ['1', '0118083', '12'],
#  'るみえ内科小児科': ['1', '0118109', '12'],
#  '医療法人社団 惇友会 荒井眼科': ['1', '0118265', '12'],
#  '医療法人社団 豊賀會 吉井耳鼻咽喉科医院': ['1', '0118281', '12'],
#  'ヒロ耳鼻科クリニック': ['1', '0118364', '12'],
#  '和康会産婦人科健康診断クリニック': ['1', '0118398', '12'],
#  '千葉寺駅前眼科': ['1', '0118414', '12'],
#  '医療法人社団桐和会 桐原クリニック': ['1', '0118497', '12'],
#  '公益財団法人ちば県民保健予防財団 千葉県庁医務室': ['1', '0118620', '12'],
#  '小松﨑耳鼻咽喉科': ['1', '0118679', '12'],
#  '社会医療法人社団同仁会 そが西口クリニック': ['1', '0118877', '12'],
#  '医療法人社団 松石会 松石内科医院': ['1', '0118927', '12'],
#  '岡田医院': ['1', '0119149', '12'],
#  'つばきこどもクリニック': ['1', '0119206', '12'],
#  '医療法人社団春鈴会 寺田クリニック': ['1', '0119404', '12'],
#  '医療法人社団晃知会 小浜内科外科クリニック': ['1', '0119438', '12'],
#  '医療法人社団豊流会 ツチダクリニック': ['1', '0119461', '12'],
#  '山口内科外科クリニック': ['1', '0119487', '12'],
#  '西川泌尿器科クリニック': ['1', '0119560', '12'],
#  '東千葉クリニック': ['1', '0119776', '12'],
#  '長谷川胃腸科クリニック': ['1', '0119818', '12'],
#  '医療法人社団青稜会 そが皮膚科': ['1', '0119875', '12'],
#  'こいで内科消化器科クリニック': ['1', '0119917', '12'],
#  '一般財団法人柏戸記念財団 ポートスクエア柏戸クリニック': ['1', '0119933', '12'],
#  '中野耳鼻咽喉科医院': ['1', '0120022', '12'],
#  '千葉そごう眼科診療所': ['1', '0120048', '12'],
#  'くすの木クリニック': ['1', '0120220', '12'],
#  '医療法人社団恵昭会 千葉駅前クリニック': ['1', '0120345', '12'],
#  '西千葉クリニック': ['1', '0120386', '12'],
#  '医療法人社団鎮誠会 千葉きぼーるクリニック': ['1', '0120667', '12'],
#  '医療法人社団 のわび会 医療法人社団 のわび会 そがこどもクリニック': ['1', '0120915', '12'],
#  '医療法人社団英正会 けやき眼科クリニック': ['1', '0120998', '12'],
#  '千葉中央こころのクリニック': ['1', '0121004', '12'],
#  '医療法人社団 貴祥会 耳鼻咽喉科なかのクリニック': ['1', '0121277', '12'],
#  '医療法人社団桃李会 なかしまクリニック': ['1', '0121335', '12'],
#  '医療法人社団 ゆう ゆうクリニック': ['1', '0121459', '12'],
#  '医療法人社団 西千葉皮膚科クリニック': ['1', '0121608', '12'],
#  '本千葉小児科': ['1', '0121616', '12'],
#  '医療法人社団あい 増田病院': ['1', '0121632', '12'],
#  '社会福祉法人淑徳福祉会 淑徳おゆみ診療所': ['1', '0121772', '12'],
#  '上田医院': ['1', '0121889', '12'],
#  'ちば美容・形成外科クリニック': ['1', '0121996', '12'],
#  '医療法人社団 千葉中央クリニック': ['1', '0122028', '12'],
#  '医療法人社団 とのおか眼科': ['1', '0122176', '12'],
#  '菫ホームクリニック': ['1', '0122317', '12'],
#  '千葉駅前心療内科': ['1', '0122424', '12'],
#  '医療法人同和会 脳神経内科千葉': ['1', '0122440', '12'],
#  '医療法人 学而会 弁天メンタルクリニック': ['1', '0122465', '12'],
#  '医療法人社団爽風会 心の風クリニック千葉': ['1', '0122473', '12'],
#  '医療法人社団純衛会 越川内科医院': ['1', '0122523', '12'],
#  '医療法人社団 彤柱会 みやこ整形外科クリニック': ['1', '0122549', '12'],
#  'すみれ眼科': ['1', '0122556', '12'],
#  '千葉シーサイドクリニック': ['1', '0122564', '12'],
#  '医療法人社団 千葉寺駅前整形外科': ['1', '0122572', '12'],
#  '医療法人社団飛鵬会 わかばクリニック': ['1', '0122598', '12'],
#  '医療法人社団双寿 ちぐさ会クリニック': ['1', '0122614', '12'],
#  '医療法人社団春日会 椎名内科': ['1', '0122689', '12'],
#  '西千葉麻酔科クリニック': ['1', '0122713', '12'],
#  '医療法人健志会 白旗整形外科内科': ['1', '0122739', '12'],
#  '医療法人社団 中村内科クリニック': ['1', '0122754', '12'],
#  'みなとこどもクリニック': ['1', '0122846', '12'],
#  '千葉訪問皮膚科': ['1', '0122853', '12'],
#  '医療法人社団報徳会 報徳千葉診療所': ['1', '0122887', '12'],
#  '医療法人社団琴誠会 いそのメディカルクリニック': ['1', '0122929', '12'],
#  '医療法人社団 米満内科医院': ['1', '0122978', '12'],
#  '医療法人財団 明理会 千葉ロイヤルクリニック': ['1', '0122986', '12'],
#  'そがメンタルクリニック': ['1', '0123059', '12'],
#  '医療法人社団 桜治会 赤坂皮フ科クリニック': ['1', '0123067', '12'],
#  '医療法人社団壮和会 ゆりの木クリニック': ['1', '0123075', '12'],
#  '旭町診療所': ['1', '0123166', '12'],
#  '千葉あおばクリニック': ['1', '0123174', '12'],
#  '医療法人社団瑛美会 千葉スキンケアクリニック': ['1', '0123208', '12'],
#  'そがリウマチ・整形外科': ['1', '0123232', '12'],
#  '千葉静脈瘤クリニック': ['1', '0123257', '12'],
#  '医療法人社団 緑萌会 高橋ウイメンズクリニック': ['1', '0123265', '12'],
#  'ゆかわクリニック': ['1', '0123273', '12'],
#  '医療法人社団 千葉中央ひかりクリニック': ['1', '0123331', '12'],
#  '医療法人社団マザー・キー なのはなクリニック': ['1', '0123364', '12'],
#  '医療法人社団童心会 若杉こどもクリニック': ['1', '0123398', '12'],
#  'ふたば訪問クリニック': ['1', '0123489', '12'],
#  '医療法人社団日敏会 浜野長嶋内科': ['1', '0123505', '12'],
#  '鍋嶋眼科医院': ['1', '0123513', '12'],
#  '千葉あおぞらクリニック': ['1', '0123638', '12'],
#  'ちばの根岸眼科': ['1', '0123646', '12'],
#  '医療法人社団 雄恵会 こもだクリニック': ['1', '0123661', '12'],
#  'にへい脳外科': ['1', '0123729', '12'],
#  '医療法人浄光会 千葉みなと病院': ['1', '0123794', '12'],
#  'HSクリニック': ['1', '0123828', '12'],
#  '医療法人社団水野胃腸科・内科': ['1', '0123885', '12'],
#  'アイクリニック千葉': ['1', '0123893', '12'],
#  '医療法人社団だいだい 千葉駅すばるクリニック': ['1', '0123927', '12'],
#  '医療法人社団城東桐和会 千葉駅総合クリニック': ['1', '0123935', '12'],
#  '医療法人社団純英会 赤井町クリニック': ['1', '0123968', '12'],
#  '千葉レディースクリニック': ['1', '0123976', '12'],
#  '医療法人社団弘恵会 そが内科小児科クリニック': ['1', '0124024', '12'],
#  '医療法人社団Blue Bird 青い鳥クリニック千葉': ['1', '0124123', '12'],
#  'りべるたすクリニック': ['1', '0124131', '12'],
#  'みらいクリニック': ['1', '0124198', '12'],
#  '医療法人社団青水会 ふくろうアイクリニック': ['1', '0124222', '12'],
#  'いそむら内科': ['1', '0124248', '12'],
#  '野井レディースクリニック': ['1', '0124263', '12'],
#  '東京ビジネスクリニックペリエ千葉エキナカ': ['1', '0124297', '12'],
#  '千葉汐見丘メンタルクリニック': ['1', '0124347', '12'],
#  '医療法人社団 千心会 市川クリニック': ['1', '0124370', '12'],
#  '山田整形外科医院': ['1', '0124438', '12'],
#  '医療法人社団夢双会 千葉中央スタークリニック': ['1', '0124461', '12'],
#  'メディカルスキャニング千葉': ['1', '0124529', '12'],
#  '霜整形外科医院': ['1', '0124537', '12'],
#  'さくさべ坂通り診療所': ['1', '0124628', '12'],
#  'ちば下肢静脈瘤クリニック': ['1', '0124636', '12'],
#  '医療法人社団響心会 東千葉ホームクリニック': ['1', '0124644', '12'],
#  'みんなのライフサポートクリニック蘇我': ['1', '0124669', '12'],
#  '奈良内科医院': ['1', '0103085', '12'],
#  '田井耳鼻咽喉科アレルギー科': ['1', '0103218', '12'],
#  '田井小児科眼科心療内科': ['1', '0103226', '12'],
#  '諏訪部産婦人科': ['1', '0103283', '12'],
#  '脊尾内科小児科': ['1', '0103382', '12'],
#  '医療法人社団晴山会 平山病院': ['1', '0110767', '12'],
#  '社会医療法人社団千葉県勤労者医療協会 花園診療所': ['1', '0110791', '12'],
#  '石橋内科小児科医院': ['1', '0111450', '12'],
#  '善利医院': ['1', '0112060', '12'],
#  '袖ヶ浦外科': ['1', '0112243', '12'],
#  '向井医院': ['1', '0112409', '12'],
#  '伊東内科医院': ['1', '0112953', '12'],
#  '医療法人社団幸有会 幸有会記念病院 ': ['1', '0113050', '12'],
#  '医療法人社団津田会 津田胃腸科医院': ['1', '0113563', '12'],
#  '医療法人社団敬仁会 神田耳鼻咽喉科医院': ['1', '0113720', '12'],
#  '医療法人社団隆陽会 さつきが丘医院': ['1', '0114017', '12'],
#  '医療法人社団悠啓会 いまにし医院': ['1', '0114124', '12'],
#  '眞清クリニック': ['1', '0114314', '12'],
#  '小池医院': ['1', '0114371', '12'],
#  '医療法人社団信和会 小泉医院': ['1', '0114611', '12'],
#  '医療法人社団 伯野外科胃腸科': ['1', '0114843', '12'],
#  'さこう医院': ['1', '0115089', '12'],
#  '幕張台クリニック': ['1', '0115162', '12'],
#  '三上眼科医院': ['1', '0115170', '12'],
#  'ちぐさ診療所': ['1', '0115246', '12'],
#  '本郷内科': ['1', '0115253', '12'],
#  '医療法人社団有相会 最成病院': ['1', '0115675', '12'],
#  '医療法人社団なのはな会 幕張本郷クリニック': ['1', '0116012', '12'],
#  '安久津眼科': ['1', '0116558', '12'],
#  '医療法人社団竹田会 武藤医院': ['1', '0117150', '12'],
#  'ちば整形外科クリニック': ['1', '0117192', '12'],
#  '幕張本郷耳鼻咽喉科医院': ['1', '0117747', '12'],
#  '医療法人社団栗田会 栗田皮フ科': ['1', '0117812', '12'],
#  '古川医院': ['1', '0118141', '12'],
#  '医療法人社団 恵佑会 元山医院': ['1', '0118273', '12'],
#  'おざきクリニック': ['1', '0118380', '12'],
#  '医療法人社団 小羊会 千葉横戸クリニック': ['1', '0118471', '12'],
#  '医療法人社団 善秀会 朝日ヶ丘医院': ['1', '0118992', '12'],
#  '千葉健生病院付属まくはり診療所': ['1', '0119172', '12'],
#  '社会医療法人社団千葉県勤労者医療協会 千葉健生病院': ['1', '0119180', '12'],
#  'ひらおか内科クリニック': ['1', '0119255', '12'],
#  '医療法人社団千秋双葉会 幕張耳鼻咽喉科': ['1', '0119453', '12'],
#  '医療法人社団 あおやぎ眼科': ['1', '0119545', '12'],
#  'メンタルクリニック とみた': ['1', '0119594', '12'],
#  '医療法人社団誠徳会 藤森小児科': ['1', '0119602', '12'],
#  '坂口医院': ['1', '0120089', '12'],
#  '幕張あんず医院': ['1', '0120261', '12'],
#  '医療法人静和会 新検見川メンタルクリニック': ['1', '0120337', '12'],
#  '医療法人杏会 松本クリニック': ['1', '0120451', '12'],
#  '医療法人社団咲心会 和久整形外科': ['1', '0120535', '12'],
#  'いけだメディカルクリニック': ['1', '0120584', '12'],
#  '水野医院': ['1', '0120626', '12'],
#  '医療法人社団 素心館 小林こどもクリニック': ['1', '0120634', '12'],
#  '医療法人社団 正心会 正岡クリニック': ['1', '0120691', '12'],
#  '医療法人社団 花也会 Wクリニックフォーマザーズ幕張': ['1', '0120790', '12'],
#  '本郷眼科': ['1', '0121194', '12'],
#  '信愛クリニック': ['1', '0121319', '12'],
#  '医療法人社団 紫陽花会 落合皮膚科': ['1', '0121392', '12'],
#  '医療法人社団オー・エフ・シー 大森ファミリークリニック': ['1', '0121426', '12'],
#  '医療法人社団聖鳥会 しらゆり眼科': ['1', '0121442', '12'],
#  '本郷並木通り内科': ['1', '0121475', '12'],
#  '宇田川婦人科': ['1', '0121517', '12'],
#  '田村ゆみこ内科クリニック': ['1', '0121525', '12'],
#  '幕張整形外科': ['1', '0121574', '12'],
#  '医療法人社団あおぞら 野瀬はなぞのクリニック': ['1', '0121673', '12'],
#  '幕張おおで眼科': ['1', '0121723', '12'],
#  'たかクリニック': ['1', '0121731', '12'],
#  '医療法人社団MSC 幕張本郷しぶやクリニック': ['1', '0122010', '12'],
#  '医療法人社団 貴駿 幕張本郷整形外科内科': ['1', '0122200', '12'],
#  '医療法人社団 ゆかり会 幕張胃腸クリニック': ['1', '0122499', '12'],
#  '医療法人社団千秋双葉会 幕張キッズクリニック': ['1', '0122622', '12'],
#  '医療法人社団彩心会 花見川ひかり整形外科': ['1', '0122655', '12'],
#  '医療法人健志会 検見川整形外科内科': ['1', '0122770', '12'],
#  '医療法人社団 有光会 花見川眼科': ['1', '0122788', '12'],
#  '医療法人社団江楓会 あかいし脳神経外科クリニック': ['1', '0122812', '12'],
#  '医療法人社団晴山会 平山病院附属 花見川腎クリニック': ['1', '0122838', '12'],
#  'ひろ内科クリニック': ['1', '0122952', '12'],
#  '医療法人社団 福医会 たなか内科クリニック': ['1', '0123034', '12'],
#  '医療法人社団 順啓会 ほしなが耳鼻咽喉科': ['1', '0123125', '12'],
#  '医療法人社団旺仁会 東山整形外科': ['1', '0123182', '12'],
#  '医療法人社団オリーブ会 いとう新検見川クリニック': ['1', '0123190', '12'],
#  '幕張あいけいクリニック': ['1', '0123224', '12'],
#  '医療法人社団恵翔会 岩田こどもクリニック': ['1', '0123612', '12'],
#  '医療法人社団恵翔会 アリス耳鼻咽喉科': ['1', '0123620', '12'],
#  '花見川中央クリニック': ['1', '0123653', '12'],
#  '医療法人社団緑隆会 みどり耳鼻咽喉科': ['1', '0123703', '12'],
#  '石川小児科医院': ['1', '0123711', '12'],
#  '一般社団法人共進会 まくはり南クリニック': ['1', '0123745', '12'],
#  '入江眼科医院': ['1', '0123760', '12'],
#  '社会福祉法人 煌徳会 般若クリニック': ['1', '0123786', '12'],
#  '検見川ウィメンズクリニック': ['1', '0124032', '12'],
#  'えじま 医院': ['1', '0124156', '12'],
#  '医療法人社団三水会 北千葉整形外科幕張クリニック': ['1', '0124164', '12'],
#  '南花園クリニック': ['1', '0124255', '12'],
#  '医療法人社団桜誠会 桜並木心療医院': ['1', '0124305', '12'],
#  'あつみ眼科': ['1', '0124586', '12'],
#  'いちのせ耳鼻咽喉科': ['1', '0124610', '12'],
#  '幕張不整脈クリニック': ['1', '0124677', '12'],
#  '医療法人社団恵佑会 宮野木台クリニック': ['1', '0124685', '12'],
#  '柴田医院': ['1', '0103895', '12'],
#  '社会医療法人社団千葉県勤労者医療協会 北部診療所': ['1', '0111039', '12'],
#  '小林眼科医院': ['1', '0111310', '12'],
#  '谷口眼科クリニック': ['1', '0111658', '12'],
#  '三枝整形外科医院': ['1', '0112631', '12'],
#  '鈴木眼科': ['1', '0113043', '12'],
#  '大塚クリニック': ['1', '0113340', '12'],
#  'たじま産婦人科': ['1', '0113480', '12'],
#  '医療法人社団薬王会 緑町診療所': ['1', '0113506', '12'],
#  '黒砂皮膚科医院': ['1', '0114041', '12'],
#  '医療法人社団光知会 千葉健康クリニック': ['1', '0114298', '12'],
#  '医療法人社団光正会 川島医院': ['1', '0114454', '12'],
#  '医療法人社団仁正会 神津医院': ['1', '0114629', '12'],
#  '医療法人社団山紫会 谷嶋医院': ['1', '0114637', '12'],
#  '医療法人社団以仁会 稲毛サティクリニック': ['1', '0114918', '12'],
#  'にしちば心和クリニック': ['1', '0115451', '12'],
#  '医療法人社団北滋会 中川産婦人科': ['1', '0115469', '12'],
#  '医療法人社団東伸会 井原医院': ['1', '0115634', '12'],
#  '医療法人社団清雄会 宇井内科クリニック': ['1', '0115741', '12'],
#  '社会医療法人社団健脳会 千葉脳神経外科病院': ['1', '0115758', '12'],
#  '医療法人社団 みうらクリニック': ['1', '0116236', '12'],
#  '鈴木内科クリニック': ['1', '0116491', '12'],
#  '岡本皮膚科': ['1', '0116970', '12'],
#  'しんわクリニック・稲毛': ['1', '0117119', '12'],
#  '勝又内科医院': ['1', '0117267', '12'],
#  '稲毛整形外科': ['1', '0117622', '12'],
#  '髙橋こどもクリニック': ['1', '0117796', '12'],
#  '栄光クリニック': ['1', '0117861', '12'],
#  '医療法人社団ふけ会 富家千葉病院': ['1', '0118042', '12'],
#  'けいよう内科クリニック': ['1', '0118059', '12'],
#  '愛和クリニック': ['1', '0118356', '12'],
#  '医療法人社団 三康会 田中クリニック': ['1', '0118521', '12'],
#  '池上内科医院': ['1', '0118588', '12'],
#  '医療法人社団 三水会 北千葉整形外科稲毛クリニック': ['1', '0118836', '12'],
#  '露崎こどもクリニック': ['1', '0118968', '12'],
#  '木内クリニック': ['1', '0119107', '12'],
#  '山田医院': ['1', '0119115', '12'],
#  '近藤医院': ['1', '0119131', '12'],
#  'なかむら泌尿器科': ['1', '0119230', '12'],
#  'のむら耳鼻咽喉科': ['1', '0119305', '12'],
#  '医療法人社団至峰会 千草台なかむらクリニック': ['1', '0119529', '12'],
#  '赤塚小児科医院': ['1', '0119578', '12'],
#  '武田クリニック': ['1', '0119586', '12'],
#  '水上医院': ['1', '0119719', '12'],
#  '医療法人社団Vision Quest Japan 吉田眼科': ['1', '0119826', '12'],
#  'ちば生活習慣病内科クリニック': ['1', '0119867', '12'],
#  '菅沼医院': ['1', '0120055', '12'],
#  '医療法人社団 稲毛皮フ科クリニック': ['1', '0120097', '12'],
#  '武久レディースクリニック': ['1', '0120121', '12'],
#  '医療法人社団遊山会 耳鼻咽喉科サージセンターちば': ['1', '0120329', '12'],
#  '長沼眼科': ['1', '0120360', '12'],
#  '医療法人社団親月会 千葉中央外科内科': ['1', '0120378', '12'],
#  '医療法人社団元志会 いなげ耳鼻咽喉科': ['1', '0120428', '12'],
#  '医療法人社団明香会 カヤマ内科泌尿器科': ['1', '0120444', '12'],
#  'せんげん通りクリニック': ['1', '0121020', '12'],
#  '林医院': ['1', '0121046', '12'],
#  '医療法人社団康葉会 稲毛整形外科クリニック': ['1', '0121129', '12'],
#  '千葉メンタルクリニック': ['1', '0121137', '12'],
#  '稲毛中央外科医院': ['1', '0121145', '12'],
#  '医療法人社団 千葉糖尿病内科会 しいなクリニック': ['1', '0121186', '12'],
#  '医療法人社団松育会 むらまつクリニック': ['1', '0121244', '12'],
#  '医療法人社団 幸葉会 西千葉整形外科': ['1', '0121434', '12'],
#  '医療法人社団三育会 宮野木外科・内科': ['1', '0121467', '12'],
#  '稲毛バースクリニック': ['1', '0121756', '12'],
#  '医療法人社団マリヤ・クリニック': ['1', '0121855', '12'],
#  '社会福祉法人生活クラブ 生活クラブ風の村園生診療所': ['1', '0121970', '12'],
#  '医療法人社団 新藤医院': ['1', '0122234', '12'],
#  '医療法人社団ティ&ケイ くろさきこどもクリニック': ['1', '0122242', '12'],
#  '医療法人社団 翠明会 山王整形クリニック': ['1', '0122275', '12'],
#  '稲毛むらさき内科クリニック': ['1', '0122309', '12'],
#  'たけだ眼科': ['1', '0122341', '12'],
#  '医療法人社団 公伸会 黒砂台診療所': ['1', '0122457', '12'],
#  '医療法人社団亮山会 わかば皮膚科': ['1', '0122648', '12'],
#  '医療法人社団ガラテア ぴあーすクリニック': ['1', '0122994', '12'],
#  'あおきこどもクリニック': ['1', '0123141', '12'],
#  'スラージュ内科クリニック': ['1', '0123281', '12'],
#  'かまだ皮フ科': ['1', '0123307', '12'],
#  '医療法人社団AZMEDICAL 小中台クリニック': ['1', '0123406', '12'],
#  '稲毛神経内科・メモリークリニック': ['1', '0123596', '12'],
#  '医療法人社団 十誠会 川上診療所': ['1', '0123687', '12'],
#  '医療法人社団 永福会 永井クリニック': ['1', '0123919', '12'],
#  '石川医院': ['1', '0123943', '12'],
#  '医療法人社団駿心会 いなげ西病院': ['1', '0124107', '12'],
#  '医療法人社団幸訪会 いなげファミリー内科クリニック': ['1', '0124115', '12'],
#  '医療法人社団駿心会 いなげ腎クリニック': ['1', '0124180', '12'],
#  '医療法人社団駿心会 稲毛病院': ['1', '0124206', '12'],
#  '医療法人社団福寿会 千葉北眼科': ['1', '0124271', '12'],
#  '医療法人社団千葉ハート 千葉ハートクリニック': ['1', '0124289', '12'],
#  '医療法人社団ことら会 稲毛とらのこ産婦人科': ['1', '0124313', '12'],
#  '医療法人社団十誠会 川上診療所分院': ['1', '0124321', '12'],
#  '医療法人社団佐々木記念会 千葉北佐々木クリニック': ['1', '0124362', '12'],
#  '医療法人社団修生会 大岩眼科': ['1', '0124453', '12'],
#  '医療法人社団 直心会 轟クリニック': ['1', '0124503', '12'],
#  '千葉在宅診療クリニック': ['1', '0124560', '12'],
#  '医療法人社団響心会 稲毛駅前ホームクリニック': ['1', '0124578', '12'],
#  '都賀診療所': ['1', '0102863', '12'],
#  '工藤内科医院': ['1', '0103671', '12'],
#  '平沢小児科': ['1', '0103853', '12'],
#  'みつわ台中央診療所': ['1', '0111047', '12'],
#  '出口眼科医院': ['1', '0111971', '12'],
#  '都賀眼科クリニック': ['1', '0113019', '12'],
#  '勝俣内科小児科': ['1', '0113100', '12'],
#  '高品クリニック': ['1', '0113126', '12'],
#  '前田皮膚科医院': ['1', '0113316', '12'],
#  '水野内科循環器科医院': ['1', '0113365', '12'],
#  '医療法人社団聖洋会 みつわ台クリニック': ['1', '0113621', '12'],
#  '医療法人社団誠馨会 総泉病院': ['1', '0113654', '12'],
#  '医療法人社団六治会 石渡内科': ['1', '0113779', '12'],
#  '医療法人社団 こま内科・呼吸器内科': ['1', '0113803', '12'],
#  '医療法人社団亮山会 つが皮膚科医院': ['1', '0114363', '12'],
#  '高圓内科医院': ['1', '0114702', '12'],
#  '医療法人社団誠馨会 千葉中央メディカルセンター': ['1', '0114728', '12'],
#  '医療法人社団興仁会 板谷内科クリニック': ['1', '0114926', '12'],
#  '高根町整形外科': ['1', '0115279', '12'],
#  'なかむら医院': ['1', '0115394', '12'],
#  '医療法人社団青草会 篠﨑病院': ['1', '0115824', '12'],
#  '医療法人社団明生会 東葉クリニック千葉': ['1', '0115832', '12'],
#  '医療法人社団邦葉会 小山内科': ['1', '0115949', '12'],
#  'あべひろきこどもクリニック': ['1', '0115956', '12'],
#  '医療法人社団 中山内科クリニック': ['1', '0116053', '12'],
#  '千葉内科クリニック': ['1', '0116251', '12'],
#  '医療法人社団鳳仁会 若林皮膚科医院': ['1', '0117374', '12'],
#  '一般財団法人柏戸記念財団 小倉台柏戸クリニック': ['1', '0117424', '12'],
#  '医療法人社団 祐紀会 小松耳鼻咽喉科医院': ['1', '0117457', '12'],
#  '医療法人社団若竹会宮内泌尿器科医院': ['1', '0117481', '12'],
#  'ちしろ台眼科': ['1', '0117713', '12'],
#  '医療法人社団謙和会 高品内科婦人科医院': ['1', '0117820', '12'],
#  '医療法人社団 榎会 千城台クリニック': ['1', '0118182', '12'],
#  '医療法人社団芳旭会 小関医院': ['1', '0118216', '12'],
#  '医療法人社団 都賀内科クリニック': ['1', '0118513', '12'],
#  'つがクリニック': ['1', '0118828', '12'],
#  '千葉市大宮学園': ['1', '0119198', '12'],
#  '医療法人社団長寿会 長谷川整形外科': ['1', '0119370', '12'],
#  '久保田医院': ['1', '0119396', '12'],
#  '医療法人社団若葉会 若葉整形外科クリニック': ['1', '0119511', '12'],
#  '堀田医院': ['1', '0119628', '12'],
#  '医療法人社団颯晃会 御成台整形外科': ['1', '0119958', '12'],
#  '千葉市桜木園': ['1', '0120154', '12'],
#  '医療法人社団志栄会 都賀レディースクリニック': ['1', '0120162', '12'],
#  '松永クリニック小児科・小児外科': ['1', '0120196', '12'],
#  '篠クリニック': ['1', '0120295', '12'],
#  '医療法人社団千葉いずみ会 泉中央病院': ['1', '0120543', '12'],
#  '医療法人社団 クレド 医療法人社団 クレド さとうクリニック': ['1', '0120873', '12'],
#  '清宮医院': ['1', '0120931', '12'],
#  'ふるかわクリニック': ['1', '0121327', '12'],
#  '医療法人社団 ひよこ会 ぬまざわ小児科・耳鼻咽喉科クリニック': ['1', '0121343', '12'],
#  '伊予クリニック': ['1', '0121376', '12'],
#  '西都賀クリニック': ['1', '0121533', '12'],
#  '医療法人社団慈徳会 つがメンタルクリニック': ['1', '0121657', '12'],
#  'たて産婦人科': ['1', '0121921', '12'],
#  'あおばクリニック': ['1', '0122002', '12'],
#  '医療法人社団淳朋会 都賀さいとう整形外科': ['1', '0122044', '12'],
#  '医療法人社団桐伸会 藤井クリニック': ['1', '0122168', '12'],
#  '医療法人社団岩鷲会 つばめ耳鼻咽喉科': ['1', '0122218', '12'],
#  '医療法人社団 みぞぶち眼科': ['1', '0122382', '12'],
#  '医療法人社団 世恵会 小倉台福田医院': ['1', '0123000', '12'],
#  '楽多クリニック': ['1', '0123018', '12'],
#  'らいむらクリニック': ['1', '0123083', '12'],
#  '医療法人社団 斎真会 古川医院': ['1', '0123109', '12'],
#  '内田耳鼻咽喉科': ['1', '0123299', '12'],
#  '医療法人社団 邦潤会 わかば宮本医院': ['1', '0123455', '12'],
#  '医療法人社団千城台耳鼻咽喉科 千城台耳鼻咽喉科医院': ['1', '0123588', '12'],
#  '医療法人社団匡仁会 梶田医院': ['1', '0124008', '12'],
#  '木下婦人科医院': ['1', '0124016', '12'],
#  '若松町ひまわりクリニック': ['1', '0124099', '12'],
#  '千野整形外科': ['1', '0124214', '12'],
#  '医療法人社団しょうじ しょうじ内科': ['1', '0124412', '12'],
#  '土屋内科医院': ['1', '0124446', '12'],
#  '忍足小児科': ['1', '0103077', '12'],
#  '大木戸整形外科': ['1', '0112102', '12'],
#  'あすなろ皮膚科': ['1', '0114009', '12'],
#  '医療法人社団 角栄団地診療所': ['1', '0114736', '12'],
#  '医療法人社団阿 の会 坂の上外科': ['1', '0115378', '12'],
#  '医療法人社団九陵会 小渋医院': ['1', '0115444', '12'],
#  'みどり泌尿器科皮フ科医院': ['1', '0115519', '12'],
#  '山本医院': ['1', '0115527', '12'],
#  '医療法人社団総和会 武村内科医院': ['1', '0115659', '12'],
#  'やまもとクリニック': ['1', '0115774', '12'],
#  '医療法人社団櫻佑会 昭和の森クリニック': ['1', '0115857', '12'],
#  '医療法人社団本郷会 鎌取内科': ['1', '0115865', '12'],
#  '医療法人社団千秋双葉会 双葉耳鼻咽喉科': ['1', '0116186', '12'],
#  '医療法人社団 令和会 鎌取駅前クリニック': ['1', '0116194', '12'],
#  '医療法人社団至玄清秀会 篠崎医院': ['1', '0116293', '12'],
#  '医療法人社団緑真会 学園前クリニック': ['1', '0116301', '12'],
#  '医療法人社団五月会 とけレディースクリニック': ['1', '0116343', '12'],
#  '田宮クリニック': ['1', '0116368', '12'],
#  'あすみが丘内科クリニック': ['1', '0116418', '12'],
#  'おゆみの整形外科クリニック': ['1', '0116517', '12'],
#  'にこにこ胃腸科・整形外科': ['1', '0116566', '12'],
#  'おゆみの耳鼻咽喉科': ['1', '0116590', '12'],
#  '医療法人社団裕仁会 かまとり医院': ['1', '0116608', '12'],
#  'かまとり皮ふ科': ['1', '0116699', '12'],
#  '医療法人社団誠心会 あすみが丘耳鼻咽喉科気管食道科': ['1', '0116798', '12'],
#  '医療法人社団芳友会 大久保クリニック': ['1', '0116806', '12'],
#  '医療法人社団紫雲会 千葉南病院': ['1', '0116855', '12'],
#  '医療法人社団あすみ会 あすみが丘佐野眼科': ['1', '0116947', '12'],
#  '医療法人社団緑生会 あらい整形外科': ['1', '0117069', '12'],
#  '医療法人社団明康会 かない内科': ['1', '0117135', '12'],
#  '川村クリニック': ['1', '0117176', '12'],
#  '若新医院': ['1', '0117242', '12'],
#  '鎌取メンタルクリニック': ['1', '0117382', '12'],
#  'こんだこども医院': ['1', '0117390', '12'],
#  'ひらた内科・小児科クリニック': ['1', '0117689', '12'],
#  '医療法人社団 夢の樹会 のせこどもクリニック': ['1', '0118075', '12'],
#  '医療法人社団 二葉会 かまとり眼科クリニック': ['1', '0118372', '12'],
#  '医療法人社団 詠冴会 千葉整形外科内科': ['1', '0118422', '12'],
#  'あすみが丘メンタルクリニック': ['1', '0118661', '12'],
#  '医療法人社団 三敬会 忍足眼科医院': ['1', '0118703', '12'],
#  '医療法人社団 淳英会 おゆみの診療所': ['1', '0118778', '12'],
#  '鈴木脳神経外科クリニック': ['1', '0118810', '12'],
#  '医療法人社団 幸樹会 おゆみのクリニック': ['1', '0118885', '12'],
#  '医療法人社団 鏡一会 鏡戸病院': ['1', '0118935', '12'],
#  '小池皮膚科': ['1', '0119313', '12'],
#  'ゲートウェイクリニックおゆみ野中央': ['1', '0119743', '12'],
#  '医療法人社団星瞳会 まなこどもクリニック': ['1', '0119792', '12'],
#  '西郡整形外科': ['1', '0119925', '12'],
#  '医療法人社団健育会 さとう小児科医院': ['1', '0119982', '12'],
#  '医療法人社団武田会 かまとり武田肛門科': ['1', '0120188', '12'],
#  'おがわ医院': ['1', '0120410', '12'],
#  '医療法人社団恵信会おゆみ野南医院': ['1', '0120501', '12'],
#  '医療法人社団廣和会おりはら耳鼻咽喉科': ['1', '0120519', '12'],
#  '土気駅前皮膚科': ['1', '0120576', '12'],
#  '佐野クリニック': ['1', '0120659', '12'],
#  '医療法人社団 豊心会 中野内科クリニック': ['1', '0120766', '12'],
#  '昭和の森耳鼻咽喉科': ['1', '0120865', '12'],
#  '内科・循環器内科 やまだクリニック': ['1', '0120881', '12'],
#  '医療法人社団 錦昌会 千葉こどもとおとなの整形外科': ['1', '0121160', '12'],
#  '医療法人社団 寄命会 椎名崎クリニック': ['1', '0121178', '12'],
#  '緑こころのクリニック': ['1', '0121509', '12'],
#  '福元クリニック': ['1', '0121624', '12'],
#  'いやしのメンタルクリニック誉田': ['1', '0121780', '12'],
#  '医療法人社団ファーティル みやけウィメンズクリニック': ['1', '0121913', '12'],
#  '医療法人社団アンダンテ きくちこどもクリニック': ['1', '0121947', '12'],
#  '医療法人社団錦昌会 みどりのは 葉記念病院': ['1', '0122143', '12'],
#  '吉原クリニック': ['1', '0122366', '12'],
#  '花レディースクリニック': ['1', '0122721', '12'],
#  '医療法人社団 みどりクリニック': ['1', '0122747', '12'],
#  '医療法人社団淳英会 おゆみの中央病院': ['1', '0122820', '12'],
#  '医療法人社団 史輝会 おゆみ野レインボー皮ふ科': ['1', '0122879', '12'],
#  'みねた婦人科クリニック': ['1', '0123315', '12'],
#  '医療法人社団 賢仁会 あすみが丘医院': ['1', '0123349', '12'],
#  '医療法人社団 大志会 ちばグリーン整形外科': ['1', '0123414', '12'],
#  '医療法人社団寄命会 土気腎クリニック': ['1', '0123737', '12'],
#  '医療法人社団房総武田会ながしまクリニック': ['1', '0123810', '12'],
#  'あずま腎クリニック': ['1', '0123984', '12'],
#  'ドクターケンクリニック': ['1', '0124040', '12'],
#  "K'sクリニックおゆみ野": ['1', '0124354', '12'],
#  '医療法人社団賢仁会 こどもの森クリニック': ['1', '0124420', '12'],
#  '医療法人社団祐会 おゆみ野眼科クリニック': ['1', '0124495', '12'],
#  '医療法人社団 圭恵会 すずらんクリニックあすみが丘': ['1', '0124693', '12'],
#  'たなべ小児科医院': ['1', '0103523', '12'],
#  'ガーデンタウンクリニック': ['1', '0103630', '12'],
#  '高根産科婦人科医院': ['1', '0103861', '12'],
#  '稲毛診療所': ['1', '0110734', '12'],
#  '関根整形外科医院': ['1', '0111518', '12'],
#  'いそべ利伊医院': ['1', '0111534', '12'],
#  '千葉市心身障害児総合通園センター': ['1', '0111831', '12'],
#  '福山医院': ['1', '0112110', '12'],
#  '千葉市立海浜病院': ['1', '0112524', '12'],
#  '千葉県精神科医療センター': ['1', '0112672', '12'],
#  '由宇クリニック': ['1', '0112730', '12'],
#  '千葉県救急医療センター': ['1', '0113274', '12'],
#  '医療法人社団慈洲会 瀨古医院': ['1', '0113456', '12'],
#  '医療法人社団光静会 成田医院': ['1', '0113589', '12'],
#  '医療法人社団四輝会 伊藤小児科': ['1', '0113613', '12'],
#  '医療法人鉄蕉会 亀田総合病院附属 幕張クリニック': ['1', '0113811', '12'],
#  '高洲中央医院': ['1', '0113928', '12'],
#  'たみたに小児科': ['1', '0113993', '12'],
#  '医療法人社団協和会 稲浜クリニック': ['1', '0114132', '12'],
#  'たかた眼科': ['1', '0114215', '12'],
#  'たかた整形外科': ['1', '0114223', '12'],
#  '美浜ひふクリニック': ['1', '0114991', '12'],
#  '医療法人社団地山会 海浜整形外科': ['1', '0115196', '12'],
#  '医療法人社団順風会 杉田耳鼻咽喉科': ['1', '0115204', '12'],
#  '医療法人社団 沼野胃腸科内科': ['1', '0115543', '12'],
#  '新美浜整形外科': ['1', '0115667', '12'],
#  'いなげ海岸クリニック': ['1', '0115790', '12'],
#  '京葉眼科医院': ['1', '0115931', '12'],
#  '医療法人社団 森整形外科クリニック': ['1', '0116137', '12'],
#  '幕張ベイクリニック': ['1', '0116152', '12'],
#  '医療法人社団樹徳会 眼科美浜クリニック': ['1', '0116392', '12'],
#  '深浦内科クリニック': ['1', '0116624', '12'],
#  '稲毛海岸神経科クリニック': ['1', '0117051', '12'],
#  '医療法人社団 赤尾クリニック': ['1', '0117143', '12'],
#  '医療法人社団恒心会 遠藤クリニック': ['1', '0117697', '12'],
#  '医療法人社団桃舞会 たかはし医院': ['1', '0117754', '12'],
#  '愛光クリニック': ['1', '0118133', '12'],
#  '医療法人社団 けやき会 なつめ皮ふ科': ['1', '0118158', '12'],
#  '幸町中央診療所': ['1', '0118570', '12'],
#  '医療法人社団 誠馨会 自動車事故対策機構 千葉療護センター': ['1', '0118646', '12'],
#  '美浜神経内科': ['1', '0118653', '12'],
#  '海浜パーククリニック': ['1', '0118802', '12'],
#  'いの皮フ科': ['1', '0119214', '12'],
#  'おおた小児科': ['1', '0119297', '12'],
#  '公益財団法人ちば県民保健予防財団 総合健診センター': ['1', '0119479', '12'],
#  '医療法人社団樹徳会 海浜幕張眼科': ['1', '0119503', '12'],
#  '医療法人社団 うたせ耳鼻咽喉科・アレルギー科': ['1', '0119552', '12'],
#  '小林整形外科': ['1', '0119610', '12'],
#  'ささき整形リハビリテーションクリニック': ['1', '0119669', '12'],
#  'あかねこどもクリニック': ['1', '0119834', '12'],
#  '医療法人社団祥孝会 幕張西クリニック': ['1', '0119842', '12'],
#  'ぴあ心療クリニック': ['1', '0119966', '12'],
#  '医療法人社団和則会 玉井こどもクリニック': ['1', '0120253', '12'],
#  '医療法人社団扇心会 幕張マリブクリニック': ['1', '0120352', '12'],
#  '医療法人社団滋聡会 うたせメディカルクリニック': ['1', '0120527', '12'],
#  '医療法人社団 前田記念 まえだ耳鼻咽喉科': ['1', '0120618', '12'],
#  '医療法人 鉄蕉会 亀田MTGクリニック': ['1', '0120824', '12'],
#  '医療法人社団 嘉泉会 うたせ眼科': ['1', '0121228', '12'],
#  '医療法人社団 聖史会 高洲公園心療医院': ['1', '0121285', '12'],
#  '医療法人社団 健輝会 八木内科クリニック': ['1', '0121293', '12'],
#  '池田クリニック': ['1', '0121558', '12'],
#  '打瀬並木道クリニック': ['1', '0121798', '12'],
#  '幕張ハートクリニック': ['1', '0121806', '12'],
#  '医療法人社団三水会 北千葉整形外科美浜クリニック': ['1', '0121830', '12'],
#  '医療法人社団魁芙会 千葉ポートメディカルクリニック': ['1', '0121939', '12'],
#  '医療法人社団誠仁会 みはま病院': ['1', '0121988', '12'],
#  '医療法人社団創志会 千葉マリンクリニック': ['1', '0122077', '12'],
#  '髙柳耳鼻咽喉科': ['1', '0122127', '12'],
#  'ふじた耳鼻咽喉科': ['1', '0122150', '12'],
#  '医療法人グリーンエミネンス 古峡みはまクリニック': ['1', '0122259', '12'],
#  '医療法人社団THY とくやまクリニック': ['1', '0122283', '12'],
#  '医療法人社団小羊会 高洲訪問クリニック': ['1', '0122531', '12'],
#  '東京ベイ先端医療・幕張クリニック': ['1', '0122663', '12'],
#  'ヘルスケアクリニック川島内科・婦人科': ['1', '0122911', '12'],
#  '社会福祉法人 兼愛会 しょうじゅクリニック': ['1', '0122937', '12'],
#  'うたせ内科・呼吸器内科': ['1', '0122945', '12'],
#  '医療法人社団明順会 瀬古眼科': ['1', '0123042', '12'],
#  '医療法人社団 千種会 あいおいクリニック': ['1', '0123133', '12'],
#  '舘野医院': ['1', '0123323', '12'],
#  '医療法人社団 裕恵会 とおやま医院': ['1', '0123372', '12'],
#  '医療法人社団 三和会 わらがいこどもクリニック': ['1', '0123380', '12'],
#  '幕張ベイタウン整形': ['1', '0123471', '12'],
#  '医療法人鉄蕉会 亀田IVFクリニック幕張': ['1', '0123547', '12'],
#  '医療法人社団汐風 きむらクリニック': ['1', '0123851', '12'],
#  '医療法人社団哲昇会 山﨑内科': ['1', '0123950', '12'],
#  '医療法人社団柏義会 こん内科クリニック': ['1', '0124149', '12'],
#  'Mスキンクリニック': ['1', '0124388', '12'],
#  '医療法人社団創志会 千葉マリンこどもクリニック': ['1', '0124396', '12'],
#  'Sleep Rest Clinic 幕張': ['1', '0124479', '12'],
#  '美浜ホームクリニック': ['1', '0124487', '12'],
#  '医療法人社団彩翔会あそうクリニック': ['1', '0124545', '12'],
#  '真砂クリニック': ['1', '0124594', '12'],
#  '医療法人社団響心会 稲毛ベイサイドホームクリニック ': ['1', '0124651', '12'],
#  '稲毛海岸脳神経外科クリニック': ['1', '0124701', '12'],
#  '野口胃腸科外科医院': ['1', '1300805', '12'],
#  '医療法人厚仁会 内田病院': ['1', '1310044', '12'],
#  '銚子市立病院': ['1', '1310051', '12'],
#  '医療法人積仁会 島田総合病院': ['1', '1310119', '12'],
#  '医療法人芳仁会 海村医院本院': ['1', '1310291', '12'],
#  '宮内内科小児科医院': ['1', '1310309', '12'],
#  '力武医院': ['1', '1310366', '12'],
#  '医療法人寿徳会 加瀬外科医院': ['1', '1310374', '12'],
#  '大野眼科': ['1', '1310457', '12'],
#  '医療法人社団延寿会 西原医院': ['1', '1310473', '12'],
#  '医療法人社団圭寿会 兒玉病院': ['1', '1310499', '12'],
#  '医療法人社団寿康会 宇野沢医院': ['1', '1310507', '12'],
#  '医療法人社団耳鼻咽喉科髙津医院': ['1', '1310523', '12'],
#  '医療法人社団今村医院': ['1', '1310531', '12'],
#  '医療法人社団昭仁会 安藤医院': ['1', '1310564', '12'],
#  '関谷医院': ['1', '1310572', '12'],
#  '医療法人社団双葉会 宮内医院': ['1', '1310580', '12'],
#  '医療法人社団 石井皮膚科診療所': ['1', '1310598', '12'],
#  'いしがみ小児科': ['1', '1310622', '12'],
#  '片倉外科医院': ['1', '1310630', '12'],
#  '吉野クリニック': ['1', '1310655', '12'],
#  '医療法人社団廣仁会 東京堂クリニック': ['1', '1310663', '12'],
#  '浅利クリニック': ['1', '1310671', '12'],
#  '海村医院分院': ['1', '1310689', '12'],
#  '野口皮膚科クリニック': ['1', '1310721', '12'],
#  'たせい耳鼻咽喉科クリニック': ['1', '1310762', '12'],
#  '医療法人社団 聡誠会 なゆきクリニック': ['1', '1310788', '12'],
#  '児玉メディカルクリニック': ['1', '1310804', '12'],
#  '医療法人社団 新生会 医療法人社団 新生会 新生産婦人科': ['1', '1310838', '12'],
#  'くぼたこどもクリニック': ['1', '1310853', '12'],
#  'さいとう眼科クリニック': ['1', '1310879', '12'],
#  '医療法人社団徳清会 三枝整形外科医院': ['1', '1310895', '12'],
#  '医療法人社団洋光会 協和医院': ['1', '1310911', '12'],
#  '須藤医院': ['1', '1310937', '12'],
#  '医療法人社団 恒友会 銚子こころクリニック': ['1', '1310945', '12'],
#  '江里川医院': ['1', '2701183', '12'],
#  '岳医院': ['1', '2701571', '12'],
#  '大倉内科小児科医院': ['1', '2702264', '12'],
#  '坂井小児科医院': ['1', '2702397', '12'],
#  '藤巻クリニック': ['1', '2702595', '12'],
#  '貝田クリニック': ['1', '2702611', '12'],
#  '吉田耳鼻咽喉科医院': ['1', '2702637', '12'],
#  '医療法人静和会 中山病院': ['1', '2710036', '12'],
#  '医療法人 式場病院': ['1', '2710176', '12'],
#  '医療法人社団一条会 一条会病院': ['1', '2710218', '12'],
#  '国府台眼科': ['1', '2710358', '12'],
#  '石黒医院': ['1', '2710515', '12'],
#  '船津整形外科内科小児科医院': ['1', '2710598', '12'],
#  '尾林内科医院': ['1', '2710622', '12'],
#  '安藤病院': ['1', '2710655', '12'],
#  '山本内科小児科医院': ['1', '2710705', '12'],
#  '石森整形外科皮膚科医院': ['1', '2710739', '12'],
#  '市川市おひさまキッズ': ['1', '2710796', '12'],
#  '小林呼吸器科外科医院': ['1', '2710853', '12'],
#  '内科行徳診療所': ['1', '2710945', '12'],
#  '池田神経内科クリニック': ['1', '2710960', '12'],
#  '成毛医院': ['1', '2710978', '12'],
#  '斎藤産婦人科眼科': ['1', '2711158', '12'],
#  '寺島医院': ['1', '2711224', '12'],
#  '両総医院': ['1', '2711364', '12'],
#  '近藤小児科': ['1', '2711422', '12'],
#  '土橋医院': ['1', '2711448', '12'],
#  '篠塚医院': ['1', '2711521', '12'],
#  '滝沢医院': ['1', '2711554', '12'],
#  '廣瀬医院': ['1', '2711711', '12'],
#  '二階堂医院': ['1', '2711802', '12'],
#  '門田整形外科医院': ['1', '2711836', '12'],
#  '宏成医院': ['1', '2711919', '12'],
#  '伊藤眼科医院': ['1', '2711935', '12'],
#  '医療法人社団健医会 セントラル眼科クリニック': ['1', '2711943', '12'],
#  '医療法人社団朋正会 熊谷外科整形外科医院': ['1', '2712032', '12'],
#  '吉田小児科医院': ['1', '2712040', '12'],
#  '医療法人社団 高仁堂医院': ['1', '2712107', '12'],
#  '高中医院': ['1', '2712123', '12'],
#  '三本松クリニック': ['1', '2712156', '12'],
#  '古谷皮膚科クリニック': ['1', '2712172', '12'],
#  '大塚医院': ['1', '2712313', '12'],
#  '中村耳鼻咽喉科医院': ['1', '2712347', '12'],
#  '相之川慶信会医院': ['1', '2712370', '12'],
#  '医療法人社団調和会 南行徳眼科クリニック': ['1', '2712487', '12'],
#  '医療法人社団悠水会 うちだ内科クリニック': ['1', '2712495', '12'],
#  '医療法人社団平静会 大村病院': ['1', '2712503', '12'],
#  '竜崎医院': ['1', '2712511', '12'],
#  '医療法人社団 市川クリニック': ['1', '2712537', '12'],
#  '医療法人社団慈恩会 吉岡医院': ['1', '2712545', '12'],
#  '医療法人社団恩明会 塩浜宮崎医院': ['1', '2712560', '12'],
#  '医療法人社団則由会 水島耳鼻咽喉科': ['1', '2712586', '12'],
#  '大谷医院': ['1', '2712610', '12'],
#  'すみや耳鼻咽喉科': ['1', '2712636', '12'],
#  '医療法人社団万美会 津田眼科医院': ['1', '2712644', '12'],
#  '医療法人社団 木暮医院': ['1', '2712651', '12'],
#  '竹内クリニック': ['1', '2712719', '12'],
#  '医療法人社団 小菅医院': ['1', '2712727', '12'],
#  '医療法人社団 国井整形外科': ['1', '2712735', '12'],
#  '医療法人社団徳山会 東菅野診療所': ['1', '2712768', '12'],
#  '仁整形外科': ['1', '2712776', '12'],
#  '医療法人社団明誠会 ありもと耳鼻咽喉科医院': ['1', '2712826', '12'],
#  '医療法人社団 菊池外科医院': ['1', '2712875', '12'],
#  '医療法人社団順心会 まえだ小児科医院': ['1', '2712883', '12'],
#  '社会医療法人社団千葉県勤労者医療協会 市川市民診療所': ['1', '2712891', '12'],
#  '伊藤内科医院': ['1', '2712917', '12'],
#  '医療法人社団 吉岡産婦人科医院': ['1', '2712925', '12'],
#  '医療法人社団三世会 大高医院': ['1', '2712933', '12'],
#  '上井内科胃腸科医院': ['1', '2712941', '12'],
#  '半沢クリニック': ['1', '2712966', '12'],
#  '白石整形外科クリニック': ['1', '2712990', '12'],
#  '医療法人社団新友会 本八幡腎クリニック': ['1', '2713014', '12'],
#  '北沢眼科医院': ['1', '2713055', '12'],
#  '慶友整形外科医院': ['1', '2713089', '12'],
#  '医療法人社団凌雲会 根本産婦人科医院': ['1', '2713097', '12'],
#  '医療法人社団信道会 姚医院': ['1', '2713105', '12'],
#  '医療法人社団慈正会 日比医院': ['1', '2713113', '12'],
#  '加藤外科内科クリニック': ['1', '2713121', '12'],
#  '医療法人社団恵愛会 小谷整形外科': ['1', '2713154', '12'],
#  '医療法人社団式場記念会 式場隆三郎記念クリニック': ['1', '2713162', '12'],
#  '医療法人社団吉田医院': ['1', '2713204', '12'],
#  '医療法人社団ゆうゆう舎 岩川小児科': ['1', '2713220', '12'],
#  '医療法人社団ゆうゆう舎 伊藤医院': ['1', '2713246', '12'],
#  '田﨑クリニック': ['1', '2713253', '12'],
#  'めめ眼科': ['1', '2713261', '12'],
#  '安田整形外科医院': ['1', '2713279', '12'],
#  'サトウ眼科クリニック': ['1', '2713295', '12'],
#  '小林医院': ['1', '2713303', '12'],
#  '野口クリニック': ['1', '2713345', '12'],
#  '加藤医院': ['1', '2713352', '12'],
#  '大沢医院': ['1', '2713360', '12'],
#  '岩沢医院': ['1', '2713378', '12'],
#  '清仁会行徳クリニック': ['1', '2713402', '12'],
#  '市川医院': ['1', '2713410', '12'],
#  '医療法人社団慶桜会 かねこ医院': ['1', '2713428', '12'],
#  '山下耳鼻咽喉科クリニック': ['1', '2713451', '12'],
#  'いわせ医院': ['1', '2713493', '12'],
#  '星耳鼻咽喉科医院': ['1', '2713527', '12'],
#  '湯本皮膚科クリニック': ['1', '2713535', '12'],
#  '医療法人社団 岩田クリニック': ['1', '2713543', '12'],
#  '大原ファミリークリニック': ['1', '2713592', '12'],
#  '医療法人社団さわやか会 茆原内科医院': ['1', '2713600', '12'],
#  '藤田耳鼻咽喉科医院': ['1', '2713642', '12'],
#  'ましずクリニック': ['1', '2713667', '12'],
#  '中島整形外科': ['1', '2713675', '12'],
#  'ひらかわクリニック': ['1', '2713691', '12'],
#  'いなだクリニック': ['1', '2713709', '12'],
#  '栗原皮フ科クリニック': ['1', '2713733', '12'],
#  '皮膚科KSクリニック': ['1', '2713758', '12'],
#  '渡辺医院': ['1', '2713808', '12'],
#  '大町植竹医院': ['1', '2713816', '12'],
#  '南八幡眼科': ['1', '2713832', '12'],
#  '越田医院内科外科ペインクリニック': ['1', '2713881', '12'],
#  'いわはらキッズクリニック': ['1', '2713964', '12'],
#  'とつか内科クリニック': ['1', '2714012', '12'],
#  '医療法人社団 あきつ会 鈴木医院': ['1', '2714061', '12'],
#  '医療法人社団 恵隆会 浮谷クリニック': ['1', '2714079', '12'],
#  'こまきクリニック': ['1', '2714111', '12'],
#  '本八幡南口眼科クリニック': ['1', '2714129', '12'],
#  '山口皮膚科医院': ['1', '2714145', '12'],
#  'ふくざわ内科クリニック': ['1', '2714152', '12'],
#  '医療法人社団 みずほ会 つやま眼科医院': ['1', '2714186', '12'],
#  '医療法人社団 藤巻耳鼻咽喉科医院': ['1', '2714194', '12'],
#  '医療法人社団 紫苑会 たかはしクリニック': ['1', '2714228', '12'],
#  '福谷内科医院': ['1', '2714244', '12'],
#  '川嶋レディースクリニック': ['1', '2714285', '12'],
#  '医療法人社団慈宏会 まさき整形外科': ['1', '2714293', '12'],
#  'いまいクリニック': ['1', '2714319', '12'],
#  '師岡医院': ['1', '2714327', '12'],
#  'たていし内科': ['1', '2714335', '12'],
#  '医療法人社団 能登クリニック': ['1', '2714343', '12'],
#  '医療法人社団 市川肛門科胃腸科クリニック': ['1', '2714368', '12'],
#  '松宮クリニック': ['1', '2714376', '12'],
#  '木下内科クリニック': ['1', '2714384', '12'],
#  '医療法人社団 北国分内科・皮膚科クリニック': ['1', '2714392', '12'],
#  '市川いけだクリニック': ['1', '2714418', '12'],
#  '玉井医院': ['1', '2714442', '12'],
#  '井上医院': ['1', '2714459', '12'],
#  '上白土ハートクリニック': ['1', '2714517', '12'],
#  '医療法人社団嵐川 大野中央病院': ['1', '2714533', '12'],
#  '市川市急病診療所': ['1', '2714558', '12'],
#  '床島耳鼻咽喉科医院': ['1', '2714566', '12'],
#  'えんぴつ公園こどもクリニック': ['1', '2714590', '12'],
#  '医療法人社団泰正会 大町成光堂クリニック': ['1', '2714657', '12'],
#  'いそべ整形外科': ['1', '2714673', '12'],
#  '本八幡クリニック': ['1', '2714681', '12'],
#  '長浜クリニック': ['1', '2714715', '12'],
#  '医療法人社団鴻翠会 柏の森クリニック': ['1', '2714731', '12'],
#  '医療法人社団みずき会 さとう整形外科': ['1', '2714749', '12'],
#  '医療法人社団安誠会 やすはら内科クリニック': ['1', '2714806', '12'],
#  '医療法人社団新友会 新南行徳クリニック': ['1', '2714848', '12'],
#  '医療法人社団聖進会 市川東病院': ['1', '2714855', '12'],
#  '医療法人友康会 行徳中央病院': ['1', '2714863', '12'],
#  '医療法人友康会 行徳中央クリニック': ['1', '2714871', '12'],
#  '医療法人社団 みつはしクリニック': ['1', '2714889', '12'],
#  '医療法人社団 誠安会 あべ内科クリニック': ['1', '2714921', '12'],
#  'ベリークリニック': ['1', '2714939', '12'],
#  '医療法人社団 吉田こどもクリニック': ['1', '2714947', '12'],
#  '医療法人社団八心会 上田医院': ['1', '2715027', '12'],
#  '仁和医院': ['1', '2715035', '12'],
#  '医療法人社団森メンタルクリニック': ['1', '2715043', '12'],
#  'あらたこどもクリニック': ['1', '2715068', '12'],
#  '医療法人社団徳明会 行徳駅前クリニック': ['1', '2715092', '12'],
#  '医療法人社団銀帆会 いいだ眼科': ['1', '2715100', '12'],
#  '医療法人社団馨仁会 妙典内科クリニック': ['1', '2715134', '12'],
#  '医療法人社団恵眼会 滝澤眼科': ['1', '2715142', '12'],
#  '北国分診療所': ['1', '2715167', '12'],
#  'ひかり耳鼻咽喉科': ['1', '2715209', '12'],
#  '若葉クリニック': ['1', '2715258', '12'],
#  '島田クリニック': ['1', '2715266', '12'],
#  'アストラル八幡クリニック': ['1', '2715274', '12'],
#  '竹林眼科': ['1', '2715282', '12'],
#  '清水クリニック': ['1', '2715290', '12'],
#  '医療法人社団 康照会 みやお整形外科': ['1', '2715316', '12'],
#  '医療法人社団 芳英会 医療法人社団 芳英会 吉野内科・神経内科医院': ['1', '2715365', '12'],
#  '医療法人社団幸留会 市川スキンクリニック': ['1', '2715407', '12'],
#  '医療法人社団優佑会 市川ケアクリニック': ['1', '2715456', '12'],
#  '西川クリニック': ['1', '2715464', '12'],
#  '藤巻眼科クリニック': ['1', '2715472', '12'],
#  'らいおんハートクリニック押切': ['1', '2715522', '12'],
#  '斎藤医院': ['1', '2715548', '12'],
#  'ふみ浜耳鼻咽喉科医院': ['1', '2715597', '12'],
#  '医療法人社団 青峯会 医聖よろずクリニック いちかわ院': ['1', '2715613', '12'],
#  'いざなぎクリニック': ['1', '2715621', '12'],
#  '行徳皮膚科クリニック': ['1', '2715639', '12'],
#  '医療法人社団互仁会 スマイル眼科': ['1', '2715647', '12'],
#  '小坂整形外科': ['1', '2715654', '12'],
#  '医療法人社団豊永会 市川駅前眼科': ['1', '2715662', '12'],
#  '医療法人社団市和会 東\ue0a1クリニック市川': ['1', '2715670', '12'],
#  'みずの皮フ科医院': ['1', '2715688', '12'],
#  '日下部クリニック': ['1', '2715696', '12'],
#  '医療法人社団 あいおいクリニック': ['1', '2715753', '12'],
#  'やなぎはら皮ふ科クリニック': ['1', '2715761', '12'],
#  '医療法人社団育明会 市川Rio皮膚科': ['1', '2715787', '12'],
#  '医療法人社団優希会 市川駅前おがわ内科': ['1', '2715803', '12'],
#  '八幡ファミリークリニック': ['1', '2715829', '12'],
#  'ながさか皮膚科クリニック': ['1', '2715837', '12'],
#  '金沢皮フ科医院': ['1', '2715845', '12'],
#  'たきあ胃腸科クリニック': ['1', '2715852', '12'],
#  'ねもとメンタルクリニック': ['1', '2715860', '12'],
#  '医療法人社団涼風会 かわしま皮膚科': ['1', '2715878', '12'],
#  '行徳じんクリニック': ['1', '2715886', '12'],
#  '福田医院': ['1', '2715894', '12'],
#  '森クリニック': ['1', '2715910', '12'],
#  '医療法人社団青和会 やまびこクリニック': ['1', '2715928', '12'],
#  'わたなべ糖内科クリニック': ['1', '2715936', '12'],
#  '医療法人社団靱生会 メディカルプラザ市川駅': ['1', '2715969', '12'],
#  '医療法人社団 緑友会 らいおんハート整形外科リハビリクリニック': ['1', '2715985', '12'],
#  '八幡眼科医院': ['1', '2716017', '12'],
#  'なかさこ医院': ['1', '2716058', '12'],
#  '医療法人社団 わたなべ医院': ['1', '2716082', '12'],
#  '医療法人健志会 行徳整形外科内科': ['1', '2716090', '12'],
#  '医療法人社団 康友会 おおわだ佐多クリニック': ['1', '2716124', '12'],
#  '市川整形外科内科': ['1', '2716132', '12'],
#  '医療法人社団 長谷川眼科クリニック': ['1', '2716140', '12'],
#  '佐々木内科医院': ['1', '2716157', '12'],
#  '医療法人社団 康友会 原田耳鼻咽喉科': ['1', '2716173', '12'],
#  '吉田クリニック': ['1', '2716199', '12'],
#  'もとやわた駅前整形外科': ['1', '2716215', '12'],
#  '藤田小児科医院': ['1', '2716231', '12'],
#  '医療法人財団 明理会 行徳総合病院': ['1', '2716249', '12'],
#  'メンタルヘルス診療所しっぽふぁーれ': ['1', '2716256', '12'],
#  '市川フォレストクリニック': ['1', '2716280', '12'],
#  '医療法人社団 長伸会 市川南クリニック': ['1', '2716306', '12'],
#  '医療法人社団健森会 まごころクリニック行徳': ['1', '2716314', '12'],
#  'ふるや内科クリニック': ['1', '2716348', '12'],
#  '市川東ヘルスクリニック': ['1', '2716355', '12'],
#  '医療法人社団 薫友会 藤井皮膚科クリニック': ['1', '2716363', '12'],
#  'あいこう耳鼻いんこう科': ['1', '2716371', '12'],
#  '本八幡セントラル放射線科クリニック': ['1', '2716405', '12'],
#  '医療法人社団 iーメンタルクリニック': ['1', '2716421', '12'],
#  '医療法人社団 泰陽会 本八幡耳鼻咽喉科': ['1', '2716439', '12'],
#  '金子皮フ科クリニック': ['1', '2716447', '12'],
#  '市川ひふ科形成外科クリニック': ['1', '2716470', '12'],
#  '医療法人社団弘豊会 本八幡皮ふ科クリニック': ['1', '2716504', '12'],
#  '医療法人社団 南行徳整形外科内科': ['1', '2716512', '12'],
#  '医療法人社団伯則会 原木医院': ['1', '2716538', '12'],
#  '医療法人社団 おひさまの会 サンサンこどもクリニック': ['1', '2716546', '12'],
#  'さくらライフ市川クリニック': ['1', '2716553', '12'],
#  '医療法人社団御波会面野医院': ['1', '2716579', '12'],
#  '医療法人社団順誠会 妙典さいとう耳鼻咽喉科': ['1', '2716587', '12'],
#  ...}

# %%
hospitalInfo_df=pd.DataFrame.from_dict(dict_hospitalInfo_base)

# %%
hospitalInfo_df
# Out:
#   千葉県がんセンター 医療法人社団福寿会 鷲見医院 医療法人緑栄会 三愛記念そが病院 千葉市 千葉市立青葉病院 クリニックあしたば  \
# 0         1              1                1            1         1
# 1   0110684        0112300          0116814      0118687   0117911
# 2        12             12               12           12        12
#
#   医療法人社団誠馨会 千葉メディカルセンター 医療法人社団 大樹 大賀医院 一般社団法人 巨樹の会 千葉みなとリハビリテーション病院  \
# 0                     1              1                            1
# 1               0123091        0123554                      0122895
# 2                    12             12                           12
#
#   独立行政法人国立病院機構 千葉医療センター 国立大学法人 千葉大学医学部附属病院  ...   あづみ野歯科    橘歯科医院     おだ歯科  \
# 0                     1                  1  ...        3        3        3
# 1               9110016            9210014  ...  2930220  2930154  2930204
# 2                    12                 12  ...       20       20       20
#
#     柏原歯科医院 あかいけ歯科クリニック 信州口腔外科インプラントセンター   芳川歯科医院   富井歯科医院 丸山さとし歯科医院  \
# 0        3           3                3        3        3         3
# 1  2930238     3130291          3237021  3330156  3330198   3430436
# 2       20          20               20       20       20        20
#
#   栄村国民健康保険栄村歯科診療所
# 0               3
# 1         3537040
# 2              20
#
# [3 rows x 50427 columns]

# %% [markdown]
# # 関数置き場

# %%
# 基本は最頻値をとる。最頻値がない時は平均をとる。numsが空の時は0にする。
def mode_average(nums):
    try:
        return mode(nums)
    except:
        if len(nums)!=0:
            return round(sum(nums) / len(nums))
        else:
            try:
                return nums[0]
            except:
                return 0  #これは危ないかも

# %%
#一部のみしか選択しないタイプ 画像を表示しない場合
def recognize5(url,n_part,start,goal):
    start_time = time.time()
    #pathからbase64にする場合
    def pil_image_to_base64(img_path):###ここは最後に消す
        pil_image = Image.open(img_path)
        buffered = BytesIO()
        pil_image.save(buffered, format="PNG")
        str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
        return str_encode_file

    #arrayからbase64にする場合
    def array_to_base64(img_array):
        pil_image = Image.fromarray(np.uint8(img_array))
        buffered = BytesIO()
        pil_image.save(buffered, format="PNG")
        str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
        return str_encode_file 

    def get_fullTextAnnotation(json_data):
        text_dict = json.loads(json_data)
        try:
            text = text_dict["responses"][0]["fullTextAnnotation"]["text"]
            return text
        except:
            print(None)
            return None

    #str_encode_file = pil_image_to_base64(url)  
    
    img = cv2.imread(url)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,0::]
#     plt.figure(figsize=[50,50])
#     plt.imshow(input_image)
    
    str_encode_file = array_to_base64(input_image)# input_imageがarrayの時
    str_url = "https://vision.googleapis.com/v1/images:annotate?key="
    str_api_key = "AIzaSyDlRRYrHEdjParsfRmh96_3xfafOo1crWY"
    str_headers = {'Content-Type': 'application/json'}
    str_json_data = {
        'requests': [
            {
                'image': {
                    'content': str_encode_file
                },
                'features': [
                    {
                        'type': "DOCUMENT_TEXT_DETECTION",
                        'maxResults': 1
                    }
                ],"imageContext": {
        "languageHints": ["ja"]
      },
            }
        ]
    }

    obj_session = Session()
    obj_request = Request("POST",
                            str_url + str_api_key,
                            data=json.dumps(str_json_data),
                            headers=str_headers
                            )
    obj_prepped = obj_session.prepare_request(obj_request)
    obj_response = obj_session.send(obj_prepped,
                                    verify=True,
                                    timeout=60
                                    )
    #もとの出力
    if obj_response.status_code == 200:
        text = get_fullTextAnnotation(obj_response.text)
        
    elapsed_time = time.time() - start_time
    print ("API終了までにかかった時間:{0}".format(elapsed_time) + "[sec]")
    #行ごとの出力    
    text_dict = json.loads(obj_response.text)
    word_list=text_dict["responses"][0]["textAnnotations"][0]["description"].split("\n")

    len_sum=0
    now_num=0
    left=[]
    right=[]
    top=[]
    bottom=[]
    dic_list=[]

    for i in range(1,len(text_dict["responses"][0]["textAnnotations"])):
        len_sum+=len(text_dict["responses"][0]["textAnnotations"][i]["description"].replace(" ",""))
        try:
            left.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["x"])
        except:
            pass
        try:
            right.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][1]["x"])
        except:
            pass
        try:
            right.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][2]["x"])
        except:
            pass
        try:
            left.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][3]["x"])
        except:
            pass

        try:
            bottom.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["y"])
        except:
            pass
        try:
            bottom.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][1]["y"])
        except:
            pass
        try:
            top.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][2]["y"])
        except:
            pass
        try:
            top.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][3]["y"])
        except:
            pass

        if len_sum==len(word_list[now_num].replace(" ","")):
            len_sum=0
            #print("word:   "+word_list[now_num])
            dic={"word":word_list[now_num],"文字の縦幅":mode_average(top)-mode_average(bottom),"x":round(mode_average(left)+mode_average(right)),"y":round(mode_average(top)+mode_average(bottom))}
            dic_list.append(dic)
            now_num+=1
            left=[]
            right=[]
            top=[]
            bottom=[]
    elapsed_time = time.time() - start_time
    print ("for文を回し終わるまでにかかった時間:{0}".format(elapsed_time) + "[sec]")
    df = pd.DataFrame(dic_list)
    df=df.sort_values('y')
    df.reset_index()
    tate_mean=df["文字の縦幅"].mean()

    diff_list=df["y"].diff()
    a_=0
    y_list=[]
    for a,b in zip(df["y"],diff_list):
        #print(a,b)
        if b<tate_mean:
            a=a_
        a_=a
        y_list.append(a)

    df["diff"]=diff_list
    df.loc[0,"diff"]=0
    df["y"]=y_list
    df=df.sort_values(["y","x"])
    grouped_df = df.groupby('y')
    grouped_list = [list(grouped_df["word"].get_group(word)) for word in grouped_df.groups]
    elapsed_time = time.time() - start_time
    print ("elapsed_time:{0}".format(elapsed_time) + "[sec]")
    return grouped_list
