# %% [markdown]
# # 準備

# %%
import random
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

#Jupyterでインライン表示するための宣言
# %matplotlib inline 
import os
import shutil
from tqdm import tqdm
import base64
import json
from requests import Request, Session
from io import BytesIO
from PIL import Image
import pandas as pd
import jaconv
import re
import cv2
import numpy as np
from symspellpy.symspellpy import SymSpell, Verbosity
import pickle
from pykakasi import kakasi
import Levenshtein
from collections import OrderedDict
import itertools

from statistics import mode
import time

import os
import sys
import requests
# If you are using a Jupyter notebook, uncomment the following line.
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO

# %% [markdown]
# # 探索

# %%
import pickle
with open('text_dic2.pickle', 'rb') as web:
    df = pickle.load(web)
    
num_list2=[int(x[6:][:-5]) for x in list(df.keys())]
num_list2.sort()
#35は除外

# %%
import pickle
with open('ocr_result_4.pickle', 'rb') as web:
    df2 = pickle.load(web)
    
#35は除外

# %%
text_list=df2["result(10,0,10)"]

# %%
num=0
for i in text_list:
    print(str(num)+"番目:"+str(num_list2[num]))
    print(i)
    num=num+1
#     for s in i:
        
#     if "保険者番号"
# Out:
# 0番目:2
# [['P. 1'], ['処', '方', '箋', 'O'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号', '01130012'], ['被保険者証・被保険'], ['1 0 8 0 9 1 2 3 4 7'], ['者手帳の記号・番号'], ['っ', '保険医療機', '東京都千代田区飯田橋4-6-9 STビル2階'], ['幸子'], ['及び名称 医療法人社団 高典会 飯田橋クリニック'], ['56才'], ['7ヶ月男の 電話番号 03-3222-6461'], ['9月 22日生', '保険医氏名 高橋 典大'], ['険者', '被扶養者', '都道府県', '1', '3', '番号', '点数表', '1', '医療機関', '0', '1', '1', '1', '2 9 4. 8'], ['処方箋の', '特に記載のある場合を除き、'], ['1年 5月', '13日', '年 月', '日交付の日を含めて4日以内に'], ['使用期間', '保険薬局に提出すること。'], ['処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合、'], ['変更不可」欄に「」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]
# 1番目:35
# [['Date'], ['.'], ['人0'], ['Os']]
# 2番目:40
# [['171'], ['外来処方箋'], ['(この処方箋はどの保険薬局でも有効です)'], ['216016', '保険者番号 0|61|38|150'], ['1633', '被保険者証・被保険|1910'], ['者手帳の記号・番号|1336373'], ['2', '東京都武蔵野市吉祥寺本町1-30-12'], ['保険医療機'], ['関の所在地 医療法人社団 東仁会 吉祥寺あさひ病院'], ['U'], ['雅子', '電話番号 0422-22-1120'], ['診療科', '膠原病内科'], ['性別 女保険医氏名 有村義宏', 'ED'], ['年9月22日(50才)'], ['被扶養者', '番号', '113', '都道府県 点数表 医療機関', '番号 コード', '1', '31317|0|129'], ['特に記載のある場合を除き、'], ['処方箋の', '交付の日を含めて4日以内に'], ['0年5月18日', '使用期間', '保険薬局に提出すること。'], ['日々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】ミゾリビン錠50mg', '3錠'], ['35日分'], ['1日1回朝食前']]
# 3番目:85
# [['処', '方', 'P. 1'], ['N', 'ge'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['割'], ['保険者番号 061 386613'], ['被保険者証・被保険'], ['者手帳の記号・番号', '12.5900516'], ['ガワミツヒロ', '保険医療機 東京都千代田区外神田5-2-3'], ['谷川 光洋', '関の所在地', '及び名称"アソルティ末広町ビル1F'], ['大昭平 40才', '末広町ヒライ耳鼻咽喉科'], ['1ヶ月男女 電話番号03-3836-3387'], ['53年11月 9日生', '保険医氏名平井 良治'], ['被保険者、被扶養者', '番号', '都道府県', '1', '3', '番号', '点数表', '1', '医療機関', 'コード', '0', '1', '1 3', '5', 'o', '38'], ['処方箋の', '特に記載のある場合を除き、'], ['平成30年', '12月 26日', '使用期間', '平成 年月 日', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['こは、「変更不可」欄に「」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】カルボシステイン錠'], ['5 0 0 mg', '3 錠'], ['1日3回 朝・昼・夕食後', '14日分']]
# 4番目:93
# [['O', 'P. 1'], ['処', '方', '箋'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号', '011 1 300112'], ['被保険者証・被保険', '50000013.109420'], ['者手帳の記号・番号'], ['保険医療機 東京都千代田区飯田橋4-4-7'], ["'", '及び名称 医療法人社団慈仁会 飯田橋小池クリニック'], ['43才'], ['4ヶ月男の 電話番号 03-3221-8858'], ['.', '4日生', '保険医氏名 小池 美由紀'], ['者', '被扶養者', '番号', '都道府県', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0', '1', '3', '415 51', '特に記載のある場合を除き、'], ['111', '5月 13日', '使用期間', '処方箋の', '年月日', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['キソプロフェンNa錠'], ['3. 錠'], ['g'], ['30日分'], ['食後服用'], ['バミピド錠 100mg', '3', '錠'], ['30日分'], ['食後服用'], ['帰四逆加呉茱萸生姜湯エキス顆粒']]
# 5番目:110
# [['P. 1'], ['処', '方'], ['G'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['11316012', '保険者番号 01 400019'], ['3175 018', '者手帳の記号・番号', '被保険者証・被保険', '92420709.975'], ['ュンコ', '保険医療機 東京都千代田区外神田5-2-3'], ['子', '関の所在地', '及び名称、アソルティ末広町ビル1F'], ['平', '36才', '末広町ヒライ耳鼻咽喉科'], ['3ヶ月男の', '電話番号03-3836-3387'], ['9月', '27日生', '保険医氏平井 良治'], ['被扶養者', '来日', '都道府県', '3', '東日', '1', '点数表 医療機関', '-', 'Q11', '3', '5', '0 13', '8']]
# 6番目:148
# [['処', '方'], ['1/1ページ'], ['(この処方箋はどの保険薬局でも有効です)'], ['12|27|1243) 保険者番号'], ['0 0 2 3 7/8', '被保険者証・被保険'], ['者手帳の記号・番号'], ['ウラノチッ', '埜 知津子', '所在地及び名称', '保険医療機関の', 'Fine F', '上西クリニック', '大阪市平野区平野西3-9-21 コーポ常'], ['年', '3月26日 女', '電話番号', '(06)6760-5630'], ['保険医氏名', '上西 正明'], ['番号', '都道府県', '27', '番号', '1', '点数表 医療機関', 'コード', '5807943'], ['30年 12月18日 処方箋 の 平成 年 月 日(特に記載のある場合を除き、'], ['に差し支えある場合「レ」又は「×」を記載 使用期間 交付の日を含め4日以内に保険薬局に提出すること)'], ['セミド錠30mg', '2錠', '1日1回朝食後', '14日分'], ['ロノラクトン錠25'], ['1錠', '1日1回朝食後', '14日分'], ['- 1 mo']]
# 7番目:301
# [['30分後もどる'], ['a'], ['処', '方'], ['(この処方箋はどの保険薬局でも有効です)', 'Page. 1'], ['保険者番号 0 6 1 3 19 1 117'], ['被保険者証・被保険', '3 2 30 · 64 0 8'], ['者手帳の記号・番号'], ['〒101-0021'], ['保険医療機', '東京都千代田区外神田六丁目14番2号'], ['山口', 'グチカナコ', '桂奈子', '関の所在地', '及び名称', 'サカイ末広ビル7階B室', '雪月花メディカルクリニック 秋葉原診療所'], ['電話番号 03-5812-5301'], ['2和50年07月26日', '男', '保険医氏名 大道雅文'], ['被保険者', '被扶養者', '番号', '都道府県', '113', '1', '番号 コード', '点数表 医療機関', '特に記載のある場合', '011/337 110'], ['を除き、交付の日を'], ['平成30年12月28日', '使用期間', '処方箋の', '平成年月日', '含めて4日以内に保険', '薬局に提出すること。'], ['LA']]
# 8番目:326
# [['院外', '処', '方', '箋 2013年09月30日 11:44 発行'], ['(この処方箋は、 どの保険薬局でも有効です。)'], ['保険者番号1062315118'], ['被保険者証・被保険]4851'], ['手帳の記号・番号|267'], ['保険医療機愛知県一宮市奥町字下口西89番地の1'], ['関の所在地 社会医療法人杏嶺会'], ['浩二', '及び名称 上林記念病院'], ['電話番号0586-61-0110', '中'], ['男女、保険医氏名', '中原保裕', '原'], ['09月28日生', '賞者 ==被扶養者==', '都道府県', '号', '213', '点数表', '号', '1', '医療機関', 'ド', '2 2 0 2 1 2 6', '特に記載のある場合を除き、'], ['01年09月 30日', '使用期間', '処方箋の', '令和 1年10月3日 榮<薬に進出すること。'], ['つ処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', ']'], ['「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること'], ['2 T'], ['【般】 リルマザホン塩酸塩錠1mg'], ['不眠時', '20回分'], ['(以下余白)']]
# 9番目:339
# [['院外処方', '箋 2019年09月27日 12:07 発行'], ['(この処方箋は,どの保険薬局でも有効です。)'], ['保険者番号101 2 3 0 0 1 0'], ['被保険者証・被験7410435'], ['者手帳の記号・番号12'], ['保険医療機愛知県一宮市奥町字下口西89番地の1'], ['智子', '関の所在地 社会医療法人杏嶺会'], ['及び名称 上林記念病院'], ['電話番号0586-61-0110'], ['10月11日生', '男・の保険医氏名 原 大', '印'], ['被扶養者', '番', '都道府県', '号', '213', '番', '点数表', '号', '1', '医療機関', 'ド', '2 202 12 6'], ['01年 09月 27日', 'の日夢内に'], ['処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること'], ['設】パロキセチン錠20mg'], ['1 T'], ['1×夕食後', '45日分'], ['(以下余白)']]
# 10番目:366
# [['処方箋'], ['部茂'], ['1:82011230-2'], ['(この処方箋は、どの保険薬局でも有効です。)', '24', '①ここには薬に関連する'], ['保険薬局に提出してく'], ['旦者番号'], ['町村番号', '保険者番号', '3 92 71 2 67', '②検査値情報をご提供い'], ['医療又は', '受給者番号', '|者手帳の記号・番号', '被保険者証・被保険13580774', '③提出を希望されない方'], ['ナオコ', '男', '所在地及び名称', '保険医療機関の〒546-0002', '大阪府大阪市東住吉区杭全', '④検査値は過去3か月間以'], ['井', '直子', '仁真会', '白鷺診療所', '⑤処方せんの有効期限は'], ['TEL. 06-6714-1661', '場合,保険薬局でお薬'], ['保険者 被扶養者', '和 15年 1月 3日生 保険医氏名', '1割', '番号', '都道府県', '|2|7', '1', '番号 コード', '点数表 医療機関', '田部 茂', 'ポ', '0805785', 'FI', 'ID:82011230', 'ヨコイ ナオコ'], ['年月日', '平成30年12月20日 | 使用期限', '処方箋の', '平成年月 日', '特に記載のある場合を除き、交付の日付を含め', '氏名:横井直子 性別', '生年月日:昭和15年1月3'], ['4日以内に保険薬局に提出してください。']]
# 11番目:435
# [['処', '方'], ['1/1ページ'], ['(この処方箋はどの保険薬局でも有効です)'], ['|13|6015) 保険者番号'], ['|13|8263'], ['8 2 8 37', '被保険者証・被保険 26-38 5209'], ['者手帳の記号・番号'], ['ブチルエ', '保険医療機関の', '東京都武蔵野市吉祥寺本町1-35-14'], ['H晴生', '所在地及び名称', 'おざき心のクリニック'], ['11月13日', '女', '電話番号', '保険医氏名', '(0422)20-5587', '尾崎純子', '尾', 've'], ['保険者', '都道府県', '番号', '13', '点数表 医療機関', '番号 コード', '3325248'], ['年5月18日 処方箋の平成 年 月 日(特に記載のある場合を除き、'], ['支えある場合「レ」又は「×」を記載 使用期間 交付の日を含め4日以内に保険薬局に提出すること)'], ['15 mg', '0.5錠'], ['20%', '0.26 mg', '分1夕食後', '28日分'], ['ng', '0.5錠', '分1就寝前', '28日分']]
# 12番目:456
# [['処方箋正', '11'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['国7-本'], ['保険者番号', '3', '8', '2', '1'], ['|域保険者証・滅険'], ['者手帳の記号・翻27-16', '• 0 3 7 5'], ['保険医療機関 武蔵野市吉祥寺本町1-33-6'], ['の所在地'], ['及び名称、 木下循環器呼吸器内科クリニック'], ['16日男 ・ 女「電話番号 0422-22-8300'], ['CD'], ['者 2.0 割「保険医氏名 木下陽'], ['5月18日', '都道府県', '番号', '13', '番号', '点数表', '1', '医療機関', 'コード', '313|2|3|8|9|6'], ['月', 'DET', '特に記載のある場合を除き、交付の日を含めて4日以内に保険薬局に提出すること。'], ['いて、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['間に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['アロプリノール錠100mg', '1', '錠'], ['ストール錠5mg', '1', '錠'], ['朝食後服用'], ['30日分'], ['ムロ配合錠AP', '1', '錠'], ['朝食後服用']]
# 13番目:504
# [['処', '方', 'P. 1'], ['箋'], ['(この処方箋は、どの保険薬局でも有効です。)', 'O'], ['保険者番号', '06132948'], ['被保険者証・被保険'], ['1 3 2 4 • 5 0 8'], ['者手帳の記号・番号'], ['保険医旅機 東京都千代田区飯田橋4-6-9 STビル2階'], ['及び名称 医療法人社団 高典会 飯田橋クリニック'], ['26才'], ['8ヶ月男の 電話番号03-3222-6461', '高'], ['JIT', '10日生', '保険医氏名 高橋 典大'], ['被扶養者', '都道府県', '1', '3', '番号', '1', '点数表 医療機関', 'コード', 'N', '0 1 9 4. 8', '1'], ['5月13日', '使用期間', '処方箋の', '年月 交付の日を含めて4日以内に', '保険薬局に提出すること。', '特に記載のある場合を除き、'], ['について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['5 mg', '1', '錠'], ['夕食後'], ['なら寝る前', '30日分'], ['ィカプセル100'], ['3', 'C']]
# 14番目:519
# [['処', '方', '箋', '負担:30%'], ['(この処方察はどの保険薬局でも有効です。', 'Tom'], ['保 険 者番号 06137087'], ['|被保険者証・被保険'], ['36 · 536'], ['者手帳の記号・番号'], ['ト', '保険医療機関の', '新宿区四谷1-2-4 クニヤビル3F'], ['所在地及び名称'], ['みどりの森ひふ科クリニック'], [')。平'], ['12日 「男女', '電話番号', '03-3352-4100'], ['保険医氏名 矢澤 徳仁'], ['被扶養者', '番号', '都道府県 点数表 医療機関', '1/3|番号|1', 'コード10|4|3|7|6|7|3'], ['特に記載のある場合を除き、交付の日を含めて'], ['10日 19日', '処方箋の 4日以内に保険薬局に提出すること。']]
# 15番目:524
# [['処方箋'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['08', '①ここには薬に関連する検査値情'], ['保険薬局に提出してください。'], ['保険者番号'], ['3 92 72 1 2 5', '②検査値情報をご提供いただくと'], ['被保険者証・被保険10403475'], ['者手帳の記号・番号', '-', '③提出を希望されない方は処方せ'], ['保険医療機関の〒546-0002'], ['男', '所在地及び名称', '七丁目十番十九等', '大阪府大阪市東住吉区杭全', '④検査値は過去3か月間以内に測:'], ['仁真会'], ['白鷺診療所', '⑤処方せんの有効期限は発行日を'], ['7月', '26日生', '保険医氏名 三橋', 'TEL. 06-6714-1661', '誠', '場合、保険薬局でお薬を受け取'], ['夫養者', '1割', '番号', '都道府県', '27', '品', '1', '点数表、 医療機関', 'lo slo 51718151', 'ID: 87012068']]
# 16番目:548
# [['処方せん'], ['(この処方せんは、どの保険薬局でも有効です)'], ['(処方せん番号: 20171228-000074)'], ['保険者番号 01 1 2 0 0 1'], ['被保険者証・被保険 159160232・7'], ['者手帳の記号・番号'], ['保険医療機関 埼玉県さいたま市桜区上大久保'], ['チ', '様」の所在地及び 884'], ['名称', '医療法人聖仁会西部総合病院'], ['月12日 |年齢 39歳 1ヶ月 「性別 男性', '電話番号 048-854-1111'], ['保険医氏名西郷嘉一郎'], ['麻薬免許番号'], ['「患者負担', '30% 番号', '11', '111', '都道府県 点数表 医療機関', '番号 コード', '1', '特に記載のある場合を除き', '01 04 000', '4,000'], ['平成29年12月28日', '使用期間', '処方せんの', '平成29年12月31日', 'に保険薬局に提出すること。', '交付の日を含めて4日以内'], ['ユ方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['三更不可」欄に「い」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['-1 【般】ロキソプロフェンNa錠60mg', '3錠', '14日分'], ['3錠 14日分'], ['【般レバミピド錠100mg'], ['分3/毎食後', '12/28から14日分'], ['・.2 【般】ケトプロフェンテープ40mg(10×14cm非温感)', '5袋'], ['1日1枚、', '12/28から'], ['部位 :胸部']]
# 17番目:630
# [['18:15="}'], ['処', '方', 'XIPRXIGE'], ['(この処方変はどの保険薬局でも有効です)', 'Page 1'], ['保険者番号', '0 11 3 0 0 1 2'], ['被保険者証・被保険', '4 2 3 6 2 4 1 2 • 18'], ['者手帳の記号・番号'], ['〒101-0021'], ['保険医療機', '東京都千代田区外神田六丁目14番2号'], ['カタマコト', '関の所在地', 'サカイ末広ビル7階B室'], ['保方誠', '及び名称', '雪月花メディカルクリニック秋葉原診療所'], ['電話番号 03-5812-5301'], ['和53年10月17日', '(', '男女', '保険医氏名 大道雅文', '(EL'], ['被保険者', '被扶養者', '番号', '都道府県', '113', '1', '番号 コード', '点数表 医療機関', '0|11313171110'], ['特に記載のある場合'], ['平成30年12月12日', '使用期間', '処方箋の', '平成年月日', 'を除き、交付の日を', '含めて4日以内に保険', '薬局に提出すること。'], ['個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', '4'], ['には、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】アロプリノール錠100mg', '3錠'], ['分3毎食後', '28日分'], ['及】*', '【般】ロキソプロフェンNa錠60mg', '3錠']]
# 18番目:655
# [['IÀ Gta'], ['処方せん', '~373)'], ['どの保険薬局でも有効です。)', '分割指示に係る分割の回目'], ['保険者番号', '4100', '14 00:38'], ['被保険者証・被保険者', '03', '335-2943-9'], ['手帳の記号・番号'], ['かわごえ むねき', '医療機関の', '東京都千代田区外神田5丁目2-7'], ['川越宗紀', '所在地及び'], ['名称'], ['明神下診療所'], ['電話番号 03-5816-3110'], ['999/09/13', '男', '保険医氏名 米田衆介', 'VON'], ['被保険者'], ['18/12/28', '処方せ県番号', '都道府113', '番', '数表', '1', '関コード', '医療機、', '011/3 4 4 3 7'], ['んの使', '用期間 平成年月日 特に記載のある場合を除き、交付の'], ['日から4日以内に保険薬局に提出す'], ['ること'], ['て、後発医薬品(ジェネリック)への変更に差し支えが判断した場合には「変更不可」欄に「レ」又は']]
# 19番目:721
# [['処', '方', 'せ', '3'], ['(後発希望'], ['(この処方せんは、どの保険薬局でも有効です。)'], ['保険者番号', '0 6 1 3 9 4', '6 3'], ['被保険者証・被保険', '100', '99744'], ['者手帳の記号・番号'], ['保健医療機関の東京都千代田区飯田橋4-5-16 コアビル3F'], ['介', '殿', '所在地及び名称'], ['飯田橋歯科クリニック'], ['電話番号 03-3288-5253'], ['年1月16日', '(男・女'], ['保険医氏名竹内均']]
# 20番目:770
# [['Po dl". X. GE'], ['方', '箋かか21'], ['(この処方類はどの保険薬局でも有効です。)', '負担:30%'], ['保険者番号 39122072'], ['被保険者証・被保険'], ['• 019 64204'], ['者手帳の記号・番号'], ['東京都台東区上野3-16-4 文行堂ビル2F'], ['ロウ', '保険医療機関の'], ['郡', '所在地及び名称'], ['医療法人社団雄翔会あさひ上野クリニック'], ['・平'], ['29日', '男女', '電話番号', '森田 秀和', '03-5818-7070'], ['保険医氏名', 'ED'], ['被扶養者', '番号 1/3|番号|1 コード06/301219', '都道府県 点数表 医療機関'], ['特に記載のある場合を除き、交付の日を含めて'], ['処方箋の 4日以内に保険薬局に提出すること。'], ['2月14日', '使用期間 平成 年月日'], ['(ジェネリック医薬品)への変更に差し支えがあると判断した場合には、'], ['」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['変更不可'], ['【内服】'], ['ン塩酸塩錠1', '【般】プラバスタチンナトリウム']]
# 21番目:775
# [['処', '方', '箋', 'l', 'P. 1'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号', '01111301012'], ['被保険者証・被保険'], ['1322316.5'], ['者手帳の記号・番号'], ['保険医療機 東京都千代田区飯田橋4-6-9 STビル2階'], ['及び名様 医療法人社団 高典会 飯田橋クリニック'], ['47才'], ['5ヶ月 男の 電話番号 03-3222-6461'], ['7日生', '保険医氏名 高橋 典大'], ['音', '被扶養者', '|都道府県', '番号', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0', '1', '1', '2', '911 8', '4'], ['年', '5月', '13日', '使用期間', '処方箋の', '年月日', '保険薬局に提出すること。', '交付の日を含めて4日以内に', '特に記載のある場合を除き、'], ['について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['-可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['ィカプセル100']]
# 22番目:786
# [['笑 2013年09月27日 12:54 発行'], ['院外 処方'], ['(この処方箋は,どの保険薬局でも有効です。)'], ['保険者番号 2 310 0 4 5'], ['被保険者証・被保険'], ['手帳の記号・番号|3226851'], ['保険医療機愛知県一宮市奥町字下口西89番地の1'], ['関の所在地 社会医療法人杏嶺会'], ['春子', '及び名称 上林記念病院'], ['電話番号 0586-61-0110'], ['男。 保険医氏名', '市橋佳世子', '養'], ['F 02月20日生', '都道府県|2|3', '2 3 *** 1 212102111216', '医療機関', 'ド'], ['険者 ==被扶養者== 番'], ['処方箋の', '令和 1年9月30日 業業に進出すること。'], ['和 01年 09月 27日', '使用期間'], ['日々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', ')'], ['は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること', 'O. 5 T'], ['エビリファイ錠3mg', '1 T'], ['【般】アムロジピン口腔内崩壊錠2.5mg', '1xEVE', '28日分'], ['2 T'], ['リフレックス錠15mg', '1×夕食後', '28日分']]
# 23番目:793
# [['処方箋'], ['Page 1'], ['の処方箋は、どの保険薬局でも有効です。)'], ['02 長'], ['2', '7', '4 2', '5', '1', '保険者番号', '39', '2', '7 11 2 6 7'], ['被保険者証・被保険 10428159'], ['5', '6', '3 4 1'], ['者手帳の記号・番号'], ['<同姓同名有り> 保険医療機関の 〒546-0002'], ['(男)', '所在地及び名称', '大阪府大阪市東住吉区杭全'], ['七丁目十番十九号'], ['様', '仁真会 白鷺診療所'], ['女', 'TEL. 06-6714-1661'], ['6月', '1日生', '保険医氏名 岡崎久宜', '所'], ['扶養者', '都道府県', '番号', '27', '1', '番号 コード', '点数表 医療機関', '08015|7185'], ['処方箋の 平成 30年 12月23日'], ['30年 12月20日', '使用期間', '4日以内に保険薬局に提出してください。', '特に記載のある場合を除き、交付の日付を含め'], ['雪々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合に', 'に]'], ['「変更不可」欄に「」または「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]
# 24番目:806
# [['2809 第01版'], ['0481', '処方'], ['箋'], ['1:19 この処方箋は、どの薬局でも有効です。(コピーは無効です。)', '1/1'], ['号'], ['号', '保険者番号|39|2|3|2|0|318'], ['は', '被保険者証・被保険|11843562'], ['番号', '者手帳の記号・番号'], ['00748 耳鼻咽喉科', 'の所在地', '保険医療機関 〒494-0001 愛知県一宮市開明字平1番地'], ['ユリコ', '及 び 名称 一 宮西病院'], ['百合子'], ['様電 話 番 号 0586-48-0077(代)'], ['年08月09日 79才女性保険 医氏名 宮田英雄'], ['Lone'], ['弁者', '負担割合 1割', '都道府県', '番号', '2 3', '番号', '点数表', '1', '医療機関', 'ド', '2|20| 3| 2|72|'], ['令和1年09月27日', '使用期限', '処方箋の', '令和1年09月30日'], ['[', '個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['には、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】 パロキセチン錠10mg', '2錠'], ['1回1錠 (1日2錠)'], ['・1日2回 朝・夕食後', '21日分'], ['2010 con 107']]
# 25番目:879
# [['P. 1'], ['処', '方', '箋', 'GE'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['割'], ['保険者番号', '0 61 34803'], ['被保険者証・被保険', '.', '532 6175'], ['者手帳の記号・番号'], ['フラメグミ', '保険医療機 東京都千代田区外神田5-2-3'], ['倉めぐみ', '関の所在地', '及び名称 アソルティ末広町ビル1F'], ['大昭平 48才', '末広町ヒライ耳鼻咽喉科'], ['9ヶ月男女 電話番号 03-3836-3387'], ['15年 3月 9日生', '保険医氏名平井 良治'], ['保険者、被扶養者', '番号', '都道府県', '1', '3', '番号', '点数表', '1', '医療機関', 'コード', '0 1 3 5110° 1.38', '特に記載のある場合を除き、'], ['処方箋の', '交付の日を含めて4日以内に'], ['平成 30年 12月', '26日', '使用期間 平成 年月', '保険薬局に提出すること。'], ['個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['ニは、「変更不可」欄に「」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]
# 26番目:885
# [['Guard'], ['Copy', 'per Copy G'], ['Guard Paper', 'opy Guard', 'jard Paper', 'Copy Guard', 'aper Copy', 'hard Paper', 'per Copy Guard', 'uard Paper Copy', 'Copy Guard Paper', 'Paper Copy Guard', 'Guard Paper Copy', 'Copy Guard Paper', 'Guar laper Cody', 'pyyuard Paper'], ['Paper Copy Guard', 'by Guard Paper Copy', 'fropy Guard Paper', 'dos Jaded', 'Copy Guard Paper Co'], ['てる方はどの保険薬局でも有効です)', 'Copard Paper Copy Gear'], ['38009', 'Co Pape', 'De 011300127 Paper Copy Guard', '保険者番号'], ['6 V Copy Guard Papa'], ['Caro y Gual', '被保険者証・被保険| 57280204'], ['9 1'], ['者手帳の記号・番号 1750', 'Lapes'], ['37', 'GUNO er opy Vaper Com', 'er cuard Woer opy Guard/', '保険医療機 opyを', '東京都武蔵野市吉祥寺本町1-30-12', 'Copy Guard Page Copy Guard Paper Cor'], ['Paper Copy Già Paper Copy Gray'], ['機地', 'Guard PT', '医療法人社団 東仁会Garam'], ['Evans paper CBS Guard Pape'], ['ne Paper Copy Sard)', 'py Guard Paper Cox'], ['0422-221120'], ['孝典', 'Paper Copy Guar'], ['ord Pa/', '診療科', 's Paper', 'Copy 人工透析内!', 'Guäm aper'], ['三8月22日(513) py Guard Paper VIK', 'Co Gual Paper Copy Gu', '性別 男 保険医氏名 笠原仁', 'Zer Copy Guard Pace'], ['被保険者', 'con', 'Pap', '\\/', '13', '都道府県 無数表 医療機関', '番号', 'コード|3|37|0|1|2|9'], ['wa Pap'], ['特に記載のある場合を除き、'], ['年5月17日', 'CO', '使用期間', '処方箋の', 'V Gud', 'per CO', 'jard Pais', 'opy Gus', 'perc', 'vard', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['ROLTIN', 'は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること、any py Guard Paper Cons', '後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', 'Guard per Copy ✓rd Paper Copy Guar', 'Estander Copy Guard Pape', 'y Guard Paper Copy'], ['-ツムラ芍薬甘草湯エキス顆粒(医療用)(2.5g) "'], ['I aper', 'Grd Paper Copy Guar'], ['er Copy Gu TV', 'x per', '下肢つり時1包', 'Paper ca', 'opy Guard PT', 'per Copy G', 'xrd Paper', 'opy Guard P', 'er Copy G', 'zard Paper Copy', 'opy Guest', 'aper Copy Guard', 'jard Paper Copy', 'Copy Guard Paper', 'aper Copy Guard', 'co', 'Copy Guard Pape', 'Paper Cop', 'Guar'], ['ELT']]
# 27番目:1011
# [['処', '方', 'P. 1'], ['箋'], ['(この処方箋は、どの保険薬局でも有効です。)', '後発希望'], ['保険者番号', '0 1 1 4 0011'], ['被保険者証・被保険'], ['者手帳の記号・番号', '2 1 3 5 0 7 2 6 • 2 1 2'], ['保険医療機 東京都千代田区飯田橋4-4-7'], ['関の所在地'], ['及び名称 医療法人社団慈仁会 飯田橋小池クリニック'], ['22才'], ['5ヶ月男の 電話番号03-3221-8858'], ['6日生', '保険医氏名 小池 美由紀'], ['被扶養者', '|都道府県', '番号', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0 1', '3', 'SR', '4 5 5 1'], ['処方箋の', '特に記載のある場合を除き、'], ['5月13日', '使用期間', '年月 日', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['いて、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['欄に「1」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['ジン錠', '3 mg', '2 錠'], ['食後服用', '5日分']]
# 28番目:1110
# [['処方箋'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号31911131111516'], ['被保険者証・被保険者', '04354858'], ['手帳の記号・番号'], ['39'], ['保険医療機関の東京都杉並区上荻2-42-11'], ['所在地及び名称 一般社団法人衛生文化協会'], ['園子', '城西病院'], ['電話番号 03-3390-4166', '矢'], ['2年2月27日 女', '保険医氏名 矢吹里香子', 'ED'], ['険者 負担割 1割'], ['都道府県番号137点数表番号1医療機関コード1570928'], ['平成30年5月18日', '処方度の', 'の日を含めて4日以内に保険薬局', '特に記載のある場合を除き交付'], ['使用期間 平成30年5月21日 に提出すること。'], ['日々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['薬'], ['・ヌビア錠50mg', '1'], ['1錠'], ['ロジンOD錠5mg'], ['(朝)'], ['1日1回 14日分']]
# 29番目:1137
# [['P. 1'], ['処', '方', '箋', 'a'], ['(この処方箋は、どの保険薬局でも有効です。)', '後発希望'], ['保険者番号', '138016'], ['被保険者証・被保険'], ['者手帳の記号・番号', '01-48.5039'], ['ョウイチ', '保険医療機 東京都千代田区飯田橋4-4-7'], ['関の所在地'], ['及び名称一医療法人社団慈仁会 飯田橋小池クリニック'], ['63才'], ['池'], ['8ヶ月)女 電話番号03-3221-8858'], ['9月 14日生', '保険医氏名 小池 美由紀', '印'], ['弁者 被扶養者', '番号', '都道府県', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0', '1', '3 4 5 5', '1'], ['処方箋の', '特に記載のある場合を除き、'], ['1年', '5月', '24日', '使用期間', '年月 月日', '保険薬局に提出すること。', '交付の日を含めて4日以内に!'], ['う薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['更不可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['アムロジピン錠2', '2. 5 mg', '1', '4.']]

# %%
url="/Users/obara/Downloads/prescription_data_jpeg_3/photo-"+str(885)+".jpeg"
outputs=recognize5(url,10,0,10)
# Out:
# API終了までにかかった時間:15.804440021514893[sec]
# for文を回し終わるまでにかかった時間:15.824541091918945[sec]
# elapsed_time:15.839486122131348[sec]

# %%
info_list=[]
info_dic={"block":"","paragraph":"","word":"","text":"","confidence":""}
for block in outputs[2]["pages"][0]["blocks"]:
    for paragraph in block["paragraphs"]:
        print("----------------------------------------------------------")
        for word in paragraph["words"]:
            print("-------------------")
            for symbol in word["symbols"]:
                info_dic={"block":"","paragraph":"","word":"","text":"","confidence":1}
                try:
                    info_dic["block"]=block["boundingBox"]
                except:
                    pass
                try:
                    info_dic["paragraph"]=paragraph["boundingBox"]
                except:
                    pass
                try:
                    info_dic["word"]=word["boundingBox"]
                except:
                    pass
                try:
                    info_dic["text"]=symbol["text"]
                except:
                    pass
                try:
                    info_dic["confidence"]=float(symbol["confidence"])
                except:
                    pass
                info_list.append(info_dic)
# Out:
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------
# -------------------
# ----------------------------------------------------------
# -------------------
# -------------------

# %%
df=pd.DataFrame(info_list)

# %%
df
# Out:
#                                                  block  \
# 0    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 1    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 2    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 3    {'vertices': [{'x': 20, 'y': 666}, {'x': 77, '...
# 4    {'vertices': [{'x': 878, 'y': 631}, {'x': 908,...
# ..                                                 ...
# 269  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 270  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 271  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 272  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
# 273  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 1    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 2    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 3    {'vertices': [{'x': 20, 'y': 666}, {'x': 77, '...
# 4    {'vertices': [{'x': 878, 'y': 631}, {'x': 908,...
# ..                                                 ...
# 269  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 270  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 271  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 272  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
# 273  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 1068, 'y': 642}, {'x': 110...    P        0.99
# 1    {'vertices': [{'x': 1068, 'y': 642}, {'x': 110...    .        0.99
# 2    {'vertices': [{'x': 1136, 'y': 643}, {'x': 115...    1        0.99
# 3    {'vertices': [{'x': 20, 'y': 666}, {'x': 77, '...    方        0.97
# 4    {'vertices': [{'x': 878, 'y': 631}, {'x': 908,...    O        0.46
# ..                                                 ...  ...         ...
# 269  {'vertices': [{'x': 102, 'y': 1410}, {'x': 172...    号        0.98
# 270  {'vertices': [{'x': 186, 'y': 1398}, {'x': 232...    1        0.13
# 271  {'vertices': [{'x': 186, 'y': 1398}, {'x': 232...    1        0.33
# 272  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...    M        0.64
# 273  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...    T        0.47
#
# [274 rows x 5 columns]

# %%
for i in df["word"][0]["vertices"]:
    x_list=[x in for ]
# Out:
#   File "<ipython-input-69-3a2cb33004d2>", line 2
#     x_list=[x in for ]
#                    ^
# SyntaxError: invalid syntax

# %%
x_list=[]
for row in df["word"]:
    try:
        x_list.append(sum([x_y["x"] for x_y in row["vertices"]])//4)
    except:
        x_list.append("")

# %%
y_list=[]
for row in df["word"]:
    try:
        y_list.append(sum([x_y["y"] for x_y in row["vertices"]])//4)
    except:
        y_list.append("")

# %%
y_list
# Out:
# [385,
#  379,
#  379,
#  368,
#  368,
#  368,
#  368,
#  365,
#  363,
#  363,
#  361,
#  359,
#  359,
#  358,
#  353,
#  353,
#  353,
#  353,
#  353,
#  346,
#  346,
#  458,
#  458,
#  458,
#  458,
#  458,
#  458,
#  458,
#  458,
#  458,
#  458,
#  458,
#  458,
#  458,
#  458,
#  542,
#  542,
#  542,
#  542,
#  541,
#  541,
#  541,
#  540,
#  540,
#  539,
#  539,
#  539,
#  539,
#  539,
#  539,
#  617,
#  617,
#  617,
#  618,
#  618,
#  618,
#  619,
#  619,
#  622,
#  622,
#  622,
#  622,
#  622,
#  622,
#  622,
#  655,
#  655,
#  655,
#  655,
#  655,
#  655,
#  655,
#  655,
#  655,
#  655,
#  728,
#  728,
#  727,
#  727,
#  727,
#  726,
#  726,
#  725,
#  724,
#  724,
#  723,
#  723,
#  722,
#  721,
#  721,
#  720,
#  720,
#  720,
#  720,
#  719,
#  719,
#  718,
#  717,
#  777,
#  777,
#  776,
#  776,
#  776,
#  774,
#  774,
#  772,
#  772,
#  771,
#  771,
#  769,
#  769,
#  769,
#  820,
#  820,
#  821,
#  821,
#  821,
#  821,
#  822,
#  822,
#  824,
#  824,
#  876,
#  876,
#  877,
#  877,
#  879,
#  879,
#  879,
#  879,
#  879,
#  879,
#  879,
#  879,
#  879,
#  879,
#  879,
#  879,
#  923,
#  928,
#  928,
#  928,
#  931,
#  931,
#  934,
#  937,
#  937,
#  937,
#  1000,
#  1000,
#  1001,
#  1002,
#  1025,
#  1018,
#  1020,
#  1021,
#  1023,
#  1024,
#  1024,
#  1024,
#  1024,
#  1024,
#  1023,
#  1023,
#  1022,
#  1110,
#  1110,
#  1112,
#  1116,
#  1117,
#  1117,
#  1119,
#  1119,
#  1120,
#  1121,
#  1122,
#  1123,
#  1124,
#  1126,
#  1126,
#  1126,
#  1127,
#  1128,
#  1128,
#  1129,
#  1129,
#  1129,
#  1131,
#  1131,
#  1131,
#  1179,
#  1179,
#  1181,
#  1181,
#  1181,
#  1181,
#  1181,
#  1181,
#  1183,
#  1183,
#  1183,
#  1183,
#  1184,
#  1185,
#  1187,
#  1187,
#  1187,
#  1188,
#  1188,
#  1188,
#  1188,
#  1188,
#  1190,
#  1190,
#  1190,
#  1191,
#  1191,
#  1191,
#  1191,
#  1193,
#  1193,
#  1218,
#  1218,
#  1219,
#  1219,
#  1219,
#  1221,
#  1221,
#  1221,
#  1221,
#  1222,
#  1223,
#  1223,
#  1223,
#  1224,
#  1224,
#  1224,
#  1225,
#  1226,
#  1227,
#  1227,
#  1227,
#  1227,
#  1229,
#  1229,
#  1229,
#  1230,
#  1230,
#  1231,
#  1231,
#  1232,
#  1232,
#  1290,
#  1291,
#  1351,
#  1351,
#  1351,
#  1351,
#  1352,
#  1358,
#  1358,
#  1359,
#  1361,
#  1404,
#  1406,
#  1406,
#  1408,
#  1408,
#  1409,
#  1031,
#  1033,
#  1004,
#  1004,
#  1004,
#  1035,
#  1036,
#  1012,
#  1021,
#  1005,
#  1005,
#  1005,
#  1005,
#  1036,
#  1116,
#  1116,
#  1218,
#  1270,
#  1270,
#  1276,
#  1276,
#  1283,
#  1283]

# %%
df["x"]=x_list
df["y"]=y_list

# %%
df
# Out:
#                                                  block  \
# 0    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 1    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 2    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 3    {'vertices': [{'x': 20, 'y': 666}, {'x': 77, '...
# 4    {'vertices': [{'x': 878, 'y': 631}, {'x': 908,...
# ..                                                 ...
# 269  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 270  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 271  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 272  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
# 273  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 1    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 2    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 3    {'vertices': [{'x': 20, 'y': 666}, {'x': 77, '...
# 4    {'vertices': [{'x': 878, 'y': 631}, {'x': 908,...
# ..                                                 ...
# 269  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 270  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 271  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 272  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
# 273  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
#
#                                                   word text  confidence     x  \
# 0    {'vertices': [{'x': 1068, 'y': 642}, {'x': 110...    P        0.99  1084
# 1    {'vertices': [{'x': 1068, 'y': 642}, {'x': 110...    .        0.99  1084
# 2    {'vertices': [{'x': 1136, 'y': 643}, {'x': 115...    1        0.99  1143
# 3    {'vertices': [{'x': 20, 'y': 666}, {'x': 77, '...    方        0.97    48
# 4    {'vertices': [{'x': 878, 'y': 631}, {'x': 908,...    O        0.46   894
# ..                                                 ...  ...         ...   ...
# 269  {'vertices': [{'x': 102, 'y': 1410}, {'x': 172...    号        0.98   140
# 270  {'vertices': [{'x': 186, 'y': 1398}, {'x': 232...    1        0.13   211
# 271  {'vertices': [{'x': 186, 'y': 1398}, {'x': 232...    1        0.33   211
# 272  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...    M        0.64   773
# 273  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...    T        0.47   773
#
#         y
# 0     662
# 1     662
# 2     663
# 3     695
# 4     688
# ..    ...
# 269  1425
# 270  1414
# 271  1414
# 272  1492
# 273  1492
#
# [274 rows x 7 columns]

# %%
sum([x_y["x"] for x_y in df["word"][0]["vertices"] ])//4
# Out:
# 175

# %%
df.loc[:,['text','confidence','word']].iloc[10:100]
# Out:
#    text  confidence                                               word
# 10    e        1.00  {'vertices': [{'x': 1196, 'y': 871}, {'x': 126...
# 11    r        0.98  {'vertices': [{'x': 1196, 'y': 871}, {'x': 126...
# 12    C        0.97  {'vertices': [{'x': 1284, 'y': 779}, {'x': 132...
# 13    o        0.99  {'vertices': [{'x': 1284, 'y': 779}, {'x': 132...
# 14    r        0.88  {'vertices': [{'x': 1284, 'y': 779}, {'x': 132...
# ..  ...         ...                                                ...
# 95    r        0.98  {'vertices': [{'x': 868, 'y': 459}, {'x': 918,...
# 96    p        0.25  {'vertices': [{'x': 972, 'y': 349}, {'x': 1011...
# 97    e        0.88  {'vertices': [{'x': 972, 'y': 349}, {'x': 1011...
# 98    r        0.88  {'vertices': [{'x': 972, 'y': 349}, {'x': 1011...
# 99    C        0.75  {'vertices': [{'x': 1036, 'y': 282}, {'x': 109...
#
# [90 rows x 3 columns]

# %%
df.loc[:,['text','confidence','x']].iloc[660:720]
# Out:
#     text  confidence    x
# 660    有        0.98  354
# 661    効        0.99  354
# 662    で        0.99  434
# 663    す        0.99  434
# 664    )        0.98  480
# 665    保        0.98  276
# 666    険        1.00  276
# 667    者        0.98  336
# 668    番        0.98  391
# 669    号        0.99  391
# 670    |        0.69  526
# 671    0        0.55  551
# 672    |        0.11  580
# 673    1        0.44  633
# 674    1        0.42  633
# 675    |        0.35  693
# 676    3        0.75  722
# 677    0        0.99  550
# 678    1        0.51  609
# 679    1        0.88  670
# 680    3        0.86  721
# 681    0        0.86  774
# 682    0        0.88  835
# 683    1        0.88  917
# 684    2        0.83  917
# 685    被        0.98  176
# 686    保        0.99  237
# 687    険        1.00  237
# 688    者        0.99  296
# 689    証        1.00  336
# 690    ・        0.98  376
# 691    被        0.97  416
# 692    保        0.99  475
# 693    険        1.00  475
# 694    |        0.64  525
# 695    5        0.73  712
# 696    7        0.81  712
# 697    2        0.91  712
# 698    8        0.99  712
# 699    0        0.99  712
# 700    2        0.98  712
# 701    0        0.99  712
# 702    4        0.98  712
# 703    者        0.95  175
# 704    手        0.96  241
# 705    帳        0.98  241
# 706    の        0.97  305
# 707    記        0.98  361
# 708    号        0.98  361
# 709    ・        0.98  420
# 710    番        0.99  477
# 711    号        1.00  477
# 712    1        0.66  628
# 713    7        0.66  628
# 714    5        0.79  628
# 715    0        0.99  628
# 716    保        0.98  196
# 717    険        1.00  196
# 718    医        0.99  269
# 719    療        1.00  269

# %%
df
# Out:
#                                                  block  \
# 0    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 1    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 2    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 3    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 4    {'vertices': [{'x': 718, 'y': 745}, {'x': 737,...
# ..                                                 ...
# 255  {'vertices': [{'x': 909, 'y': 1456}, {'x': 120...
# 256  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 257  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 258  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 259  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 1    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 2    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 3    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 4    {'vertices': [{'x': 718, 'y': 745}, {'x': 737,...
# ..                                                 ...
# 255  {'vertices': [{'x': 909, 'y': 1456}, {'x': 120...
# 256  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 257  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 258  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 259  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
#
#                                                   word text  confidence     x  \
# 0    {'vertices': [{'x': -8, 'y': 636}, {'x': 16, '...    文        0.35     6
# 1    {'vertices': [{'x': 79, 'y': 633}, {'x': 317, ...    も        0.88   200
# 2    {'vertices': [{'x': 79, 'y': 633}, {'x': 317, ...    ど        0.89   200
# 3    {'vertices': [{'x': 79, 'y': 633}, {'x': 317, ...    る        0.85   200
# 4    {'vertices': [{'x': 718, 'y': 745}, {'x': 737,...    a        0.30   729
# ..                                                 ...  ...         ...   ...
# 255  {'vertices': [{'x': 1181, 'y': 1539}, {'x': 11...    。        0.98  1185
# 256  {'vertices': [{'x': 882, 'y': 1597}, {'x': 905...    本        0.06   893
# 257  {'vertices': [{'x': 910, 'y': 1597}, {'x': 935...    日        0.49   922
# 258  {'vertices': [{'x': 917, 'y': 1596}, {'x': 961...    B        0.92   939
# 259  {'vertices': [{'x': 917, 'y': 1596}, {'x': 961...    A        0.94   939
#
#         y
# 0     697
# 1     691
# 2     691
# 3     691
# 4     778
# ..    ...
# 255  1555
# 256  1604
# 257  1604
# 258  1603
# 259  1603
#
# [260 rows x 7 columns]

# %%
df[((df["text"]=="1")& (df["confidence"]>0.2))|((df["text"]!="1")&(df["text"]!="|"))].reset_index()["text"]
# Out:
# 0      文
# 1      も
# 2      ど
# 3      る
# 4      a
#       ..
# 247    。
# 248    本
# 249    日
# 250    B
# 251    A
# Name: text, Length: 252, dtype: object

# %%
"".join(df[((df["text"]=="1")& (df["confidence"]>0.2))|((df["text"]!="1")&(df["text"]!="|"))].reset_index()["text"])
# Out:
# '文もどるa方方箋はどの保険薬局でも有効です)Page.保険者番号06139117被保険者証・被保険者手帳の記号・番号3230・6408保険医療機、〒101-0021東京都千代田区外神田六丁目14番2号関の所在地サカイ末広ビル7階B室及び名称雪月花メディカルクリニック秋葉原診療所電話番号03-5812-5301保険医氏名大道雅文男医療機関都道府県番号点数表番号1131養者コード01337100処方箋の使用期間平成年月日特に記載のある場合を除き、交付の日を含めて4日以内に保険薬局に提出すること。本日BA'

# %%
df[((df["text"]=="1")& (df["confidence"]<0.2))]
# Out:
#                                                 block  \
# 34  {'vertices': [{'x': 195, 'y': 977}, {'x': 1211...
# 37  {'vertices': [{'x': 195, 'y': 977}, {'x': 1211...
#
#                                             paragraph  \
# 34  {'vertices': [{'x': 204, 'y': 977}, {'x': 1211...
# 37  {'vertices': [{'x': 204, 'y': 977}, {'x': 1211...
#
#                                                  word text  confidence    x  \
# 34  {'vertices': [{'x': 704, 'y': 960}, {'x': 806,...    1        0.08  756
# 37  {'vertices': [{'x': 909, 'y': 950}, {'x': 979,...    1        0.16  945
#
#       y
# 34  981
# 37  972

# %%
result_list
# Out:
# [{'num': 2,
#   'result': 'P.1方O箋の保険薬局でも有効です。)保険者番号011301012被保険者証・被保険者手帳の記号・番号1080912.347保険医療機東京都千代田区飯田橋4-6-9STビル2階愛医療法人社団高典会飯田橋クリニック首í1191分電話番号03-3222-6461保険医氏名高橋典大都道府県3点数表医療機関0248コード番号処方箋の特に記載のある場合を除き、年月日交付の日を含めて4日以内に使用期間保険薬局に提出すること。ジェネリック医薬品)への変更に差し支えがあると判断した場合]」を記載し、「保険医署名」欄に署名又は記名・押印すること。番号1MT'},
#  {'num': 35, 'result': 'DateIKEtre'},
#  {'num': 40,
#   'result': '処方箋1/1この保険薬局でも有効です)保険者番号06138150被保険者証・被保険1910者手帳の記号・番号1336373村1東京都武蔵野市吉祥寺本町1-30-12保険医療機関の所在地医療法人社団東仁会吉祥寺あさひ病院電話番号0422-22-1120診療科膠原病内科有村義宏ED別女保険医氏名「都道府県点数表医療機関133370129番号番号コード髪の特に記載のある場合を除き、交付の日を含めて4日以内に■期間保険薬局に提出すること。富品(ジェネリック医薬品)への変更に差し支えがあると判断した場合は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。3錠35日分ho'},
#  {'num': 85,
#   'result': '方箋は、どの保険薬局でも有効です。)Ngean保険者番号O6138663被保険者証・被保険者手帳の記号・番号12.5900516111F111保険医療機東京都千代田区外神田5-2-3関の所在地及び名称アソルティ末広町ビル1F才末広町ヒライ耳鼻咽喉科月島女電話番号03-3836-3387保険医氏平井良治養者都道府県3点数表医療機関番号0コード番号35038処方箋の特に記載のある場合を除き、26日使用期間平成年月日交付の日を含めて4日以内に保険薬局に提出すること。医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。イン錠3錠夕食後14日分'},
#  {'num': 93,
#   'result': 'OP.1薬局でも有効です。)保険者番号o1130012被保険者証・被保険者手帳の記号・番号50000013.109420保険医療機東京都千代田区飯田橋4-4-7及び名称医療法人社団慈仁会飯田橋小池クリニックO1111電話番号03-3221-8858保険医氏名小池美由紀都道府県3点数表医療機関314551番号番号処方箋の特に記載のある場合を除き、交付の日を含めて4日以内に年月日使用期間保険薬局に提出すること。ネリック医薬品)への変更に差し支えがあると判断した場合記載し、「保険医署名」欄に署名又は記名・押印すること。錠3錠30日分3錠mg30日分湯エキス顆粒('},
#  {'num': 110,
#   'result': 'P.1GE薬局でも有効です。)保険者番号01400019被保険者証・被保険者手帳の記号・番号92420709.975保険医療機東京都千代田区外神田5-2-3関の所在地及び名称アソルティ末広町ビル1F末広町ヒライ耳鼻咽喉科電話番号03-3836-3387保険医氏孝平井良治都道府県3医療機関013点数表5038来日東日コード'},
#  {'num': 148,
#   'result': '方はどの保険薬局でも有効です)1/1ページ43保険者番号18.被保険者証・被保険者手帳の記号・番号大阪市平野区平野西3-9-21コーポ常保険医療機関のF所在地及び名称上西クリニック女電話番号(06)6760-5630保険医氏名上西正明都道府県点数表医療機関27番号番号5807943コード処方箋の平成年月日(特に記載のある場合を除き、を記載使用期間交付の日を含め4日以内に保険薬局に提出すること)2錠1日1回朝食後14日分151錠1日1回朝食後14日分'},
#  {'num': 301,
#   'result': '文もどるa方方箋はどの保険薬局でも有効です)Page.保険者番号06139117被保険者証・被保険者手帳の記号・番号3230・6408保険医療機、〒101-0021東京都千代田区外神田六丁目14番2号関の所在地サカイ末広ビル7階B室及び名称雪月花メディカルクリニック秋葉原診療所電話番号03-5812-5301保険医氏名大道雅文男医療機関都道府県番号点数表番号1131養者コード01337100処方箋の使用期間平成年月日特に記載のある場合を除き、交付の日を含めて4日以内に保険薬局に提出すること。本日BA'},
#  {'num': 326,
#   'result': '方2019年09月30日11:44発行箋年処どの保険薬局でも有効です。)保険者番号106231518概険者証・被保険4851手帳の記号・番号267保険医療機愛知県一宮市奥町字下口西89番地の1関の所在地社会医療法人杏嶺会及び名称上林記念病院電話番号0586-61-0110市男・女保険医氏名中原保裕ETS都道府県医療機関番213221021216類普2音に30日後痛義副令和1年10月3日榮淡に進学しました。薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合又は「×」を記載し、「保険医署名」欄に署名又は記名・押印することte1mg2T不眠時20回分(以下余白)点数表番号1ド号]'},
#  {'num': 339,
#   'result': '処方箋2019年09月27日12:07発行どの保険薬局でも有効です。)保険者番号01230010被保険者証・被験7410435手帳の記号・番号2保険医療機愛知県一宮市奥町字下口西89番地の1関の所在地社会医療法人杏嶺会及び名称上林記念病院電話番号0586-61-0110・保険医氏名原大En都道府県者23220212627日後痛義副令和1年9月30日峯島に進出すどな。品(ジェネリック医薬品)への変更に差し支えがあると判断した場合は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること1T1×夕食後45日分(以下余白)番号点数表番号11医療機関ド内に]KÉ20mg'},
#  {'num': 366,
#   'result': 'erj方箋方箋は、どの保険薬局でも有効です。)29①ここには薬に関連する保険薬局に提出してく-一②検査値情報をご提供い③提出を希望されない方④検査値は過去3か月間以保険者番号39271267被保険者証・被保険13580774者手帳の記号・番号保険医療機関の〒546-0002所在地及び名称大阪府大阪市東住吉区杭全男七丁目十番十九号仁真会白鷺診療所TEL.06-6714-16613日生保険医氏名田部茂印都道府県点数表医療機関1割27番号0805785番号処方箋の平成年月日特に記載のある場合を除き、交付の日付を含め4日以内に保険薬局に提出してください。⑤処方せんの有効期限は場合,保険薬局でお薬-一1コードID:82011230ヨコイコ氏名:横井直子性別生年月日:昭和15年1月0日使用期限'},
#  {'num': 435,
#   'result': '方箋1/1ページ険薬局でも有効です)保険者番号3182:63被保険者証・被保険26-38.5209者手帳の記号・番号東京都武蔵野市吉祥寺本町1-35-14保険医療機関の所在地及び名称おざき心のクリニック尾do1電話番号(0422)20-5587保険医氏名尾崎純子道府県点数表医療機関番号133325248番号コード・方箋の平成年月日(特に記載のある場合を除き、巨用期間交付の日を含め4日以内に保険薬局に提出すること)0.5錠26mg分1夕食後28日分0.5錠分1就寝前28日分'},
#  {'num': 456,
#   'result': '方箋正11どの保険薬局でも有効です。)国7-本18271保険者番号3被保険者証・械者手帳の記号・927-16•0375網地称武蔵野市吉祥寺本町1-33-6地木下循環器呼吸器内科クリニック号0422-22-8300ED氏名木下陽県113点数表医療機関番号コード31323896載のある場合を除き、交付の日を含めて4日以内に保険薬局に提出すること。ック医薬品)への変更に差し支えがあると判断した場合し、「保険医署名」欄に署名又は記名・押印すること。1Ft100mg11錠錠30日分錠1'},
#  {'num': 504,
#   'result': 'P.1でも有効です。)保険者番号06132948険者証・被保険三帳の記号・番号1324•508険医療機東京都千代田区飯田橋4-6-9STビル2階の所在地医療法人社団高典会飯田橋クリニック高橋1話番号03-3222-6461験医氏名高橋典大点数表113医療機関号02番号191コード48L方箋の特に記載のある場合を除き、年月日交付の日を含めて4日以内に巨用期間保険薬局に提出すること。ック医薬品)への変更に差し支えがあると判断した場合]し、「保険医署名」欄に署名又は記名・押印すること。錠30日分'},
#  {'num': 519,
#   'result': '方負担:30%険薬局でも有効です。保険者番号06137087被保険者証・被保険36·536者手帳の記号・番号新宿区四谷1-2-4クニヤビル3F険医療機関の在地及び名称、みどりの森ひふ科クリニック電話番号03-3352-4100険医氏名矢澤徳仁道府県点数表医療機関番号13番号1コード0437673特に記載のある場合を除き、交付の日を含めて方箋の4日以内に保険薬局に提出すること。'},
#  {'num': 524,
#   'result': 'bi箋保険薬局でも有効です。)08①ここには薬に関連する検査値情保険薬局に提出してください.②検査値情報をご提供いただくと-③提出を希望されない方は処方せ-保険者番号39272125被保険者証・被保険10403475者手帳の記号・番号保険医療機関の〒546-0002所在地及び名称大阪府大阪市東住吉区杭全七丁目十番十九秀仁真会白鷺診療所TEL.06-6714-1661保険医氏名三橋橋誠都道府県点数表271医療機関oslolT71815・番号④検査値は過去3か月間以内に測:⑤処方せんの有効期限は発行日を場合,保険薬局でお薬を受け取ID:87012068品'},
#  {'num': 548,
#   'result': '方せんは、どの保険薬局でも有効です)(処方せん番号:20171228-000074)2100103保険者番号01被保険者証・被保険59160232・7者手帳の記号・番号保険医療機関埼玉県さいたま市桜区上大久保様の所在地及び884名称性別男性医療法人聖仁会西部総合病院電話番号048-854-1111保険医氏名西郷嘉一郎麻薬免許番号「都道府県点数表医療機関1110104000背負担30%番号番号1040コード処方せんの特に記載のある場合を除き使用期間平成29年12月31日交付の日を含めて4日以内に保険薬局に提出すること。ジェネリック医薬品)への変更に差し支えがあると判断した場合を記載し、「保険医署名」欄に署名又は記名・押印すること。VafoOmgmg3錠3錠14日分14日分12/28から14日分5袋-740mg(10x14cmJERE)12/28から'},
#  {'num': 630,
#   'result': '(8115="3XIPPXIGE方方箋はどの保険薬局でも有効です)Page.1保険者番号011300112被保険者証・被保険者手帳の記号・番号42362412•18保険医療機、T101-0021東京都千代田区外神田六丁目14番2号関の所在地サカイ末広ビル7階B室及び名称、雪月花メディカルクリニック秋葉原診療所電話番号03-5812-5301保険医氏名大道雅文K)女EN呑13番号都道府県、点数表医療機関011/33710番号コード特に記載のある場合処方箋のを除き、交付の日を使用期間平成年月日含めて4日以内に保険薬局に提出すること。後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。プリノール錠100mg3錠後28日分)・ソプロフェンNa錠60mg3錠'},
#  {'num': 655,
#   'result': '処方せん~373)分割指示に係る分割の回目効です。)保険者番号1400:380被保険者証・被保険者手帳の記号・番号03・335-2943-9ON東京都千代田区外神田5丁目2-7医療機関の所在地及び名称明神下診療所電話番号03-5816-3110男保険医氏名米田衆介都道府13点数表医療機101134437号方せ県番号関コードしの使月期間平成年月日特に記載のある場合を除き、交付の日から4日以内に保険薬局に提出することック)への変更に差し支えが判断した場合には「変更不可」欄に「レ」又は'},
#  {'num': 721,
#   'result': 'th5せh後発希望ーは、どの保険薬局でも有効です。)保険者番号06139494663被保険者証・被保険者手帳の記号・番号10099744保健医療機関の東京都千代田区飯田橋4-5-16コアビル3F所在地及び名称飯田橋歯科クリニック、電話番号03-3288-5253保険医氏名竹内均'},
#  {'num': 770,
#   'result': 'Pods".X.GE箋が71負担:30%局でも有効です。)思険者番号39122072保険者証・被保険・01964204手帳の記号・番号東京都台東区上野3-16-4文行堂ビル2F医療機関の地及び名称医療法人社団雄翔会あさひ上野クリニック番号03-5818-7070森田秀和医氏名ED県点数表医療機関13番号1コード(06/301/29特に記載のある場合を除き、交付の日を含めて4日以内に保険薬局に提出すること。期間平成年月日変更に差し支えがあると判断した場合には、欄に署名又は記名・押印すること。変更不可【内服】【般】プラバスタチンナトリウム'},
#  {'num': 775,
#   'result': 'oP.1険薬局でも有効です。)保険者番号01130012被保険者証・被保険者手帳の記号・番号1322316.5保険医療機東京都千代田区飯田橋4-6-9STビル2階及び名蘇“医療法人社団高典会飯田橋クリニック11o1電話番号03-3222-6461保険医氏名高橋典大都道府県3点数表医療機関番号2番号9148コード処方箋の特に記載のある場合を除き、交付の日を含めて4日以内に使用期間年月日保険薬局に提出すること。ネリック医薬品)への変更に差し支えがあると判断した場合記載し、「保険医署名」欄に署名又は記名・押印すること。'},
#  {'num': 786,
#   'result': '処方箋2019年09月27日12:54発行.どの保険薬局でも有効です。)保険者番号2310045被保険者証・被保険手帳の記号・番号3226851保険医療機愛知県一宮市奥町字下口西89番地の1関の所在地社会医療法人杏嶺会及び名称上林記念病院電話番号0586-61-0110男・の保険医氏名市橋佳世子都道府県点数表23■医療機関養者==220226番27日令和1年9月30日業薬に提出すること。使用期間芸薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合又は「×」を記載し、「保険医署名」欄に署名又は記名・押印することmg0.5Tンロ腔内崩壊錠2.5mg1T1×朝食後28日分1ド号号5mg2T28日分1xbTE'},
#  {'num': 793,
#   'result': '方箋Page.1保険薬局でも有効です。)02長1保険者番号39271267被保険者証・被保険10428159者手帳の記号・番号岡り>保険医療機関の〒546-0002(男)所在地及び名称大阪府大阪市東住吉区杭全七丁目十番十九号仁真会白鷺診療所女TEL.06-6714-1661保険医氏名岡崎久宜都道府県点数表医療機関270805785番号番号処方箋の平成30年12月23日使用期間特に記載のある場合を除き、交付の日付を含め4日以内に保険薬局に提出してください。発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合に]または「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。1'},
#  {'num': 806,
#   'result': '処方等に、どの薬局でも有効です。(コピーは無効です。)1/1保険者番号39232038被保険者証・被保険11843562者手帳の記号・番号保険医療機関〒494-0001愛知県一宮市開明字平1番地の所在地及び名称一宮西病院様電話番号0586-48-0077(代)79才女性「保険医氏名宮田英雄担割合232203272Coor1割「都道府県番号点数表番号1医療機関ド処方箋の月27日令和1年09月30日使用期限いて、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。]2錠チン錠10mg1日2錠)朝・夕食後21日分'},
#  {'num': 879,
#   'result': 'P.1方箋GEは、どの保険薬局でも有効です。)保険者番号061348013被保険者証・被保険者手帳の記号・番号532.6175保険医療機東京都千代田区外神田5-2-3関の所在地及び名称"アソルティ末広町ビル1F末広町ヒライ耳鼻咽喉科男の電話番号03-3836-3387保険医氏名平井良治都道府県点数表医療機関3養者0351038番号番号処方箋の特に記載のある場合を除き、交付の日を含めて4日以内に26日使用期間平成年月日条険薬局に提出すること。医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。111コード'},
#  {'num': 885,
#   'result': "pyGuardPaperCorマは「×」を記載し、いくる」ZalandP/erCopyGuardPageuard来処方箋GuardByquardPaperPaperCopyGuard\\...*VGapyGuardP'sGuard医療法人社団東仁会吉祥寺あさひ9Guard京都武蔵野市吉祥寺本町1-30-12Sopy人工透析内科Yard?特に記載のある場合を除き、欄に署名又は記名・押印ybyGuardPaperConsどの保険薬局でも有効です)保険者番号011301130012被保険者証・被保険57280204者手帳の記号・番号1750保険医療機関の所在地電話番号0422-22=1120診療科性別男保険医氏名笠原仁都道府県点数表医療機関113番号番号337012193-F期間保険薬局に提出すること。薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合vardpergerOPatsedPayIdPaperやsuaaperzny\\dedPaperyGuardPaperCorIdPaperCopyGuarCopyGuardPapePaperCopCopyGardPaperCopyacoGuarderCopyGardPaper"},
#  {'num': 1011,
#   'result': 'P.1箋でも有効です。)後発希望保険者番号O1140011保険者証・被保険」手帳の記号・番号21350726•212険医療機東京都千代田区飯田橋4-4-7医療法人社団慈仁会飯田橋小池クリニックの所在地」び名称、=号11二話番号03-3221-8858険医氏名小池美由紀Q道府県点数表3医療機関01番号3455コード三方箋の特に記載のある場合を除き、日用期間年月日交付の日を含めて4日以内に保険薬局に提出すること。ンク医薬品)への変更に差し支えがあると判断した場合し、「保険医署名」欄に署名又は記名・押印すること。2錠5日分'},
#  {'num': 1110,
#   'result': '方箋どの保険薬局でも有効です。)保険者番号319311156被保険者証・被保険者手帳の記号・番号.・04354858保険医療機関の東京都杉並区上荻2-42-11所在地及び名称一般社団法人衛生文化協会城西病院電話番号03-3390-4166保険医氏名矢吹里香子ED女割都道府県番号13点数表番号1医療機関コード1570928処方箋の特に記載のある場合を除き交付の日を含めて4日以内に保険薬局使用期間平成30年5月21日に提出すること。薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。]1錠1錠1日1回14日分'},
#  {'num': 1137,
#   'result': 'P.1方O箋の保険薬局でも有効です。)後発希望保険者番号138016被保険者証・被保険者手帳の記号・番号01-48.5039保険医療機東京都千代田区飯田橋4-4-7及び名称一医療法人社団慈仁会飯田橋小池クリニック関の所在地者111女電話番号03-3221-8858保険医氏名小池美由紀印都道府県点数表3医療機関03番号545コード番号処方箋の特に記載のある場合を除き、使用期間年月日交付の日を含めて4日以内に保険薬局に提出すること。ジェネリック医薬品)への変更に差し支えがあると判断した場合」を記載し、「保険医署名」欄に署名又は記名・押印すること。5mg4'}]

# %%
df3=pd.DataFrame(result_list)
df3.to_csv("re3.csv",encoding="utf_8_sig")

# %%
result_list=[]
for num in tqdm(num_list2):
    result_dic={"num":num,"result":""}
    url="/Users/obara/Downloads/prescription_data_jpeg_3/photo-"+str(num)+".jpeg"
    outputs=recognize5(url,10,0,10)
    info_list=[]
    info_dic={"block":"","paragraph":"","word":"","text":"","confidence":""}
    for block in outputs[2]["pages"][0]["blocks"]:
        for paragraph in block["paragraphs"]:
            #print("----------------------------------------------------------")
            for word in paragraph["words"]:
                #print("-------------------")
                for symbol in word["symbols"]:
                    info_dic={"block":"","paragraph":"","word":"","text":"","confidence":1}
                    try:
                        info_dic["block"]=block["boundingBox"]
                    except:
                        pass
                    try:
                        info_dic["paragraph"]=paragraph["boundingBox"]
                    except:
                        pass
                    try:
                        info_dic["word"]=word["boundingBox"]
                    except:
                        pass
                    try:
                        info_dic["text"]=symbol["text"]
                    except:
                        pass
                    try:
                        info_dic["confidence"]=float(symbol["confidence"])
                    except:
                        pass
                    info_list.append(info_dic)
    df=pd.DataFrame(info_list)
    print(df)
    x_list=[]
    for row in df["word"]:
        try:
            x_list.append(sum([x_y["x"] for x_y in row["vertices"]])//4)
        except:
            x_list.append("")
            
    y_list=[]
    for row in df["word"]:
        try:
            y_list.append(sum([x_y["y"] for x_y in row["vertices"]])//4)
        except:
            y_list.append("")
    df["x"]=x_list
    df["y"]=y_list
    result_dic["result"]="".join(df[((df["text"]=="1")& (df["confidence"]>0.2))|((df["text"]!="1")&(df["text"]!="|"))].reset_index()["text"])
    result_list.append(result_dic)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#   3%|▎         | 1/30 [00:09<04:43,  9.79s/it]
# API終了までにかかった時間:9.690528869628906[sec]
# for文を回し終わるまでにかかった時間:9.7014901638031[sec]
# elapsed_time:9.736762046813965[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 1    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 2    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 3    {'vertices': [{'x': 20, 'y': 666}, {'x': 77, '...
# 4    {'vertices': [{'x': 878, 'y': 631}, {'x': 908,...
# ..                                                 ...
# 269  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 270  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 271  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 272  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
# 273  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 1    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 2    {'vertices': [{'x': 1068, 'y': 642}, {'x': 115...
# 3    {'vertices': [{'x': 20, 'y': 666}, {'x': 77, '...
# 4    {'vertices': [{'x': 878, 'y': 631}, {'x': 908,...
# ..                                                 ...
# 269  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 270  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 271  {'vertices': [{'x': 102, 'y': 1410}, {'x': 232...
# 272  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
# 273  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 1068, 'y': 642}, {'x': 110...    P        0.99
# 1    {'vertices': [{'x': 1068, 'y': 642}, {'x': 110...    .        0.99
# 2    {'vertices': [{'x': 1136, 'y': 643}, {'x': 115...    1        0.99
# 3    {'vertices': [{'x': 20, 'y': 666}, {'x': 77, '...    方        0.97
# 4    {'vertices': [{'x': 878, 'y': 631}, {'x': 908,...    O        0.46
# ..                                                 ...  ...         ...
# 269  {'vertices': [{'x': 102, 'y': 1410}, {'x': 172...    号        0.98
# 270  {'vertices': [{'x': 186, 'y': 1398}, {'x': 232...    1        0.13
# 271  {'vertices': [{'x': 186, 'y': 1398}, {'x': 232...    1        0.33
# 272  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...    M        0.64
# 273  {'vertices': [{'x': 781, 'y': 1480}, {'x': 781...    T        0.47
#
# [274 rows x 5 columns]
#   7%|▋         | 2/30 [00:26<05:31, 11.85s/it]
# API終了までにかかった時間:16.59343123435974[sec]
# for文を回し終わるまでにかかった時間:16.594004154205322[sec]
# elapsed_time:16.60190510749817[sec]
#                                                block  \
# 0  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...
# 1  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...
# 2  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...
# 3  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...
# 4  {'vertices': [{'x': 322, 'y': 1027}, {'x': 617...
# 5  {'vertices': [{'x': 322, 'y': 1027}, {'x': 617...
# 6  {'vertices': [{'x': 322, 'y': 1027}, {'x': 617...
# 7  {'vertices': [{'x': 499, 'y': 1210}, {'x': 498...
# 8  {'vertices': [{'x': 499, 'y': 1210}, {'x': 498...
# 9  {'vertices': [{'x': 499, 'y': 1210}, {'x': 498...
#
#                                            paragraph  \
# 0  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...
# 1  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...
# 2  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...
# 3  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...
# 4  {'vertices': [{'x': 322, 'y': 1027}, {'x': 617...
# 5  {'vertices': [{'x': 322, 'y': 1027}, {'x': 617...
# 6  {'vertices': [{'x': 322, 'y': 1027}, {'x': 617...
# 7  {'vertices': [{'x': 499, 'y': 1210}, {'x': 498...
# 8  {'vertices': [{'x': 499, 'y': 1210}, {'x': 498...
# 9  {'vertices': [{'x': 499, 'y': 1210}, {'x': 498...
#
#                                                 word text  confidence
# 0  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...    D        0.99
# 1  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...    a        1.00
# 2  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...    t        1.00
# 3  {'vertices': [{'x': 630, 'y': 460}, {'x': 699,...    e        1.00
# 4  {'vertices': [{'x': 322, 'y': 1027}, {'x': 617...    I        0.72
# 5  {'vertices': [{'x': 322, 'y': 1027}, {'x': 617...    K        0.67
# 6  {'vertices': [{'x': 322, 'y': 1027}, {'x': 617...    E        0.50
# 7  {'vertices': [{'x': 499, 'y': 1210}, {'x': 498...    t        0.95
# 8  {'vertices': [{'x': 499, 'y': 1210}, {'x': 498...    r        0.73
# 9  {'vertices': [{'x': 499, 'y': 1210}, {'x': 498...    e        0.87
#  10%|█         | 3/30 [00:33<04:41, 10.43s/it]
# API終了までにかかった時間:7.065199136734009[sec]
# for文を回し終わるまでにかかった時間:7.073328018188477[sec]
# elapsed_time:7.0870521068573[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 57, 'y': 492}, {'x': 265, ...
# 1    {'vertices': [{'x': 57, 'y': 492}, {'x': 265, ...
# 2    {'vertices': [{'x': 57, 'y': 492}, {'x': 265, ...
# 3    {'vertices': [{'x': -3, 'y': 508}, {'x': 962, ...
# 4    {'vertices': [{'x': -3, 'y': 508}, {'x': 962, ...
# ..                                                 ...
# 297  {'vertices': [{'x': -19, 'y': 856}, {'x': 1113...
# 298  {'vertices': [{'x': -19, 'y': 856}, {'x': 1113...
# 299  {'vertices': [{'x': -19, 'y': 856}, {'x': 1113...
# 300  {'vertices': [{'x': 17, 'y': 1473}, {'x': 18, ...
# 301  {'vertices': [{'x': 17, 'y': 1473}, {'x': 18, ...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 57, 'y': 492}, {'x': 265, ...
# 1    {'vertices': [{'x': 57, 'y': 492}, {'x': 265, ...
# 2    {'vertices': [{'x': 57, 'y': 492}, {'x': 265, ...
# 3    {'vertices': [{'x': -3, 'y': 508}, {'x': 962, ...
# 4    {'vertices': [{'x': -3, 'y': 508}, {'x': 962, ...
# ..                                                 ...
# 297  {'vertices': [{'x': 818, 'y': 1498}, {'x': 950...
# 298  {'vertices': [{'x': 818, 'y': 1498}, {'x': 950...
# 299  {'vertices': [{'x': 818, 'y': 1498}, {'x': 950...
# 300  {'vertices': [{'x': 17, 'y': 1473}, {'x': 18, ...
# 301  {'vertices': [{'x': 17, 'y': 1473}, {'x': 18, ...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 57, 'y': 492}, {'x': 211, ...    処        0.74
# 1    {'vertices': [{'x': 57, 'y': 492}, {'x': 211, ...    方        0.65
# 2    {'vertices': [{'x': 238, 'y': 496}, {'x': 265,...    箋        0.74
# 3    {'vertices': [{'x': 863, 'y': 491}, {'x': 962,...    1        0.99
# 4    {'vertices': [{'x': 863, 'y': 491}, {'x': 962,...    /        0.91
# ..                                                 ...  ...         ...
# 297  {'vertices': [{'x': 818, 'y': 1498}, {'x': 861...    5        0.74
# 298  {'vertices': [{'x': 882, 'y': 1496}, {'x': 893...    日        0.74
# 299  {'vertices': [{'x': 930, 'y': 1495}, {'x': 950...    分        0.98
# 300  {'vertices': [{'x': 17, 'y': 1473}, {'x': 18, ...    h        0.44
# 301  {'vertices': [{'x': 17, 'y': 1473}, {'x': 18, ...    o        0.11
#
# [302 rows x 5 columns]
#  13%|█▎        | 4/30 [00:40<04:05,  9.44s/it]
# API終了までにかかった時間:7.063644886016846[sec]
# for文を回し終わるまでにかかった時間:7.071809768676758[sec]
# elapsed_time:7.0831077098846436[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 140, 'y': 456}, {'x': 198,...
# 1    {'vertices': [{'x': 445, 'y': 481}, {'x': 505,...
# 2    {'vertices': [{'x': 39, 'y': 527}, {'x': 469, ...
# 3    {'vertices': [{'x': 39, 'y': 527}, {'x': 469, ...
# 4    {'vertices': [{'x': 39, 'y': 527}, {'x': 469, ...
# ..                                                 ...
# 306  {'vertices': [{'x': -6, 'y': 842}, {'x': 1279,...
# 307  {'vertices': [{'x': -6, 'y': 842}, {'x': 1279,...
# 308  {'vertices': [{'x': -6, 'y': 842}, {'x': 1279,...
# 309  {'vertices': [{'x': -6, 'y': 842}, {'x': 1279,...
# 310  {'vertices': [{'x': -6, 'y': 842}, {'x': 1279,...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 140, 'y': 456}, {'x': 198,...
# 1    {'vertices': [{'x': 445, 'y': 481}, {'x': 505,...
# 2    {'vertices': [{'x': 39, 'y': 527}, {'x': 469, ...
# 3    {'vertices': [{'x': 39, 'y': 527}, {'x': 469, ...
# 4    {'vertices': [{'x': 39, 'y': 527}, {'x': 469, ...
# ..                                                 ...
# 306  {'vertices': [{'x': 2, 'y': 1473}, {'x': 722, ...
# 307  {'vertices': [{'x': 869, 'y': 1543}, {'x': 102...
# 308  {'vertices': [{'x': 869, 'y': 1543}, {'x': 102...
# 309  {'vertices': [{'x': 869, 'y': 1543}, {'x': 102...
# 310  {'vertices': [{'x': 869, 'y': 1543}, {'x': 102...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 140, 'y': 456}, {'x': 198,...    方        0.98
# 1    {'vertices': [{'x': 445, 'y': 481}, {'x': 505,...    箋        0.89
# 2    {'vertices': [{'x': 39, 'y': 528}, {'x': 47, '...    は        0.53
# 3    {'vertices': [{'x': 61, 'y': 529}, {'x': 69, '...    、        0.58
# 4    {'vertices': [{'x': 90, 'y': 529}, {'x': 137, ...    ど        0.54
# ..                                                 ...  ...         ...
# 306  {'vertices': [{'x': 92, 'y': 1540}, {'x': 132,...    後        0.99
# 307  {'vertices': [{'x': 869, 'y': 1543}, {'x': 910...    1        0.98
# 308  {'vertices': [{'x': 869, 'y': 1543}, {'x': 910...    4        0.98
# 309  {'vertices': [{'x': 947, 'y': 1543}, {'x': 972...    日        0.98
# 310  {'vertices': [{'x': 987, 'y': 1542}, {'x': 102...    分        0.98
#
# [311 rows x 5 columns]
#  17%|█▋        | 5/30 [00:47<03:32,  8.51s/it]
# API終了までにかかった時間:6.295245170593262[sec]
# for文を回し終わるまでにかかった時間:6.3034749031066895[sec]
# elapsed_time:6.3155670166015625[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 831, 'y': 134}, {'x': 830,...
# 1    {'vertices': [{'x': 1003, 'y': 146}, {'x': 108...
# 2    {'vertices': [{'x': 1003, 'y': 146}, {'x': 108...
# 3    {'vertices': [{'x': 1003, 'y': 146}, {'x': 108...
# 4    {'vertices': [{'x': -8, 'y': 287}, {'x': 267, ...
# ..                                                 ...
# 277  {'vertices': [{'x': -8, 'y': 1558}, {'x': 342,...
# 278  {'vertices': [{'x': -8, 'y': 1558}, {'x': 342,...
# 279  {'vertices': [{'x': -8, 'y': 1558}, {'x': 342,...
# 280  {'vertices': [{'x': -8, 'y': 1558}, {'x': 342,...
# 281  {'vertices': [{'x': -8, 'y': 1558}, {'x': 342,...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 831, 'y': 134}, {'x': 830,...
# 1    {'vertices': [{'x': 1003, 'y': 146}, {'x': 108...
# 2    {'vertices': [{'x': 1003, 'y': 146}, {'x': 108...
# 3    {'vertices': [{'x': 1003, 'y': 146}, {'x': 108...
# 4    {'vertices': [{'x': -8, 'y': 287}, {'x': 267, ...
# ..                                                 ...
# 277  {'vertices': [{'x': -8, 'y': 1558}, {'x': 342,...
# 278  {'vertices': [{'x': -8, 'y': 1558}, {'x': 342,...
# 279  {'vertices': [{'x': -8, 'y': 1558}, {'x': 342,...
# 280  {'vertices': [{'x': -8, 'y': 1558}, {'x': 342,...
# 281  {'vertices': [{'x': -8, 'y': 1558}, {'x': 342,...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 831, 'y': 134}, {'x': 830,...    O        0.69
# 1    {'vertices': [{'x': 1003, 'y': 146}, {'x': 103...    P        0.99
# 2    {'vertices': [{'x': 1003, 'y': 146}, {'x': 103...    .        0.99
# 3    {'vertices': [{'x': 1076, 'y': 146}, {'x': 108...    1        0.97
# 4    {'vertices': [{'x': -8, 'y': 287}, {'x': 39, '...    薬        0.97
# ..                                                 ...  ...         ...
# 277  {'vertices': [{'x': 51, 'y': 1556}, {'x': 192,...    キ        0.99
# 278  {'vertices': [{'x': 51, 'y': 1556}, {'x': 192,...    ス        0.99
# 279  {'vertices': [{'x': 205, 'y': 1552}, {'x': 279...    顆        0.99
# 280  {'vertices': [{'x': 205, 'y': 1552}, {'x': 279...    粒        1.00
# 281  {'vertices': [{'x': 330, 'y': 1549}, {'x': 342...    (        0.99
#
# [282 rows x 5 columns]
#  20%|██        | 6/30 [00:52<03:04,  7.69s/it]
# API終了までにかかった時間:5.707255125045776[sec]
# for文を回し終わるまでにかかった時間:5.713579177856445[sec]
# elapsed_time:5.7263970375061035[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 922, 'y': 879}, {'x': 1000...
# 1    {'vertices': [{'x': 922, 'y': 879}, {'x': 1000...
# 2    {'vertices': [{'x': 922, 'y': 879}, {'x': 1000...
# 3    {'vertices': [{'x': 473, 'y': 884}, {'x': 849,...
# 4    {'vertices': [{'x': 473, 'y': 884}, {'x': 849,...
# ..                                                 ...
# 156  {'vertices': [{'x': 268, 'y': 1599}, {'x': 315...
# 157  {'vertices': [{'x': 268, 'y': 1599}, {'x': 315...
# 158  {'vertices': [{'x': 434, 'y': 1599}, {'x': 502...
# 159  {'vertices': [{'x': 434, 'y': 1599}, {'x': 502...
# 160  {'vertices': [{'x': 434, 'y': 1599}, {'x': 502...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 922, 'y': 879}, {'x': 1000...
# 1    {'vertices': [{'x': 922, 'y': 879}, {'x': 1000...
# 2    {'vertices': [{'x': 922, 'y': 879}, {'x': 1000...
# 3    {'vertices': [{'x': 473, 'y': 884}, {'x': 849,...
# 4    {'vertices': [{'x': 473, 'y': 884}, {'x': 849,...
# ..                                                 ...
# 156  {'vertices': [{'x': 268, 'y': 1599}, {'x': 315...
# 157  {'vertices': [{'x': 268, 'y': 1599}, {'x': 315...
# 158  {'vertices': [{'x': 434, 'y': 1599}, {'x': 502...
# 159  {'vertices': [{'x': 434, 'y': 1599}, {'x': 502...
# 160  {'vertices': [{'x': 434, 'y': 1599}, {'x': 502...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 922, 'y': 879}, {'x': 954,...    P        0.99
# 1    {'vertices': [{'x': 922, 'y': 879}, {'x': 954,...    .        0.99
# 2    {'vertices': [{'x': 987, 'y': 879}, {'x': 1000...    1        0.97
# 3    {'vertices': [{'x': 473, 'y': 884}, {'x': 849,...    G        0.99
# 4    {'vertices': [{'x': 473, 'y': 884}, {'x': 849,...    E        0.96
# ..                                                 ...  ...         ...
# 156  {'vertices': [{'x': 268, 'y': 1599}, {'x': 289...    東        0.88
# 157  {'vertices': [{'x': 294, 'y': 1599}, {'x': 315...    日        0.70
# 158  {'vertices': [{'x': 434, 'y': 1599}, {'x': 502...    コ        0.23
# 159  {'vertices': [{'x': 434, 'y': 1599}, {'x': 502...    ー        0.82
# 160  {'vertices': [{'x': 434, 'y': 1599}, {'x': 502...    ド        0.35
#
# [161 rows x 5 columns]
# API終了までにかかった時間:7.382947683334351[sec]
# for文を回し終わるまでにかかった時間:7.5643229484558105[sec]
# elapsed_time:7.582010746002197[sec]
#                                                  block  \
# 0    {'vertices': [{'x': -6, 'y': 224}, {'x': 626, ...
# 1    {'vertices': [{'x': -6, 'y': 224}, {'x': 626, ...
# 2    {'vertices': [{'x': -6, 'y': 224}, {'x': 626, ...
# 3    {'vertices': [{'x': -6, 'y': 224}, {'x': 626, ...
# 4    {'vertices': [{'x': -6, 'y': 224}, {'x': 626, ...
# ..                                                 ...
# 223  {'vertices': [{'x': 582, 'y': 1479}, {'x': 907...
# 224  {'vertices': [{'x': 1145, 'y': 1491}, {'x': 12...
# 225  {'vertices': [{'x': 1145, 'y': 1491}, {'x': 12...
# 226  {'vertices': [{'x': 1145, 'y': 1491}, {'x': 12...
# 227  {'vertices': [{'x': 1145, 'y': 1491}, {'x': 12...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': -6, 'y': 224}, {'x': 626, ...
# 1    {'vertices': [{'x': -6, 'y': 224}, {'x': 626, ...
# 2    {'vertices': [{'x': -6, 'y': 224}, {'x': 626, ...
# 3    {'vertices': [{'x': -6, 'y': 224}, {'x': 626, ...
# 4    {'vertices': [{'x': -6, 'y': 224}, {'x': 626, ...
# ..                                                 ...
# 223  {'vertices': [{'x': 582, 'y': 1479}, {'x': 907...
# 224  {'vertices': [{'x': 1145, 'y': 1491}, {'x': 12...
# 225  {'vertices': [{'x': 1145, 'y': 1491}, {'x': 12...
# 226  {'vertices': [{'x': 1145, 'y': 1491}, {'x': 12...
# 227  {'vertices': [{'x': 1145, 'y': 1491}, {'x': 12...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 162, 'y': 227}, {'x': 233,...    方        0.96
# 1    {'vertices': [{'x': -7, 'y': 317}, {'x': 39, '...    は        0.69
# 2    {'vertices': [{'x': 56, 'y': 317}, {'x': 142, ...    ど        0.69
# 3    {'vertices': [{'x': 56, 'y': 317}, {'x': 142, ...    の        0.48
# 4    {'vertices': [{'x': 145, 'y': 318}, {'x': 231,...    保        0.98
# ..                                                 ...  ...         ...
# 223  {'vertices': [{'x': 862, 'y': 1482}, {'x': 907...    後        0.99
# 224  {'vertices': [{'x': 1145, 'y': 1491}, {'x': 11...    1        0.98
# 225  {'vertices': [{'x': 1145, 'y': 1491}, {'x': 11...    4        0.99
# 226  {'vertices': [{'x': 1204, 'y': 1491}, {'x': 12...    日        0.99
# 227  {'vertices': [{'x': 1248, 'y': 1491}, {'x': 12...    分        0.98
#
# [228 rows x 5 columns]
#  23%|██▎       | 7/30 [01:00<02:57,  7.71s/it]
#  27%|██▋       | 8/30 [01:07<02:45,  7.54s/it]
# API終了までにかかった時間:7.049402713775635[sec]
# for文を回し終わるまでにかかった時間:7.056643724441528[sec]
# elapsed_time:7.069972991943359[sec]
#                                                  block  \
# 0    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 1    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 2    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 3    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 4    {'vertices': [{'x': 718, 'y': 745}, {'x': 737,...
# ..                                                 ...
# 255  {'vertices': [{'x': 909, 'y': 1456}, {'x': 120...
# 256  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 257  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 258  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 259  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 1    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 2    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 3    {'vertices': [{'x': -8, 'y': 636}, {'x': 317, ...
# 4    {'vertices': [{'x': 718, 'y': 745}, {'x': 737,...
# ..                                                 ...
# 255  {'vertices': [{'x': 909, 'y': 1456}, {'x': 120...
# 256  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 257  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 258  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
# 259  {'vertices': [{'x': 882, 'y': 1597}, {'x': 961...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': -8, 'y': 636}, {'x': 16, '...    文        0.35
# 1    {'vertices': [{'x': 79, 'y': 633}, {'x': 317, ...    も        0.88
# 2    {'vertices': [{'x': 79, 'y': 633}, {'x': 317, ...    ど        0.89
# 3    {'vertices': [{'x': 79, 'y': 633}, {'x': 317, ...    る        0.85
# 4    {'vertices': [{'x': 718, 'y': 745}, {'x': 737,...    a        0.30
# ..                                                 ...  ...         ...
# 255  {'vertices': [{'x': 1181, 'y': 1539}, {'x': 11...    。        0.98
# 256  {'vertices': [{'x': 882, 'y': 1597}, {'x': 905...    本        0.06
# 257  {'vertices': [{'x': 910, 'y': 1597}, {'x': 935...    日        0.49
# 258  {'vertices': [{'x': 917, 'y': 1596}, {'x': 961...    B        0.92
# 259  {'vertices': [{'x': 917, 'y': 1596}, {'x': 961...    A        0.94
#
# [260 rows x 5 columns]
#  30%|███       | 9/30 [01:14<02:32,  7.27s/it]
# API終了までにかかった時間:6.6094651222229[sec]
# for文を回し終わるまでにかかった時間:6.61654806137085[sec]
# elapsed_time:6.629722833633423[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 428, 'y': 277}, {'x': 500,...
# 1    {'vertices': [{'x': -31, 'y': 243}, {'x': 1473...
# 2    {'vertices': [{'x': -31, 'y': 243}, {'x': 1473...
# 3    {'vertices': [{'x': -31, 'y': 243}, {'x': 1473...
# 4    {'vertices': [{'x': -31, 'y': 243}, {'x': 1473...
# ..                                                 ...
# 298  {'vertices': [{'x': 574, 'y': 897}, {'x': 696,...
# 299  {'vertices': [{'x': 731, 'y': 904}, {'x': 766,...
# 300  {'vertices': [{'x': 949, 'y': 922}, {'x': 966,...
# 301  {'vertices': [{'x': 366, 'y': 936}, {'x': 393,...
# 302  {'vertices': [{'x': 1263, 'y': 1080}, {'x': 13...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 428, 'y': 277}, {'x': 500,...
# 1    {'vertices': [{'x': 835, 'y': 226}, {'x': 1473...
# 2    {'vertices': [{'x': 835, 'y': 226}, {'x': 1473...
# 3    {'vertices': [{'x': 835, 'y': 226}, {'x': 1473...
# 4    {'vertices': [{'x': 835, 'y': 226}, {'x': 1473...
# ..                                                 ...
# 298  {'vertices': [{'x': 574, 'y': 897}, {'x': 696,...
# 299  {'vertices': [{'x': 731, 'y': 904}, {'x': 766,...
# 300  {'vertices': [{'x': 949, 'y': 922}, {'x': 966,...
# 301  {'vertices': [{'x': 366, 'y': 936}, {'x': 393,...
# 302  {'vertices': [{'x': 1263, 'y': 1080}, {'x': 13...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 428, 'y': 277}, {'x': 500,...    方        0.98
# 1    {'vertices': [{'x': 835, 'y': 226}, {'x': 933,...    2        0.99
# 2    {'vertices': [{'x': 835, 'y': 226}, {'x': 933,...    0        0.99
# 3    {'vertices': [{'x': 835, 'y': 226}, {'x': 933,...    1        0.99
# 4    {'vertices': [{'x': 835, 'y': 226}, {'x': 933,...    9        0.97
# ..                                                 ...  ...         ...
# 298  {'vertices': [{'x': 669, 'y': 928}, {'x': 696,...    号        0.97
# 299  {'vertices': [{'x': 731, 'y': 904}, {'x': 766,...    1        0.99
# 300  {'vertices': [{'x': 949, 'y': 922}, {'x': 966,...    ド        0.80
# 301  {'vertices': [{'x': 366, 'y': 936}, {'x': 393,...    号        0.97
# 302  {'vertices': [{'x': 1263, 'y': 1080}, {'x': 13...    ]        0.58
#
# [303 rows x 5 columns]
#  33%|███▎      | 10/30 [01:25<02:49,  8.46s/it]
# API終了までにかかった時間:11.171270847320557[sec]
# for文を回し終わるまでにかかった時間:11.179605960845947[sec]
# elapsed_time:11.192055940628052[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 137, 'y': 347}, {'x': 208,...
# 1    {'vertices': [{'x': -4, 'y': 293}, {'x': 1448,...
# 2    {'vertices': [{'x': -4, 'y': 293}, {'x': 1448,...
# 3    {'vertices': [{'x': -4, 'y': 293}, {'x': 1448,...
# 4    {'vertices': [{'x': -4, 'y': 293}, {'x': 1448,...
# ..                                                 ...
# 287  {'vertices': [{'x': -1, 'y': 1239}, {'x': 245,...
# 288  {'vertices': [{'x': -1, 'y': 1239}, {'x': 245,...
# 289  {'vertices': [{'x': -1, 'y': 1239}, {'x': 245,...
# 290  {'vertices': [{'x': -1, 'y': 1239}, {'x': 245,...
# 291  {'vertices': [{'x': -1, 'y': 1239}, {'x': 245,...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 137, 'y': 347}, {'x': 208,...
# 1    {'vertices': [{'x': 4, 'y': 359}, {'x': 1441, ...
# 2    {'vertices': [{'x': 4, 'y': 359}, {'x': 1441, ...
# 3    {'vertices': [{'x': 4, 'y': 359}, {'x': 1441, ...
# 4    {'vertices': [{'x': 4, 'y': 359}, {'x': 1441, ...
# ..                                                 ...
# 287  {'vertices': [{'x': -1, 'y': 1239}, {'x': 245,...
# 288  {'vertices': [{'x': -1, 'y': 1239}, {'x': 245,...
# 289  {'vertices': [{'x': -1, 'y': 1239}, {'x': 245,...
# 290  {'vertices': [{'x': -1, 'y': 1239}, {'x': 245,...
# 291  {'vertices': [{'x': -1, 'y': 1239}, {'x': 245,...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 137, 'y': 347}, {'x': 208,...    処        0.97
# 1    {'vertices': [{'x': 401, 'y': 343}, {'x': 740,...    方        0.97
# 2    {'vertices': [{'x': 401, 'y': 343}, {'x': 740,...    箋        0.98
# 3    {'vertices': [{'x': 799, 'y': 327}, {'x': 896,...    2        0.65
# 4    {'vertices': [{'x': 799, 'y': 327}, {'x': 896,...    0        0.95
# ..                                                 ...  ...         ...
# 287  {'vertices': [{'x': -1, 'y': 1240}, {'x': 37, ...    É        0.10
# 288  {'vertices': [{'x': 56, 'y': 1244}, {'x': 150,...    2        0.78
# 289  {'vertices': [{'x': 56, 'y': 1244}, {'x': 150,...    0        0.26
# 290  {'vertices': [{'x': 157, 'y': 1251}, {'x': 246...    m        0.48
# 291  {'vertices': [{'x': 157, 'y': 1251}, {'x': 246...    g        0.44
#
# [292 rows x 5 columns]
#  37%|███▋      | 11/30 [01:36<02:52,  9.11s/it]
# API終了までにかかった時間:10.54636001586914[sec]
# for文を回し終わるまでにかかった時間:10.556682825088501[sec]
# elapsed_time:10.568599939346313[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 81, 'y': 748}, {'x': 461, ...
# 1    {'vertices': [{'x': 81, 'y': 748}, {'x': 461, ...
# 2    {'vertices': [{'x': 81, 'y': 748}, {'x': 461, ...
# 3    {'vertices': [{'x': 81, 'y': 748}, {'x': 461, ...
# 4    {'vertices': [{'x': 81, 'y': 748}, {'x': 461, ...
# ..                                                 ...
# 348  {'vertices': [{'x': 5, 'y': 1536}, {'x': 245, ...
# 349  {'vertices': [{'x': 5, 'y': 1536}, {'x': 245, ...
# 350  {'vertices': [{'x': 5, 'y': 1536}, {'x': 245, ...
# 351  {'vertices': [{'x': 5, 'y': 1536}, {'x': 245, ...
# 352  {'vertices': [{'x': 5, 'y': 1536}, {'x': 245, ...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 81, 'y': 748}, {'x': 303, ...
# 1    {'vertices': [{'x': 81, 'y': 748}, {'x': 303, ...
# 2    {'vertices': [{'x': 81, 'y': 748}, {'x': 303, ...
# 3    {'vertices': [{'x': 241, 'y': 749}, {'x': 461,...
# 4    {'vertices': [{'x': 241, 'y': 749}, {'x': 461,...
# ..                                                 ...
# 348  {'vertices': [{'x': 5, 'y': 1536}, {'x': 245, ...
# 349  {'vertices': [{'x': 5, 'y': 1536}, {'x': 245, ...
# 350  {'vertices': [{'x': 5, 'y': 1536}, {'x': 245, ...
# 351  {'vertices': [{'x': 5, 'y': 1536}, {'x': 245, ...
# 352  {'vertices': [{'x': 5, 'y': 1536}, {'x': 245, ...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 81, 'y': 748}, {'x': 125, ...    e        0.88
# 1    {'vertices': [{'x': 81, 'y': 748}, {'x': 125, ...    r        0.92
# 2    {'vertices': [{'x': 285, 'y': 748}, {'x': 303,...    j        0.89
# 3    {'vertices': [{'x': 241, 'y': 749}, {'x': 297,...    方        0.97
# 4    {'vertices': [{'x': 408, 'y': 755}, {'x': 461,...    箋        0.97
# ..                                                 ...  ...         ...
# 348  {'vertices': [{'x': 75, 'y': 1542}, {'x': 82, ...    |        0.09
# 349  {'vertices': [{'x': 101, 'y': 1544}, {'x': 170...    使        0.35
# 350  {'vertices': [{'x': 101, 'y': 1544}, {'x': 170...    用        0.32
# 351  {'vertices': [{'x': 177, 'y': 1549}, {'x': 246...    期        0.47
# 352  {'vertices': [{'x': 177, 'y': 1549}, {'x': 246...    限        1.00
#
# [353 rows x 5 columns]
#  40%|████      | 12/30 [01:42<02:29,  8.31s/it]
# API終了までにかかった時間:6.391267776489258[sec]
# for文を回し終わるまでにかかった時間:6.398671865463257[sec]
# elapsed_time:6.412536859512329[sec]
#                                                  block  \
# 0    {'vertices': [{'x': -8, 'y': 392}, {'x': 51, '...
# 1    {'vertices': [{'x': 323, 'y': 445}, {'x': 385,...
# 2    {'vertices': [{'x': 765, 'y': 445}, {'x': 959,...
# 3    {'vertices': [{'x': 765, 'y': 445}, {'x': 959,...
# 4    {'vertices': [{'x': 765, 'y': 445}, {'x': 959,...
# ..                                                 ...
# 234  {'vertices': [{'x': 391, 'y': 1478}, {'x': 592...
# 235  {'vertices': [{'x': 821, 'y': 1476}, {'x': 948...
# 236  {'vertices': [{'x': 821, 'y': 1476}, {'x': 948...
# 237  {'vertices': [{'x': 821, 'y': 1476}, {'x': 948...
# 238  {'vertices': [{'x': 821, 'y': 1476}, {'x': 948...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': -8, 'y': 392}, {'x': 51, '...
# 1    {'vertices': [{'x': 323, 'y': 445}, {'x': 385,...
# 2    {'vertices': [{'x': 765, 'y': 445}, {'x': 959,...
# 3    {'vertices': [{'x': 765, 'y': 445}, {'x': 959,...
# 4    {'vertices': [{'x': 765, 'y': 445}, {'x': 959,...
# ..                                                 ...
# 234  {'vertices': [{'x': 391, 'y': 1478}, {'x': 592...
# 235  {'vertices': [{'x': 821, 'y': 1476}, {'x': 948...
# 236  {'vertices': [{'x': 821, 'y': 1476}, {'x': 948...
# 237  {'vertices': [{'x': 821, 'y': 1476}, {'x': 948...
# 238  {'vertices': [{'x': 821, 'y': 1476}, {'x': 948...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': -8, 'y': 392}, {'x': 51, '...    方        0.97
# 1    {'vertices': [{'x': 323, 'y': 445}, {'x': 385,...    箋        0.87
# 2    {'vertices': [{'x': 765, 'y': 445}, {'x': 818,...    1        0.98
# 3    {'vertices': [{'x': 765, 'y': 445}, {'x': 818,...    /        0.98
# 4    {'vertices': [{'x': 765, 'y': 445}, {'x': 818,...    1        0.99
# ..                                                 ...  ...         ...
# 234  {'vertices': [{'x': 553, 'y': 1476}, {'x': 592...    前        0.99
# 235  {'vertices': [{'x': 821, 'y': 1476}, {'x': 861...    2        0.99
# 236  {'vertices': [{'x': 821, 'y': 1476}, {'x': 861...    8        0.98
# 237  {'vertices': [{'x': 872, 'y': 1476}, {'x': 894...    日        0.98
# 238  {'vertices': [{'x': 909, 'y': 1475}, {'x': 948...    分        0.98
#
# [239 rows x 5 columns]
#  43%|████▎     | 13/30 [01:49<02:12,  7.81s/it]
# API終了までにかかった時間:6.591402053833008[sec]
# for文を回し終わるまでにかかった時間:6.599190950393677[sec]
# elapsed_time:6.613186836242676[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 104, 'y': 281}, {'x': 359,...
# 1    {'vertices': [{'x': 104, 'y': 281}, {'x': 359,...
# 2    {'vertices': [{'x': 511, 'y': 308}, {'x': 559,...
# 3    {'vertices': [{'x': 1055, 'y': 329}, {'x': 109...
# 4    {'vertices': [{'x': 1055, 'y': 329}, {'x': 109...
# ..                                                 ...
# 240  {'vertices': [{'x': 964, 'y': 1426}, {'x': 116...
# 241  {'vertices': [{'x': 964, 'y': 1426}, {'x': 116...
# 242  {'vertices': [{'x': 964, 'y': 1426}, {'x': 116...
# 243  {'vertices': [{'x': 964, 'y': 1426}, {'x': 116...
# 244  {'vertices': [{'x': 708, 'y': 1504}, {'x': 742...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 104, 'y': 281}, {'x': 359,...
# 1    {'vertices': [{'x': 104, 'y': 281}, {'x': 359,...
# 2    {'vertices': [{'x': 511, 'y': 308}, {'x': 559,...
# 3    {'vertices': [{'x': 1055, 'y': 329}, {'x': 109...
# 4    {'vertices': [{'x': 1055, 'y': 329}, {'x': 109...
# ..                                                 ...
# 240  {'vertices': [{'x': 964, 'y': 1426}, {'x': 116...
# 241  {'vertices': [{'x': 964, 'y': 1426}, {'x': 116...
# 242  {'vertices': [{'x': 964, 'y': 1426}, {'x': 116...
# 243  {'vertices': [{'x': 964, 'y': 1426}, {'x': 116...
# 244  {'vertices': [{'x': 708, 'y': 1504}, {'x': 742...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 104, 'y': 281}, {'x': 171,...    方        0.97
# 1    {'vertices': [{'x': 288, 'y': 289}, {'x': 359,...    箋        0.98
# 2    {'vertices': [{'x': 511, 'y': 308}, {'x': 559,...    正        0.98
# 3    {'vertices': [{'x': 1055, 'y': 329}, {'x': 109...    1        0.98
# 4    {'vertices': [{'x': 1055, 'y': 329}, {'x': 109...    1        0.99
# ..                                                 ...  ...         ...
# 240  {'vertices': [{'x': 1008, 'y': 1426}, {'x': 10...    0        0.99
# 241  {'vertices': [{'x': 1074, 'y': 1426}, {'x': 10...    日        0.98
# 242  {'vertices': [{'x': 1116, 'y': 1426}, {'x': 11...    分        0.99
# 243  {'vertices': [{'x': 964, 'y': 1496}, {'x': 101...    錠        0.98
# 244  {'vertices': [{'x': 708, 'y': 1504}, {'x': 742...    1        0.99
#
# [245 rows x 5 columns]
#  47%|████▋     | 14/30 [01:55<01:58,  7.44s/it]
# API終了までにかかった時間:6.474356174468994[sec]
# for文を回し終わるまでにかかった時間:6.483387231826782[sec]
# elapsed_time:6.501199245452881[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 800, 'y': 440}, {'x': 870,...
# 1    {'vertices': [{'x': 800, 'y': 440}, {'x': 870,...
# 2    {'vertices': [{'x': 800, 'y': 440}, {'x': 870,...
# 3    {'vertices': [{'x': -7, 'y': 526}, {'x': 175, ...
# 4    {'vertices': [{'x': -7, 'y': 526}, {'x': 175, ...
# ..                                                 ...
# 243  {'vertices': [{'x': 345, 'y': 1300}, {'x': 382...
# 244  {'vertices': [{'x': 510, 'y': 1421}, {'x': 651...
# 245  {'vertices': [{'x': 510, 'y': 1421}, {'x': 651...
# 246  {'vertices': [{'x': 510, 'y': 1421}, {'x': 651...
# 247  {'vertices': [{'x': 510, 'y': 1421}, {'x': 651...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 800, 'y': 440}, {'x': 870,...
# 1    {'vertices': [{'x': 800, 'y': 440}, {'x': 870,...
# 2    {'vertices': [{'x': 800, 'y': 440}, {'x': 870,...
# 3    {'vertices': [{'x': -7, 'y': 526}, {'x': 175, ...
# 4    {'vertices': [{'x': -7, 'y': 526}, {'x': 175, ...
# ..                                                 ...
# 243  {'vertices': [{'x': 345, 'y': 1300}, {'x': 382...
# 244  {'vertices': [{'x': 510, 'y': 1421}, {'x': 651...
# 245  {'vertices': [{'x': 510, 'y': 1421}, {'x': 651...
# 246  {'vertices': [{'x': 510, 'y': 1421}, {'x': 651...
# 247  {'vertices': [{'x': 510, 'y': 1421}, {'x': 651...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 800, 'y': 440}, {'x': 828,...    P        0.99
# 1    {'vertices': [{'x': 800, 'y': 440}, {'x': 828,...    .        0.99
# 2    {'vertices': [{'x': 859, 'y': 442}, {'x': 870,...    1        0.99
# 3    {'vertices': [{'x': -7, 'y': 527}, {'x': 33, '...    で        0.98
# 4    {'vertices': [{'x': -7, 'y': 527}, {'x': 33, '...    も        0.99
# ..                                                 ...  ...         ...
# 243  {'vertices': [{'x': 345, 'y': 1300}, {'x': 382...    錠        0.95
# 244  {'vertices': [{'x': 510, 'y': 1421}, {'x': 546...    3        0.98
# 245  {'vertices': [{'x': 510, 'y': 1421}, {'x': 546...    0        0.99
# 246  {'vertices': [{'x': 581, 'y': 1421}, {'x': 600...    日        0.98
# 247  {'vertices': [{'x': 614, 'y': 1420}, {'x': 651...    分        0.98
#
# [248 rows x 5 columns]
#  50%|█████     | 15/30 [02:01<01:44,  6.95s/it]
# API終了までにかかった時間:5.7524049282073975[sec]
# for文を回し終わるまでにかかった時間:5.758092164993286[sec]
# elapsed_time:5.769864082336426[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 21, 'y': 439}, {'x': 65, '...
# 1    {'vertices': [{'x': 765, 'y': 501}, {'x': 1066...
# 2    {'vertices': [{'x': 765, 'y': 501}, {'x': 1066...
# 3    {'vertices': [{'x': 765, 'y': 501}, {'x': 1066...
# 4    {'vertices': [{'x': 765, 'y': 501}, {'x': 1066...
# ..                                                 ...
# 193  {'vertices': [{'x': -10, 'y': 1187}, {'x': 120...
# 194  {'vertices': [{'x': -10, 'y': 1187}, {'x': 120...
# 195  {'vertices': [{'x': -10, 'y': 1187}, {'x': 120...
# 196  {'vertices': [{'x': -10, 'y': 1187}, {'x': 120...
# 197  {'vertices': [{'x': -10, 'y': 1187}, {'x': 120...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 21, 'y': 439}, {'x': 65, '...
# 1    {'vertices': [{'x': 765, 'y': 501}, {'x': 1066...
# 2    {'vertices': [{'x': 765, 'y': 501}, {'x': 1066...
# 3    {'vertices': [{'x': 765, 'y': 501}, {'x': 1066...
# 4    {'vertices': [{'x': 765, 'y': 501}, {'x': 1066...
# ..                                                 ...
# 193  {'vertices': [{'x': 6, 'y': 1517}, {'x': 1188,...
# 194  {'vertices': [{'x': 6, 'y': 1517}, {'x': 1188,...
# 195  {'vertices': [{'x': 6, 'y': 1517}, {'x': 1188,...
# 196  {'vertices': [{'x': 6, 'y': 1517}, {'x': 1188,...
# 197  {'vertices': [{'x': 6, 'y': 1517}, {'x': 1188,...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 21, 'y': 439}, {'x': 65, '...    方        0.98
# 1    {'vertices': [{'x': 765, 'y': 501}, {'x': 894,...    負        0.97
# 2    {'vertices': [{'x': 765, 'y': 501}, {'x': 894,...    担        0.99
# 3    {'vertices': [{'x': 913, 'y': 501}, {'x': 920,...    :        0.98
# 4    {'vertices': [{'x': 949, 'y': 500}, {'x': 1020...    3        0.98
# ..                                                 ...  ...         ...
# 193  {'vertices': [{'x': 833, 'y': 1551}, {'x': 905...    す        0.99
# 194  {'vertices': [{'x': 833, 'y': 1551}, {'x': 905...    る        0.99
# 195  {'vertices': [{'x': 921, 'y': 1551}, {'x': 993...    こ        0.99
# 196  {'vertices': [{'x': 921, 'y': 1551}, {'x': 993...    と        0.99
# 197  {'vertices': [{'x': 1009, 'y': 1550}, {'x': 10...    。        0.66
#
# [198 rows x 5 columns]
#  53%|█████▎    | 16/30 [02:08<01:37,  6.98s/it]
# API終了までにかかった時間:7.012975215911865[sec]
# for文を回し終わるまでにかかった時間:7.0208611488342285[sec]
# elapsed_time:7.032487869262695[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 20, 'y': 840}, {'x': 79, '...
# 1    {'vertices': [{'x': 20, 'y': 840}, {'x': 79, '...
# 2    {'vertices': [{'x': 184, 'y': 906}, {'x': 248,...
# 3    {'vertices': [{'x': 4, 'y': 996}, {'x': 444, '...
# 4    {'vertices': [{'x': 4, 'y': 996}, {'x': 444, '...
# ..                                                 ...
# 274  {'vertices': [{'x': 1098, 'y': 1563}, {'x': 13...
# 275  {'vertices': [{'x': 1098, 'y': 1563}, {'x': 13...
# 276  {'vertices': [{'x': 1098, 'y': 1563}, {'x': 13...
# 277  {'vertices': [{'x': 1098, 'y': 1563}, {'x': 13...
# 278  {'vertices': [{'x': 246, 'y': 1595}, {'x': 265...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 20, 'y': 840}, {'x': 79, '...
# 1    {'vertices': [{'x': 20, 'y': 840}, {'x': 79, '...
# 2    {'vertices': [{'x': 184, 'y': 906}, {'x': 248,...
# 3    {'vertices': [{'x': 4, 'y': 996}, {'x': 444, '...
# 4    {'vertices': [{'x': 4, 'y': 996}, {'x': 444, '...
# ..                                                 ...
# 274  {'vertices': [{'x': 1098, 'y': 1563}, {'x': 13...
# 275  {'vertices': [{'x': 1098, 'y': 1563}, {'x': 13...
# 276  {'vertices': [{'x': 1098, 'y': 1563}, {'x': 13...
# 277  {'vertices': [{'x': 1098, 'y': 1563}, {'x': 13...
# 278  {'vertices': [{'x': 246, 'y': 1595}, {'x': 265...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 20, 'y': 840}, {'x': 79, '...    b        0.93
# 1    {'vertices': [{'x': 20, 'y': 840}, {'x': 79, '...    i        0.16
# 2    {'vertices': [{'x': 184, 'y': 906}, {'x': 248,...    箋        0.28
# 3    {'vertices': [{'x': 4, 'y': 996}, {'x': 79, 'y...    保        0.98
# 4    {'vertices': [{'x': 4, 'y': 996}, {'x': 79, 'y...    険        1.00
# ..                                                 ...  ...         ...
# 274  {'vertices': [{'x': 1160, 'y': 1565}, {'x': 13...    2        0.90
# 275  {'vertices': [{'x': 1160, 'y': 1565}, {'x': 13...    0        0.99
# 276  {'vertices': [{'x': 1160, 'y': 1565}, {'x': 13...    6        0.87
# 277  {'vertices': [{'x': 1160, 'y': 1565}, {'x': 13...    8        0.97
# 278  {'vertices': [{'x': 246, 'y': 1595}, {'x': 265...    品        0.06
#
# [279 rows x 5 columns]
#  57%|█████▋    | 17/30 [02:16<01:32,  7.10s/it]
# API終了までにかかった時間:7.295109748840332[sec]
# for文を回し終わるまでにかかった時間:7.305266857147217[sec]
# elapsed_time:7.318065881729126[sec]
#                                                  block  \
# 0    {'vertices': [{'x': -11, 'y': 345}, {'x': 1039...
# 1    {'vertices': [{'x': -11, 'y': 345}, {'x': 1039...
# 2    {'vertices': [{'x': -11, 'y': 345}, {'x': 1039...
# 3    {'vertices': [{'x': -11, 'y': 345}, {'x': 1039...
# 4    {'vertices': [{'x': -11, 'y': 345}, {'x': 1039...
# ..                                                 ...
# 376  {'vertices': [{'x': -8, 'y': 1430}, {'x': 502,...
# 377  {'vertices': [{'x': -8, 'y': 1430}, {'x': 502,...
# 378  {'vertices': [{'x': -8, 'y': 1430}, {'x': 502,...
# 379  {'vertices': [{'x': -8, 'y': 1430}, {'x': 502,...
# 380  {'vertices': [{'x': -8, 'y': 1430}, {'x': 502,...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': -11, 'y': 345}, {'x': 443,...
# 1    {'vertices': [{'x': -11, 'y': 345}, {'x': 443,...
# 2    {'vertices': [{'x': -11, 'y': 345}, {'x': 443,...
# 3    {'vertices': [{'x': -11, 'y': 345}, {'x': 443,...
# 4    {'vertices': [{'x': -11, 'y': 345}, {'x': 443,...
# ..                                                 ...
# 376  {'vertices': [{'x': 233, 'y': 1495}, {'x': 388...
# 377  {'vertices': [{'x': 233, 'y': 1495}, {'x': 388...
# 378  {'vertices': [{'x': 233, 'y': 1495}, {'x': 388...
# 379  {'vertices': [{'x': 233, 'y': 1495}, {'x': 388...
# 380  {'vertices': [{'x': 233, 'y': 1495}, {'x': 388...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 26, 'y': 344}, {'x': 45, '...    方        0.99
# 1    {'vertices': [{'x': 217, 'y': 335}, {'x': 236,...    せ        0.99
# 2    {'vertices': [{'x': 399, 'y': 326}, {'x': 418,...    ん        0.99
# 3    {'vertices': [{'x': -8, 'y': 416}, {'x': 15, '...    は        0.98
# 4    {'vertices': [{'x': 33, 'y': 414}, {'x': 42, '...    、        0.94
# ..                                                 ...  ...         ...
# 376  {'vertices': [{'x': 233, 'y': 1495}, {'x': 319...    /        0.99
# 377  {'vertices': [{'x': 233, 'y': 1495}, {'x': 319...    2        0.99
# 378  {'vertices': [{'x': 233, 'y': 1495}, {'x': 319...    8        0.99
# 379  {'vertices': [{'x': 329, 'y': 1494}, {'x': 388...    か        0.97
# 380  {'vertices': [{'x': 329, 'y': 1494}, {'x': 388...    ら        0.99
#
# [381 rows x 5 columns]
#  60%|██████    | 18/30 [02:25<01:32,  7.71s/it]
# API終了までにかかった時間:9.082068920135498[sec]
# for文を回し終わるまでにかかった時間:9.092848062515259[sec]
# elapsed_time:9.106592893600464[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 570, 'y': 384}, {'x': 1250...
# 1    {'vertices': [{'x': 570, 'y': 384}, {'x': 1250...
# 2    {'vertices': [{'x': 570, 'y': 384}, {'x': 1250...
# 3    {'vertices': [{'x': 570, 'y': 384}, {'x': 1250...
# 4    {'vertices': [{'x': 570, 'y': 384}, {'x': 1250...
# ..                                                 ...
# 370  {'vertices': [{'y': 1558}, {'x': 565, 'y': 155...
# 371  {'vertices': [{'y': 1558}, {'x': 565, 'y': 155...
# 372  {'vertices': [{'y': 1558}, {'x': 565, 'y': 155...
# 373  {'vertices': [{'x': 900, 'y': 1549}, {'x': 960...
# 374  {'vertices': [{'x': 900, 'y': 1549}, {'x': 960...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 570, 'y': 386}, {'x': 1080...
# 1    {'vertices': [{'x': 570, 'y': 386}, {'x': 1080...
# 2    {'vertices': [{'x': 570, 'y': 386}, {'x': 1080...
# 3    {'vertices': [{'x': 570, 'y': 386}, {'x': 1080...
# 4    {'vertices': [{'x': 570, 'y': 386}, {'x': 1080...
# ..                                                 ...
# 370  {'vertices': [{'y': 1558}, {'x': 565, 'y': 155...
# 371  {'vertices': [{'y': 1558}, {'x': 565, 'y': 155...
# 372  {'vertices': [{'y': 1558}, {'x': 565, 'y': 155...
# 373  {'vertices': [{'x': 900, 'y': 1549}, {'x': 960...
# 374  {'vertices': [{'x': 900, 'y': 1549}, {'x': 960...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 570, 'y': 386}, {'x': 608,...    (        0.57
# 1    {'vertices': [{'x': 604, 'y': 383}, {'x': 862,...    8        0.97
# 2    {'vertices': [{'x': 604, 'y': 383}, {'x': 862,...    1        0.27
# 3    {'vertices': [{'x': 604, 'y': 383}, {'x': 862,...    1        0.93
# 4    {'vertices': [{'x': 604, 'y': 383}, {'x': 862,...    5        0.91
# ..                                                 ...  ...         ...
# 370  {'vertices': [{'x': 414, 'y': 1558}, {'x': 565...    0        0.99
# 371  {'vertices': [{'x': 414, 'y': 1558}, {'x': 565...    m        0.97
# 372  {'vertices': [{'x': 414, 'y': 1558}, {'x': 565...    g        0.98
# 373  {'vertices': [{'x': 900, 'y': 1549}, {'x': 916...    3        0.98
# 374  {'vertices': [{'x': 922, 'y': 1549}, {'x': 960...    錠        0.98
#
# [375 rows x 5 columns]
#  63%|██████▎   | 19/30 [02:31<01:20,  7.31s/it]
# API終了までにかかった時間:6.300685167312622[sec]
# for文を回し終わるまでにかかった時間:6.3070878982543945[sec]
# elapsed_time:6.319366931915283[sec]
#                                                  block  \
# 0    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...
# 1    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...
# 2    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...
# 3    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...
# 4    {'vertices': [{'x': 538, 'y': 536}, {'x': 1045...
# ..                                                 ...
# 238  {'vertices': [{'x': -15, 'y': 952}, {'x': 1226...
# 239  {'vertices': [{'x': -15, 'y': 952}, {'x': 1226...
# 240  {'vertices': [{'x': -15, 'y': 952}, {'x': 1226...
# 241  {'vertices': [{'x': -15, 'y': 952}, {'x': 1226...
# 242  {'vertices': [{'x': -15, 'y': 952}, {'x': 1226...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...
# 1    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...
# 2    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...
# 3    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...
# 4    {'vertices': [{'x': 538, 'y': 536}, {'x': 1045...
# ..                                                 ...
# 238  {'vertices': [{'x': 2, 'y': 1518}, {'x': 1199,...
# 239  {'vertices': [{'x': 2, 'y': 1518}, {'x': 1199,...
# 240  {'vertices': [{'x': 2, 'y': 1518}, {'x': 1199,...
# 241  {'vertices': [{'x': 2, 'y': 1518}, {'x': 1199,...
# 242  {'vertices': [{'x': 2, 'y': 1518}, {'x': 1199,...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...    処        0.97
# 1    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...    方        0.99
# 2    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...    せ        0.99
# 3    {'vertices': [{'x': -8, 'y': 503}, {'x': 366, ...    ん        1.00
# 4    {'vertices': [{'x': 538, 'y': 536}, {'x': 564,...    ~        0.59
# ..                                                 ...  ...         ...
# 238  {'vertices': [{'x': 1040, 'y': 1567}, {'x': 10...    「        0.98
# 239  {'vertices': [{'x': 1072, 'y': 1567}, {'x': 10...    レ        0.98
# 240  {'vertices': [{'x': 1096, 'y': 1567}, {'x': 11...    」        0.99
# 241  {'vertices': [{'x': 1128, 'y': 1566}, {'x': 11...    又        0.96
# 242  {'vertices': [{'x': 1128, 'y': 1566}, {'x': 11...    は        0.99
#
# [243 rows x 5 columns]
#  67%|██████▋   | 20/30 [02:37<01:08,  6.85s/it]
# API終了までにかかった時間:5.713263034820557[sec]
# for文を回し終わるまでにかかった時間:5.717160224914551[sec]
# elapsed_time:5.7296061515808105[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 1198, 'y': 657}, {'x': 119...
# 1    {'vertices': [{'x': 1198, 'y': 657}, {'x': 119...
# 2    {'vertices': [{'x': -6, 'y': 676}, {'x': 45, '...
# 3    {'vertices': [{'x': 305, 'y': 676}, {'x': 323,...
# 4    {'vertices': [{'x': 596, 'y': 675}, {'x': 613,...
# ..                                                 ...
# 134  {'vertices': [{'x': 81, 'y': 1529}, {'x': 536,...
# 135  {'vertices': [{'x': 81, 'y': 1529}, {'x': 536,...
# 136  {'vertices': [{'x': 81, 'y': 1529}, {'x': 536,...
# 137  {'vertices': [{'x': 81, 'y': 1529}, {'x': 536,...
# 138  {'vertices': [{'x': 81, 'y': 1529}, {'x': 536,...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 1198, 'y': 657}, {'x': 119...
# 1    {'vertices': [{'x': 1198, 'y': 657}, {'x': 119...
# 2    {'vertices': [{'x': -6, 'y': 676}, {'x': 45, '...
# 3    {'vertices': [{'x': 305, 'y': 676}, {'x': 323,...
# 4    {'vertices': [{'x': 596, 'y': 675}, {'x': 613,...
# ..                                                 ...
# ...
# 300  {'vertices': [{'x': 3, 'y': 1515}, {'x': 1265,...
# 301  {'vertices': [{'x': 3, 'y': 1515}, {'x': 1265,...
# 302  {'vertices': [{'x': 3, 'y': 1515}, {'x': 1265,...
# 303  {'vertices': [{'x': 609, 'y': 1259}, {'x': 646...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 37, 'y': 270}, {'x': 63, '...    方        0.91
# 1    {'vertices': [{'x': 281, 'y': 269}, {'x': 307,...    箋        0.99
# 2    {'vertices': [{'x': 1093, 'y': 369}, {'x': 116...    P        0.99
# 3    {'vertices': [{'x': 1093, 'y': 369}, {'x': 116...    a        0.99
# 4    {'vertices': [{'x': 1093, 'y': 369}, {'x': 116...    g        0.99
# ..                                                 ...  ...         ...
# 299  {'vertices': [{'x': 1057, 'y': 1521}, {'x': 11...    る        0.99
# 300  {'vertices': [{'x': 1131, 'y': 1519}, {'x': 11...    こ        0.99
# 301  {'vertices': [{'x': 1131, 'y': 1519}, {'x': 11...    と        0.99
# 302  {'vertices': [{'x': 1199, 'y': 1517}, {'x': 12...    。        0.82
# 303  {'vertices': [{'x': 609, 'y': 1259}, {'x': 646...    1        0.99
#
# [304 rows x 5 columns]
#  83%|████████▎ | 25/30 [03:12<00:35,  7.15s/it]
# API終了までにかかった時間:7.770014047622681[sec]
# for文を回し終わるまでにかかった時間:7.7782721519470215[sec]
# elapsed_time:7.789775133132935[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 6, 'y': 417}, {'x': 92, 'y...
# 1    {'vertices': [{'x': -7, 'y': 386}, {'x': 1030,...
# 2    {'vertices': [{'x': -7, 'y': 386}, {'x': 1030,...
# 3    {'vertices': [{'x': -7, 'y': 386}, {'x': 1030,...
# 4    {'vertices': [{'x': -7, 'y': 386}, {'x': 1030,...
# ..                                                 ...
# 308  {'vertices': [{'x': -7, 'y': 1432}, {'x': 316,...
# 309  {'vertices': [{'x': 1076, 'y': 1554}, {'x': 12...
# 310  {'vertices': [{'x': 1076, 'y': 1554}, {'x': 12...
# 311  {'vertices': [{'x': 1076, 'y': 1554}, {'x': 12...
# 312  {'vertices': [{'x': 1076, 'y': 1554}, {'x': 12...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 6, 'y': 417}, {'x': 92, 'y...
# 1    {'vertices': [{'x': -7, 'y': 386}, {'x': 1030,...
# 2    {'vertices': [{'x': -7, 'y': 386}, {'x': 1030,...
# 3    {'vertices': [{'x': -7, 'y': 386}, {'x': 1030,...
# 4    {'vertices': [{'x': -7, 'y': 386}, {'x': 1030,...
# ..                                                 ...
# 308  {'vertices': [{'x': -7, 'y': 1432}, {'x': 316,...
# 309  {'vertices': [{'x': 1076, 'y': 1554}, {'x': 12...
# 310  {'vertices': [{'x': 1076, 'y': 1554}, {'x': 12...
# 311  {'vertices': [{'x': 1076, 'y': 1554}, {'x': 12...
# 312  {'vertices': [{'x': 1076, 'y': 1554}, {'x': 12...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 6, 'y': 417}, {'x': 92, 'y...    処        0.98
# 1    {'vertices': [{'x': 283, 'y': 391}, {'x': 358,...    方        0.66
# 2    {'vertices': [{'x': 551, 'y': 389}, {'x': 622,...    等        0.64
# 3    {'vertices': [{'x': -7, 'y': 473}, {'x': 5, 'y...    に        0.05
# 4    {'vertices': [{'x': 13, 'y': 473}, {'x': 24, '...    、        0.33
# ..                                                 ...  ...         ...
# 308  {'vertices': [{'x': 228, 'y': 1541}, {'x': 272...    後        0.87
# 309  {'vertices': [{'x': 1076, 'y': 1554}, {'x': 11...    2        0.99
# 310  {'vertices': [{'x': 1076, 'y': 1554}, {'x': 11...    1        0.98
# 311  {'vertices': [{'x': 1138, 'y': 1554}, {'x': 11...    日        0.98
# 312  {'vertices': [{'x': 1179, 'y': 1554}, {'x': 12...    分        0.98
#
# [313 rows x 5 columns]
#  87%|████████▋ | 26/30 [03:19<00:28,  7.19s/it]
# API終了までにかかった時間:7.226012229919434[sec]
# for文を回し終わるまでにかかった時間:7.2356390953063965[sec]
# elapsed_time:7.248079061508179[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 1133, 'y': 629}, {'x': 121...
# 1    {'vertices': [{'x': 1133, 'y': 629}, {'x': 121...
# 2    {'vertices': [{'x': 1133, 'y': 629}, {'x': 121...
# 3    {'vertices': [{'x': 110, 'y': 656}, {'x': 163,...
# 4    {'vertices': [{'x': 406, 'y': 692}, {'x': 464,...
# ..                                                 ...
# 290  {'vertices': [{'x': 556, 'y': 1378}, {'x': 589...
# 291  {'vertices': [{'x': 831, 'y': 1371}, {'x': 863...
# 292  {'vertices': [{'x': 646, 'y': 1395}, {'x': 717...
# 293  {'vertices': [{'x': 646, 'y': 1395}, {'x': 717...
# 294  {'vertices': [{'x': 646, 'y': 1395}, {'x': 717...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 1133, 'y': 629}, {'x': 121...
# 1    {'vertices': [{'x': 1133, 'y': 629}, {'x': 121...
# 2    {'vertices': [{'x': 1133, 'y': 629}, {'x': 121...
# 3    {'vertices': [{'x': 110, 'y': 656}, {'x': 163,...
# 4    {'vertices': [{'x': 406, 'y': 692}, {'x': 464,...
# ..                                                 ...
# 290  {'vertices': [{'x': 556, 'y': 1378}, {'x': 589...
# 291  {'vertices': [{'x': 831, 'y': 1371}, {'x': 863...
# 292  {'vertices': [{'x': 646, 'y': 1395}, {'x': 717...
# 293  {'vertices': [{'x': 646, 'y': 1395}, {'x': 717...
# 294  {'vertices': [{'x': 646, 'y': 1395}, {'x': 717...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 1133, 'y': 629}, {'x': 116...    P        0.99
# 1    {'vertices': [{'x': 1133, 'y': 629}, {'x': 116...    .        0.97
# 2    {'vertices': [{'x': 1200, 'y': 629}, {'x': 121...    1        0.98
# 3    {'vertices': [{'x': 110, 'y': 656}, {'x': 163,...    方        0.96
# 4    {'vertices': [{'x': 406, 'y': 692}, {'x': 464,...    箋        0.85
# ..                                                 ...  ...         ...
# 290  {'vertices': [{'x': 556, 'y': 1378}, {'x': 589...    1        0.99
# 291  {'vertices': [{'x': 831, 'y': 1371}, {'x': 863...    1        0.99
# 292  {'vertices': [{'x': 646, 'y': 1395}, {'x': 717...    コ        0.98
# 293  {'vertices': [{'x': 646, 'y': 1395}, {'x': 717...    ー        0.99
# 294  {'vertices': [{'x': 646, 'y': 1395}, {'x': 717...    ド        0.99
#
# [295 rows x 5 columns]
#  90%|█████████ | 27/30 [03:27<00:22,  7.47s/it]
# API終了までにかかった時間:8.034673929214478[sec]
# for文を回し終わるまでにかかった時間:8.064390897750854[sec]
# elapsed_time:8.08314299583435[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 1082, 'y': 984}, {'x': 132...
# 1    {'vertices': [{'x': 1082, 'y': 984}, {'x': 132...
# 2    {'vertices': [{'x': 1082, 'y': 984}, {'x': 132...
# 3    {'vertices': [{'x': 1082, 'y': 984}, {'x': 132...
# 4    {'vertices': [{'x': 1082, 'y': 984}, {'x': 132...
# ..                                                 ...
# 963  {'vertices': [{'x': 25, 'y': 1586}, {'x': 194,...
# 964  {'vertices': [{'x': 25, 'y': 1586}, {'x': 194,...
# 965  {'vertices': [{'x': 25, 'y': 1586}, {'x': 194,...
# 966  {'vertices': [{'x': 25, 'y': 1586}, {'x': 194,...
# 967  {'vertices': [{'x': 25, 'y': 1586}, {'x': 194,...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 1083, 'y': 985}, {'x': 126...
# 1    {'vertices': [{'x': 1083, 'y': 985}, {'x': 126...
# 2    {'vertices': [{'x': 1083, 'y': 985}, {'x': 126...
# 3    {'vertices': [{'x': 1083, 'y': 985}, {'x': 126...
# 4    {'vertices': [{'x': 1083, 'y': 985}, {'x': 126...
# ..                                                 ...
# 963  {'vertices': [{'x': 114, 'y': 1579}, {'x': 233...
# 964  {'vertices': [{'x': 114, 'y': 1579}, {'x': 233...
# 965  {'vertices': [{'x': 114, 'y': 1579}, {'x': 233...
# 966  {'vertices': [{'x': 114, 'y': 1579}, {'x': 233...
# 967  {'vertices': [{'x': 114, 'y': 1579}, {'x': 233...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 1087, 'y': 989}, {'x': 110...    p        0.40
# 1    {'vertices': [{'x': 1087, 'y': 989}, {'x': 110...    y        0.30
# 2    {'vertices': [{'x': 1115, 'y': 954}, {'x': 118...    G        0.83
# 3    {'vertices': [{'x': 1115, 'y': 954}, {'x': 118...    u        0.86
# 4    {'vertices': [{'x': 1115, 'y': 954}, {'x': 118...    a        0.91
# ..                                                 ...  ...         ...
# 963  {'vertices': [{'x': 155, 'y': 1540}, {'x': 232...    P        0.99
# 964  {'vertices': [{'x': 155, 'y': 1540}, {'x': 232...    a        1.00
# 965  {'vertices': [{'x': 155, 'y': 1540}, {'x': 232...    p        0.99
# 966  {'vertices': [{'x': 155, 'y': 1540}, {'x': 232...    e        1.00
# 967  {'vertices': [{'x': 155, 'y': 1540}, {'x': 232...    r        0.99
#
# [968 rows x 5 columns]
#  93%|█████████▎| 28/30 [03:34<00:14,  7.27s/it]
# API終了までにかかった時間:6.717824220657349[sec]
# for文を回し終わるまでにかかった時間:6.725963115692139[sec]
# elapsed_time:6.738859176635742[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 976, 'y': 429}, {'x': 1061...
# 1    {'vertices': [{'x': 976, 'y': 429}, {'x': 1061...
# 2    {'vertices': [{'x': 976, 'y': 429}, {'x': 1061...
# 3    {'vertices': [{'x': 203, 'y': 479}, {'x': 263,...
# 4    {'vertices': [{'x': -7, 'y': 530}, {'x': 224, ...
# ..                                                 ...
# 260  {'vertices': [{'x': -8, 'y': 1055}, {'x': 1081...
# 261  {'vertices': [{'x': -8, 'y': 1055}, {'x': 1081...
# 262  {'vertices': [{'x': -8, 'y': 1055}, {'x': 1081...
# 263  {'vertices': [{'x': -8, 'y': 1055}, {'x': 1081...
# 264  {'vertices': [{'x': -8, 'y': 1055}, {'x': 1081...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 976, 'y': 429}, {'x': 1061...
# 1    {'vertices': [{'x': 976, 'y': 429}, {'x': 1061...
# 2    {'vertices': [{'x': 976, 'y': 429}, {'x': 1061...
# 3    {'vertices': [{'x': 203, 'y': 479}, {'x': 263,...
# 4    {'vertices': [{'x': -7, 'y': 530}, {'x': 224, ...
# ..                                                 ...
# 260  {'vertices': [{'x': -8, 'y': 1299}, {'x': 1029...
# 261  {'vertices': [{'x': -8, 'y': 1299}, {'x': 1029...
# 262  {'vertices': [{'x': 668, 'y': 1513}, {'x': 810...
# 263  {'vertices': [{'x': 668, 'y': 1513}, {'x': 810...
# 264  {'vertices': [{'x': 668, 'y': 1513}, {'x': 810...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 976, 'y': 430}, {'x': 1010...    P        0.99
# 1    {'vertices': [{'x': 976, 'y': 430}, {'x': 1010...    .        0.99
# 2    {'vertices': [{'x': 1047, 'y': 430}, {'x': 106...    1        0.99
# 3    {'vertices': [{'x': 203, 'y': 479}, {'x': 263,...    箋        0.88
# 4    {'vertices': [{'x': -7, 'y': 530}, {'x': 62, '...    で        0.83
# ..                                                 ...  ...         ...
# 260  {'vertices': [{'x': 297, 'y': 1453}, {'x': 315...    2        0.99
# 261  {'vertices': [{'x': 445, 'y': 1448}, {'x': 489...    錠        0.98
# 262  {'vertices': [{'x': 668, 'y': 1514}, {'x': 687...    5        0.98
# 263  {'vertices': [{'x': 728, 'y': 1515}, {'x': 751...    日        0.92
# 264  {'vertices': [{'x': 768, 'y': 1515}, {'x': 810...    分        0.91
#
# [265 rows x 5 columns]
#  97%|█████████▋| 29/30 [03:41<00:07,  7.02s/it]
# API終了までにかかった時間:6.308439016342163[sec]
# for文を回し終わるまでにかかった時間:6.342806100845337[sec]
# elapsed_time:6.367141962051392[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 48, 'y': 211}, {'x': 1142,...
# 1    {'vertices': [{'x': 48, 'y': 211}, {'x': 1142,...
# 2    {'vertices': [{'x': 48, 'y': 211}, {'x': 1142,...
# 3    {'vertices': [{'x': 48, 'y': 211}, {'x': 1142,...
# 4    {'vertices': [{'x': 48, 'y': 211}, {'x': 1142,...
# ..                                                 ...
# 293  {'vertices': [{'x': 202, 'y': 1553}, {'x': 549...
# 294  {'vertices': [{'x': 202, 'y': 1553}, {'x': 549...
# 295  {'vertices': [{'x': 202, 'y': 1553}, {'x': 549...
# 296  {'vertices': [{'x': 202, 'y': 1553}, {'x': 549...
# 297  {'vertices': [{'x': 202, 'y': 1553}, {'x': 549...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 48, 'y': 211}, {'x': 623, ...
# 1    {'vertices': [{'x': 48, 'y': 211}, {'x': 623, ...
# 2    {'vertices': [{'x': 48, 'y': 211}, {'x': 623, ...
# 3    {'vertices': [{'x': 48, 'y': 211}, {'x': 623, ...
# 4    {'vertices': [{'x': 48, 'y': 211}, {'x': 623, ...
# ..                                                 ...
# 293  {'vertices': [{'x': 202, 'y': 1553}, {'x': 549...
# 294  {'vertices': [{'x': 202, 'y': 1553}, {'x': 549...
# 295  {'vertices': [{'x': 202, 'y': 1553}, {'x': 549...
# 296  {'vertices': [{'x': 202, 'y': 1553}, {'x': 549...
# 297  {'vertices': [{'x': 202, 'y': 1553}, {'x': 549...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 137, 'y': 211}, {'x': 207,...    方        0.97
# 1    {'vertices': [{'x': 369, 'y': 208}, {'x': 438,...    箋        0.11
# 2    {'vertices': [{'x': 49, 'y': 299}, {'x': 121, ...    ど        0.98
# 3    {'vertices': [{'x': 49, 'y': 299}, {'x': 121, ...    の        0.99
# 4    {'vertices': [{'x': 128, 'y': 298}, {'x': 208,...    保        0.98
# ..                                                 ...  ...         ...
# 293  {'vertices': [{'x': 320, 'y': 1551}, {'x': 334...    回        0.99
# 294  {'vertices': [{'x': 404, 'y': 1549}, {'x': 442...    1        0.63
# 295  {'vertices': [{'x': 404, 'y': 1549}, {'x': 442...    4        0.76
# 296  {'vertices': [{'x': 460, 'y': 1549}, {'x': 474...    日        0.77
# 297  {'vertices': [{'x': 519, 'y': 1547}, {'x': 549...    分        0.98
#
# [298 rows x 5 columns]
# 100%|██████████| 30/30 [03:47<00:00,  7.59s/it]
# API終了までにかかった時間:6.551307916641235[sec]
# for文を回し終わるまでにかかった時間:6.568734884262085[sec]
# elapsed_time:6.5911688804626465[sec]
#                                                  block  \
# 0    {'vertices': [{'x': 1217, 'y': 454}, {'x': 131...
# 1    {'vertices': [{'x': 1217, 'y': 454}, {'x': 131...
# 2    {'vertices': [{'x': 1217, 'y': 454}, {'x': 131...
# 3    {'vertices': [{'x': 38, 'y': 486}, {'x': 96, '...
# 4    {'vertices': [{'x': 1015, 'y': 432}, {'x': 115...
# ..                                                 ...
# 275  {'vertices': [{'x': 2, 'y': 1150}, {'x': 1327,...
# 276  {'vertices': [{'x': 92, 'y': 1573}, {'x': 225,...
# 277  {'vertices': [{'x': 92, 'y': 1573}, {'x': 225,...
# 278  {'vertices': [{'x': 92, 'y': 1573}, {'x': 225,...
# 279  {'vertices': [{'x': 472, 'y': 1581}, {'x': 494...
#
#                                              paragraph  \
# 0    {'vertices': [{'x': 1217, 'y': 454}, {'x': 131...
# 1    {'vertices': [{'x': 1217, 'y': 454}, {'x': 131...
# 2    {'vertices': [{'x': 1217, 'y': 454}, {'x': 131...
# 3    {'vertices': [{'x': 38, 'y': 486}, {'x': 96, '...
# 4    {'vertices': [{'x': 1015, 'y': 432}, {'x': 115...
# ..                                                 ...
# 275  {'vertices': [{'y': 1416}, {'x': 1272, 'y': 14...
# 276  {'vertices': [{'x': 92, 'y': 1573}, {'x': 225,...
# 277  {'vertices': [{'x': 92, 'y': 1573}, {'x': 225,...
# 278  {'vertices': [{'x': 92, 'y': 1573}, {'x': 225,...
# 279  {'vertices': [{'x': 472, 'y': 1581}, {'x': 494...
#
#                                                   word text  confidence
# 0    {'vertices': [{'x': 1217, 'y': 454}, {'x': 125...    P        0.99
# 1    {'vertices': [{'x': 1217, 'y': 454}, {'x': 125...    .        0.99
# 2    {'vertices': [{'x': 1296, 'y': 454}, {'x': 131...    1        0.97
# 3    {'vertices': [{'x': 38, 'y': 486}, {'x': 96, '...    方        0.97
# 4    {'vertices': [{'x': 1015, 'y': 432}, {'x': 115...    O        0.49
# ..                                                 ...  ...         ...
# 275  {'vertices': [{'x': 992, 'y': 1498}, {'x': 100...    。        0.98
# 276  {'vertices': [{'x': 92, 'y': 1573}, {'x': 103,...    5        0.99
# 277  {'vertices': [{'x': 119, 'y': 1574}, {'x': 225...    m        0.99
# 278  {'vertices': [{'x': 119, 'y': 1574}, {'x': 225...    g        1.00
# 279  {'vertices': [{'x': 472, 'y': 1581}, {'x': 494...    4        0.99
#
# [280 rows x 5 columns]

# %%
'''
ソレっぽい部分が前から何番目？を検出してから、
dfの対応する部分をgetする。
'''

# %% [markdown]
# # 関数

# %%
#一部のみしか選択しないタイプ 
#画像を表示しない場合
#単純なOCR
#urlが入力
#出力はOCR結果とガチの出力

def recognize5(url,n_part,start,goal):
    start_time = time.time()
    #pathからbase64にする場合
    def pil_image_to_base64(img_path):###ここは最後に消す
        pil_image = Image.open(img_path)
        buffered = BytesIO()
        pil_image.save(buffered, format="PNG")
        str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
        return str_encode_file

    #arrayからbase64にする場合
    def array_to_base64(img_array):
        pil_image = Image.fromarray(np.uint8(img_array))
        buffered = BytesIO()
        pil_image.save(buffered, format="PNG")
        str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
        return str_encode_file 

    def get_fullTextAnnotation(json_data):
        text_dict = json.loads(json_data)
        try:
            text = text_dict["responses"][0]["fullTextAnnotation"]["text"]
            blocks=text_dict["responses"][0]["fullTextAnnotation"]
            return text,blocks
        except:
            print(None)
            return None

    #str_encode_file = pil_image_to_base64(url)  
    
    img = cv2.imread(url)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,0::]
#     plt.figure(figsize=[50,50])
#     plt.imshow(input_image)
    
    str_encode_file = array_to_base64(input_image)# input_imageがarrayの時
    str_url = "https://vision.googleapis.com/v1/images:annotate?key="
    str_api_key = "AIzaSyDlRRYrHEdjParsfRmh96_3xfafOo1crWY"
    str_headers = {'Content-Type': 'application/json'}
    str_json_data = {
        'requests': [
            {
                'image': {
                    'content': str_encode_file
                },
                'features': [
                    {
                        'type': "DOCUMENT_TEXT_DETECTION",
                        'maxResults': 1
                    }
                ],"imageContext": {
        "languageHints": ["ja"]
      },
            }
        ]
    }

    obj_session = Session()
    obj_request = Request("POST",
                            str_url + str_api_key,
                            data=json.dumps(str_json_data),
                            headers=str_headers
                            )
    obj_prepped = obj_session.prepare_request(obj_request)
    obj_response = obj_session.send(obj_prepped,
                                    verify=True,
                                    timeout=60
                                    )
    #もとの出力
    if obj_response.status_code == 200:
        text = get_fullTextAnnotation(obj_response.text)[0]
        blocks=get_fullTextAnnotation(obj_response.text)[1]
        
    elapsed_time = time.time() - start_time
    print ("API終了までにかかった時間:{0}".format(elapsed_time) + "[sec]")
    #行ごとの出力    
    text_dict = json.loads(obj_response.text)
    word_list=text_dict["responses"][0]["textAnnotations"][0]["description"].split("\n")

    len_sum=0
    now_num=0
    left=[]
    right=[]
    top=[]
    bottom=[]
    dic_list=[]

    for i in range(1,len(text_dict["responses"][0]["textAnnotations"])):
        len_sum+=len(text_dict["responses"][0]["textAnnotations"][i]["description"].replace(" ",""))
        try:
            left.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["x"])
        except:
            pass
        try:
            right.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][1]["x"])
        except:
            pass
        try:
            right.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][2]["x"])
        except:
            pass
        try:
            left.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][3]["x"])
        except:
            pass

        try:
            bottom.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["y"])
        except:
            pass
        try:
            bottom.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][1]["y"])
        except:
            pass
        try:
            top.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][2]["y"])
        except:
            pass
        try:
            top.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][3]["y"])
        except:
            pass

        if len_sum==len(word_list[now_num].replace(" ","")):
            len_sum=0
            #print("word:   "+word_list[now_num])
            dic={"word":word_list[now_num],"文字の縦幅":mode_average(top)-mode_average(bottom),"x":round(mode_average(left)+mode_average(right)),"y":round(mode_average(top)+mode_average(bottom))}
            dic_list.append(dic)
            now_num+=1
            left=[]
            right=[]
            top=[]
            bottom=[]
    elapsed_time = time.time() - start_time
    print ("for文を回し終わるまでにかかった時間:{0}".format(elapsed_time) + "[sec]")
    df = pd.DataFrame(dic_list)
    df=df.sort_values('y')
    df.reset_index()
    tate_mean=df["文字の縦幅"].mean()

    diff_list=df["y"].diff()
    a_=0
    y_list=[]
    for a,b in zip(df["y"],diff_list):
        #print(a,b)
        if b<tate_mean:
            a=a_
        a_=a
        y_list.append(a)

    df["diff"]=diff_list
    df.loc[0,"diff"]=0
    df["y"]=y_list
    df=df.sort_values(["y","x"])
    grouped_df = df.groupby('y')
    grouped_list = [list(grouped_df["word"].get_group(word)) for word in grouped_df.groups]
    elapsed_time = time.time() - start_time
    print ("elapsed_time:{0}".format(elapsed_time) + "[sec]")
    return grouped_list,obj_response,blocks

# %%
# 基本は最頻値をとる。最頻値がない時は平均をとる。numsが空の時は0にする。
def mode_average(nums):
    try:
        return mode(nums)
    except:
        if len(nums)!=0:
            return round(sum(nums) / len(nums))
        else:
            try:
                return nums[0]
            except:
                return 0  #これは危ないかも
