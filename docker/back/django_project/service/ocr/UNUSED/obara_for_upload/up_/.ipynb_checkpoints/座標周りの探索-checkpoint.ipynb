# %% [markdown]
# # 準備

# %%
import random
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

#Jupyterでインライン表示するための宣言
# %matplotlib inline 
import os
import shutil
from tqdm import tqdm
import base64
import json
from requests import Request, Session
from io import BytesIO
from PIL import Image
import pandas as pd
import jaconv
import re
import cv2
import numpy as np
from symspellpy.symspellpy import SymSpell, Verbosity
import pickle
from pykakasi import kakasi
import Levenshtein
from collections import OrderedDict
import itertools

from statistics import mode

# %% [markdown]
# # 関数

# %%
#pathからbase64にする場合
def pil_image_to_base64(img_path):###ここは最後に消す
    pil_image = Image.open(img_path)
    buffered = BytesIO()
    pil_image.save(buffered, format="PNG")
    str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
    return str_encode_file

#arrayからbase64にする場合
def array_to_base64(img_array):
    pil_image = Image.fromarray(np.uint8(img_array))
    buffered = BytesIO()
    pil_image.save(buffered, format="PNG")
    str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
    return str_encode_file 

def get_fullTextAnnotation(json_data):
    text_dict = json.loads(json_data)
    try:
        text = text_dict["responses"][0]["fullTextAnnotation"]["text"]
        return text
    except:
        print(None)
        return None

str_encode_file = pil_image_to_base64("/Users/obara/Downloads/sample_API.png")  
#str_encode_file = array_to_base64(input_image)# input_imageがarrayの時
str_url = "https://vision.googleapis.com/v1/images:annotate?key="
str_api_key = "AIzaSyDlRRYrHEdjParsfRmh96_3xfafOo1crWY"
str_headers = {'Content-Type': 'application/json'}
str_json_data = {
    'requests': [
        {
            'image': {
                'content': str_encode_file
            },
            'features': [
                {
                    'type': "DOCUMENT_TEXT_DETECTION",
                    'maxResults': 1
                }
            ],"imageContext": {
    "languageHints": ["ja"]
  },
        }
    ]
}

obj_session = Session()
obj_request = Request("POST",
                        str_url + str_api_key,
                        data=json.dumps(str_json_data),
                        headers=str_headers
                        )
obj_prepped = obj_session.prepare_request(obj_request)
obj_response = obj_session.send(obj_prepped,
                                verify=True,
                                timeout=60
                                )

if obj_response.status_code == 200:
    text = get_fullTextAnnotation(obj_response.text)

# %%
text_dict = json.loads(obj_response.text)
text_dict
# Out:
# {'responses': [{'textAnnotations': [{'locale': 'ja',
#      'description': '1\n【般】ベタメタゾン吉草酸エステル・ゲ\nンタマイシン硫酸塩軟膏\n亜鉛華軟膏\n(ミックス)\n(下腿)\n10 g\n10 g\n1調剤\n',
#      'boundingPoly': {'vertices': [{'x': 36, 'y': 3},
#        {'x': 1053, 'y': 3},
#        {'x': 1053, 'y': 152},
#        {'x': 36, 'y': 152}]}},
#     {'description': '1',
#      'boundingPoly': {'vertices': [{'x': 36, 'y': 10},
#        {'x': 41, 'y': 10},
#        {'x': 41, 'y': 30},
#        {'x': 36, 'y': 30}]}},
#     {'description': '【',
#      'boundingPoly': {'vertices': [{'x': 97, 'y': 3},
#        {'x': 106, 'y': 3},
#        {'x': 106, 'y': 38},
#        {'x': 97, 'y': 38}]}},
#     {'description': '般',
#      'boundingPoly': {'vertices': [{'x': 126, 'y': 3},
#        {'x': 135, 'y': 3},
#        {'x': 135, 'y': 38},
#        {'x': 126, 'y': 38}]}},
#     {'description': '】',
#      'boundingPoly': {'vertices': [{'x': 151, 'y': 4},
#        {'x': 160, 'y': 4},
#        {'x': 160, 'y': 39},
#        {'x': 151, 'y': 39}]}},
#     {'description': 'ベタメタゾン',
#      'boundingPoly': {'vertices': [{'x': 191, 'y': 4},
#        {'x': 386, 'y': 6},
#        {'x': 386, 'y': 42},
#        {'x': 191, 'y': 40}]}},
#     {'description': '吉草酸',
#      'boundingPoly': {'vertices': [{'x': 386, 'y': 6},
#        {'x': 492, 'y': 7},
#        {'x': 492, 'y': 43},
#        {'x': 386, 'y': 42}]}},
#     {'description': 'エステル',
#      'boundingPoly': {'vertices': [{'x': 492, 'y': 7},
#        {'x': 625, 'y': 8},
#        {'x': 625, 'y': 44},
#        {'x': 492, 'y': 43}]}},
#     {'description': '・',
#      'boundingPoly': {'vertices': [{'x': 633, 'y': 9},
#        {'x': 642, 'y': 9},
#        {'x': 642, 'y': 44},
#        {'x': 633, 'y': 44}]}},
#     {'description': 'ゲ',
#      'boundingPoly': {'vertices': [{'x': 669, 'y': 9},
#        {'x': 678, 'y': 9},
#        {'x': 678, 'y': 44},
#        {'x': 669, 'y': 44}]}},
#     {'description': 'ンタマイシン',
#      'boundingPoly': {'vertices': [{'x': 80, 'y': 31},
#        {'x': 280, 'y': 34},
#        {'x': 279, 'y': 66},
#        {'x': 80, 'y': 63}]}},
#     {'description': '硫酸',
#      'boundingPoly': {'vertices': [{'x': 292, 'y': 34},
#        {'x': 355, 'y': 35},
#        {'x': 355, 'y': 67},
#        {'x': 292, 'y': 66}]}},
#     {'description': '塩',
#      'boundingPoly': {'vertices': [{'x': 363, 'y': 36},
#        {'x': 371, 'y': 36},
#        {'x': 371, 'y': 67},
#        {'x': 363, 'y': 67}]}},
#     {'description': '軟膏',
#      'boundingPoly': {'vertices': [{'x': 397, 'y': 36},
#        {'x': 449, 'y': 37},
#        {'x': 449, 'y': 69},
#        {'x': 397, 'y': 68}]}},
#     {'description': '亜鉛',
#      'boundingPoly': {'vertices': [{'x': 75, 'y': 61},
#        {'x': 147, 'y': 62},
#        {'x': 147, 'y': 93},
#        {'x': 75, 'y': 92}]}},
#     {'description': '華',
#      'boundingPoly': {'vertices': [{'x': 158, 'y': 62},
#        {'x': 166, 'y': 62},
#        {'x': 166, 'y': 92},
#        {'x': 158, 'y': 92}]}},
#     {'description': '軟膏',
#      'boundingPoly': {'vertices': [{'x': 190, 'y': 62},
#        {'x': 245, 'y': 62},
#        {'x': 245, 'y': 92},
#        {'x': 190, 'y': 92}]}},
#     {'description': '(',
#      'boundingPoly': {'vertices': [{'x': 101, 'y': 88},
#        {'x': 109, 'y': 88},
#        {'x': 108, 'y': 120},
#        {'x': 100, 'y': 120}]}},
#     {'description': 'ミックス',
#      'boundingPoly': {'vertices': [{'x': 119, 'y': 88},
#        {'x': 248, 'y': 90},
#        {'x': 247, 'y': 123},
#        {'x': 118, 'y': 121}]}},
#     {'description': ')',
#      'boundingPoly': {'vertices': [{'x': 250, 'y': 91},
#        {'x': 258, 'y': 91},
#        {'x': 257, 'y': 123},
#        {'x': 249, 'y': 123}]}},
#     {'description': '(',
#      'boundingPoly': {'vertices': [{'x': 104, 'y': 118},
#        {'x': 112, 'y': 118},
#        {'x': 112, 'y': 148},
#        {'x': 104, 'y': 148}]}},
#     {'description': '下',
#      'boundingPoly': {'vertices': [{'x': 129, 'y': 118},
#        {'x': 137, 'y': 118},
#        {'x': 137, 'y': 148},
#        {'x': 129, 'y': 148}]}},
#     {'description': '腿',
#      'boundingPoly': {'vertices': [{'x': 163, 'y': 119},
#        {'x': 171, 'y': 119},
#        {'x': 171, 'y': 149},
#        {'x': 163, 'y': 149}]}},
#     {'description': ')',
#      'boundingPoly': {'vertices': [{'x': 182, 'y': 119},
#        {'x': 190, 'y': 119},
#        {'x': 190, 'y': 149},
#        {'x': 182, 'y': 149}]}},
#     {'description': '10',
#      'boundingPoly': {'vertices': [{'x': 823, 'y': 39},
#        {'x': 857, 'y': 41},
#        {'x': 855, 'y': 72},
#        {'x': 821, 'y': 70}]}},
#     {'description': 'g',
#      'boundingPoly': {'vertices': [{'x': 877, 'y': 42},
#        {'x': 885, 'y': 42},
#        {'x': 883, 'y': 73},
#        {'x': 875, 'y': 73}]}},
#     {'description': '10',
#      'boundingPoly': {'vertices': [{'x': 824, 'y': 68},
#        {'x': 858, 'y': 69},
#        {'x': 857, 'y': 97},
#        {'x': 823, 'y': 96}]}},
#     {'description': 'g',
#      'boundingPoly': {'vertices': [{'x': 878, 'y': 71},
#        {'x': 885, 'y': 71},
#        {'x': 884, 'y': 98},
#        {'x': 877, 'y': 98}]}},
#     {'description': '1',
#      'boundingPoly': {'vertices': [{'x': 976, 'y': 122},
#        {'x': 984, 'y': 122},
#        {'x': 984, 'y': 152},
#        {'x': 976, 'y': 152}]}},
#     {'description': '調',
#      'boundingPoly': {'vertices': [{'x': 1011, 'y': 122},
#        {'x': 1019, 'y': 122},
#        {'x': 1019, 'y': 152},
#        {'x': 1011, 'y': 152}]}},
#     {'description': '剤',
#      'boundingPoly': {'vertices': [{'x': 1045, 'y': 122},
#        {'x': 1053, 'y': 122},
#        {'x': 1053, 'y': 152},
#        {'x': 1045, 'y': 152}]}}],
#    'fullTextAnnotation': {'pages': [{'property': {'detectedLanguages': [{'languageCode': 'ja',
#          'confidence': 0.74},
#         {'languageCode': 'en', 'confidence': 0.06}]},
#       'width': 1080,
#       'height': 162,
#       'blocks': [{'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#           {'x': 41, 'y': 10},
#           {'x': 41, 'y': 30},
#           {'x': 36, 'y': 30}]},
#         'paragraphs': [{'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#             {'x': 41, 'y': 10},
#             {'x': 41, 'y': 30},
#             {'x': 36, 'y': 30}]},
#           'words': [{'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#               {'x': 41, 'y': 10},
#               {'x': 41, 'y': 30},
#               {'x': 36, 'y': 30}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#                 {'x': 41, 'y': 10},
#                 {'x': 41, 'y': 30},
#                 {'x': 36, 'y': 30}]},
#               'text': '1',
#               'confidence': 0.99}],
#             'confidence': 0.99}],
#           'confidence': 0.99}],
#         'blockType': 'TEXT',
#         'confidence': 0.99},
#        {'property': {'detectedLanguages': [{'languageCode': 'ja',
#            'confidence': 0.91}]},
#         'boundingBox': {'vertices': [{'x': 76, 'y': 2},
#           {'x': 678, 'y': 9},
#           {'x': 676, 'y': 155},
#           {'x': 74, 'y': 148}]},
#         'paragraphs': [{'property': {'detectedLanguages': [{'languageCode': 'ja',
#              'confidence': 0.91}]},
#           'boundingBox': {'vertices': [{'x': 76, 'y': 2},
#             {'x': 678, 'y': 9},
#             {'x': 676, 'y': 155},
#             {'x': 74, 'y': 148}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 97, 'y': 3},
#               {'x': 106, 'y': 3},
#               {'x': 106, 'y': 38},
#               {'x': 97, 'y': 38}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 97, 'y': 3},
#                 {'x': 106, 'y': 3},
#                 {'x': 106, 'y': 38},
#                 {'x': 97, 'y': 38}]},
#               'text': '【',
#               'confidence': 0.99}],
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 126, 'y': 3},
#               {'x': 135, 'y': 3},
#               {'x': 135, 'y': 38},
#               {'x': 126, 'y': 38}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 126, 'y': 3},
#                 {'x': 135, 'y': 3},
#                 {'x': 135, 'y': 38},
#                 {'x': 126, 'y': 38}]},
#               'text': '般',
#               'confidence': 0.97}],
#             'confidence': 0.97},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 151, 'y': 4},
#               {'x': 160, 'y': 4},
#               {'x': 160, 'y': 39},
#               {'x': 151, 'y': 39}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 151, 'y': 4},
#                 {'x': 160, 'y': 4},
#                 {'x': 160, 'y': 39},
#                 {'x': 151, 'y': 39}]},
#               'text': '】',
#               'confidence': 1}],
#             'confidence': 1},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 191, 'y': 4},
#               {'x': 386, 'y': 6},
#               {'x': 386, 'y': 42},
#               {'x': 191, 'y': 40}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 191, 'y': 4},
#                 {'x': 214, 'y': 4},
#                 {'x': 214, 'y': 39},
#                 {'x': 191, 'y': 39}]},
#               'text': 'ベ',
#               'confidence': 0.71},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 218, 'y': 5},
#                 {'x': 244, 'y': 5},
#                 {'x': 244, 'y': 40},
#                 {'x': 218, 'y': 40}]},
#               'text': 'タ',
#               'confidence': 0.62},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 254, 'y': 5},
#                 {'x': 281, 'y': 5},
#                 {'x': 281, 'y': 40},
#                 {'x': 254, 'y': 40}]},
#               'text': 'メ',
#               'confidence': 0.64},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 286, 'y': 5},
#                 {'x': 313, 'y': 5},
#                 {'x': 313, 'y': 40},
#                 {'x': 286, 'y': 40}]},
#               'text': 'タ',
#               'confidence': 1},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 321, 'y': 6},
#                 {'x': 350, 'y': 6},
#                 {'x': 350, 'y': 41},
#                 {'x': 321, 'y': 41}]},
#               'text': 'ゾ',
#               'confidence': 0.99},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 357, 'y': 6},
#                 {'x': 386, 'y': 6},
#                 {'x': 386, 'y': 41},
#                 {'x': 357, 'y': 41}]},
#               'text': 'ン',
#               'confidence': 0.99}],
#             'confidence': 0.82},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 386, 'y': 6},
#               {'x': 492, 'y': 7},
#               {'x': 492, 'y': 43},
#               {'x': 386, 'y': 42}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 386, 'y': 6},
#                 {'x': 414, 'y': 6},
#                 {'x': 414, 'y': 41},
#                 {'x': 386, 'y': 41}]},
#               'text': '吉',
#               'confidence': 0.99},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 421, 'y': 7},
#                 {'x': 451, 'y': 7},
#                 {'x': 451, 'y': 42},
#                 {'x': 421, 'y': 42}]},
#               'text': '草',
#               'confidence': 0.99},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 460, 'y': 7},
#                 {'x': 492, 'y': 7},
#                 {'x': 492, 'y': 42},
#                 {'x': 460, 'y': 42}]},
#               'text': '酸',
#               'confidence': 1}],
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 492, 'y': 7},
#               {'x': 625, 'y': 8},
#               {'x': 625, 'y': 44},
#               {'x': 492, 'y': 43}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 492, 'y': 7},
#                 {'x': 518, 'y': 7},
#                 {'x': 518, 'y': 42},
#                 {'x': 492, 'y': 42}]},
#               'text': 'エ',
#               'confidence': 0.99},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 525, 'y': 8},
#                 {'x': 550, 'y': 8},
#                 {'x': 550, 'y': 43},
#                 {'x': 525, 'y': 43}]},
#               'text': 'ス',
#               'confidence': 0.99},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 555, 'y': 8},
#                 {'x': 584, 'y': 8},
#                 {'x': 584, 'y': 43},
#                 {'x': 555, 'y': 43}]},
#               'text': 'テ',
#               'confidence': 0.99},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 594, 'y': 8},
#                 {'x': 625, 'y': 8},
#                 {'x': 625, 'y': 43},
#                 {'x': 594, 'y': 43}]},
#               'text': 'ル',
#               'confidence': 0.99}],
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 633, 'y': 9},
#               {'x': 642, 'y': 9},
#               {'x': 642, 'y': 44},
#               {'x': 633, 'y': 44}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 633, 'y': 9},
#                 {'x': 642, 'y': 9},
#                 {'x': 642, 'y': 44},
#                 {'x': 633, 'y': 44}]},
#               'text': '・',
#               'confidence': 0.83}],
#             'confidence': 0.83},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 669, 'y': 9},
#               {'x': 678, 'y': 9},
#               {'x': 678, 'y': 44},
#               {'x': 669, 'y': 44}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#                'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'boundingBox': {'vertices': [{'x': 669, 'y': 9},
#                 {'x': 678, 'y': 9},
#                 {'x': 678, 'y': 44},
#                 {'x': 669, 'y': 44}]},
#               'text': 'ゲ',
#               'confidence': 0.82}],
#             'confidence': 0.82},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 80, 'y': 31},
#               {'x': 280, 'y': 34},
#               {'x': 279, 'y': 66},
#               {'x': 80, 'y': 63}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 80, 'y': 31},
#                 {'x': 109, 'y': 31},
#                 {'x': 109, 'y': 62},
#                 {'x': 80, 'y': 62}]},
#               'text': 'ン',
#               'confidence': 0.98},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 116, 'y': 32},
#                 {'x': 144, 'y': 32},
#                 {'x': 144, 'y': 63},
#                 {'x': 116, 'y': 63}]},
#               'text': 'タ',
#               'confidence': 0.99},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 152, 'y': 32},
#                 {'x': 178, 'y': 32},
#                 {'x': 178, 'y': 63},
#                 {'x': 152, 'y': 63}]},
#               'text': 'マ',
#               'confidence': 0.97},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 183, 'y': 33},
#                 {'x': 211, 'y': 33},
#                 {'x': 211, 'y': 64},
#                 {'x': 183, 'y': 64}]},
#               'text': 'イ',
#               'confidence': 0.98},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 221, 'y': 34},
#                 {'x': 249, 'y': 34},
#                 {'x': 249, 'y': 65},
#                 {'x': 221, 'y': 65}]},
#               'text': 'シ',
#               'confidence': 0.98},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 255, 'y': 34},
#                 {'x': 280, 'y': 34},
#                 {'x': 280, 'y': 65},
#                 {'x': 255, 'y': 65}]},
#               'text': 'ン',
#               'confidence': 0.99}],
#             'confidence': 0.98},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 292, 'y': 34},
#               {'x': 355, 'y': 35},
#               {'x': 355, 'y': 67},
#               {'x': 292, 'y': 66}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 292, 'y': 35},
#                 {'x': 320, 'y': 35},
#                 {'x': 320, 'y': 66},
#                 {'x': 292, 'y': 66}]},
#               'text': '硫',
#               'confidence': 0.98},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 327, 'y': 35},
#                 {'x': 355, 'y': 35},
#                 {'x': 355, 'y': 66},
#                 {'x': 327, 'y': 66}]},
#               'text': '酸',
#               'confidence': 1}],
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 363, 'y': 36},
#               {'x': 371, 'y': 36},
#               {'x': 371, 'y': 67},
#               {'x': 363, 'y': 67}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 363, 'y': 36},
#                 {'x': 371, 'y': 36},
#                 {'x': 371, 'y': 67},
#                 {'x': 363, 'y': 67}]},
#               'text': '塩',
#               'confidence': 0.99}],
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 397, 'y': 36},
#               {'x': 449, 'y': 37},
#               {'x': 449, 'y': 69},
#               {'x': 397, 'y': 68}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 397, 'y': 36},
#                 {'x': 420, 'y': 36},
#                 {'x': 420, 'y': 67},
#                 {'x': 397, 'y': 67}]},
#               'text': '軟',
#               'confidence': 0.97},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#                'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'boundingBox': {'vertices': [{'x': 426, 'y': 37},
#                 {'x': 449, 'y': 37},
#                 {'x': 449, 'y': 68},
#                 {'x': 426, 'y': 68}]},
#               'text': '膏',
#               'confidence': 1}],
#             'confidence': 0.98},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 75, 'y': 61},
#               {'x': 147, 'y': 62},
#               {'x': 147, 'y': 93},
#               {'x': 75, 'y': 92}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 75, 'y': 61},
#                 {'x': 107, 'y': 61},
#                 {'x': 107, 'y': 91},
#                 {'x': 75, 'y': 91}]},
#               'text': '亜',
#               'confidence': 0.98},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 115, 'y': 62},
#                 {'x': 147, 'y': 62},
#                 {'x': 147, 'y': 92},
#                 {'x': 115, 'y': 92}]},
#               'text': '鉛',
#               'confidence': 1}],
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 158, 'y': 62},
#               {'x': 166, 'y': 62},
#               {'x': 166, 'y': 92},
#               {'x': 158, 'y': 92}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 158, 'y': 62},
#                 {'x': 166, 'y': 62},
#                 {'x': 166, 'y': 92},
#                 {'x': 158, 'y': 92}]},
#               'text': '華',
#               'confidence': 0.99}],
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 190, 'y': 62},
#               {'x': 245, 'y': 62},
#               {'x': 245, 'y': 92},
#               {'x': 190, 'y': 92}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 190, 'y': 62},
#                 {'x': 214, 'y': 62},
#                 {'x': 214, 'y': 92},
#                 {'x': 190, 'y': 92}]},
#               'text': '軟',
#               'confidence': 1},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#                'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'boundingBox': {'vertices': [{'x': 221, 'y': 62},
#                 {'x': 245, 'y': 62},
#                 {'x': 245, 'y': 92},
#                 {'x': 221, 'y': 92}]},
#               'text': '膏',
#               'confidence': 1}],
#             'confidence': 1},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 101, 'y': 88},
#               {'x': 109, 'y': 88},
#               {'x': 108, 'y': 120},
#               {'x': 100, 'y': 120}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 101, 'y': 88},
#                 {'x': 109, 'y': 88},
#                 {'x': 108, 'y': 120},
#                 {'x': 100, 'y': 120}]},
#               'text': '(',
#               'confidence': 0.98}],
#             'confidence': 0.98},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 119, 'y': 88},
#               {'x': 248, 'y': 90},
#               {'x': 247, 'y': 123},
#               {'x': 118, 'y': 121}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 119, 'y': 89},
#                 {'x': 145, 'y': 89},
#                 {'x': 144, 'y': 121},
#                 {'x': 118, 'y': 121}]},
#               'text': 'ミ',
#               'confidence': 0.98},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 153, 'y': 89},
#                 {'x': 181, 'y': 89},
#                 {'x': 180, 'y': 121},
#                 {'x': 152, 'y': 121}]},
#               'text': 'ッ',
#               'confidence': 0.97},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 185, 'y': 90},
#                 {'x': 211, 'y': 90},
#                 {'x': 210, 'y': 122},
#                 {'x': 184, 'y': 122}]},
#               'text': 'ク',
#               'confidence': 0.99},
#              {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#               'boundingBox': {'vertices': [{'x': 220, 'y': 90},
#                 {'x': 248, 'y': 90},
#                 {'x': 247, 'y': 122},
#                 {'x': 219, 'y': 122}]},
#               'text': 'ス',
#               'confidence': 0.99}],
#             'confidence': 0.98},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 250, 'y': 91},
#               {'x': 258, 'y': 91},
#               {'x': 257, 'y': 123},
#               {'x': 249, 'y': 123}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#                'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'boundingBox': {'vertices': [{'x': 250, 'y': 91},
#                 {'x': 258, 'y': 91},
#                 {'x': 257, 'y': 123},
#                 {'x': 249, 'y': 123}]},
#               'text': ')',
#               'confidence': 0.99}],
#             'confidence': 0.99},
#            {'boundingBox': {'vertices': [{'x': 104, 'y': 118},
#               {'x': 112, 'y': 118},
#               {'x': 112, 'y': 148},
#               {'x': 104, 'y': 148}]},
#             'symbols': [{'boundingBox': {'vertices': [{'x': 104, 'y': 118},
#                 {'x': 112, 'y': 118},
#                 {'x': 112, 'y': 148},
#                 {'x': 104, 'y': 148}]},
#               'text': '(',
#               'confidence': 0.98}],
#             'confidence': 0.98},
#            {'boundingBox': {'vertices': [{'x': 129, 'y': 118},
#               {'x': 137, 'y': 118},
#               {'x': 137, 'y': 148},
#               {'x': 129, 'y': 148}]},
#             'symbols': [{'boundingBox': {'vertices': [{'x': 129, 'y': 118},
#                 {'x': 137, 'y': 118},
#                 {'x': 137, 'y': 148},
#                 {'x': 129, 'y': 148}]},
#               'text': '下',
#               'confidence': 0.98}],
#             'confidence': 0.98},
#            {'boundingBox': {'vertices': [{'x': 163, 'y': 119},
#               {'x': 171, 'y': 119},
#               {'x': 171, 'y': 149},
#               {'x': 163, 'y': 149}]},
#             'symbols': [{'boundingBox': {'vertices': [{'x': 163, 'y': 119},
#                 {'x': 171, 'y': 119},
#                 {'x': 171, 'y': 149},
#                 {'x': 163, 'y': 149}]},
#               'text': '腿',
#               'confidence': 0.91}],
#             'confidence': 0.91},
#            {'boundingBox': {'vertices': [{'x': 182, 'y': 119},
#               {'x': 190, 'y': 119},
#               {'x': 190, 'y': 149},
#               {'x': 182, 'y': 149}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'boundingBox': {'vertices': [{'x': 182, 'y': 119},
#                 {'x': 190, 'y': 119},
#                 {'x': 190, 'y': 149},
#                 {'x': 182, 'y': 149}]},
#               'text': ')',
#               'confidence': 0.77}],
#             'confidence': 0.77}],
#           'confidence': 0.95}],
#         'blockType': 'TEXT',
#         'confidence': 0.95},
#        {'property': {'detectedLanguages': [{'languageCode': 'en',
#            'confidence': 0.5}]},
#         'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#           {'x': 886, 'y': 42},
#           {'x': 883, 'y': 99},
#           {'x': 820, 'y': 96}]},
#         'paragraphs': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#              'confidence': 0.5}]},
#           'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#             {'x': 886, 'y': 42},
#             {'x': 883, 'y': 99},
#             {'x': 820, 'y': 96}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en'}]},
#             'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#               {'x': 857, 'y': 41},
#               {'x': 855, 'y': 72},
#               {'x': 821, 'y': 70}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'en'}]},
#               'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#                 {'x': 838, 'y': 40},
#                 {'x': 836, 'y': 71},
#                 {'x': 821, 'y': 70}]},
#               'text': '1',
#               'confidence': 0.96},
#              {'property': {'detectedLanguages': [{'languageCode': 'en'}],
#                'detectedBreak': {'type': 'SPACE'}},
#               'boundingBox': {'vertices': [{'x': 842, 'y': 40},
#                 {'x': 857, 'y': 41},
#                 {'x': 855, 'y': 72},
#                 {'x': 840, 'y': 71}]},
#               'text': '0',
#               'confidence': 0.99}],
#             'confidence': 0.97},
#            {'property': {'detectedLanguages': [{'languageCode': 'en'}]},
#             'boundingBox': {'vertices': [{'x': 877, 'y': 42},
#               {'x': 885, 'y': 42},
#               {'x': 883, 'y': 73},
#               {'x': 875, 'y': 73}]},
#             'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'en'}],
#                'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'boundingBox': {'vertices': [{'x': 877, 'y': 42},
#                 {'x': 885, 'y': 42},
#                 {'x': 883, 'y': 73},
#                 {'x': 875, 'y': 73}]},
#               'text': 'g',
#               'confidence': 0.99}],
#             'confidence': 0.99},
#            {'boundingBox': {'vertices': [{'x': 824, 'y': 68},
#               {'x': 858, 'y': 69},
#               {'x': 857, 'y': 97},
#               {'x': 823, 'y': 96}]},
#             'symbols': [{'boundingBox': {'vertices': [{'x': 824, 'y': 69},
#                 {'x': 839, 'y': 70},
#                 {'x': 838, 'y': 97},
#                 {'x': 823, 'y': 96}]},
#               'text': '1',
#               'confidence': 0.99},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'boundingBox': {'vertices': [{'x': 843, 'y': 69},
#                 {'x': 858, 'y': 70},
#                 {'x': 857, 'y': 97},
#                 {'x': 842, 'y': 96}]},
#               'text': '0',
#               'confidence': 0.99}],
#             'confidence': 0.99},
#            {'boundingBox': {'vertices': [{'x': 878, 'y': 71},
#               {'x': 885, 'y': 71},
#               {'x': 884, 'y': 98},
#               {'x': 877, 'y': 98}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'boundingBox': {'vertices': [{'x': 878, 'y': 71},
#                 {'x': 885, 'y': 71},
#                 {'x': 884, 'y': 98},
#                 {'x': 877, 'y': 98}]},
#               'text': 'g',
#               'confidence': 0.97}],
#             'confidence': 0.97}],
#           'confidence': 0.98}],
#         'blockType': 'TEXT',
#         'confidence': 0.98},
#        {'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#           {'x': 1053, 'y': 122},
#           {'x': 1053, 'y': 152},
#           {'x': 976, 'y': 152}]},
#         'paragraphs': [{'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#             {'x': 1053, 'y': 122},
#             {'x': 1053, 'y': 152},
#             {'x': 976, 'y': 152}]},
#           'words': [{'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#               {'x': 984, 'y': 122},
#               {'x': 984, 'y': 152},
#               {'x': 976, 'y': 152}]},
#             'symbols': [{'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#                 {'x': 984, 'y': 122},
#                 {'x': 984, 'y': 152},
#                 {'x': 976, 'y': 152}]},
#               'text': '1',
#               'confidence': 0.98}],
#             'confidence': 0.98},
#            {'boundingBox': {'vertices': [{'x': 1011, 'y': 122},
#               {'x': 1019, 'y': 122},
#               {'x': 1019, 'y': 152},
#               {'x': 1011, 'y': 152}]},
#             'symbols': [{'boundingBox': {'vertices': [{'x': 1011, 'y': 122},
#                 {'x': 1019, 'y': 122},
#                 {'x': 1019, 'y': 152},
#                 {'x': 1011, 'y': 152}]},
#               'text': '調',
#               'confidence': 0.97}],
#             'confidence': 0.97},
#            {'boundingBox': {'vertices': [{'x': 1045, 'y': 122},
#               {'x': 1053, 'y': 122},
#               {'x': 1053, 'y': 152},
#               {'x': 1045, 'y': 152}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'boundingBox': {'vertices': [{'x': 1045, 'y': 122},
#                 {'x': 1053, 'y': 122},
#                 {'x': 1053, 'y': 152},
#                 {'x': 1045, 'y': 152}]},
#               'text': '剤',
#               'confidence': 0.99}],
#             'confidence': 0.99}],
#           'confidence': 0.98}],
#         'blockType': 'TEXT',
#         'confidence': 0.98}]}],
#     'text': '1\n【般】ベタメタゾン吉草酸エステル・ゲ\nンタマイシン硫酸塩軟膏\n亜鉛華軟膏\n(ミックス)\n(下腿)\n10 g\n10 g\n1調剤\n'}}]}

# %%
text_dict["responses"]
# Out:
# [{'textAnnotations': [{'locale': 'ja',
#     'description': '1\n【般】ベタメタゾン吉草酸エステル・ゲ\nンタマイシン硫酸塩軟膏\n亜鉛華軟膏\n(ミックス)\n(下腿)\n10 g\n10 g\n1調剤\n',
#     'boundingPoly': {'vertices': [{'x': 36, 'y': 3},
#       {'x': 1053, 'y': 3},
#       {'x': 1053, 'y': 152},
#       {'x': 36, 'y': 152}]}},
#    {'description': '1',
#     'boundingPoly': {'vertices': [{'x': 36, 'y': 10},
#       {'x': 41, 'y': 10},
#       {'x': 41, 'y': 30},
#       {'x': 36, 'y': 30}]}},
#    {'description': '【',
#     'boundingPoly': {'vertices': [{'x': 97, 'y': 3},
#       {'x': 106, 'y': 3},
#       {'x': 106, 'y': 38},
#       {'x': 97, 'y': 38}]}},
#    {'description': '般',
#     'boundingPoly': {'vertices': [{'x': 126, 'y': 3},
#       {'x': 135, 'y': 3},
#       {'x': 135, 'y': 38},
#       {'x': 126, 'y': 38}]}},
#    {'description': '】',
#     'boundingPoly': {'vertices': [{'x': 151, 'y': 4},
#       {'x': 160, 'y': 4},
#       {'x': 160, 'y': 39},
#       {'x': 151, 'y': 39}]}},
#    {'description': 'ベタメタゾン',
#     'boundingPoly': {'vertices': [{'x': 191, 'y': 4},
#       {'x': 386, 'y': 6},
#       {'x': 386, 'y': 42},
#       {'x': 191, 'y': 40}]}},
#    {'description': '吉草酸',
#     'boundingPoly': {'vertices': [{'x': 386, 'y': 6},
#       {'x': 492, 'y': 7},
#       {'x': 492, 'y': 43},
#       {'x': 386, 'y': 42}]}},
#    {'description': 'エステル',
#     'boundingPoly': {'vertices': [{'x': 492, 'y': 7},
#       {'x': 625, 'y': 8},
#       {'x': 625, 'y': 44},
#       {'x': 492, 'y': 43}]}},
#    {'description': '・',
#     'boundingPoly': {'vertices': [{'x': 633, 'y': 9},
#       {'x': 642, 'y': 9},
#       {'x': 642, 'y': 44},
#       {'x': 633, 'y': 44}]}},
#    {'description': 'ゲ',
#     'boundingPoly': {'vertices': [{'x': 669, 'y': 9},
#       {'x': 678, 'y': 9},
#       {'x': 678, 'y': 44},
#       {'x': 669, 'y': 44}]}},
#    {'description': 'ンタマイシン',
#     'boundingPoly': {'vertices': [{'x': 80, 'y': 31},
#       {'x': 280, 'y': 34},
#       {'x': 279, 'y': 66},
#       {'x': 80, 'y': 63}]}},
#    {'description': '硫酸',
#     'boundingPoly': {'vertices': [{'x': 292, 'y': 34},
#       {'x': 355, 'y': 35},
#       {'x': 355, 'y': 67},
#       {'x': 292, 'y': 66}]}},
#    {'description': '塩',
#     'boundingPoly': {'vertices': [{'x': 363, 'y': 36},
#       {'x': 371, 'y': 36},
#       {'x': 371, 'y': 67},
#       {'x': 363, 'y': 67}]}},
#    {'description': '軟膏',
#     'boundingPoly': {'vertices': [{'x': 397, 'y': 36},
#       {'x': 449, 'y': 37},
#       {'x': 449, 'y': 69},
#       {'x': 397, 'y': 68}]}},
#    {'description': '亜鉛',
#     'boundingPoly': {'vertices': [{'x': 75, 'y': 61},
#       {'x': 147, 'y': 62},
#       {'x': 147, 'y': 93},
#       {'x': 75, 'y': 92}]}},
#    {'description': '華',
#     'boundingPoly': {'vertices': [{'x': 158, 'y': 62},
#       {'x': 166, 'y': 62},
#       {'x': 166, 'y': 92},
#       {'x': 158, 'y': 92}]}},
#    {'description': '軟膏',
#     'boundingPoly': {'vertices': [{'x': 190, 'y': 62},
#       {'x': 245, 'y': 62},
#       {'x': 245, 'y': 92},
#       {'x': 190, 'y': 92}]}},
#    {'description': '(',
#     'boundingPoly': {'vertices': [{'x': 101, 'y': 88},
#       {'x': 109, 'y': 88},
#       {'x': 108, 'y': 120},
#       {'x': 100, 'y': 120}]}},
#    {'description': 'ミックス',
#     'boundingPoly': {'vertices': [{'x': 119, 'y': 88},
#       {'x': 248, 'y': 90},
#       {'x': 247, 'y': 123},
#       {'x': 118, 'y': 121}]}},
#    {'description': ')',
#     'boundingPoly': {'vertices': [{'x': 250, 'y': 91},
#       {'x': 258, 'y': 91},
#       {'x': 257, 'y': 123},
#       {'x': 249, 'y': 123}]}},
#    {'description': '(',
#     'boundingPoly': {'vertices': [{'x': 104, 'y': 118},
#       {'x': 112, 'y': 118},
#       {'x': 112, 'y': 148},
#       {'x': 104, 'y': 148}]}},
#    {'description': '下',
#     'boundingPoly': {'vertices': [{'x': 129, 'y': 118},
#       {'x': 137, 'y': 118},
#       {'x': 137, 'y': 148},
#       {'x': 129, 'y': 148}]}},
#    {'description': '腿',
#     'boundingPoly': {'vertices': [{'x': 163, 'y': 119},
#       {'x': 171, 'y': 119},
#       {'x': 171, 'y': 149},
#       {'x': 163, 'y': 149}]}},
#    {'description': ')',
#     'boundingPoly': {'vertices': [{'x': 182, 'y': 119},
#       {'x': 190, 'y': 119},
#       {'x': 190, 'y': 149},
#       {'x': 182, 'y': 149}]}},
#    {'description': '10',
#     'boundingPoly': {'vertices': [{'x': 823, 'y': 39},
#       {'x': 857, 'y': 41},
#       {'x': 855, 'y': 72},
#       {'x': 821, 'y': 70}]}},
#    {'description': 'g',
#     'boundingPoly': {'vertices': [{'x': 877, 'y': 42},
#       {'x': 885, 'y': 42},
#       {'x': 883, 'y': 73},
#       {'x': 875, 'y': 73}]}},
#    {'description': '10',
#     'boundingPoly': {'vertices': [{'x': 824, 'y': 68},
#       {'x': 858, 'y': 69},
#       {'x': 857, 'y': 97},
#       {'x': 823, 'y': 96}]}},
#    {'description': 'g',
#     'boundingPoly': {'vertices': [{'x': 878, 'y': 71},
#       {'x': 885, 'y': 71},
#       {'x': 884, 'y': 98},
#       {'x': 877, 'y': 98}]}},
#    {'description': '1',
#     'boundingPoly': {'vertices': [{'x': 976, 'y': 122},
#       {'x': 984, 'y': 122},
#       {'x': 984, 'y': 152},
#       {'x': 976, 'y': 152}]}},
#    {'description': '調',
#     'boundingPoly': {'vertices': [{'x': 1011, 'y': 122},
#       {'x': 1019, 'y': 122},
#       {'x': 1019, 'y': 152},
#       {'x': 1011, 'y': 152}]}},
#    {'description': '剤',
#     'boundingPoly': {'vertices': [{'x': 1045, 'y': 122},
#       {'x': 1053, 'y': 122},
#       {'x': 1053, 'y': 152},
#       {'x': 1045, 'y': 152}]}}],
#   'fullTextAnnotation': {'pages': [{'property': {'detectedLanguages': [{'languageCode': 'ja',
#         'confidence': 0.74},
#        {'languageCode': 'en', 'confidence': 0.06}]},
#      'width': 1080,
#      'height': 162,
#      'blocks': [{'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#          {'x': 41, 'y': 10},
#          {'x': 41, 'y': 30},
#          {'x': 36, 'y': 30}]},
#        'paragraphs': [{'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#            {'x': 41, 'y': 10},
#            {'x': 41, 'y': 30},
#            {'x': 36, 'y': 30}]},
#          'words': [{'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#              {'x': 41, 'y': 10},
#              {'x': 41, 'y': 30},
#              {'x': 36, 'y': 30}]},
#            'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#              'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#                {'x': 41, 'y': 10},
#                {'x': 41, 'y': 30},
#                {'x': 36, 'y': 30}]},
#              'text': '1',
#              'confidence': 0.99}],
#            'confidence': 0.99}],
#          'confidence': 0.99}],
#        'blockType': 'TEXT',
#        'confidence': 0.99},
#       {'property': {'detectedLanguages': [{'languageCode': 'ja',
#           'confidence': 0.91}]},
#        'boundingBox': {'vertices': [{'x': 76, 'y': 2},
#          {'x': 678, 'y': 9},
#          {'x': 676, 'y': 155},
#          {'x': 74, 'y': 148}]},
#        'paragraphs': [{'property': {'detectedLanguages': [{'languageCode': 'ja',
#             'confidence': 0.91}]},
#          'boundingBox': {'vertices': [{'x': 76, 'y': 2},
#            {'x': 678, 'y': 9},
#            {'x': 676, 'y': 155},
#            {'x': 74, 'y': 148}]},
#          'words': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 97, 'y': 3},
#              {'x': 106, 'y': 3},
#              {'x': 106, 'y': 38},
#              {'x': 97, 'y': 38}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 97, 'y': 3},
#                {'x': 106, 'y': 3},
#                {'x': 106, 'y': 38},
#                {'x': 97, 'y': 38}]},
#              'text': '【',
#              'confidence': 0.99}],
#            'confidence': 0.99},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 126, 'y': 3},
#              {'x': 135, 'y': 3},
#              {'x': 135, 'y': 38},
#              {'x': 126, 'y': 38}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 126, 'y': 3},
#                {'x': 135, 'y': 3},
#                {'x': 135, 'y': 38},
#                {'x': 126, 'y': 38}]},
#              'text': '般',
#              'confidence': 0.97}],
#            'confidence': 0.97},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 151, 'y': 4},
#              {'x': 160, 'y': 4},
#              {'x': 160, 'y': 39},
#              {'x': 151, 'y': 39}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 151, 'y': 4},
#                {'x': 160, 'y': 4},
#                {'x': 160, 'y': 39},
#                {'x': 151, 'y': 39}]},
#              'text': '】',
#              'confidence': 1}],
#            'confidence': 1},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 191, 'y': 4},
#              {'x': 386, 'y': 6},
#              {'x': 386, 'y': 42},
#              {'x': 191, 'y': 40}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 191, 'y': 4},
#                {'x': 214, 'y': 4},
#                {'x': 214, 'y': 39},
#                {'x': 191, 'y': 39}]},
#              'text': 'ベ',
#              'confidence': 0.71},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 218, 'y': 5},
#                {'x': 244, 'y': 5},
#                {'x': 244, 'y': 40},
#                {'x': 218, 'y': 40}]},
#              'text': 'タ',
#              'confidence': 0.62},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 254, 'y': 5},
#                {'x': 281, 'y': 5},
#                {'x': 281, 'y': 40},
#                {'x': 254, 'y': 40}]},
#              'text': 'メ',
#              'confidence': 0.64},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 286, 'y': 5},
#                {'x': 313, 'y': 5},
#                {'x': 313, 'y': 40},
#                {'x': 286, 'y': 40}]},
#              'text': 'タ',
#              'confidence': 1},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 321, 'y': 6},
#                {'x': 350, 'y': 6},
#                {'x': 350, 'y': 41},
#                {'x': 321, 'y': 41}]},
#              'text': 'ゾ',
#              'confidence': 0.99},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 357, 'y': 6},
#                {'x': 386, 'y': 6},
#                {'x': 386, 'y': 41},
#                {'x': 357, 'y': 41}]},
#              'text': 'ン',
#              'confidence': 0.99}],
#            'confidence': 0.82},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 386, 'y': 6},
#              {'x': 492, 'y': 7},
#              {'x': 492, 'y': 43},
#              {'x': 386, 'y': 42}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 386, 'y': 6},
#                {'x': 414, 'y': 6},
#                {'x': 414, 'y': 41},
#                {'x': 386, 'y': 41}]},
#              'text': '吉',
#              'confidence': 0.99},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 421, 'y': 7},
#                {'x': 451, 'y': 7},
#                {'x': 451, 'y': 42},
#                {'x': 421, 'y': 42}]},
#              'text': '草',
#              'confidence': 0.99},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 460, 'y': 7},
#                {'x': 492, 'y': 7},
#                {'x': 492, 'y': 42},
#                {'x': 460, 'y': 42}]},
#              'text': '酸',
#              'confidence': 1}],
#            'confidence': 0.99},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 492, 'y': 7},
#              {'x': 625, 'y': 8},
#              {'x': 625, 'y': 44},
#              {'x': 492, 'y': 43}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 492, 'y': 7},
#                {'x': 518, 'y': 7},
#                {'x': 518, 'y': 42},
#                {'x': 492, 'y': 42}]},
#              'text': 'エ',
#              'confidence': 0.99},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 525, 'y': 8},
#                {'x': 550, 'y': 8},
#                {'x': 550, 'y': 43},
#                {'x': 525, 'y': 43}]},
#              'text': 'ス',
#              'confidence': 0.99},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 555, 'y': 8},
#                {'x': 584, 'y': 8},
#                {'x': 584, 'y': 43},
#                {'x': 555, 'y': 43}]},
#              'text': 'テ',
#              'confidence': 0.99},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 594, 'y': 8},
#                {'x': 625, 'y': 8},
#                {'x': 625, 'y': 43},
#                {'x': 594, 'y': 43}]},
#              'text': 'ル',
#              'confidence': 0.99}],
#            'confidence': 0.99},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 633, 'y': 9},
#              {'x': 642, 'y': 9},
#              {'x': 642, 'y': 44},
#              {'x': 633, 'y': 44}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 633, 'y': 9},
#                {'x': 642, 'y': 9},
#                {'x': 642, 'y': 44},
#                {'x': 633, 'y': 44}]},
#              'text': '・',
#              'confidence': 0.83}],
#            'confidence': 0.83},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 669, 'y': 9},
#              {'x': 678, 'y': 9},
#              {'x': 678, 'y': 44},
#              {'x': 669, 'y': 44}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#               'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#              'boundingBox': {'vertices': [{'x': 669, 'y': 9},
#                {'x': 678, 'y': 9},
#                {'x': 678, 'y': 44},
#                {'x': 669, 'y': 44}]},
#              'text': 'ゲ',
#              'confidence': 0.82}],
#            'confidence': 0.82},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 80, 'y': 31},
#              {'x': 280, 'y': 34},
#              {'x': 279, 'y': 66},
#              {'x': 80, 'y': 63}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 80, 'y': 31},
#                {'x': 109, 'y': 31},
#                {'x': 109, 'y': 62},
#                {'x': 80, 'y': 62}]},
#              'text': 'ン',
#              'confidence': 0.98},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 116, 'y': 32},
#                {'x': 144, 'y': 32},
#                {'x': 144, 'y': 63},
#                {'x': 116, 'y': 63}]},
#              'text': 'タ',
#              'confidence': 0.99},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 152, 'y': 32},
#                {'x': 178, 'y': 32},
#                {'x': 178, 'y': 63},
#                {'x': 152, 'y': 63}]},
#              'text': 'マ',
#              'confidence': 0.97},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 183, 'y': 33},
#                {'x': 211, 'y': 33},
#                {'x': 211, 'y': 64},
#                {'x': 183, 'y': 64}]},
#              'text': 'イ',
#              'confidence': 0.98},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 221, 'y': 34},
#                {'x': 249, 'y': 34},
#                {'x': 249, 'y': 65},
#                {'x': 221, 'y': 65}]},
#              'text': 'シ',
#              'confidence': 0.98},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 255, 'y': 34},
#                {'x': 280, 'y': 34},
#                {'x': 280, 'y': 65},
#                {'x': 255, 'y': 65}]},
#              'text': 'ン',
#              'confidence': 0.99}],
#            'confidence': 0.98},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 292, 'y': 34},
#              {'x': 355, 'y': 35},
#              {'x': 355, 'y': 67},
#              {'x': 292, 'y': 66}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 292, 'y': 35},
#                {'x': 320, 'y': 35},
#                {'x': 320, 'y': 66},
#                {'x': 292, 'y': 66}]},
#              'text': '硫',
#              'confidence': 0.98},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 327, 'y': 35},
#                {'x': 355, 'y': 35},
#                {'x': 355, 'y': 66},
#                {'x': 327, 'y': 66}]},
#              'text': '酸',
#              'confidence': 1}],
#            'confidence': 0.99},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 363, 'y': 36},
#              {'x': 371, 'y': 36},
#              {'x': 371, 'y': 67},
#              {'x': 363, 'y': 67}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 363, 'y': 36},
#                {'x': 371, 'y': 36},
#                {'x': 371, 'y': 67},
#                {'x': 363, 'y': 67}]},
#              'text': '塩',
#              'confidence': 0.99}],
#            'confidence': 0.99},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 397, 'y': 36},
#              {'x': 449, 'y': 37},
#              {'x': 449, 'y': 69},
#              {'x': 397, 'y': 68}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 397, 'y': 36},
#                {'x': 420, 'y': 36},
#                {'x': 420, 'y': 67},
#                {'x': 397, 'y': 67}]},
#              'text': '軟',
#              'confidence': 0.97},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#               'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#              'boundingBox': {'vertices': [{'x': 426, 'y': 37},
#                {'x': 449, 'y': 37},
#                {'x': 449, 'y': 68},
#                {'x': 426, 'y': 68}]},
#              'text': '膏',
#              'confidence': 1}],
#            'confidence': 0.98},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 75, 'y': 61},
#              {'x': 147, 'y': 62},
#              {'x': 147, 'y': 93},
#              {'x': 75, 'y': 92}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 75, 'y': 61},
#                {'x': 107, 'y': 61},
#                {'x': 107, 'y': 91},
#                {'x': 75, 'y': 91}]},
#              'text': '亜',
#              'confidence': 0.98},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 115, 'y': 62},
#                {'x': 147, 'y': 62},
#                {'x': 147, 'y': 92},
#                {'x': 115, 'y': 92}]},
#              'text': '鉛',
#              'confidence': 1}],
#            'confidence': 0.99},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 158, 'y': 62},
#              {'x': 166, 'y': 62},
#              {'x': 166, 'y': 92},
#              {'x': 158, 'y': 92}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 158, 'y': 62},
#                {'x': 166, 'y': 62},
#                {'x': 166, 'y': 92},
#                {'x': 158, 'y': 92}]},
#              'text': '華',
#              'confidence': 0.99}],
#            'confidence': 0.99},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 190, 'y': 62},
#              {'x': 245, 'y': 62},
#              {'x': 245, 'y': 92},
#              {'x': 190, 'y': 92}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 190, 'y': 62},
#                {'x': 214, 'y': 62},
#                {'x': 214, 'y': 92},
#                {'x': 190, 'y': 92}]},
#              'text': '軟',
#              'confidence': 1},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#               'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#              'boundingBox': {'vertices': [{'x': 221, 'y': 62},
#                {'x': 245, 'y': 62},
#                {'x': 245, 'y': 92},
#                {'x': 221, 'y': 92}]},
#              'text': '膏',
#              'confidence': 1}],
#            'confidence': 1},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 101, 'y': 88},
#              {'x': 109, 'y': 88},
#              {'x': 108, 'y': 120},
#              {'x': 100, 'y': 120}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 101, 'y': 88},
#                {'x': 109, 'y': 88},
#                {'x': 108, 'y': 120},
#                {'x': 100, 'y': 120}]},
#              'text': '(',
#              'confidence': 0.98}],
#            'confidence': 0.98},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 119, 'y': 88},
#              {'x': 248, 'y': 90},
#              {'x': 247, 'y': 123},
#              {'x': 118, 'y': 121}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 119, 'y': 89},
#                {'x': 145, 'y': 89},
#                {'x': 144, 'y': 121},
#                {'x': 118, 'y': 121}]},
#              'text': 'ミ',
#              'confidence': 0.98},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 153, 'y': 89},
#                {'x': 181, 'y': 89},
#                {'x': 180, 'y': 121},
#                {'x': 152, 'y': 121}]},
#              'text': 'ッ',
#              'confidence': 0.97},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 185, 'y': 90},
#                {'x': 211, 'y': 90},
#                {'x': 210, 'y': 122},
#                {'x': 184, 'y': 122}]},
#              'text': 'ク',
#              'confidence': 0.99},
#             {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#              'boundingBox': {'vertices': [{'x': 220, 'y': 90},
#                {'x': 248, 'y': 90},
#                {'x': 247, 'y': 122},
#                {'x': 219, 'y': 122}]},
#              'text': 'ス',
#              'confidence': 0.99}],
#            'confidence': 0.98},
#           {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#            'boundingBox': {'vertices': [{'x': 250, 'y': 91},
#              {'x': 258, 'y': 91},
#              {'x': 257, 'y': 123},
#              {'x': 249, 'y': 123}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#               'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#              'boundingBox': {'vertices': [{'x': 250, 'y': 91},
#                {'x': 258, 'y': 91},
#                {'x': 257, 'y': 123},
#                {'x': 249, 'y': 123}]},
#              'text': ')',
#              'confidence': 0.99}],
#            'confidence': 0.99},
#           {'boundingBox': {'vertices': [{'x': 104, 'y': 118},
#              {'x': 112, 'y': 118},
#              {'x': 112, 'y': 148},
#              {'x': 104, 'y': 148}]},
#            'symbols': [{'boundingBox': {'vertices': [{'x': 104, 'y': 118},
#                {'x': 112, 'y': 118},
#                {'x': 112, 'y': 148},
#                {'x': 104, 'y': 148}]},
#              'text': '(',
#              'confidence': 0.98}],
#            'confidence': 0.98},
#           {'boundingBox': {'vertices': [{'x': 129, 'y': 118},
#              {'x': 137, 'y': 118},
#              {'x': 137, 'y': 148},
#              {'x': 129, 'y': 148}]},
#            'symbols': [{'boundingBox': {'vertices': [{'x': 129, 'y': 118},
#                {'x': 137, 'y': 118},
#                {'x': 137, 'y': 148},
#                {'x': 129, 'y': 148}]},
#              'text': '下',
#              'confidence': 0.98}],
#            'confidence': 0.98},
#           {'boundingBox': {'vertices': [{'x': 163, 'y': 119},
#              {'x': 171, 'y': 119},
#              {'x': 171, 'y': 149},
#              {'x': 163, 'y': 149}]},
#            'symbols': [{'boundingBox': {'vertices': [{'x': 163, 'y': 119},
#                {'x': 171, 'y': 119},
#                {'x': 171, 'y': 149},
#                {'x': 163, 'y': 149}]},
#              'text': '腿',
#              'confidence': 0.91}],
#            'confidence': 0.91},
#           {'boundingBox': {'vertices': [{'x': 182, 'y': 119},
#              {'x': 190, 'y': 119},
#              {'x': 190, 'y': 149},
#              {'x': 182, 'y': 149}]},
#            'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#              'boundingBox': {'vertices': [{'x': 182, 'y': 119},
#                {'x': 190, 'y': 119},
#                {'x': 190, 'y': 149},
#                {'x': 182, 'y': 149}]},
#              'text': ')',
#              'confidence': 0.77}],
#            'confidence': 0.77}],
#          'confidence': 0.95}],
#        'blockType': 'TEXT',
#        'confidence': 0.95},
#       {'property': {'detectedLanguages': [{'languageCode': 'en',
#           'confidence': 0.5}]},
#        'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#          {'x': 886, 'y': 42},
#          {'x': 883, 'y': 99},
#          {'x': 820, 'y': 96}]},
#        'paragraphs': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#             'confidence': 0.5}]},
#          'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#            {'x': 886, 'y': 42},
#            {'x': 883, 'y': 99},
#            {'x': 820, 'y': 96}]},
#          'words': [{'property': {'detectedLanguages': [{'languageCode': 'en'}]},
#            'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#              {'x': 857, 'y': 41},
#              {'x': 855, 'y': 72},
#              {'x': 821, 'y': 70}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'en'}]},
#              'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#                {'x': 838, 'y': 40},
#                {'x': 836, 'y': 71},
#                {'x': 821, 'y': 70}]},
#              'text': '1',
#              'confidence': 0.96},
#             {'property': {'detectedLanguages': [{'languageCode': 'en'}],
#               'detectedBreak': {'type': 'SPACE'}},
#              'boundingBox': {'vertices': [{'x': 842, 'y': 40},
#                {'x': 857, 'y': 41},
#                {'x': 855, 'y': 72},
#                {'x': 840, 'y': 71}]},
#              'text': '0',
#              'confidence': 0.99}],
#            'confidence': 0.97},
#           {'property': {'detectedLanguages': [{'languageCode': 'en'}]},
#            'boundingBox': {'vertices': [{'x': 877, 'y': 42},
#              {'x': 885, 'y': 42},
#              {'x': 883, 'y': 73},
#              {'x': 875, 'y': 73}]},
#            'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'en'}],
#               'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#              'boundingBox': {'vertices': [{'x': 877, 'y': 42},
#                {'x': 885, 'y': 42},
#                {'x': 883, 'y': 73},
#                {'x': 875, 'y': 73}]},
#              'text': 'g',
#              'confidence': 0.99}],
#            'confidence': 0.99},
#           {'boundingBox': {'vertices': [{'x': 824, 'y': 68},
#              {'x': 858, 'y': 69},
#              {'x': 857, 'y': 97},
#              {'x': 823, 'y': 96}]},
#            'symbols': [{'boundingBox': {'vertices': [{'x': 824, 'y': 69},
#                {'x': 839, 'y': 70},
#                {'x': 838, 'y': 97},
#                {'x': 823, 'y': 96}]},
#              'text': '1',
#              'confidence': 0.99},
#             {'property': {'detectedBreak': {'type': 'SPACE'}},
#              'boundingBox': {'vertices': [{'x': 843, 'y': 69},
#                {'x': 858, 'y': 70},
#                {'x': 857, 'y': 97},
#                {'x': 842, 'y': 96}]},
#              'text': '0',
#              'confidence': 0.99}],
#            'confidence': 0.99},
#           {'boundingBox': {'vertices': [{'x': 878, 'y': 71},
#              {'x': 885, 'y': 71},
#              {'x': 884, 'y': 98},
#              {'x': 877, 'y': 98}]},
#            'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#              'boundingBox': {'vertices': [{'x': 878, 'y': 71},
#                {'x': 885, 'y': 71},
#                {'x': 884, 'y': 98},
#                {'x': 877, 'y': 98}]},
#              'text': 'g',
#              'confidence': 0.97}],
#            'confidence': 0.97}],
#          'confidence': 0.98}],
#        'blockType': 'TEXT',
#        'confidence': 0.98},
#       {'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#          {'x': 1053, 'y': 122},
#          {'x': 1053, 'y': 152},
#          {'x': 976, 'y': 152}]},
#        'paragraphs': [{'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#            {'x': 1053, 'y': 122},
#            {'x': 1053, 'y': 152},
#            {'x': 976, 'y': 152}]},
#          'words': [{'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#              {'x': 984, 'y': 122},
#              {'x': 984, 'y': 152},
#              {'x': 976, 'y': 152}]},
#            'symbols': [{'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#                {'x': 984, 'y': 122},
#                {'x': 984, 'y': 152},
#                {'x': 976, 'y': 152}]},
#              'text': '1',
#              'confidence': 0.98}],
#            'confidence': 0.98},
#           {'boundingBox': {'vertices': [{'x': 1011, 'y': 122},
#              {'x': 1019, 'y': 122},
#              {'x': 1019, 'y': 152},
#              {'x': 1011, 'y': 152}]},
#            'symbols': [{'boundingBox': {'vertices': [{'x': 1011, 'y': 122},
#                {'x': 1019, 'y': 122},
#                {'x': 1019, 'y': 152},
#                {'x': 1011, 'y': 152}]},
#              'text': '調',
#              'confidence': 0.97}],
#            'confidence': 0.97},
#           {'boundingBox': {'vertices': [{'x': 1045, 'y': 122},
#              {'x': 1053, 'y': 122},
#              {'x': 1053, 'y': 152},
#              {'x': 1045, 'y': 152}]},
#            'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#              'boundingBox': {'vertices': [{'x': 1045, 'y': 122},
#                {'x': 1053, 'y': 122},
#                {'x': 1053, 'y': 152},
#                {'x': 1045, 'y': 152}]},
#              'text': '剤',
#              'confidence': 0.99}],
#            'confidence': 0.99}],
#          'confidence': 0.98}],
#        'blockType': 'TEXT',
#        'confidence': 0.98}]}],
#    'text': '1\n【般】ベタメタゾン吉草酸エステル・ゲ\nンタマイシン硫酸塩軟膏\n亜鉛華軟膏\n(ミックス)\n(下腿)\n10 g\n10 g\n1調剤\n'}}]

# %%
text_dict["responses"][0]
# Out:
# {'textAnnotations': [{'locale': 'ja',
#    'description': '1\n【般】ベタメタゾン吉草酸エステル・ゲ\nンタマイシン硫酸塩軟膏\n亜鉛華軟膏\n(ミックス)\n(下腿)\n10 g\n10 g\n1調剤\n',
#    'boundingPoly': {'vertices': [{'x': 36, 'y': 3},
#      {'x': 1053, 'y': 3},
#      {'x': 1053, 'y': 152},
#      {'x': 36, 'y': 152}]}},
#   {'description': '1',
#    'boundingPoly': {'vertices': [{'x': 36, 'y': 10},
#      {'x': 41, 'y': 10},
#      {'x': 41, 'y': 30},
#      {'x': 36, 'y': 30}]}},
#   {'description': '【',
#    'boundingPoly': {'vertices': [{'x': 97, 'y': 3},
#      {'x': 106, 'y': 3},
#      {'x': 106, 'y': 38},
#      {'x': 97, 'y': 38}]}},
#   {'description': '般',
#    'boundingPoly': {'vertices': [{'x': 126, 'y': 3},
#      {'x': 135, 'y': 3},
#      {'x': 135, 'y': 38},
#      {'x': 126, 'y': 38}]}},
#   {'description': '】',
#    'boundingPoly': {'vertices': [{'x': 151, 'y': 4},
#      {'x': 160, 'y': 4},
#      {'x': 160, 'y': 39},
#      {'x': 151, 'y': 39}]}},
#   {'description': 'ベタメタゾン',
#    'boundingPoly': {'vertices': [{'x': 191, 'y': 4},
#      {'x': 386, 'y': 6},
#      {'x': 386, 'y': 42},
#      {'x': 191, 'y': 40}]}},
#   {'description': '吉草酸',
#    'boundingPoly': {'vertices': [{'x': 386, 'y': 6},
#      {'x': 492, 'y': 7},
#      {'x': 492, 'y': 43},
#      {'x': 386, 'y': 42}]}},
#   {'description': 'エステル',
#    'boundingPoly': {'vertices': [{'x': 492, 'y': 7},
#      {'x': 625, 'y': 8},
#      {'x': 625, 'y': 44},
#      {'x': 492, 'y': 43}]}},
#   {'description': '・',
#    'boundingPoly': {'vertices': [{'x': 633, 'y': 9},
#      {'x': 642, 'y': 9},
#      {'x': 642, 'y': 44},
#      {'x': 633, 'y': 44}]}},
#   {'description': 'ゲ',
#    'boundingPoly': {'vertices': [{'x': 669, 'y': 9},
#      {'x': 678, 'y': 9},
#      {'x': 678, 'y': 44},
#      {'x': 669, 'y': 44}]}},
#   {'description': 'ンタマイシン',
#    'boundingPoly': {'vertices': [{'x': 80, 'y': 31},
#      {'x': 280, 'y': 34},
#      {'x': 279, 'y': 66},
#      {'x': 80, 'y': 63}]}},
#   {'description': '硫酸',
#    'boundingPoly': {'vertices': [{'x': 292, 'y': 34},
#      {'x': 355, 'y': 35},
#      {'x': 355, 'y': 67},
#      {'x': 292, 'y': 66}]}},
#   {'description': '塩',
#    'boundingPoly': {'vertices': [{'x': 363, 'y': 36},
#      {'x': 371, 'y': 36},
#      {'x': 371, 'y': 67},
#      {'x': 363, 'y': 67}]}},
#   {'description': '軟膏',
#    'boundingPoly': {'vertices': [{'x': 397, 'y': 36},
#      {'x': 449, 'y': 37},
#      {'x': 449, 'y': 69},
#      {'x': 397, 'y': 68}]}},
#   {'description': '亜鉛',
#    'boundingPoly': {'vertices': [{'x': 75, 'y': 61},
#      {'x': 147, 'y': 62},
#      {'x': 147, 'y': 93},
#      {'x': 75, 'y': 92}]}},
#   {'description': '華',
#    'boundingPoly': {'vertices': [{'x': 158, 'y': 62},
#      {'x': 166, 'y': 62},
#      {'x': 166, 'y': 92},
#      {'x': 158, 'y': 92}]}},
#   {'description': '軟膏',
#    'boundingPoly': {'vertices': [{'x': 190, 'y': 62},
#      {'x': 245, 'y': 62},
#      {'x': 245, 'y': 92},
#      {'x': 190, 'y': 92}]}},
#   {'description': '(',
#    'boundingPoly': {'vertices': [{'x': 101, 'y': 88},
#      {'x': 109, 'y': 88},
#      {'x': 108, 'y': 120},
#      {'x': 100, 'y': 120}]}},
#   {'description': 'ミックス',
#    'boundingPoly': {'vertices': [{'x': 119, 'y': 88},
#      {'x': 248, 'y': 90},
#      {'x': 247, 'y': 123},
#      {'x': 118, 'y': 121}]}},
#   {'description': ')',
#    'boundingPoly': {'vertices': [{'x': 250, 'y': 91},
#      {'x': 258, 'y': 91},
#      {'x': 257, 'y': 123},
#      {'x': 249, 'y': 123}]}},
#   {'description': '(',
#    'boundingPoly': {'vertices': [{'x': 104, 'y': 118},
#      {'x': 112, 'y': 118},
#      {'x': 112, 'y': 148},
#      {'x': 104, 'y': 148}]}},
#   {'description': '下',
#    'boundingPoly': {'vertices': [{'x': 129, 'y': 118},
#      {'x': 137, 'y': 118},
#      {'x': 137, 'y': 148},
#      {'x': 129, 'y': 148}]}},
#   {'description': '腿',
#    'boundingPoly': {'vertices': [{'x': 163, 'y': 119},
#      {'x': 171, 'y': 119},
#      {'x': 171, 'y': 149},
#      {'x': 163, 'y': 149}]}},
#   {'description': ')',
#    'boundingPoly': {'vertices': [{'x': 182, 'y': 119},
#      {'x': 190, 'y': 119},
#      {'x': 190, 'y': 149},
#      {'x': 182, 'y': 149}]}},
#   {'description': '10',
#    'boundingPoly': {'vertices': [{'x': 823, 'y': 39},
#      {'x': 857, 'y': 41},
#      {'x': 855, 'y': 72},
#      {'x': 821, 'y': 70}]}},
#   {'description': 'g',
#    'boundingPoly': {'vertices': [{'x': 877, 'y': 42},
#      {'x': 885, 'y': 42},
#      {'x': 883, 'y': 73},
#      {'x': 875, 'y': 73}]}},
#   {'description': '10',
#    'boundingPoly': {'vertices': [{'x': 824, 'y': 68},
#      {'x': 858, 'y': 69},
#      {'x': 857, 'y': 97},
#      {'x': 823, 'y': 96}]}},
#   {'description': 'g',
#    'boundingPoly': {'vertices': [{'x': 878, 'y': 71},
#      {'x': 885, 'y': 71},
#      {'x': 884, 'y': 98},
#      {'x': 877, 'y': 98}]}},
#   {'description': '1',
#    'boundingPoly': {'vertices': [{'x': 976, 'y': 122},
#      {'x': 984, 'y': 122},
#      {'x': 984, 'y': 152},
#      {'x': 976, 'y': 152}]}},
#   {'description': '調',
#    'boundingPoly': {'vertices': [{'x': 1011, 'y': 122},
#      {'x': 1019, 'y': 122},
#      {'x': 1019, 'y': 152},
#      {'x': 1011, 'y': 152}]}},
#   {'description': '剤',
#    'boundingPoly': {'vertices': [{'x': 1045, 'y': 122},
#      {'x': 1053, 'y': 122},
#      {'x': 1053, 'y': 152},
#      {'x': 1045, 'y': 152}]}}],
#  'fullTextAnnotation': {'pages': [{'property': {'detectedLanguages': [{'languageCode': 'ja',
#        'confidence': 0.74},
#       {'languageCode': 'en', 'confidence': 0.06}]},
#     'width': 1080,
#     'height': 162,
#     'blocks': [{'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#         {'x': 41, 'y': 10},
#         {'x': 41, 'y': 30},
#         {'x': 36, 'y': 30}]},
#       'paragraphs': [{'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#           {'x': 41, 'y': 10},
#           {'x': 41, 'y': 30},
#           {'x': 36, 'y': 30}]},
#         'words': [{'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#             {'x': 41, 'y': 10},
#             {'x': 41, 'y': 30},
#             {'x': 36, 'y': 30}]},
#           'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#             'boundingBox': {'vertices': [{'x': 36, 'y': 10},
#               {'x': 41, 'y': 10},
#               {'x': 41, 'y': 30},
#               {'x': 36, 'y': 30}]},
#             'text': '1',
#             'confidence': 0.99}],
#           'confidence': 0.99}],
#         'confidence': 0.99}],
#       'blockType': 'TEXT',
#       'confidence': 0.99},
#      {'property': {'detectedLanguages': [{'languageCode': 'ja',
#          'confidence': 0.91}]},
#       'boundingBox': {'vertices': [{'x': 76, 'y': 2},
#         {'x': 678, 'y': 9},
#         {'x': 676, 'y': 155},
#         {'x': 74, 'y': 148}]},
#       'paragraphs': [{'property': {'detectedLanguages': [{'languageCode': 'ja',
#            'confidence': 0.91}]},
#         'boundingBox': {'vertices': [{'x': 76, 'y': 2},
#           {'x': 678, 'y': 9},
#           {'x': 676, 'y': 155},
#           {'x': 74, 'y': 148}]},
#         'words': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 97, 'y': 3},
#             {'x': 106, 'y': 3},
#             {'x': 106, 'y': 38},
#             {'x': 97, 'y': 38}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 97, 'y': 3},
#               {'x': 106, 'y': 3},
#               {'x': 106, 'y': 38},
#               {'x': 97, 'y': 38}]},
#             'text': '【',
#             'confidence': 0.99}],
#           'confidence': 0.99},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 126, 'y': 3},
#             {'x': 135, 'y': 3},
#             {'x': 135, 'y': 38},
#             {'x': 126, 'y': 38}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 126, 'y': 3},
#               {'x': 135, 'y': 3},
#               {'x': 135, 'y': 38},
#               {'x': 126, 'y': 38}]},
#             'text': '般',
#             'confidence': 0.97}],
#           'confidence': 0.97},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 151, 'y': 4},
#             {'x': 160, 'y': 4},
#             {'x': 160, 'y': 39},
#             {'x': 151, 'y': 39}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 151, 'y': 4},
#               {'x': 160, 'y': 4},
#               {'x': 160, 'y': 39},
#               {'x': 151, 'y': 39}]},
#             'text': '】',
#             'confidence': 1}],
#           'confidence': 1},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 191, 'y': 4},
#             {'x': 386, 'y': 6},
#             {'x': 386, 'y': 42},
#             {'x': 191, 'y': 40}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 191, 'y': 4},
#               {'x': 214, 'y': 4},
#               {'x': 214, 'y': 39},
#               {'x': 191, 'y': 39}]},
#             'text': 'ベ',
#             'confidence': 0.71},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 218, 'y': 5},
#               {'x': 244, 'y': 5},
#               {'x': 244, 'y': 40},
#               {'x': 218, 'y': 40}]},
#             'text': 'タ',
#             'confidence': 0.62},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 254, 'y': 5},
#               {'x': 281, 'y': 5},
#               {'x': 281, 'y': 40},
#               {'x': 254, 'y': 40}]},
#             'text': 'メ',
#             'confidence': 0.64},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 286, 'y': 5},
#               {'x': 313, 'y': 5},
#               {'x': 313, 'y': 40},
#               {'x': 286, 'y': 40}]},
#             'text': 'タ',
#             'confidence': 1},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 321, 'y': 6},
#               {'x': 350, 'y': 6},
#               {'x': 350, 'y': 41},
#               {'x': 321, 'y': 41}]},
#             'text': 'ゾ',
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 357, 'y': 6},
#               {'x': 386, 'y': 6},
#               {'x': 386, 'y': 41},
#               {'x': 357, 'y': 41}]},
#             'text': 'ン',
#             'confidence': 0.99}],
#           'confidence': 0.82},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 386, 'y': 6},
#             {'x': 492, 'y': 7},
#             {'x': 492, 'y': 43},
#             {'x': 386, 'y': 42}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 386, 'y': 6},
#               {'x': 414, 'y': 6},
#               {'x': 414, 'y': 41},
#               {'x': 386, 'y': 41}]},
#             'text': '吉',
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 421, 'y': 7},
#               {'x': 451, 'y': 7},
#               {'x': 451, 'y': 42},
#               {'x': 421, 'y': 42}]},
#             'text': '草',
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 460, 'y': 7},
#               {'x': 492, 'y': 7},
#               {'x': 492, 'y': 42},
#               {'x': 460, 'y': 42}]},
#             'text': '酸',
#             'confidence': 1}],
#           'confidence': 0.99},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 492, 'y': 7},
#             {'x': 625, 'y': 8},
#             {'x': 625, 'y': 44},
#             {'x': 492, 'y': 43}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 492, 'y': 7},
#               {'x': 518, 'y': 7},
#               {'x': 518, 'y': 42},
#               {'x': 492, 'y': 42}]},
#             'text': 'エ',
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 525, 'y': 8},
#               {'x': 550, 'y': 8},
#               {'x': 550, 'y': 43},
#               {'x': 525, 'y': 43}]},
#             'text': 'ス',
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 555, 'y': 8},
#               {'x': 584, 'y': 8},
#               {'x': 584, 'y': 43},
#               {'x': 555, 'y': 43}]},
#             'text': 'テ',
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 594, 'y': 8},
#               {'x': 625, 'y': 8},
#               {'x': 625, 'y': 43},
#               {'x': 594, 'y': 43}]},
#             'text': 'ル',
#             'confidence': 0.99}],
#           'confidence': 0.99},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 633, 'y': 9},
#             {'x': 642, 'y': 9},
#             {'x': 642, 'y': 44},
#             {'x': 633, 'y': 44}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 633, 'y': 9},
#               {'x': 642, 'y': 9},
#               {'x': 642, 'y': 44},
#               {'x': 633, 'y': 44}]},
#             'text': '・',
#             'confidence': 0.83}],
#           'confidence': 0.83},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 669, 'y': 9},
#             {'x': 678, 'y': 9},
#             {'x': 678, 'y': 44},
#             {'x': 669, 'y': 44}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#              'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#             'boundingBox': {'vertices': [{'x': 669, 'y': 9},
#               {'x': 678, 'y': 9},
#               {'x': 678, 'y': 44},
#               {'x': 669, 'y': 44}]},
#             'text': 'ゲ',
#             'confidence': 0.82}],
#           'confidence': 0.82},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 80, 'y': 31},
#             {'x': 280, 'y': 34},
#             {'x': 279, 'y': 66},
#             {'x': 80, 'y': 63}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 80, 'y': 31},
#               {'x': 109, 'y': 31},
#               {'x': 109, 'y': 62},
#               {'x': 80, 'y': 62}]},
#             'text': 'ン',
#             'confidence': 0.98},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 116, 'y': 32},
#               {'x': 144, 'y': 32},
#               {'x': 144, 'y': 63},
#               {'x': 116, 'y': 63}]},
#             'text': 'タ',
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 152, 'y': 32},
#               {'x': 178, 'y': 32},
#               {'x': 178, 'y': 63},
#               {'x': 152, 'y': 63}]},
#             'text': 'マ',
#             'confidence': 0.97},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 183, 'y': 33},
#               {'x': 211, 'y': 33},
#               {'x': 211, 'y': 64},
#               {'x': 183, 'y': 64}]},
#             'text': 'イ',
#             'confidence': 0.98},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 221, 'y': 34},
#               {'x': 249, 'y': 34},
#               {'x': 249, 'y': 65},
#               {'x': 221, 'y': 65}]},
#             'text': 'シ',
#             'confidence': 0.98},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 255, 'y': 34},
#               {'x': 280, 'y': 34},
#               {'x': 280, 'y': 65},
#               {'x': 255, 'y': 65}]},
#             'text': 'ン',
#             'confidence': 0.99}],
#           'confidence': 0.98},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 292, 'y': 34},
#             {'x': 355, 'y': 35},
#             {'x': 355, 'y': 67},
#             {'x': 292, 'y': 66}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 292, 'y': 35},
#               {'x': 320, 'y': 35},
#               {'x': 320, 'y': 66},
#               {'x': 292, 'y': 66}]},
#             'text': '硫',
#             'confidence': 0.98},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 327, 'y': 35},
#               {'x': 355, 'y': 35},
#               {'x': 355, 'y': 66},
#               {'x': 327, 'y': 66}]},
#             'text': '酸',
#             'confidence': 1}],
#           'confidence': 0.99},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 363, 'y': 36},
#             {'x': 371, 'y': 36},
#             {'x': 371, 'y': 67},
#             {'x': 363, 'y': 67}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 363, 'y': 36},
#               {'x': 371, 'y': 36},
#               {'x': 371, 'y': 67},
#               {'x': 363, 'y': 67}]},
#             'text': '塩',
#             'confidence': 0.99}],
#           'confidence': 0.99},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 397, 'y': 36},
#             {'x': 449, 'y': 37},
#             {'x': 449, 'y': 69},
#             {'x': 397, 'y': 68}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 397, 'y': 36},
#               {'x': 420, 'y': 36},
#               {'x': 420, 'y': 67},
#               {'x': 397, 'y': 67}]},
#             'text': '軟',
#             'confidence': 0.97},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#              'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#             'boundingBox': {'vertices': [{'x': 426, 'y': 37},
#               {'x': 449, 'y': 37},
#               {'x': 449, 'y': 68},
#               {'x': 426, 'y': 68}]},
#             'text': '膏',
#             'confidence': 1}],
#           'confidence': 0.98},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 75, 'y': 61},
#             {'x': 147, 'y': 62},
#             {'x': 147, 'y': 93},
#             {'x': 75, 'y': 92}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 75, 'y': 61},
#               {'x': 107, 'y': 61},
#               {'x': 107, 'y': 91},
#               {'x': 75, 'y': 91}]},
#             'text': '亜',
#             'confidence': 0.98},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 115, 'y': 62},
#               {'x': 147, 'y': 62},
#               {'x': 147, 'y': 92},
#               {'x': 115, 'y': 92}]},
#             'text': '鉛',
#             'confidence': 1}],
#           'confidence': 0.99},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 158, 'y': 62},
#             {'x': 166, 'y': 62},
#             {'x': 166, 'y': 92},
#             {'x': 158, 'y': 92}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 158, 'y': 62},
#               {'x': 166, 'y': 62},
#               {'x': 166, 'y': 92},
#               {'x': 158, 'y': 92}]},
#             'text': '華',
#             'confidence': 0.99}],
#           'confidence': 0.99},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 190, 'y': 62},
#             {'x': 245, 'y': 62},
#             {'x': 245, 'y': 92},
#             {'x': 190, 'y': 92}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 190, 'y': 62},
#               {'x': 214, 'y': 62},
#               {'x': 214, 'y': 92},
#               {'x': 190, 'y': 92}]},
#             'text': '軟',
#             'confidence': 1},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#              'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#             'boundingBox': {'vertices': [{'x': 221, 'y': 62},
#               {'x': 245, 'y': 62},
#               {'x': 245, 'y': 92},
#               {'x': 221, 'y': 92}]},
#             'text': '膏',
#             'confidence': 1}],
#           'confidence': 1},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 101, 'y': 88},
#             {'x': 109, 'y': 88},
#             {'x': 108, 'y': 120},
#             {'x': 100, 'y': 120}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 101, 'y': 88},
#               {'x': 109, 'y': 88},
#               {'x': 108, 'y': 120},
#               {'x': 100, 'y': 120}]},
#             'text': '(',
#             'confidence': 0.98}],
#           'confidence': 0.98},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 119, 'y': 88},
#             {'x': 248, 'y': 90},
#             {'x': 247, 'y': 123},
#             {'x': 118, 'y': 121}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 119, 'y': 89},
#               {'x': 145, 'y': 89},
#               {'x': 144, 'y': 121},
#               {'x': 118, 'y': 121}]},
#             'text': 'ミ',
#             'confidence': 0.98},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 153, 'y': 89},
#               {'x': 181, 'y': 89},
#               {'x': 180, 'y': 121},
#               {'x': 152, 'y': 121}]},
#             'text': 'ッ',
#             'confidence': 0.97},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 185, 'y': 90},
#               {'x': 211, 'y': 90},
#               {'x': 210, 'y': 122},
#               {'x': 184, 'y': 122}]},
#             'text': 'ク',
#             'confidence': 0.99},
#            {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#             'boundingBox': {'vertices': [{'x': 220, 'y': 90},
#               {'x': 248, 'y': 90},
#               {'x': 247, 'y': 122},
#               {'x': 219, 'y': 122}]},
#             'text': 'ス',
#             'confidence': 0.99}],
#           'confidence': 0.98},
#          {'property': {'detectedLanguages': [{'languageCode': 'ja'}]},
#           'boundingBox': {'vertices': [{'x': 250, 'y': 91},
#             {'x': 258, 'y': 91},
#             {'x': 257, 'y': 123},
#             {'x': 249, 'y': 123}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'ja'}],
#              'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#             'boundingBox': {'vertices': [{'x': 250, 'y': 91},
#               {'x': 258, 'y': 91},
#               {'x': 257, 'y': 123},
#               {'x': 249, 'y': 123}]},
#             'text': ')',
#             'confidence': 0.99}],
#           'confidence': 0.99},
#          {'boundingBox': {'vertices': [{'x': 104, 'y': 118},
#             {'x': 112, 'y': 118},
#             {'x': 112, 'y': 148},
#             {'x': 104, 'y': 148}]},
#           'symbols': [{'boundingBox': {'vertices': [{'x': 104, 'y': 118},
#               {'x': 112, 'y': 118},
#               {'x': 112, 'y': 148},
#               {'x': 104, 'y': 148}]},
#             'text': '(',
#             'confidence': 0.98}],
#           'confidence': 0.98},
#          {'boundingBox': {'vertices': [{'x': 129, 'y': 118},
#             {'x': 137, 'y': 118},
#             {'x': 137, 'y': 148},
#             {'x': 129, 'y': 148}]},
#           'symbols': [{'boundingBox': {'vertices': [{'x': 129, 'y': 118},
#               {'x': 137, 'y': 118},
#               {'x': 137, 'y': 148},
#               {'x': 129, 'y': 148}]},
#             'text': '下',
#             'confidence': 0.98}],
#           'confidence': 0.98},
#          {'boundingBox': {'vertices': [{'x': 163, 'y': 119},
#             {'x': 171, 'y': 119},
#             {'x': 171, 'y': 149},
#             {'x': 163, 'y': 149}]},
#           'symbols': [{'boundingBox': {'vertices': [{'x': 163, 'y': 119},
#               {'x': 171, 'y': 119},
#               {'x': 171, 'y': 149},
#               {'x': 163, 'y': 149}]},
#             'text': '腿',
#             'confidence': 0.91}],
#           'confidence': 0.91},
#          {'boundingBox': {'vertices': [{'x': 182, 'y': 119},
#             {'x': 190, 'y': 119},
#             {'x': 190, 'y': 149},
#             {'x': 182, 'y': 149}]},
#           'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#             'boundingBox': {'vertices': [{'x': 182, 'y': 119},
#               {'x': 190, 'y': 119},
#               {'x': 190, 'y': 149},
#               {'x': 182, 'y': 149}]},
#             'text': ')',
#             'confidence': 0.77}],
#           'confidence': 0.77}],
#         'confidence': 0.95}],
#       'blockType': 'TEXT',
#       'confidence': 0.95},
#      {'property': {'detectedLanguages': [{'languageCode': 'en',
#          'confidence': 0.5}]},
#       'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#         {'x': 886, 'y': 42},
#         {'x': 883, 'y': 99},
#         {'x': 820, 'y': 96}]},
#       'paragraphs': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#            'confidence': 0.5}]},
#         'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#           {'x': 886, 'y': 42},
#           {'x': 883, 'y': 99},
#           {'x': 820, 'y': 96}]},
#         'words': [{'property': {'detectedLanguages': [{'languageCode': 'en'}]},
#           'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#             {'x': 857, 'y': 41},
#             {'x': 855, 'y': 72},
#             {'x': 821, 'y': 70}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'en'}]},
#             'boundingBox': {'vertices': [{'x': 823, 'y': 39},
#               {'x': 838, 'y': 40},
#               {'x': 836, 'y': 71},
#               {'x': 821, 'y': 70}]},
#             'text': '1',
#             'confidence': 0.96},
#            {'property': {'detectedLanguages': [{'languageCode': 'en'}],
#              'detectedBreak': {'type': 'SPACE'}},
#             'boundingBox': {'vertices': [{'x': 842, 'y': 40},
#               {'x': 857, 'y': 41},
#               {'x': 855, 'y': 72},
#               {'x': 840, 'y': 71}]},
#             'text': '0',
#             'confidence': 0.99}],
#           'confidence': 0.97},
#          {'property': {'detectedLanguages': [{'languageCode': 'en'}]},
#           'boundingBox': {'vertices': [{'x': 877, 'y': 42},
#             {'x': 885, 'y': 42},
#             {'x': 883, 'y': 73},
#             {'x': 875, 'y': 73}]},
#           'symbols': [{'property': {'detectedLanguages': [{'languageCode': 'en'}],
#              'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#             'boundingBox': {'vertices': [{'x': 877, 'y': 42},
#               {'x': 885, 'y': 42},
#               {'x': 883, 'y': 73},
#               {'x': 875, 'y': 73}]},
#             'text': 'g',
#             'confidence': 0.99}],
#           'confidence': 0.99},
#          {'boundingBox': {'vertices': [{'x': 824, 'y': 68},
#             {'x': 858, 'y': 69},
#             {'x': 857, 'y': 97},
#             {'x': 823, 'y': 96}]},
#           'symbols': [{'boundingBox': {'vertices': [{'x': 824, 'y': 69},
#               {'x': 839, 'y': 70},
#               {'x': 838, 'y': 97},
#               {'x': 823, 'y': 96}]},
#             'text': '1',
#             'confidence': 0.99},
#            {'property': {'detectedBreak': {'type': 'SPACE'}},
#             'boundingBox': {'vertices': [{'x': 843, 'y': 69},
#               {'x': 858, 'y': 70},
#               {'x': 857, 'y': 97},
#               {'x': 842, 'y': 96}]},
#             'text': '0',
#             'confidence': 0.99}],
#           'confidence': 0.99},
#          {'boundingBox': {'vertices': [{'x': 878, 'y': 71},
#             {'x': 885, 'y': 71},
#             {'x': 884, 'y': 98},
#             {'x': 877, 'y': 98}]},
#           'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#             'boundingBox': {'vertices': [{'x': 878, 'y': 71},
#               {'x': 885, 'y': 71},
#               {'x': 884, 'y': 98},
#               {'x': 877, 'y': 98}]},
#             'text': 'g',
#             'confidence': 0.97}],
#           'confidence': 0.97}],
#         'confidence': 0.98}],
#       'blockType': 'TEXT',
#       'confidence': 0.98},
#      {'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#         {'x': 1053, 'y': 122},
#         {'x': 1053, 'y': 152},
#         {'x': 976, 'y': 152}]},
#       'paragraphs': [{'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#           {'x': 1053, 'y': 122},
#           {'x': 1053, 'y': 152},
#           {'x': 976, 'y': 152}]},
#         'words': [{'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#             {'x': 984, 'y': 122},
#             {'x': 984, 'y': 152},
#             {'x': 976, 'y': 152}]},
#           'symbols': [{'boundingBox': {'vertices': [{'x': 976, 'y': 122},
#               {'x': 984, 'y': 122},
#               {'x': 984, 'y': 152},
#               {'x': 976, 'y': 152}]},
#             'text': '1',
#             'confidence': 0.98}],
#           'confidence': 0.98},
#          {'boundingBox': {'vertices': [{'x': 1011, 'y': 122},
#             {'x': 1019, 'y': 122},
#             {'x': 1019, 'y': 152},
#             {'x': 1011, 'y': 152}]},
#           'symbols': [{'boundingBox': {'vertices': [{'x': 1011, 'y': 122},
#               {'x': 1019, 'y': 122},
#               {'x': 1019, 'y': 152},
#               {'x': 1011, 'y': 152}]},
#             'text': '調',
#             'confidence': 0.97}],
#           'confidence': 0.97},
#          {'boundingBox': {'vertices': [{'x': 1045, 'y': 122},
#             {'x': 1053, 'y': 122},
#             {'x': 1053, 'y': 152},
#             {'x': 1045, 'y': 152}]},
#           'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#             'boundingBox': {'vertices': [{'x': 1045, 'y': 122},
#               {'x': 1053, 'y': 122},
#               {'x': 1053, 'y': 152},
#               {'x': 1045, 'y': 152}]},
#             'text': '剤',
#             'confidence': 0.99}],
#           'confidence': 0.99}],
#         'confidence': 0.98}],
#       'blockType': 'TEXT',
#       'confidence': 0.98}]}],
#   'text': '1\n【般】ベタメタゾン吉草酸エステル・ゲ\nンタマイシン硫酸塩軟膏\n亜鉛華軟膏\n(ミックス)\n(下腿)\n10 g\n10 g\n1調剤\n'}}

# %%
text_dict["responses"][0]["textAnnotations"]
# Out:
# [{'locale': 'ja',
#   'description': '1\n【般】ベタメタゾン吉草酸エステル・ゲ\nンタマイシン硫酸塩軟膏\n亜鉛華軟膏\n(ミックス)\n(下腿)\n10 g\n10 g\n1調剤\n',
#   'boundingPoly': {'vertices': [{'x': 36, 'y': 3},
#     {'x': 1053, 'y': 3},
#     {'x': 1053, 'y': 152},
#     {'x': 36, 'y': 152}]}},
#  {'description': '1',
#   'boundingPoly': {'vertices': [{'x': 36, 'y': 10},
#     {'x': 41, 'y': 10},
#     {'x': 41, 'y': 30},
#     {'x': 36, 'y': 30}]}},
#  {'description': '【',
#   'boundingPoly': {'vertices': [{'x': 97, 'y': 3},
#     {'x': 106, 'y': 3},
#     {'x': 106, 'y': 38},
#     {'x': 97, 'y': 38}]}},
#  {'description': '般',
#   'boundingPoly': {'vertices': [{'x': 126, 'y': 3},
#     {'x': 135, 'y': 3},
#     {'x': 135, 'y': 38},
#     {'x': 126, 'y': 38}]}},
#  {'description': '】',
#   'boundingPoly': {'vertices': [{'x': 151, 'y': 4},
#     {'x': 160, 'y': 4},
#     {'x': 160, 'y': 39},
#     {'x': 151, 'y': 39}]}},
#  {'description': 'ベタメタゾン',
#   'boundingPoly': {'vertices': [{'x': 191, 'y': 4},
#     {'x': 386, 'y': 6},
#     {'x': 386, 'y': 42},
#     {'x': 191, 'y': 40}]}},
#  {'description': '吉草酸',
#   'boundingPoly': {'vertices': [{'x': 386, 'y': 6},
#     {'x': 492, 'y': 7},
#     {'x': 492, 'y': 43},
#     {'x': 386, 'y': 42}]}},
#  {'description': 'エステル',
#   'boundingPoly': {'vertices': [{'x': 492, 'y': 7},
#     {'x': 625, 'y': 8},
#     {'x': 625, 'y': 44},
#     {'x': 492, 'y': 43}]}},
#  {'description': '・',
#   'boundingPoly': {'vertices': [{'x': 633, 'y': 9},
#     {'x': 642, 'y': 9},
#     {'x': 642, 'y': 44},
#     {'x': 633, 'y': 44}]}},
#  {'description': 'ゲ',
#   'boundingPoly': {'vertices': [{'x': 669, 'y': 9},
#     {'x': 678, 'y': 9},
#     {'x': 678, 'y': 44},
#     {'x': 669, 'y': 44}]}},
#  {'description': 'ンタマイシン',
#   'boundingPoly': {'vertices': [{'x': 80, 'y': 31},
#     {'x': 280, 'y': 34},
#     {'x': 279, 'y': 66},
#     {'x': 80, 'y': 63}]}},
#  {'description': '硫酸',
#   'boundingPoly': {'vertices': [{'x': 292, 'y': 34},
#     {'x': 355, 'y': 35},
#     {'x': 355, 'y': 67},
#     {'x': 292, 'y': 66}]}},
#  {'description': '塩',
#   'boundingPoly': {'vertices': [{'x': 363, 'y': 36},
#     {'x': 371, 'y': 36},
#     {'x': 371, 'y': 67},
#     {'x': 363, 'y': 67}]}},
#  {'description': '軟膏',
#   'boundingPoly': {'vertices': [{'x': 397, 'y': 36},
#     {'x': 449, 'y': 37},
#     {'x': 449, 'y': 69},
#     {'x': 397, 'y': 68}]}},
#  {'description': '亜鉛',
#   'boundingPoly': {'vertices': [{'x': 75, 'y': 61},
#     {'x': 147, 'y': 62},
#     {'x': 147, 'y': 93},
#     {'x': 75, 'y': 92}]}},
#  {'description': '華',
#   'boundingPoly': {'vertices': [{'x': 158, 'y': 62},
#     {'x': 166, 'y': 62},
#     {'x': 166, 'y': 92},
#     {'x': 158, 'y': 92}]}},
#  {'description': '軟膏',
#   'boundingPoly': {'vertices': [{'x': 190, 'y': 62},
#     {'x': 245, 'y': 62},
#     {'x': 245, 'y': 92},
#     {'x': 190, 'y': 92}]}},
#  {'description': '(',
#   'boundingPoly': {'vertices': [{'x': 101, 'y': 88},
#     {'x': 109, 'y': 88},
#     {'x': 108, 'y': 120},
#     {'x': 100, 'y': 120}]}},
#  {'description': 'ミックス',
#   'boundingPoly': {'vertices': [{'x': 119, 'y': 88},
#     {'x': 248, 'y': 90},
#     {'x': 247, 'y': 123},
#     {'x': 118, 'y': 121}]}},
#  {'description': ')',
#   'boundingPoly': {'vertices': [{'x': 250, 'y': 91},
#     {'x': 258, 'y': 91},
#     {'x': 257, 'y': 123},
#     {'x': 249, 'y': 123}]}},
#  {'description': '(',
#   'boundingPoly': {'vertices': [{'x': 104, 'y': 118},
#     {'x': 112, 'y': 118},
#     {'x': 112, 'y': 148},
#     {'x': 104, 'y': 148}]}},
#  {'description': '下',
#   'boundingPoly': {'vertices': [{'x': 129, 'y': 118},
#     {'x': 137, 'y': 118},
#     {'x': 137, 'y': 148},
#     {'x': 129, 'y': 148}]}},
#  {'description': '腿',
#   'boundingPoly': {'vertices': [{'x': 163, 'y': 119},
#     {'x': 171, 'y': 119},
#     {'x': 171, 'y': 149},
#     {'x': 163, 'y': 149}]}},
#  {'description': ')',
#   'boundingPoly': {'vertices': [{'x': 182, 'y': 119},
#     {'x': 190, 'y': 119},
#     {'x': 190, 'y': 149},
#     {'x': 182, 'y': 149}]}},
#  {'description': '10',
#   'boundingPoly': {'vertices': [{'x': 823, 'y': 39},
#     {'x': 857, 'y': 41},
#     {'x': 855, 'y': 72},
#     {'x': 821, 'y': 70}]}},
#  {'description': 'g',
#   'boundingPoly': {'vertices': [{'x': 877, 'y': 42},
#     {'x': 885, 'y': 42},
#     {'x': 883, 'y': 73},
#     {'x': 875, 'y': 73}]}},
#  {'description': '10',
#   'boundingPoly': {'vertices': [{'x': 824, 'y': 68},
#     {'x': 858, 'y': 69},
#     {'x': 857, 'y': 97},
#     {'x': 823, 'y': 96}]}},
#  {'description': 'g',
#   'boundingPoly': {'vertices': [{'x': 878, 'y': 71},
#     {'x': 885, 'y': 71},
#     {'x': 884, 'y': 98},
#     {'x': 877, 'y': 98}]}},
#  {'description': '1',
#   'boundingPoly': {'vertices': [{'x': 976, 'y': 122},
#     {'x': 984, 'y': 122},
#     {'x': 984, 'y': 152},
#     {'x': 976, 'y': 152}]}},
#  {'description': '調',
#   'boundingPoly': {'vertices': [{'x': 1011, 'y': 122},
#     {'x': 1019, 'y': 122},
#     {'x': 1019, 'y': 152},
#     {'x': 1011, 'y': 152}]}},
#  {'description': '剤',
#   'boundingPoly': {'vertices': [{'x': 1045, 'y': 122},
#     {'x': 1053, 'y': 122},
#     {'x': 1053, 'y': 152},
#     {'x': 1045, 'y': 152}]}}]

# %%
len(text_dict["responses"][0]["textAnnotations"])
# Out:
# 31

# %%
text_dict["responses"][0]["textAnnotations"][1]
# Out:
# {'description': '1',
#  'boundingPoly': {'vertices': [{'x': 36, 'y': 10},
#    {'x': 41, 'y': 10},
#    {'x': 41, 'y': 30},
#    {'x': 36, 'y': 30}]}}

# %%
text_dict["responses"][0]["textAnnotations"][2]
# Out:
# {'description': '【',
#  'boundingPoly': {'vertices': [{'x': 97, 'y': 3},
#    {'x': 106, 'y': 3},
#    {'x': 106, 'y': 38},
#    {'x': 97, 'y': 38}]}}

# %%
text_dict["responses"][0]["textAnnotations"][3]
# Out:
# {'description': '般',
#  'boundingPoly': {'vertices': [{'x': 126, 'y': 3},
#    {'x': 135, 'y': 3},
#    {'x': 135, 'y': 38},
#    {'x': 126, 'y': 38}]}}

# %%
word_list=text_dict["responses"][0]["textAnnotations"][0]["description"].split("\n")

# %%
print(word_list[1])
len(word_list[1])
# Out:
# 【般】ベタメタゾン吉草酸エステル・ゲ
# 18

# %%
for i in range

# %%
word_list
# Out:
# ['1',
#  '【般】ベタメタゾン吉草酸エステル・ゲ',
#  'ンタマイシン硫酸塩軟膏',
#  '亜鉛華軟膏',
#  '(ミックス)',
#  '(下腿)',
#  '10 g',
#  '10 g',
#  '1調剤',
#  '']

# %%
len(word_list[6])
# Out:
# 4

# %%
text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["x"]
# Out:
# 36

# %%
for i in range(1,31):
    print(text_dict["responses"][0]["textAnnotations"][i]["description"])
    print("-------------------------------------")
# Out:
# 1
# -------------------------------------
# 【
# -------------------------------------
# 般
# -------------------------------------
# 】
# -------------------------------------
# ベタメタゾン
# -------------------------------------
# 吉草酸
# -------------------------------------
# エステル
# -------------------------------------
# ・
# -------------------------------------
# ゲ
# -------------------------------------
# ンタマイシン
# -------------------------------------
# 硫酸
# -------------------------------------
# 塩
# -------------------------------------
# 軟膏
# -------------------------------------
# 亜鉛
# -------------------------------------
# 華
# -------------------------------------
# 軟膏
# -------------------------------------
# (
# -------------------------------------
# ミックス
# -------------------------------------
# )
# -------------------------------------
# (
# -------------------------------------
# 下
# -------------------------------------
# 腿
# -------------------------------------
# )
# -------------------------------------
# 10
# -------------------------------------
# g
# -------------------------------------
# 10
# -------------------------------------
# g
# -------------------------------------
# 1
# -------------------------------------
# 調
# -------------------------------------
# 剤
# -------------------------------------

# %%
text_dict["responses"][0]["textAnnotations"][30]["description"]
# Out:
# '剤'

# %%
# info_list
# word_dic={"word":,"place"}
len_sum=0
now_num=0
# left_bottom_x=[]
# left_bottom_y=[]
# left_top_x=[]
# left_top_y=[]
# right_bottom_x=[]
# right_bottom_y=[]
# right_top_x=[]
# right_top_y=[]
left=[]
right=[]
top=[]
bottom=[]
dic_list=[]

for i in range(1,31):
    len_sum+=len(text_dict["responses"][0]["textAnnotations"][i]["description"].replace(" ",""))
    left.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["x"])
    right.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][1]["x"])
    right.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][2]["x"])
    left.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][3]["x"])
    
    bottom.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["y"])
    bottom.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][1]["y"])
    top.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][2]["y"])
    top.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][3]["y"])
#     print("len_sum:"+str(len_sum))
#     print("word_list:"+str(len(word_list[now_num].replace(" ",""))))
    print(text_dict["responses"][0]["textAnnotations"][i]["description"])
    if len_sum==len(word_list[now_num].replace(" ","")):
        len_sum=0
        print("word:   "+word_list[now_num])
        dic={"word":word_list[now_num],"文字の縦幅":mode_average(top)-mode_average(bottom),"x":round(mode_average(left)+mode_average(right)),"y":round(mode_average(top)+mode_average(bottom))}
        dic_list.append(dic)
        now_num+=1
        print(mode_average(left))
        print("-------")
        print(mode_average(right))
        print("-------")
        print(mode_average(bottom))
        print("-------")
        print(mode_average(top))
        print(dic)
        print("------------------------------------------------------")
        left=[]
        right=[]
        top=[]
        bottom=[]
#     print(text_dict["responses"][0]["textAnnotations"][i]["description"])
#     print(len(text_dict["responses"][0]["textAnnotations"][i]["description"]))
#     print("-------------------")
# Out:
# 1
# word:   1
# 36
# -------
# 41
# -------
# 10
# -------
# 30
# {'word': '1', '文字の縦幅': 20, 'x': 77, 'y': 40}
# ------------------------------------------------------
# 【
# 般
# 】
# ベタメタゾン
# 吉草酸
# エステル
# ・
# ゲ
# word:   【般】ベタメタゾン吉草酸エステル・ゲ
# 343
# -------
# 403
# -------
# 6
# -------
# 44
# {'word': '【般】ベタメタゾン吉草酸エステル・ゲ', '文字の縦幅': 38, 'x': 746, 'y': 50}
# ------------------------------------------------------
# ンタマイシン
# 硫酸
# 塩
# 軟膏
# word:   ンタマイシン硫酸塩軟膏
# 283
# -------
# 364
# -------
# 36
# -------
# 67
# {'word': 'ンタマイシン硫酸塩軟膏', '文字の縦幅': 31, 'x': 647, 'y': 103}
# ------------------------------------------------------
# 亜鉛
# 華
# 軟膏
# word:   亜鉛華軟膏
# 141
# -------
# 186
# -------
# 62
# -------
# 92
# {'word': '亜鉛華軟膏', '文字の縦幅': 30, 'x': 327, 'y': 154}
# ------------------------------------------------------
# (
# ミックス
# )
# word:   (ミックス)
# 156
# -------
# 204
# -------
# 88
# -------
# 123
# {'word': '(ミックス)', '文字の縦幅': 35, 'x': 360, 'y': 211}
# ------------------------------------------------------
# (
# 下
# 腿
# )
# word:   (下腿)
# 144
# -------
# 152
# -------
# 118
# -------
# 148
# {'word': '(下腿)', '文字の縦幅': 30, 'x': 296, 'y': 266}
# ------------------------------------------------------
# 10
# g
# word:   10 g
# 849
# -------
# 870
# -------
# 42
# -------
# 73
# {'word': '10 g', '文字の縦幅': 31, 'x': 1719, 'y': 115}
# ------------------------------------------------------
# 10
# g
# word:   10 g
# 850
# -------
# 871
# -------
# 71
# -------
# 98
# {'word': '10 g', '文字の縦幅': 27, 'x': 1721, 'y': 169}
# ------------------------------------------------------
# 1
# 調
# 剤
# word:   1調剤
# 1011
# -------
# 1019
# -------
# 122
# -------
# 152
# {'word': '1調剤', '文字の縦幅': 30, 'x': 2030, 'y': 274}
# ------------------------------------------------------

# %%
dic_list
# Out:
# [{'word': '1', '文字の縦幅': 20, 'x': 77, 'y': 40},
#  {'word': '【般】ベタメタゾン吉草酸エステル・ゲ', '文字の縦幅': 38, 'x': 746, 'y': 50},
#  {'word': 'ンタマイシン硫酸塩軟膏', '文字の縦幅': 31, 'x': 647, 'y': 103},
#  {'word': '亜鉛華軟膏', '文字の縦幅': 30, 'x': 327, 'y': 154},
#  {'word': '(ミックス)', '文字の縦幅': 35, 'x': 360, 'y': 211},
#  {'word': '(下腿)', '文字の縦幅': 30, 'x': 296, 'y': 266},
#  {'word': '10 g', '文字の縦幅': 31, 'x': 1719, 'y': 115},
#  {'word': '10 g', '文字の縦幅': 27, 'x': 1721, 'y': 169},
#  {'word': '1調剤', '文字の縦幅': 30, 'x': 2030, 'y': 274}]

# %%
df = pd.DataFrame(dic_list)
df=df.sort_values('y')
df.reset_index()
tate_mean=df["文字の縦幅"].mean()

# %%
df
# Out:
#                  word  文字の縦幅     x    y
# 0                   1     20    77   40
# 1  【般】ベタメタゾン吉草酸エステル・ゲ     38   746   50
# 2         ンタマイシン硫酸塩軟膏     31   647  103
# 6                10 g     31  1719  115
# 3               亜鉛華軟膏     30   327  154
# 7                10 g     27  1721  169
# 4              (ミックス)     35   360  211
# 5                (下腿)     30   296  266
# 8                 1調剤     30  2030  274

# %%
diff_list=df["y"].diff()

a_=0
y_list=[]
for a,b in zip(df["y"],diff_list):
    #print(a,b)
    if b<30:
        a=a_
    a_=a
    y_list.append(a)

# %%
df["diff"]=diff_list
df.loc[0,"diff"]=0
df["y"]=y_list

# %%
df.sort_values(["y","x"])
# Out:
#                  word  文字の縦幅     x    y  diff
# 0                   1     20    77   40   0.0
# 1  【般】ベタメタゾン吉草酸エステル・ゲ     38   746   40  10.0
# 2         ンタマイシン硫酸塩軟膏     31   647  103  53.0
# 6                10 g     31  1719  103  12.0
# 3               亜鉛華軟膏     30   327  154  39.0
# 7                10 g     27  1721  154  15.0
# 4              (ミックス)     35   360  211  42.0
# 5                (下腿)     30   296  266  55.0
# 8                 1調剤     30  2030  266   8.0

# %%
grouped_df = df.groupby('y')
grouped_list = [grouped_df["word"].get_group(word) for word in grouped_df.groups]

# %%
list(grouped_list[1])
# Out:
# ['ンタマイシン硫酸塩軟膏', '10 g']

# %%
list(df["y"].diff())
# Out:
# [nan, 10.0, 53.0, 12.0, 39.0, 15.0, 42.0, 55.0, 8.0]

# %%
a_=0
y_list=[]
for a,b in zip(df["y"],list(df["y"].diff())):
    #print(a,b)
    if b<30:
        a=a_
    a_=a
    y_list.append(a)

# %%
df.loc[0,"diff"]=0
df["y"]=y_list

# %%
for i in range(1,len(df)):
    if df.loc[i,"diff"]<tate_mean:
        df_copy=df.copy()
        y_value=df_copy.loc[i-1,"y"]
        df.loc[i,"y"]=y_value

# %%
df
# Out:
#                  word  文字の縦幅     x    y  diff
# 0                   1     20    77   40   0.0
# 1  【般】ベタメタゾン吉草酸エステル・ゲ     38   746   40   NaN
# 2         ンタマイシン硫酸塩軟膏     31   647  103   NaN
# 6                10 g     31  1719  103   NaN
# 3               亜鉛華軟膏     30   327  154   NaN
# 7                10 g     27  1721  154   NaN
# 4              (ミックス)     35   360  211   NaN
# 5                (下腿)     30   296  266   NaN
# 8                 1調剤     30  2030  266   NaN

# %%
y=0

for index, row in df.iterrows():
    if row["diff"]<tate_mean:
        row["diff"]
# Out:
#                  word  文字の縦幅     x    y  diff
# 0                   1     20    77   40   NaN
# 1  【般】ベタメタゾン吉草酸エステル・ゲ     38   746   50  10.0
# 2         ンタマイシン硫酸塩軟膏     31   647  103  53.0
# 6                10 g     31  1719  115  12.0
# 3               亜鉛華軟膏     30   327  154  39.0
# 7                10 g     27  1721  169  15.0
# 4              (ミックス)     35   360  211  42.0
# 5                (下腿)     30   296  266  55.0
# 8                 1調剤     30  2030  274   8.0

# %%
def mode_average(nums):
    try:
        return mode(nums)
    except:
        if len(nums)!=0:
            return round(sum(nums) / len(nums))
        else:
            return nums[0]

# %%
obj_response.text
# Out:
# '{\n  "responses": [\n    {\n      "textAnnotations": [\n        {\n          "locale": "ja",\n          "description": "1\\n【般】ベタメタゾン吉草酸エステル・ゲ\\nンタマイシン硫酸塩軟膏\\n亜鉛華軟膏\\n(ミックス)\\n(下腿)\\n10 g\\n10 g\\n1調剤\\n",\n          "boundingPoly": {\n            "vertices": [\n              {\n                "x": 36,\n                "y": 3\n              },\n              {\n                "x": 1053,\n                "y": 3\n              },\n              {\n                "x": 1053,\n                "y": 152\n              },\n              {\n                "x": 36,\n                "y": 152\n              }\n            ]\n          }\n        },\n        {\n          "description": "1",\n          "boundingPoly": {\n            "vertices": [\n              {\n                "x": 36,\n                "y": 10\n              },\n              {\n                "x": 41,\n                "y": 10\n              },\n              {\n                "x": 41,\n                "y": 30\n              },\n              {\n                "x": 36,\n                "y": 30\n              }\n            ]\n          }\n        },\n        {\n          "description": "【",\n          "boundingPoly": {\n            "vertices": [\n              {\n                "x": 97,\n                "y": 3\n              },\n              {\n                "x": 106,\n                "y": 3\n              },\n              {\n                "x": 106,\n                "y": 38\n              },\n              {\n                "x": 97,\n                "y": 38\n              }\n            ]\n          }\n        },\n        {\n          "description": "般",\n          "boundingPoly": {\n            "vertices": [\n              {\n                "x": 126,\n                "y": 3\n              },\n              {\n                "x": 135,\n                "y": 3\n              },\n              {\n                "x": 135,\n                "y": 38\n              },\n              {\n                "x": 126,\n                "y": 38\n              }\n            ]\n          }\n        },\n        {\n          "description": "】",\n          "boundingPoly": {\n            "vertices": [\n              {\n                "x": 151,\n                "y": 4\n              },\n              {\n                "x": 160,\n                "y": 4\n              },\n              {\n                "x": 160,\n                "y": 39\n              },\n              {\n                "x": 151,\n                "y": 39\n              }\n            ]\n          }\n        },\n        {\n          "description": "ベタメタゾン",\n          "boundingPoly": {\n            "vertices": [\n              {\n                "x": 191,\n                "y": 4\n              },\n              {\n                "x": 386,\n                "y": 6\n              },\n              {\n                "x": 386,\n                "y": 42\n              },\n              {\n                "x": 191,\n                "y": 40\n              }\n            ]\n          }\n        },\n        {\n          "description": "吉草酸",\n          "boundingPoly": {\n            "vertices": [\n              {\n                "x": 386,\n                "y": 6\n              },\n              {\n                "x": 492,\n                "y": 7\n              },\n              {\n                "x": 492,\n                "y": 43\n              },\n              {\n                "x": 386,\n                "y": 42\n              }\n            ]\n          }\n        },\n        {\n          "description": "エステル",\n          "boundingPoly": {\n            "vertices": [\n              {\n                "x": 492,\n                "y": 7\n              },\n              {\n                "x": 625,\n                "y": 8\n              },\n              {\n                "x": 625,\n                "y": 44\n              },\n              {\n                "x": 492,\n                "y": 43\n              }\n   ...

# %%
document = obj_response.text
img = Image.open("/Users/obara/Downloads/prescription_data_jpeg/photo-13.jpeg")
img_symbol = img.copy()
for page in document.pages:
    for block in page.blocks:
        for paragraph in block.paragraphs:
            for word in paragraph.words:
                for symbol in word.symbols:
                    bounding_box = symbol.bounding_box
                    xmin = bounding_box.vertices[0].x
                    ymin = bounding_box.vertices[0].y
                    xmax = bounding_box.vertices[2].x
                    ymax = bounding_box.vertices[2].y
                    cv2.rectangle(img_symbol, (xmin, ymin), (xmax, ymax), (0, 255, 0), thickness=1, lineType=cv2.LINE_AA)
plt.figure(figsize=[10,10])
plt.imshow(img_symbol[:,:,::-1]);plt.title("img_symbol")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-296c749fa07b> in <module>
#       2 img = Image.open("/Users/obara/Downloads/prescription_data_jpeg/photo-13.jpeg")
#       3 img_symbol = img.copy()
# ----> 4 for page in document.pages:
#       5     for block in page.blocks:
#       6         for paragraph in block.paragraphs:
#
# AttributeError: 'str' object has no attribute 'pages'
