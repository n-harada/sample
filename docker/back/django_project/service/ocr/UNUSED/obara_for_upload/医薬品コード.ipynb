# %%
import pickle

# %%
# %cd ..
# Out:
# /Users/obara/work/prescription

# %%
with open('df_medicineInfo.pickle', 'rb') as f:
    df_medicineInfo = pickle.load(f)
df_medicineInfo = df_medicineInfo.rename(columns={'name':'品名'})

# %%
for i in df_medicineInfo["4_YJコード"]:
    if i==None:
        print(i)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
with open('dict_branded2GE.pickle','rb') as f:
    dict_branded2GE = pickle.load(f)

# %%
dict_branded2GE
# Out:
# {'ビアサン': ['重散'],
#  'ビットサン': ['重散'],
#  'レキソタン錠1 1mg': ['セニラン細粒1%',
#   'ブロマゼパム1%細粒',
#   'ブロマゼパム細粒1%「サンド」',
#   'セニラン錠2mg',
#   'セニラン錠3mg',
#   'セニラン錠5mg',
#   'ブロマゼパム2mg錠',
#   'ブロマゼパム3mg錠',
#   'ブロマゼパム5mg錠',
#   'ブロマゼパム錠2mg「サンド」',
#   'ブロマゼパム錠3mg「サンド」',
#   'ブロマゼパム錠5mg「サンド」'],
#  'レキソタン錠2 2mg': ['セニラン錠2mg',
#   'ブロマゼパム2mg錠',
#   'ブロマゼパム錠2mg「サンド」',
#   'セニラン錠3mg',
#   'セニラン錠5mg',
#   'ブロマゼパム3mg錠',
#   'ブロマゼパム5mg錠',
#   'セニラン細粒1%',
#   'ブロマゼパム1%細粒',
#   'ブロマゼパム錠3mg「サンド」',
#   'ブロマゼパム錠5mg「サンド」',
#   'ブロマゼパム細粒1%「サンド」'],
#  'レキソタン錠5 5mg': ['セニラン錠5mg',
#   'ブロマゼパム5mg錠',
#   'ブロマゼパム錠5mg「サンド」',
#   'セニラン錠2mg',
#   'セニラン錠3mg',
#   'ブロマゼパム2mg錠',
#   'ブロマゼパム3mg錠',
#   'セニラン細粒1%',
#   'ブロマゼパム1%細粒',
#   'ブロマゼパム錠2mg「サンド」',
#   'ブロマゼパム錠3mg「サンド」',
#   'ブロマゼパム細粒1%「サンド」'],
#  'レキソタン細粒1%': ['セニラン細粒1%',
#   'ブロマゼパム1%細粒',
#   'ブロマゼパム細粒1%「サンド」',
#   'セニラン錠2mg',
#   'セニラン錠3mg',
#   'セニラン錠5mg',
#   'ブロマゼパム2mg錠',
#   'ブロマゼパム3mg錠',
#   'ブロマゼパム5mg錠',
#   'ブロマゼパム錠2mg「サンド」',
#   'ブロマゼパム錠3mg「サンド」',
# ...
