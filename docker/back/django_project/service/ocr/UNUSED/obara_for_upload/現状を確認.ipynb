# %% [markdown]
# # 準備

# %%
import pickle

# %%
#

# %%
import pickle
with open('ocr_result.pickle', 'rb') as web:
    df = pickle.load(web)

# %%
df
# Out:
#           file_name                                     result(10,0,4)  \
# 0      photo-2.jpeg  [[P. 1], [処, 方, 箋, O], [7977], [(この処方箋は、どの保険薬局...
# 1     photo-35.jpeg              [[Date], [x], [A, 14], [tre, A], [S]]
# 2     photo-40.jpeg  [[内服1日量, 外来処方箋, 1 / 1], [(この処方箋はどの保険薬局でも有効です)]...
# 3     photo-85.jpeg  [[処, 方, 箋, P. 1], [2620, (この処方箋は、どの保険薬局でも有効です。...
# 4     photo-93.jpeg  [[P. 1], [処, 方, 箋], [3581, (この処方箋は、どの保険薬局でも有効で...
# 5    photo-110.jpeg  [[処, 方, 箋, P. 1], [101, G], [(この処方箋は、どの保険薬局でも有...
# 6    photo-148.jpeg  [[処, 方], [3224-1, 1/1ページ], [(この処方箋はどの保険薬局でも有効で...
# 7    photo-301.jpeg  [[~30分後もどる], [13:30~, a], [処, 方], [(この処方箋はどの保険...
# 8    photo-326.jpeg  [[外 処方 箋 2019年09月30日 11:44 発行], [精神科, 院], [(この...
# 9    photo-339.jpeg  [[精神科, 院外処, 処方, 方箋 2019年09月27日 12:07 発行], [患者I...
# 10   photo-366.jpeg  [[処方], [田部 茂, 箋], [ID:82011230-2], [(この処方箋は、どの...
# 11   photo-435.jpeg  [[処], [方], [2387-1, 箋, 1/1ページ], [(この処方箋はどの保険薬局...
# ...
