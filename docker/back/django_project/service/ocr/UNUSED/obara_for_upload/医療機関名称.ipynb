# %% [markdown]
# # 準備

# %%
import random
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

#Jupyterでインライン表示するための宣言
# %matplotlib inline 
import os
import shutil
from tqdm import tqdm
import base64
import json
from requests import Request, Session
from io import BytesIO
from PIL import Image
import pandas as pd
import jaconv
import re
import cv2
import numpy as np
from symspellpy.symspellpy import SymSpell, Verbosity
import pickle
from pykakasi import kakasi
import Levenshtein
from collections import OrderedDict
import itertools

from statistics import mode
import time
from janome.tokenizer import Tokenizer

# %% [markdown]
# # 探索

# %% [markdown]
# # 切り取って保存

# %%
#とりあえず試し

num=1
start=0
goal=3
n_part=10
url="/Users/obara/Downloads/prescription_data_jpeg/photo-"+str(num)+".jpeg"
img = cv2.imread(url)
#img = plt.imread(url)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#plt.imshow(img)
input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,img.shape[1]*2//7:img.shape[1]*6//7]
#plt.figure(figsize=[50,50])
#plt.imshow(input_image)
plt.imsave("/Users/obara/Downloads/prescription_data_jpeg_4/photo-"+str(num)+".jpeg",input_image)

# %%
#関数化
def image_check(url,n_part,start,goal):
    img = cv2.imread(url)
    #img = plt.imread(url)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    #plt.imshow(img)
    #input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,0:img.shape[1]//2]
    input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,img.shape[1]*2//7:img.shape[1]]
    #plt.figure(figsize=[50,50])
    #plt.imshow(input_image)
    plt.imsave("/Users/obara/Downloads/prescription_data_jpeg_4/photo-"+str(num)+".jpeg",input_image)
    return

# %%
import pickle
with open('text_dic2.pickle', 'rb') as web:
    df = pickle.load(web)
    
num_list=[int(x[6:][:-5]) for x in list(df.keys())]
num_list.sort()
num_list
#35は除外
# Out:
# [2,
#  35,
#  40,
#  85,
#  93,
#  110,
#  148,
#  301,
#  326,
#  339,
#  366,
#  435,
#  456,
#  504,
#  519,
#  524,
#  548,
#  630,
#  655,
#  721,
#  770,
#  775,
#  786,
#  793,
#  806,
#  879,
#  885,
#  1011,
#  1110,
#  1137]

# %%
#for文

for num in tqdm(num_list):
    url="/Users/obara/Downloads/prescription_data_jpeg/photo-"+str(num)+".jpeg"
    image_check(url,10,0,4)
# Out:
# 100%|██████████| 30/30 [00:14<00:00,  2.06it/s]

# %% [markdown]
# ## OCR結果を保存

# %%
info_list=[]
for i in tqdm(num_list):
    try:
        dic={"file_name":"","result(10,0,10)":""}
        url="/Users/obara/Downloads/prescription_data_jpeg_4/photo-"+str(i)+".jpeg"
        dic["file_name"]="photo-"+str(i)+".jpeg"
        dic["result(10,0,10)"]=recognize5(url,10,0,10)
        info_list.append(dic)
        print(dic)
    except:
        print("photo-"+str(i)+".jpeg")
        print("ミスーーーーーーーーーーーーーーーーーーーー")
        pass

#csvに保存
df=pd.DataFrame(info_list)
df.to_csv("ocr_result_4.csv",encoding="utf_8_sig")

#pickleファイルに保存
with open('ocr_result_4.pickle', 'wb') as web:
    pickle.dump(df , web)
# Out:
#   3%|▎         | 1/30 [00:03<01:44,  3.60s/it]
# API終了までにかかった時間:3.5632479190826416[sec]
# for文を回し終わるまでにかかった時間:3.5728278160095215[sec]
# elapsed_time:3.590301990509033[sec]
# {'file_name': 'photo-2.jpeg', 'result(10,0,10)': [['P. 1'], ['処', '方', '箋', 'O'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号', '01130012'], ['被保険者証・被保険'], ['1 0 8 0 9 1 2 3 4 7'], ['者手帳の記号・番号'], ['っ', '保険医療機', '東京都千代田区飯田橋4-6-9 STビル2階'], ['幸子'], ['及び名称 医療法人社団 高典会 飯田橋クリニック'], ['56才'], ['7ヶ月男の 電話番号 03-3222-6461'], ['9月 22日生', '保険医氏名 高橋 典大'], ['険者', '被扶養者', '都道府県', '1', '3', '番号', '点数表', '1', '医療機関', '0', '1', '1', '1', '2 9 4. 8'], ['処方箋の', '特に記載のある場合を除き、'], ['1年 5月', '13日', '年 月', '日交付の日を含めて4日以内に'], ['使用期間', '保険薬局に提出すること。'], ['処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合、'], ['変更不可」欄に「」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]}
#   7%|▋         | 2/30 [00:07<01:43,  3.70s/it]
# API終了までにかかった時間:3.9103331565856934[sec]
# for文を回し終わるまでにかかった時間:3.9110610485076904[sec]
# elapsed_time:3.919351100921631[sec]
# {'file_name': 'photo-35.jpeg', 'result(10,0,10)': [['Date'], ['.'], ['人0'], ['Os']]}
#  10%|█         | 3/30 [00:11<01:41,  3.77s/it]
# API終了までにかかった時間:3.928049325942993[sec]
# for文を回し終わるまでにかかった時間:3.937465190887451[sec]
# elapsed_time:3.9503071308135986[sec]
# {'file_name': 'photo-40.jpeg', 'result(10,0,10)': [['171'], ['外来処方箋'], ['(この処方箋はどの保険薬局でも有効です)'], ['216016', '保険者番号 0|61|38|150'], ['1633', '被保険者証・被保険|1910'], ['者手帳の記号・番号|1336373'], ['2', '東京都武蔵野市吉祥寺本町1-30-12'], ['保険医療機'], ['関の所在地 医療法人社団 東仁会 吉祥寺あさひ病院'], ['U'], ['雅子', '電話番号 0422-22-1120'], ['診療科', '膠原病内科'], ['性別 女保険医氏名 有村義宏', 'ED'], ['年9月22日(50才)'], ['被扶養者', '番号', '113', '都道府県 点数表 医療機関', '番号 コード', '1', '31317|0|129'], ['特に記載のある場合を除き、'], ['処方箋の', '交付の日を含めて4日以内に'], ['0年5月18日', '使用期間', '保険薬局に提出すること。'], ['日々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】ミゾリビン錠50mg', '3錠'], ['35日分'], ['1日1回朝食前']]}
#  13%|█▎        | 4/30 [00:15<01:38,  3.80s/it]
# API終了までにかかった時間:3.7550361156463623[sec]
# for文を回し終わるまでにかかった時間:3.8354332447052[sec]
# elapsed_time:3.8499040603637695[sec]
# {'file_name': 'photo-85.jpeg', 'result(10,0,10)': [['処', '方', 'P. 1'], ['N', 'ge'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['割'], ['保険者番号 061 386613'], ['被保険者証・被保険'], ['者手帳の記号・番号', '12.5900516'], ['ガワミツヒロ', '保険医療機 東京都千代田区外神田5-2-3'], ['谷川 光洋', '関の所在地', '及び名称"アソルティ末広町ビル1F'], ['大昭平 40才', '末広町ヒライ耳鼻咽喉科'], ['1ヶ月男女 電話番号03-3836-3387'], ['53年11月 9日生', '保険医氏名平井 良治'], ['被保険者、被扶養者', '番号', '都道府県', '1', '3', '番号', '点数表', '1', '医療機関', 'コード', '0', '1', '1 3', '5', 'o', '38'], ['処方箋の', '特に記載のある場合を除き、'], ['平成30年', '12月 26日', '使用期間', '平成 年月 日', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['こは、「変更不可」欄に「」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】カルボシステイン錠'], ['5 0 0 mg', '3 錠'], ['1日3回 朝・昼・夕食後', '14日分']]}
#  17%|█▋        | 5/30 [00:19<01:34,  3.77s/it]
# API終了までにかかった時間:3.6544740200042725[sec]
# for文を回し終わるまでにかかった時間:3.664755344390869[sec]
# elapsed_time:3.678230047225952[sec]
# {'file_name': 'photo-93.jpeg', 'result(10,0,10)': [['O', 'P. 1'], ['処', '方', '箋'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号', '011 1 300112'], ['被保険者証・被保険', '50000013.109420'], ['者手帳の記号・番号'], ['保険医療機 東京都千代田区飯田橋4-4-7'], ["'", '及び名称 医療法人社団慈仁会 飯田橋小池クリニック'], ['43才'], ['4ヶ月男の 電話番号 03-3221-8858'], ['.', '4日生', '保険医氏名 小池 美由紀'], ['者', '被扶養者', '番号', '都道府県', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0', '1', '3', '415 51', '特に記載のある場合を除き、'], ['111', '5月 13日', '使用期間', '処方箋の', '年月日', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['キソプロフェンNa錠'], ['3. 錠'], ['g'], ['30日分'], ['食後服用'], ['バミピド錠 100mg', '3', '錠'], ['30日分'], ['食後服用'], ['帰四逆加呉茱萸生姜湯エキス顆粒']]}
#  20%|██        | 6/30 [00:22<01:28,  3.69s/it]
# API終了までにかかった時間:3.464254140853882[sec]
# for文を回し終わるまでにかかった時間:3.476135015487671[sec]
# elapsed_time:3.4894440174102783[sec]
# {'file_name': 'photo-110.jpeg', 'result(10,0,10)': [['P. 1'], ['処', '方'], ['G'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['11316012', '保険者番号 01 400019'], ['3175 018', '者手帳の記号・番号', '被保険者証・被保険', '92420709.975'], ['ュンコ', '保険医療機 東京都千代田区外神田5-2-3'], ['子', '関の所在地', '及び名称、アソルティ末広町ビル1F'], ['平', '36才', '末広町ヒライ耳鼻咽喉科'], ['3ヶ月男の', '電話番号03-3836-3387'], ['9月', '27日生', '保険医氏平井 良治'], ['被扶養者', '来日', '都道府県', '3', '東日', '1', '点数表 医療機関', '-', 'Q11', '3', '5', '0 13', '8']]}
#  23%|██▎       | 7/30 [00:26<01:25,  3.71s/it]
# API終了までにかかった時間:3.6491799354553223[sec]
# for文を回し終わるまでにかかった時間:3.701417922973633[sec]
# elapsed_time:3.7469940185546875[sec]
# {'file_name': 'photo-148.jpeg', 'result(10,0,10)': [['処', '方'], ['1/1ページ'], ['(この処方箋はどの保険薬局でも有効です)'], ['12|27|1243) 保険者番号'], ['0 0 2 3 7/8', '被保険者証・被保険'], ['者手帳の記号・番号'], ['ウラノチッ', '埜 知津子', '所在地及び名称', '保険医療機関の', 'Fine F', '上西クリニック', '大阪市平野区平野西3-9-21 コーポ常'], ['年', '3月26日 女', '電話番号', '(06)6760-5630'], ['保険医氏名', '上西 正明'], ['番号', '都道府県', '27', '番号', '1', '点数表 医療機関', 'コード', '5807943'], ['30年 12月18日 処方箋 の 平成 年 月 日(特に記載のある場合を除き、'], ['に差し支えある場合「レ」又は「×」を記載 使用期間 交付の日を含め4日以内に保険薬局に提出すること)'], ['セミド錠30mg', '2錠', '1日1回朝食後', '14日分'], ['ロノラクトン錠25'], ['1錠', '1日1回朝食後', '14日分'], ['- 1 mo']]}
#  27%|██▋       | 8/30 [00:30<01:22,  3.73s/it]
# API終了までにかかった時間:3.7502691745758057[sec]
# for文を回し終わるまでにかかった時間:3.7616400718688965[sec]
# elapsed_time:3.7782509326934814[sec]
# {'file_name': 'photo-301.jpeg', 'result(10,0,10)': [['30分後もどる'], ['a'], ['処', '方'], ['(この処方箋はどの保険薬局でも有効です)', 'Page. 1'], ['保険者番号 0 6 1 3 19 1 117'], ['被保険者証・被保険', '3 2 30 · 64 0 8'], ['者手帳の記号・番号'], ['〒101-0021'], ['保険医療機', '東京都千代田区外神田六丁目14番2号'], ['山口', 'グチカナコ', '桂奈子', '関の所在地', '及び名称', 'サカイ末広ビル7階B室', '雪月花メディカルクリニック 秋葉原診療所'], ['電話番号 03-5812-5301'], ['2和50年07月26日', '男', '保険医氏名 大道雅文'], ['被保険者', '被扶養者', '番号', '都道府県', '113', '1', '番号 コード', '点数表 医療機関', '特に記載のある場合', '011/337 110'], ['を除き、交付の日を'], ['平成30年12月28日', '使用期間', '処方箋の', '平成年月日', '含めて4日以内に保険', '薬局に提出すること。'], ['LA']]}
#  30%|███       | 9/30 [00:33<01:14,  3.53s/it]
# API終了までにかかった時間:3.0428662300109863[sec]
# for文を回し終わるまでにかかった時間:3.0529801845550537[sec]
# elapsed_time:3.0662362575531006[sec]
# {'file_name': 'photo-326.jpeg', 'result(10,0,10)': [['院外', '処', '方', '箋 2013年09月30日 11:44 発行'], ['(この処方箋は、 どの保険薬局でも有効です。)'], ['保険者番号1062315118'], ['被保険者証・被保険]4851'], ['手帳の記号・番号|267'], ['保険医療機愛知県一宮市奥町字下口西89番地の1'], ['関の所在地 社会医療法人杏嶺会'], ['浩二', '及び名称 上林記念病院'], ['電話番号0586-61-0110', '中'], ['男女、保険医氏名', '中原保裕', '原'], ['09月28日生', '賞者 ==被扶養者==', '都道府県', '号', '213', '点数表', '号', '1', '医療機関', 'ド', '2 2 0 2 1 2 6', '特に記載のある場合を除き、'], ['01年09月 30日', '使用期間', '処方箋の', '令和 1年10月3日 榮<薬に進出すること。'], ['つ処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', ']'], ['「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること'], ['2 T'], ['【般】 リルマザホン塩酸塩錠1mg'], ['不眠時', '20回分'], ['(以下余白)']]}
#  33%|███▎      | 10/30 [00:36<01:07,  3.38s/it]
# API終了までにかかった時間:2.989309310913086[sec]
# for文を回し終わるまでにかかった時間:3.0035083293914795[sec]
# elapsed_time:3.021700143814087[sec]
# {'file_name': 'photo-339.jpeg', 'result(10,0,10)': [['院外処方', '箋 2019年09月27日 12:07 発行'], ['(この処方箋は,どの保険薬局でも有効です。)'], ['保険者番号101 2 3 0 0 1 0'], ['被保険者証・被験7410435'], ['者手帳の記号・番号12'], ['保険医療機愛知県一宮市奥町字下口西89番地の1'], ['智子', '関の所在地 社会医療法人杏嶺会'], ['及び名称 上林記念病院'], ['電話番号0586-61-0110'], ['10月11日生', '男・の保険医氏名 原 大', '印'], ['被扶養者', '番', '都道府県', '号', '213', '番', '点数表', '号', '1', '医療機関', 'ド', '2 202 12 6'], ['01年 09月 27日', 'の日夢内に'], ['処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること'], ['設】パロキセチン錠20mg'], ['1 T'], ['1×夕食後', '45日分'], ['(以下余白)']]}
#  37%|███▋      | 11/30 [00:39<01:03,  3.34s/it]
# API終了までにかかった時間:3.2105908393859863[sec]
# for文を回し終わるまでにかかった時間:3.2229747772216797[sec]
# elapsed_time:3.235473871231079[sec]
# {'file_name': 'photo-366.jpeg', 'result(10,0,10)': [['処方箋'], ['部茂'], ['1:82011230-2'], ['(この処方箋は、どの保険薬局でも有効です。)', '24', '①ここには薬に関連する'], ['保険薬局に提出してく'], ['旦者番号'], ['町村番号', '保険者番号', '3 92 71 2 67', '②検査値情報をご提供い'], ['医療又は', '受給者番号', '|者手帳の記号・番号', '被保険者証・被保険13580774', '③提出を希望されない方'], ['ナオコ', '男', '所在地及び名称', '保険医療機関の〒546-0002', '大阪府大阪市東住吉区杭全', '④検査値は過去3か月間以'], ['井', '直子', '仁真会', '白鷺診療所', '⑤処方せんの有効期限は'], ['TEL. 06-6714-1661', '場合,保険薬局でお薬'], ['保険者 被扶養者', '和 15年 1月 3日生 保険医氏名', '1割', '番号', '都道府県', '|2|7', '1', '番号 コード', '点数表 医療機関', '田部 茂', 'ポ', '0805785', 'FI', 'ID:82011230', 'ヨコイ ナオコ'], ['年月日', '平成30年12月20日 | 使用期限', '処方箋の', '平成年月 日', '特に記載のある場合を除き、交付の日付を含め', '氏名:横井直子 性別', '生年月日:昭和15年1月3'], ['4日以内に保険薬局に提出してください。']]}
#  40%|████      | 12/30 [00:43<01:03,  3.52s/it]
# API終了までにかかった時間:3.857180118560791[sec]
# for文を回し終わるまでにかかった時間:3.8723082542419434[sec]
# elapsed_time:3.906266212463379[sec]
# {'file_name': 'photo-435.jpeg', 'result(10,0,10)': [['処', '方'], ['1/1ページ'], ['(この処方箋はどの保険薬局でも有効です)'], ['|13|6015) 保険者番号'], ['|13|8263'], ['8 2 8 37', '被保険者証・被保険 26-38 5209'], ['者手帳の記号・番号'], ['ブチルエ', '保険医療機関の', '東京都武蔵野市吉祥寺本町1-35-14'], ['H晴生', '所在地及び名称', 'おざき心のクリニック'], ['11月13日', '女', '電話番号', '保険医氏名', '(0422)20-5587', '尾崎純子', '尾', 've'], ['保険者', '都道府県', '番号', '13', '点数表 医療機関', '番号 コード', '3325248'], ['年5月18日 処方箋の平成 年 月 日(特に記載のある場合を除き、'], ['支えある場合「レ」又は「×」を記載 使用期間 交付の日を含め4日以内に保険薬局に提出すること)'], ['15 mg', '0.5錠'], ['20%', '0.26 mg', '分1夕食後', '28日分'], ['ng', '0.5錠', '分1就寝前', '28日分']]}
#  43%|████▎     | 13/30 [00:46<01:00,  3.56s/it]
# API終了までにかかった時間:3.600536823272705[sec]
# for文を回し終わるまでにかかった時間:3.6123969554901123[sec]
# elapsed_time:3.628598928451538[sec]
# {'file_name': 'photo-456.jpeg', 'result(10,0,10)': [['処方箋正', '11'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['国7-本'], ['保険者番号', '3', '8', '2', '1'], ['|域保険者証・滅険'], ['者手帳の記号・翻27-16', '• 0 3 7 5'], ['保険医療機関 武蔵野市吉祥寺本町1-33-6'], ['の所在地'], ['及び名称、 木下循環器呼吸器内科クリニック'], ['16日男 ・ 女「電話番号 0422-22-8300'], ['CD'], ['者 2.0 割「保険医氏名 木下陽'], ['5月18日', '都道府県', '番号', '13', '番号', '点数表', '1', '医療機関', 'コード', '313|2|3|8|9|6'], ['月', 'DET', '特に記載のある場合を除き、交付の日を含めて4日以内に保険薬局に提出すること。'], ['いて、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['間に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['アロプリノール錠100mg', '1', '錠'], ['ストール錠5mg', '1', '錠'], ['朝食後服用'], ['30日分'], ['ムロ配合錠AP', '1', '錠'], ['朝食後服用']]}
#  47%|████▋     | 14/30 [00:50<00:56,  3.53s/it]
# API終了までにかかった時間:3.444812774658203[sec]
# for文を回し終わるまでにかかった時間:3.45491099357605[sec]
# elapsed_time:3.470231056213379[sec]
# {'file_name': 'photo-504.jpeg', 'result(10,0,10)': [['処', '方', 'P. 1'], ['箋'], ['(この処方箋は、どの保険薬局でも有効です。)', 'O'], ['保険者番号', '06132948'], ['被保険者証・被保険'], ['1 3 2 4 • 5 0 8'], ['者手帳の記号・番号'], ['保険医旅機 東京都千代田区飯田橋4-6-9 STビル2階'], ['及び名称 医療法人社団 高典会 飯田橋クリニック'], ['26才'], ['8ヶ月男の 電話番号03-3222-6461', '高'], ['JIT', '10日生', '保険医氏名 高橋 典大'], ['被扶養者', '都道府県', '1', '3', '番号', '1', '点数表 医療機関', 'コード', 'N', '0 1 9 4. 8', '1'], ['5月13日', '使用期間', '処方箋の', '年月 交付の日を含めて4日以内に', '保険薬局に提出すること。', '特に記載のある場合を除き、'], ['について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['5 mg', '1', '錠'], ['夕食後'], ['なら寝る前', '30日分'], ['ィカプセル100'], ['3', 'C']]}
#  50%|█████     | 15/30 [00:54<00:54,  3.60s/it]
# API終了までにかかった時間:3.743975877761841[sec]
# for文を回し終わるまでにかかった時間:3.7504429817199707[sec]
# elapsed_time:3.762104034423828[sec]
# {'file_name': 'photo-519.jpeg', 'result(10,0,10)': [['処', '方', '箋', '負担:30%'], ['(この処方察はどの保険薬局でも有効です。', 'Tom'], ['保 険 者番号 06137087'], ['|被保険者証・被保険'], ['36 · 536'], ['者手帳の記号・番号'], ['ト', '保険医療機関の', '新宿区四谷1-2-4 クニヤビル3F'], ['所在地及び名称'], ['みどりの森ひふ科クリニック'], [')。平'], ['12日 「男女', '電話番号', '03-3352-4100'], ['保険医氏名 矢澤 徳仁'], ['被扶養者', '番号', '都道府県 点数表 医療機関', '1/3|番号|1', 'コード10|4|3|7|6|7|3'], ['特に記載のある場合を除き、交付の日を含めて'], ['10日 19日', '処方箋の 4日以内に保険薬局に提出すること。']]}
#  53%|█████▎    | 16/30 [00:57<00:50,  3.58s/it]
# API終了までにかかった時間:3.4554319381713867[sec]
# for文を回し終わるまでにかかった時間:3.501258134841919[sec]
# elapsed_time:3.5130271911621094[sec]
# {'file_name': 'photo-524.jpeg', 'result(10,0,10)': [['処方箋'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['08', '①ここには薬に関連する検査値情'], ['保険薬局に提出してください。'], ['保険者番号'], ['3 92 72 1 2 5', '②検査値情報をご提供いただくと'], ['被保険者証・被保険10403475'], ['者手帳の記号・番号', '-', '③提出を希望されない方は処方せ'], ['保険医療機関の〒546-0002'], ['男', '所在地及び名称', '七丁目十番十九等', '大阪府大阪市東住吉区杭全', '④検査値は過去3か月間以内に測:'], ['仁真会'], ['白鷺診療所', '⑤処方せんの有効期限は発行日を'], ['7月', '26日生', '保険医氏名 三橋', 'TEL. 06-6714-1661', '誠', '場合、保険薬局でお薬を受け取'], ['夫養者', '1割', '番号', '都道府県', '27', '品', '1', '点数表、 医療機関', 'lo slo 51718151', 'ID: 87012068']]}
#  57%|█████▋    | 17/30 [01:01<00:45,  3.54s/it]
# API終了までにかかった時間:3.4047110080718994[sec]
# for文を回し終わるまでにかかった時間:3.416616916656494[sec]
# elapsed_time:3.430040121078491[sec]
# {'file_name': 'photo-548.jpeg', 'result(10,0,10)': [['処方せん'], ['(この処方せんは、どの保険薬局でも有効です)'], ['(処方せん番号: 20171228-000074)'], ['保険者番号 01 1 2 0 0 1'], ['被保険者証・被保険 159160232・7'], ['者手帳の記号・番号'], ['保険医療機関 埼玉県さいたま市桜区上大久保'], ['チ', '様」の所在地及び 884'], ['名称', '医療法人聖仁会西部総合病院'], ['月12日 |年齢 39歳 1ヶ月 「性別 男性', '電話番号 048-854-1111'], ['保険医氏名西郷嘉一郎'], ['麻薬免許番号'], ['「患者負担', '30% 番号', '11', '111', '都道府県 点数表 医療機関', '番号 コード', '1', '特に記載のある場合を除き', '01 04 000', '4,000'], ['平成29年12月28日', '使用期間', '処方せんの', '平成29年12月31日', 'に保険薬局に提出すること。', '交付の日を含めて4日以内'], ['ユ方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['三更不可」欄に「い」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['-1 【般】ロキソプロフェンNa錠60mg', '3錠', '14日分'], ['3錠 14日分'], ['【般レバミピド錠100mg'], ['分3/毎食後', '12/28から14日分'], ['・.2 【般】ケトプロフェンテープ40mg(10×14cm非温感)', '5袋'], ['1日1枚、', '12/28から'], ['部位 :胸部']]}
#  60%|██████    | 18/30 [01:04<00:41,  3.47s/it]
# API終了までにかかった時間:3.2948219776153564[sec]
# for文を回し終わるまでにかかった時間:3.306245803833008[sec]
# elapsed_time:3.3198788166046143[sec]
# {'file_name': 'photo-630.jpeg', 'result(10,0,10)': [['18:15="}'], ['処', '方', 'XIPRXIGE'], ['(この処方変はどの保険薬局でも有効です)', 'Page 1'], ['保険者番号', '0 11 3 0 0 1 2'], ['被保険者証・被保険', '4 2 3 6 2 4 1 2 • 18'], ['者手帳の記号・番号'], ['〒101-0021'], ['保険医療機', '東京都千代田区外神田六丁目14番2号'], ['カタマコト', '関の所在地', 'サカイ末広ビル7階B室'], ['保方誠', '及び名称', '雪月花メディカルクリニック秋葉原診療所'], ['電話番号 03-5812-5301'], ['和53年10月17日', '(', '男女', '保険医氏名 大道雅文', '(EL'], ['被保険者', '被扶養者', '番号', '都道府県', '113', '1', '番号 コード', '点数表 医療機関', '0|11313171110'], ['特に記載のある場合'], ['平成30年12月12日', '使用期間', '処方箋の', '平成年月日', 'を除き、交付の日を', '含めて4日以内に保険', '薬局に提出すること。'], ['個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', '4'], ['には、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】アロプリノール錠100mg', '3錠'], ['分3毎食後', '28日分'], ['及】*', '【般】ロキソプロフェンNa錠60mg', '3錠']]}
#  63%|██████▎   | 19/30 [01:07<00:36,  3.34s/it]
# API終了までにかかった時間:3.0032529830932617[sec]
# for文を回し終わるまでにかかった時間:3.012009859085083[sec]
# elapsed_time:3.0241987705230713[sec]
# {'file_name': 'photo-655.jpeg', 'result(10,0,10)': [['IÀ Gta'], ['処方せん', '~373)'], ['どの保険薬局でも有効です。)', '分割指示に係る分割の回目'], ['保険者番号', '4100', '14 00:38'], ['被保険者証・被保険者', '03', '335-2943-9'], ['手帳の記号・番号'], ['かわごえ むねき', '医療機関の', '東京都千代田区外神田5丁目2-7'], ['川越宗紀', '所在地及び'], ['名称'], ['明神下診療所'], ['電話番号 03-5816-3110'], ['999/09/13', '男', '保険医氏名 米田衆介', 'VON'], ['被保険者'], ['18/12/28', '処方せ県番号', '都道府113', '番', '数表', '1', '関コード', '医療機、', '011/3 4 4 3 7'], ['んの使', '用期間 平成年月日 特に記載のある場合を除き、交付の'], ['日から4日以内に保険薬局に提出す'], ['ること'], ['て、後発医薬品(ジェネリック)への変更に差し支えが判断した場合には「変更不可」欄に「レ」又は']]}
#  67%|██████▋   | 20/30 [01:11<00:33,  3.38s/it]
# API終了までにかかった時間:3.450183868408203[sec]
# for文を回し終わるまでにかかった時間:3.455782890319824[sec]
# elapsed_time:3.4684829711914062[sec]
# {'file_name': 'photo-721.jpeg', 'result(10,0,10)': [['処', '方', 'せ', '3'], ['(後発希望'], ['(この処方せんは、どの保険薬局でも有効です。)'], ['保険者番号', '0 6 1 3 9 4', '6 3'], ['被保険者証・被保険', '100', '99744'], ['者手帳の記号・番号'], ['保健医療機関の東京都千代田区飯田橋4-5-16 コアビル3F'], ['介', '殿', '所在地及び名称'], ['飯田橋歯科クリニック'], ['電話番号 03-3288-5253'], ['年1月16日', '(男・女'], ['保険医氏名竹内均']]}
#  70%|███████   | 21/30 [01:14<00:31,  3.48s/it]
# API終了までにかかった時間:3.6923370361328125[sec]
# for文を回し終わるまでにかかった時間:3.7017760276794434[sec]
# elapsed_time:3.715696096420288[sec]
# {'file_name': 'photo-770.jpeg', 'result(10,0,10)': [['Po dl". X. GE'], ['方', '箋かか21'], ['(この処方類はどの保険薬局でも有効です。)', '負担:30%'], ['保険者番号 39122072'], ['被保険者証・被保険'], ['• 019 64204'], ['者手帳の記号・番号'], ['東京都台東区上野3-16-4 文行堂ビル2F'], ['ロウ', '保険医療機関の'], ['郡', '所在地及び名称'], ['医療法人社団雄翔会あさひ上野クリニック'], ['・平'], ['29日', '男女', '電話番号', '森田 秀和', '03-5818-7070'], ['保険医氏名', 'ED'], ['被扶養者', '番号 1/3|番号|1 コード06/301219', '都道府県 点数表 医療機関'], ['特に記載のある場合を除き、交付の日を含めて'], ['処方箋の 4日以内に保険薬局に提出すること。'], ['2月14日', '使用期間 平成 年月日'], ['(ジェネリック医薬品)への変更に差し支えがあると判断した場合には、'], ['」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['変更不可'], ['【内服】'], ['ン塩酸塩錠1', '【般】プラバスタチンナトリウム']]}
#  73%|███████▎  | 22/30 [01:18<00:27,  3.45s/it]
# API終了までにかかった時間:3.3580851554870605[sec]
# for文を回し終わるまでにかかった時間:3.3667609691619873[sec]
# elapsed_time:3.3794400691986084[sec]
# {'file_name': 'photo-775.jpeg', 'result(10,0,10)': [['処', '方', '箋', 'l', 'P. 1'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号', '01111301012'], ['被保険者証・被保険'], ['1322316.5'], ['者手帳の記号・番号'], ['保険医療機 東京都千代田区飯田橋4-6-9 STビル2階'], ['及び名様 医療法人社団 高典会 飯田橋クリニック'], ['47才'], ['5ヶ月 男の 電話番号 03-3222-6461'], ['7日生', '保険医氏名 高橋 典大'], ['音', '被扶養者', '|都道府県', '番号', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0', '1', '1', '2', '911 8', '4'], ['年', '5月', '13日', '使用期間', '処方箋の', '年月日', '保険薬局に提出すること。', '交付の日を含めて4日以内に', '特に記載のある場合を除き、'], ['について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['-可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['ィカプセル100']]}
#  77%|███████▋  | 23/30 [01:21<00:24,  3.54s/it]
# API終了までにかかった時間:3.6992950439453125[sec]
# for文を回し終わるまでにかかった時間:3.710732936859131[sec]
# elapsed_time:3.723552942276001[sec]
# {'file_name': 'photo-786.jpeg', 'result(10,0,10)': [['笑 2013年09月27日 12:54 発行'], ['院外 処方'], ['(この処方箋は,どの保険薬局でも有効です。)'], ['保険者番号 2 310 0 4 5'], ['被保険者証・被保険'], ['手帳の記号・番号|3226851'], ['保険医療機愛知県一宮市奥町字下口西89番地の1'], ['関の所在地 社会医療法人杏嶺会'], ['春子', '及び名称 上林記念病院'], ['電話番号 0586-61-0110'], ['男。 保険医氏名', '市橋佳世子', '養'], ['F 02月20日生', '都道府県|2|3', '2 3 *** 1 212102111216', '医療機関', 'ド'], ['険者 ==被扶養者== 番'], ['処方箋の', '令和 1年9月30日 業業に進出すること。'], ['和 01年 09月 27日', '使用期間'], ['日々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', ')'], ['は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること', 'O. 5 T'], ['エビリファイ錠3mg', '1 T'], ['【般】アムロジピン口腔内崩壊錠2.5mg', '1xEVE', '28日分'], ['2 T'], ['リフレックス錠15mg', '1×夕食後', '28日分']]}
#  80%|████████  | 24/30 [01:26<00:24,  4.00s/it]
# API終了までにかかった時間:5.052948951721191[sec]
# for文を回し終わるまでにかかった時間:5.064063787460327[sec]
# elapsed_time:5.076608896255493[sec]
# {'file_name': 'photo-793.jpeg', 'result(10,0,10)': [['処方箋'], ['Page 1'], ['の処方箋は、どの保険薬局でも有効です。)'], ['02 長'], ['2', '7', '4 2', '5', '1', '保険者番号', '39', '2', '7 11 2 6 7'], ['被保険者証・被保険 10428159'], ['5', '6', '3 4 1'], ['者手帳の記号・番号'], ['<同姓同名有り> 保険医療機関の 〒546-0002'], ['(男)', '所在地及び名称', '大阪府大阪市東住吉区杭全'], ['七丁目十番十九号'], ['様', '仁真会 白鷺診療所'], ['女', 'TEL. 06-6714-1661'], ['6月', '1日生', '保険医氏名 岡崎久宜', '所'], ['扶養者', '都道府県', '番号', '27', '1', '番号 コード', '点数表 医療機関', '08015|7185'], ['処方箋の 平成 30年 12月23日'], ['30年 12月20日', '使用期間', '4日以内に保険薬局に提出してください。', '特に記載のある場合を除き、交付の日付を含め'], ['雪々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合に', 'に]'], ['「変更不可」欄に「」または「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]}
#  83%|████████▎ | 25/30 [01:33<00:24,  4.85s/it]
# API終了までにかかった時間:6.779211044311523[sec]
# for文を回し終わるまでにかかった時間:6.791145086288452[sec]
# elapsed_time:6.808765172958374[sec]
# {'file_name': 'photo-806.jpeg', 'result(10,0,10)': [['2809 第01版'], ['0481', '処方'], ['箋'], ['1:19 この処方箋は、どの薬局でも有効です。(コピーは無効です。)', '1/1'], ['号'], ['号', '保険者番号|39|2|3|2|0|318'], ['は', '被保険者証・被保険|11843562'], ['番号', '者手帳の記号・番号'], ['00748 耳鼻咽喉科', 'の所在地', '保険医療機関 〒494-0001 愛知県一宮市開明字平1番地'], ['ユリコ', '及 び 名称 一 宮西病院'], ['百合子'], ['様電 話 番 号 0586-48-0077(代)'], ['年08月09日 79才女性保険 医氏名 宮田英雄'], ['Lone'], ['弁者', '負担割合 1割', '都道府県', '番号', '2 3', '番号', '点数表', '1', '医療機関', 'ド', '2|20| 3| 2|72|'], ['令和1年09月27日', '使用期限', '処方箋の', '令和1年09月30日'], ['[', '個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['には、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['【般】 パロキセチン錠10mg', '2錠'], ['1回1錠 (1日2錠)'], ['・1日2回 朝・夕食後', '21日分'], ['2010 con 107']]}
#  87%|████████▋ | 26/30 [01:38<00:19,  4.86s/it]
# API終了までにかかった時間:4.860499858856201[sec]
# for文を回し終わるまでにかかった時間:4.870249032974243[sec]
# elapsed_time:4.883002042770386[sec]
# {'file_name': 'photo-879.jpeg', 'result(10,0,10)': [['P. 1'], ['処', '方', '箋', 'GE'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['割'], ['保険者番号', '0 61 34803'], ['被保険者証・被保険', '.', '532 6175'], ['者手帳の記号・番号'], ['フラメグミ', '保険医療機 東京都千代田区外神田5-2-3'], ['倉めぐみ', '関の所在地', '及び名称 アソルティ末広町ビル1F'], ['大昭平 48才', '末広町ヒライ耳鼻咽喉科'], ['9ヶ月男女 電話番号 03-3836-3387'], ['15年 3月 9日生', '保険医氏名平井 良治'], ['保険者、被扶養者', '番号', '都道府県', '1', '3', '番号', '点数表', '1', '医療機関', 'コード', '0 1 3 5110° 1.38', '特に記載のある場合を除き、'], ['処方箋の', '交付の日を含めて4日以内に'], ['平成 30年 12月', '26日', '使用期間 平成 年月', '保険薬局に提出すること。'], ['個々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['ニは、「変更不可」欄に「」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]}
#  90%|█████████ | 27/30 [01:43<00:14,  4.97s/it]
# API終了までにかかった時間:5.085760831832886[sec]
# for文を回し終わるまでにかかった時間:5.120459794998169[sec]
# elapsed_time:5.211035966873169[sec]
# {'file_name': 'photo-885.jpeg', 'result(10,0,10)': [['Guard'], ['Copy', 'per Copy G'], ['Guard Paper', 'opy Guard', 'jard Paper', 'Copy Guard', 'aper Copy', 'hard Paper', 'per Copy Guard', 'uard Paper Copy', 'Copy Guard Paper', 'Paper Copy Guard', 'Guard Paper Copy', 'Copy Guard Paper', 'Guar laper Cody', 'pyyuard Paper'], ['Paper Copy Guard', 'by Guard Paper Copy', 'fropy Guard Paper', 'dos Jaded', 'Copy Guard Paper Co'], ['てる方はどの保険薬局でも有効です)', 'Copard Paper Copy Gear'], ['38009', 'Co Pape', 'De 011300127 Paper Copy Guard', '保険者番号'], ['6 V Copy Guard Papa'], ['Caro y Gual', '被保険者証・被保険| 57280204'], ['9 1'], ['者手帳の記号・番号 1750', 'Lapes'], ['37', 'GUNO er opy Vaper Com', 'er cuard Woer opy Guard/', '保険医療機 opyを', '東京都武蔵野市吉祥寺本町1-30-12', 'Copy Guard Page Copy Guard Paper Cor'], ['Paper Copy Già Paper Copy Gray'], ['機地', 'Guard PT', '医療法人社団 東仁会Garam'], ['Evans paper CBS Guard Pape'], ['ne Paper Copy Sard)', 'py Guard Paper Cox'], ['0422-221120'], ['孝典', 'Paper Copy Guar'], ['ord Pa/', '診療科', 's Paper', 'Copy 人工透析内!', 'Guäm aper'], ['三8月22日(513) py Guard Paper VIK', 'Co Gual Paper Copy Gu', '性別 男 保険医氏名 笠原仁', 'Zer Copy Guard Pace'], ['被保険者', 'con', 'Pap', '\\/', '13', '都道府県 無数表 医療機関', '番号', 'コード|3|37|0|1|2|9'], ['wa Pap'], ['特に記載のある場合を除き、'], ['年5月17日', 'CO', '使用期間', '処方箋の', 'V Gud', 'per CO', 'jard Pais', 'opy Gus', 'perc', 'vard', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['ROLTIN', 'は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること、any py Guard Paper Cons', '後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合', 'Guard per Copy ✓rd Paper Copy Guar', 'Estander Copy Guard Pape', 'y Guard Paper Copy'], ['-ツムラ芍薬甘草湯エキス顆粒(医療用)(2.5g) "'], ['I aper', 'Grd Paper Copy Guar'], ['er Copy Gu TV', 'x per', '下肢つり時1包', 'Paper ca', 'opy Guard PT', 'per Copy G', 'xrd Paper', 'opy Guard P', 'er Copy G', 'zard Paper Copy', 'opy Guest', 'aper Copy Guard', 'jard Paper Copy', 'Copy Guard Paper', 'aper Copy Guard', 'co', 'Copy Guard Pape', 'Paper Cop', 'Guar'], ['ELT']]}
# API終了までにかかった時間:4.411003112792969[sec]
# for文を回し終わるまでにかかった時間:4.633635997772217[sec]
#  93%|█████████▎| 28/30 [01:48<00:09,  4.90s/it]
# elapsed_time:4.709389925003052[sec]
# {'file_name': 'photo-1011.jpeg', 'result(10,0,10)': [['処', '方', 'P. 1'], ['箋'], ['(この処方箋は、どの保険薬局でも有効です。)', '後発希望'], ['保険者番号', '0 1 1 4 0011'], ['被保険者証・被保険'], ['者手帳の記号・番号', '2 1 3 5 0 7 2 6 • 2 1 2'], ['保険医療機 東京都千代田区飯田橋4-4-7'], ['関の所在地'], ['及び名称 医療法人社団慈仁会 飯田橋小池クリニック'], ['22才'], ['5ヶ月男の 電話番号03-3221-8858'], ['6日生', '保険医氏名 小池 美由紀'], ['被扶養者', '|都道府県', '番号', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0 1', '3', 'SR', '4 5 5 1'], ['処方箋の', '特に記載のある場合を除き、'], ['5月13日', '使用期間', '年月 日', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['いて、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['欄に「1」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['ジン錠', '3 mg', '2 錠'], ['食後服用', '5日分']]}
#  97%|█████████▋| 29/30 [01:52<00:04,  4.72s/it]
# API終了までにかかった時間:4.283455848693848[sec]
# for文を回し終わるまでにかかった時間:4.294160842895508[sec]
# elapsed_time:4.308790922164917[sec]
# {'file_name': 'photo-1110.jpeg', 'result(10,0,10)': [['処方箋'], ['(この処方箋は、どの保険薬局でも有効です。)'], ['保険者番号31911131111516'], ['被保険者証・被保険者', '04354858'], ['手帳の記号・番号'], ['39'], ['保険医療機関の東京都杉並区上荻2-42-11'], ['所在地及び名称 一般社団法人衛生文化協会'], ['園子', '城西病院'], ['電話番号 03-3390-4166', '矢'], ['2年2月27日 女', '保険医氏名 矢吹里香子', 'ED'], ['険者 負担割 1割'], ['都道府県番号137点数表番号1医療機関コード1570928'], ['平成30年5月18日', '処方度の', 'の日を含めて4日以内に保険薬局', '特に記載のある場合を除き交付'], ['使用期間 平成30年5月21日 に提出すること。'], ['日々の処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['は、「変更不可」欄に「レ」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['薬'], ['・ヌビア錠50mg', '1'], ['1錠'], ['ロジンOD錠5mg'], ['(朝)'], ['1日1回 14日分']]}
# 100%|██████████| 30/30 [01:56<00:00,  3.89s/it]
# API終了までにかかった時間:3.648853063583374[sec]
# for文を回し終わるまでにかかった時間:3.6584889888763428[sec]
# elapsed_time:3.6707749366760254[sec]
# {'file_name': 'photo-1137.jpeg', 'result(10,0,10)': [['P. 1'], ['処', '方', '箋', 'a'], ['(この処方箋は、どの保険薬局でも有効です。)', '後発希望'], ['保険者番号', '138016'], ['被保険者証・被保険'], ['者手帳の記号・番号', '01-48.5039'], ['ョウイチ', '保険医療機 東京都千代田区飯田橋4-4-7'], ['関の所在地'], ['及び名称一医療法人社団慈仁会 飯田橋小池クリニック'], ['63才'], ['池'], ['8ヶ月)女 電話番号03-3221-8858'], ['9月 14日生', '保険医氏名 小池 美由紀', '印'], ['弁者 被扶養者', '番号', '都道府県', '1', '3', '番号', '1', '点数表 医療機関', 'コード', '0', '1', '3 4 5 5', '1'], ['処方箋の', '特に記載のある場合を除き、'], ['1年', '5月', '24日', '使用期間', '年月 月日', '保険薬局に提出すること。', '交付の日を含めて4日以内に!'], ['う薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合'], ['更不可」欄に「/」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['アムロジピン錠2', '2. 5 mg', '1', '4.']]}

# %%
#住所の後、電話番号の前
#所在地及び名称より後ろ
#クリニック、医療法人、

# %%
text_list=list(df["result(10,0,10)"])

# %%
text_list[0]
# Out:
# [['P. 1'],
#  ['処', '方', '箋', 'O'],
#  ['(この処方箋は、どの保険薬局でも有効です。)'],
#  ['保険者番号', '01130012'],
#  ['被保険者証・被保険'],
#  ['1 0 8 0 9 1 2 3 4 7'],
#  ['者手帳の記号・番号'],
#  ['っ', '保険医療機', '東京都千代田区飯田橋4-6-9 STビル2階'],
#  ['幸子'],
#  ['及び名称 医療法人社団 高典会 飯田橋クリニック'],
#  ['56才'],
#  ['7ヶ月男の 電話番号 03-3222-6461'],
#  ['9月 22日生', '保険医氏名 高橋 典大'],
#  ['険者',
#   '被扶養者',
#   '都道府県',
#   '1',
#   '3',
#   '番号',
#   '点数表',
#   '1',
#   '医療機関',
#   '0',
#   '1',
#   '1',
#   '1',
#   '2 9 4. 8'],
#  ['処方箋の', '特に記載のある場合を除き、'],
#  ['1年 5月', '13日', '年 月', '日交付の日を含めて4日以内に'],
#  ['使用期間', '保険薬局に提出すること。'],
#  ['処方薬について、後発医薬品(ジェネリック医薬品)への変更に差し支えがあると判断した場合、'],
#  ['変更不可」欄に「」又は「×」を記載し、「保険医署名」欄に署名又は記名・押印すること。']]

# %%
#上を関数化　ある単語を含んでいたら、それ以降全てを取得（その単語は含まない）
def word_check_list(words_list,check_word):
    word=check_word
    candidate_list=[]
    for num in range(len(words_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            candidate1=[]
            candidate2=[]
            candidate3=[]
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][s+1:])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)
#1,15が二回,18,19,20

# %%
#上を関数化　ある単語を含んでいたら、それ以降全てを取得（その単語は含む）
def word_check_list2(words_list,check_word):
    word=check_word
    candidate_list=[]
    for num in range(len(words_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            candidate1=[]
            candidate2=[]
            candidate3=[]
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][s:])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)
#1,15が二回,18,19,20

# %%
#上を関数化　ある単語を含んでいたら、それより前を全てを取得（その単語は含まない）
def word_check_list_before(words_list,check_word):
    word=check_word
    candidate_list=[]
    for num in range(len(words_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            candidate1=[]
            candidate2=[]
            candidate3=[]
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][:s])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)
#1,15が二回,18,19,20

# %%
text_list=list(df["result(10,0,10)"])
text_list=word_check_list_before(text_list,"話番号")
text_list=word_check_list2(text_list,"所在地")
text_list=word_check_list2(text_list,"及び名称")
text_list=word_check_list(text_list,"記号・番号")
text_list=word_check_list_before(text_list,"都道府県")
# text_list=word_check_list_before(text_list,"保険医療")
# text_list=word_check_list_before(text_list,"医療機")
# text_list=word_check_list_before(text_list,"〒")
# text_list=word_check_list_before(text_list,"東京都")
# text_list=word_check_list_before(text_list,"町")
# text_list=word_check_list_before(text_list,"区")
# text_list=word_check_list(text_list,"険者番号")
# # text_list=word_check_list_before(text_list,"所在地")
# text_list=word_check_list_before(text_list,"電話番号")
text_list
# Out:
# [[['及び名称 医療法人社団 高典会 飯田橋クリニック'], ['56才']],
#  [['Date'], ['.'], ['人0'], ['Os']],
#  [['関の所在地 医療法人社団 東仁会 吉祥寺あさひ病院'], ['U']],
#  [['谷川 光洋', '関の所在地', '及び名称"アソルティ末広町ビル1F'], ['大昭平 40才', '末広町ヒライ耳鼻咽喉科']],
#  [["'", '及び名称 医療法人社団慈仁会 飯田橋小池クリニック'], ['43才']],
#  [['子', '関の所在地', '及び名称、アソルティ末広町ビル1F'], ['平', '36才', '末広町ヒライ耳鼻咽喉科']],
#  [['ウラノチッ',
#    '埜 知津子',
#    '所在地及び名称',
#    '保険医療機関の',
#    'Fine F',
#    '上西クリニック',
#    '大阪市平野区平野西3-9-21 コーポ常']],
#  [['山口',
#    'グチカナコ',
#    '桂奈子',
#    '関の所在地',
#    '及び名称',
#    'サカイ末広ビル7階B室',
#    '雪月花メディカルクリニック 秋葉原診療所']],
#  [['浩二', '及び名称 上林記念病院']],
#  [['及び名称 上林記念病院']],
#  [['ナオコ', '男', '所在地及び名称', '保険医療機関の〒546-0002', '大阪府大阪市東住吉区杭全', '④検査値は過去3か月間以'],
#   ['井', '直子', '仁真会', '白鷺診療所', '⑤処方せんの有効期限は'],
#   ['TEL. 06-6714-1661', '場合,保険薬局でお薬']],
#  [['H晴生', '所在地及び名称', 'おざき心のクリニック']],
#  [['及び名称、 木下循環器呼吸器内科クリニック']],
#  [['及び名称 医療法人社団 高典会 飯田橋クリニック'], ['26才']],
#  [['所在地及び名称'], ['みどりの森ひふ科クリニック'], [')。平']],
#  [['男', '所在地及び名称', '七丁目十番十九等', '大阪府大阪市東住吉区杭全', '④検査値は過去3か月間以内に測:'],
#   ['仁真会'],
#   ['白鷺診療所', '⑤処方せんの有効期限は発行日を'],
#   ['7月', '26日生', '保険医氏名 三橋', 'TEL. 06-6714-1661', '誠', '場合、保険薬局でお薬を受け取']],
#  [['チ', '様」の所在地及び 884'], ['名称', '医療法人聖仁会西部総合病院']],
#  [['保方誠', '及び名称', '雪月花メディカルクリニック秋葉原診療所']],
#  [['川越宗紀', '所在地及び'], ['名称'], ['明神下診療所']],
#  [['介', '殿', '所在地及び名称'], ['飯田橋歯科クリニック']],
#  [['郡', '所在地及び名称'], ['医療法人社団雄翔会あさひ上野クリニック'], ['・平']],
#  [['保険医療機 東京都千代田区飯田橋4-6-9 STビル2階'], ['及び名様 医療法人社団 高典会 飯田橋クリニック'], ['47才']],
#  [['春子', '及び名称 上林記念病院']],
#  [['(男)', '所在地及び名称', '大阪府大阪市東住吉区杭全'],
#   ['七丁目十番十九号'],
#   ['様', '仁真会 白鷺診療所'],
#   ['女', 'TEL. 06-6714-1661'],
#   ['6月', '1日生', '保険医氏名 岡崎久宜', '所']],
#  [['ユリコ', '及 び 名称 一 宮西病院'], ['百合子']],
#  [['倉めぐみ', '関の所在地', '及び名称 アソルティ末広町ビル1F'], ['大昭平 48才', '末広町ヒライ耳鼻咽喉科']],
#  [['37',
#    'GUNO er opy Vaper Com',
#    'er cuard Woer opy Guard/',
#    '保険医療機 opyを',
#    '東京都武蔵野市吉祥寺本町1-30-12',
#    'Copy Guard Page Copy Guard Paper Cor'],
#   ['Paper Copy Già Paper Copy Gray'],
#   ['機地', 'Guard PT', '医療法人社団 東仁会Garam'],
#   ['Evans paper CBS Guard Pape'],
#   ['ne Paper Copy Sard)', 'py Guard Paper Cox'],
#   ['0422-221120'],
#   ['孝典', 'Paper Copy Guar'],
#   ['ord Pa/', '診療科', 's Paper', 'Copy 人工透析内!', 'Guäm aper'],
#   ['三8月22日(513) py Guard Paper VIK',
#    'Co Gual Paper Copy Gu',
#    '性別 男 保険医氏名 笠原仁',
#    'Zer Copy Guard Pace']],
#  [['及び名称 医療法人社団慈仁会 飯田橋小池クリニック'], ['22才']],
#  [['所在地及び名称 一般社団法人衛生文化協会'], ['園子', '城西病院']],
#  [['及び名称一医療法人社団慈仁会 飯田橋小池クリニック'], ['63才'], ['池']]]

# %%
for i in text_list:
    for s in i:
        for s_ in s.split(" "):
            if s_ in list(df_hospital.keys()):
                print(s_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-1f37b8f848fd> in <module>
#       1 for i in text_list:
#       2     for s in i:
# ----> 3         for s_ in s.split(" "):
#       4             if s_ in list(df_hospital.keys()):
#       5                 print(s_)
#
# AttributeError: 'list' object has no attribute 'split'

# %%
for i in text_list:
    for s in i:
        for s_ in s.split(" "):
            if s_ in list(df_hospital.keys()):
                print(s_)

# %%
t = Tokenizer("merge.csv", udic_enc="utf-8")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a2984eec731e> in <module>
# ----> 1 t = Tokenizer("merge.csv", udic_enc="utf-8")
#
# NameError: name 'Tokenizer' is not defined

# %%
t = Tokenizer("merge.csv", udic_enc="utf-8")
def wakati(text):
    sei=""
    mei=""
    for token in t.tokenize(text):
        if token.part_of_speech.split(",")[2]=="人名" and (token.part_of_speech.split(",")[3]=="姓" or token.part_of_speech.split(",")[3]=="性"):
            sei=token.surface
        if token.part_of_speech.split(",")[2]=="人名" and token.part_of_speech.split(",")[3]=="名":
            mei=token.surface
    return sei,mei

# %%
for token in t.tokenize("東大病院及び名称一医療法人社団慈仁会 飯田橋小池クリニック"):
    print(token)
# Out:
# 東大	名詞,固有名詞,組織,*,*,*,東大,トウダイ,トーダイ
# 病院	名詞,一般,*,*,*,*,病院,ビョウイン,ビョーイン
# 及び	接続詞,*,*,*,*,*,及び,オヨビ,オヨビ
# 名称	名詞,一般,*,*,*,*,名称,メイショウ,メイショー
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# 医療	名詞,一般,*,*,*,*,医療,イリョウ,イリョー
# 法人	名詞,一般,*,*,*,*,法人,ホウジン,ホージン
# 社団	名詞,一般,*,*,*,*,社団,シャダン,シャダン
# 慈仁会	名詞,一般,*,*,*,*,慈仁会,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 飯田橋	名詞,固有名詞,地域,一般,*,*,飯田橋,イイダバシ,イーダバシ
# 小池	名詞,固有名詞,組織,*,*,*,小池,コイケ,コイケ
# クリニック	名詞,一般,*,*,*,*,クリニック,クリニック,クリニック

# %%
import pickle
with open('dict_hospitalInfo.pickle', 'rb') as web:
    df_hospital = pickle.load(web)

# %%
len(df_hospital)
# Out:
# 50427

# %%
for i in list(df_hospital.keys()):
    if "みどりの森" in i:
        print(i)
# Out:
# 芝山みどりの森クリニック
# みどりの森ひふ科クリニック
# 医療法人財団 真和会 みどりの森デンタルクリニック町田
# 医療法人財団真和会 みどりの森デンタルクリニック高座渋谷
# 医療法人財団真和会 みどりの森デンタルクリニック

# %%
df_hospital.keys()
# Out:
# dict_keys(['千葉県がんセンター', '医療法人社団福寿会 鷲見医院', '医療法人緑栄会 三愛記念そが病院', '千葉市 千葉市立青葉病院', 'クリニックあしたば', '医療法人社団誠馨会 千葉メディカルセンター', '医療法人社団 大樹 大賀医院', '一般社団法人 巨樹の会 千葉みなとリハビリテーション病院', '独立行政法人国立病院機構 千葉医療センター', '国立大学法人 千葉大学医学部附属病院', '独立行政法人国立病院機構 千葉東病院', '医療法人社団翠明会 山王病院', '国立研究開発法人 量子科学技術研究開発機構 QST病院', '清和園多部田診療所', '医療法人社団創進会 みつわ台総合病院', '社会福祉法人千葉県身体障害者福祉事業団 千葉県千葉リハビリテーションセンター', '千葉県こども病院', 'しののめ元山医院', '医療法人社団圭恵会 すずらんクリニック', '独立行政法人国立病院機構 下総精神医療センター', '千葉市休日救急診療所', '医療法人社団 千葉白報会 総合クリニック ドクターランド幕張', '医療法人社団究美会 肌と歯のクリニック 東京ベイ幕張', '医療法人財団みさき会 たむら記念病院', '東京歯科大学市川総合病院', '医療法人社団 瑞鶴会 鶴木クリニック医科・歯科', 'タムス市川リハビリテーション病院', '国立研究開発法人国立国際医療研究センター国府台病院', '独立行政法人地域医療機能推進機構船橋中央病院', '医療法人同和会 千葉病院', '芝山医科歯科クリニック', '医療法人社団三松会 さくらクリニック', '医療法人社団誠馨会 セコメディック病院', 'いけだハートクリニック 船橋駅前診療所', '船橋市立医療センター', '医療法人社団千葉白報会 総合クリニック ドクターランド船橋', '医療法人社団慈善会 ぜんり歯科内科クリニック', '医療法人社団協和会 滝不動病院', '医療法人鉄蕉会 亀田ファミリークリニック館山', '医療法人沖縄徳洲会 館山病院', '国保直営総合病院 君津中央病院', '医療法人社団志仁会 薬丸病院', '日本大学松戸歯学部付属病院', '医療法人社団慈朋会 金子医院', '医療法人沖縄徳洲会 千葉西総合病院', '松戸市立総合医療センター', '医療法人社団真療会 野田病院', '医療法人社団天榮会 茂原機能クリニック', '医療法人社団 剛裕会 須田外科・歯科医院', '医療法人社団聖母会 聖マリア記念病院', '日本赤十字社 成田赤十字病院', '成田病院', '成田市急病診療所', '医療法人社団心和会 成田リハビリテーション病院', '日本医科大学成田国際空港クリニック', '国際医療福祉大学成田病院', '佐倉市休日夜間急病診療所', '和田診療所', '医療法人静和会 浅井病院', '東千葉メディカルセンター', '夢屋診療所', '重症心身障害児施設 聖母療育園', '総合病院国保旭中央病院', '社会医療法人社団菊田会 習志野第一病院', '社会福祉法人恩賜財団済生会支部千葉県済生会 千葉県済生会 習志野病院', '医療法人社団柏水会 初石病院', '医療法人社団秀和会 秀和会クリニック', '医療法人社団天宣会 北柏リハビリ総合病院', '医療法人社団協友会 柏厚生総合病院', '公益財団法人柏市医療公社 医療センター', '社会医療法人社団蛍水会 名戸ケ谷病院付属名戸ケ谷診療所', '社会医療法人社団蛍水会 名戸ヶ谷病院', '国立研究開発法人国立がん研究センター東病院', '千葉県循環器病センター', '独立行政法人 労働者健康安全機構 千葉労災病院', '市原市急病センター', '帝京大学ちば総合医療センター', '流山市平日夜間・休日診療所', '医療法人社団心和会 新八千代病院', '医療法人社団心和会 八千代病院', '東京女子医科大学附属八千代医療センター', '我孫子市休日診療所', '医療法人緑生会 あびこクリニック', '天龍堂クリニック', '医療法人社団聖仁会 我孫子聖仁会病院', '医療法人鉄蕉会 亀田総合病院', '亀田クリニック', '鴨川市立国保病院', '医療法人社団宏和会 エビハラ病院', '医療法人梨香会 秋元病院', '医療法人沖縄徳洲会 鎌ケ谷総合病院', '医療法人社団君津あすなろ会 あすなろクリニック', 'あさひクリニック', '医療法人沖縄徳洲会 四街道徳洲会病院', '独立行政法人国立病院機構 下志津病院', '千葉県袖ヶ浦福祉センター', '東京都千葉福祉園診療所', '医療法人社団良康会 福王台皮膚科歯科', '医療法人みつや会 新八街総合病院', '日本医科大学千葉北総病院', '医療法人社団 昭桜会 桜台メディカルクリニック', '千葉県立佐原病院', '香取おみがわ医療センター', 'さんむ医療センター', '医療法人社団仁和会 睦岡クリニック', '髙根病院', '長谷川医院', '松本医院', '医療法人グリーンエミネンス 中村古峡記念病院', '医療法人社団普照会 井上記念病院', '医療法人柏葉会 柏戸病院', '医療法人 三橋病院', '医療法人学而会 木村病院', '医療法人 石郷岡病院', '千葉県精神保健福祉センター', '独立行政法人地域医療機能推進機構 千葉病院', '一般社団法人千葉衛生福祉協会 千葉診療所', '医療法人社団福生会 斎藤労災病院', '千葉セントラル神経科クリニック', '新千葉医院', '山崎皮膚科医院', '浜田小児科医院', '医療法人 椎名内科医院', '西千葉眼科医院', '医療法人社団一陽会 髙部内科医院', '林内科医院', '髙木整形外科', '医療法人社団仁静堂 平山整形外科・外科医院', '医療法人社団伸幸会 登戸クリニック', '山崎整形外科医院', '医療法人社団有馬会 有馬外科胃腸科', '木村整形外科', '医療法人社団翔葉会 今井医院', '医療法人社団峰明会 青木内科医院', '医療法人社団巖会 あさひ眼科医院', '久保小児科内科', '医療法人社団清弘会 神田内科医院', '医療法人社団青光会 今井町診療所', '医療法人社団仁威会 実川外科医院', '医療法人社団望葉会 日下医院', '医療法人社団柏陽会 柏木産婦人科', '新宿外科医院', '医療法人社団博洋会 大濱医院', '医療法人社団椿森会 椿森クリニック', 'わたなべ整形外科', 'もり内科クリニック', '千葉眼科', '医療法人社団春光会 千葉市役所前クリニック', '榎本医院', '医療法人緑栄会 三愛記念病院', '医療法人社団細川会 えりやま内科皮膚科医院', '医療法人社団宗仙会 山口耳鼻咽喉科', 'ちば宇津木皮膚科', '医療法人志方記念会 三木クリニック', '医療法人社団ヘルスアンドスポーツ会 鍋島整形外科', '医療法人社団生実会 ホタカ整形外科', '亘内科医院', '千葉クリニック', '青柳内科クリニック', '武本眼科医院', '医療法人社団澤泉会 矢澤内科医院', 'ジツカワ眼科', '医療法人社団 和田医院', 'しまだ医院', '本千葉メンタルクリニック', '小野寺産婦人科', '医療法人社団 喜美会 自由が丘クリニックソフィア', '医療法人社団 至心会 田那村内科小児科医院', '医療法人社団 煌和会 國分クリニック', '島野眼科医院', 'るみえ内科小児科', '医療法人社団 惇友会 荒井眼科', '医療法人社団 豊賀會 吉井耳鼻咽喉科医院', 'ヒロ耳鼻科クリニック', '和康会産婦人科健康診断クリニック', '千葉寺駅前眼科', '医療法人社団桐和会 桐原クリニック', '公益財団法人ちば県民保健予防財団 千葉県庁医務室', '小松﨑耳鼻咽喉科', '社会医療法人社団同仁会 そが西口クリニック', '医療法人社団 松石会 松石内科医院', '岡田医院', 'つばきこどもクリニック', '医療法人社団春鈴会 寺田クリニック', '医療法人社団晃知会 小浜内科外科クリニック', '医療法人社団豊流会 ツチダクリニック', '山口内科外科クリニック', '西川泌尿器科クリニック', '東千葉クリニック', '長谷川胃腸科クリニック', '医療法人社団青稜会 そが皮膚科', 'こいで内科消化器科クリニック', '一般財団法人柏戸記念財団 ポートスクエア柏戸クリニック', '中野耳鼻咽喉科医院', '千葉そごう眼科診療所', 'くすの木クリニック', '医療法人社団恵昭会 千葉駅前クリニック', '西千葉クリニック', '医療法人社団鎮誠会 千葉きぼーるクリニック', '医療法人社団 のわび会 医療法人社団 のわび会 そがこどもクリニック', '医療法人社団英正会 けやき眼科クリニック', '千葉中央こころのクリニック', '医療法人社団 貴祥会 耳鼻咽喉科なかのクリニック', '医療法人社団桃李会 なかしまクリニック', '医療法人社団 ゆう ゆうクリニック', '医療法人社団 西千葉皮膚科クリニック', '本千葉小児科', '医療法人社団あい 増田病院', '社会福祉法人淑徳福祉会 淑徳おゆみ診療所', '上田医院', 'ちば美容・形成外科クリニック', '医療法人社団 千葉中央クリニック', '医療法人社団 とのおか眼科', '菫ホームクリニック', '千葉駅前心療内科 ...

# %%
c=[i.split(",")[1]+",-1,-1,10000,名詞,固有名詞,医療機関名,,*,*,"+i.split(",")[0]+","+jaconv.hira2kata(i.split(",")[0])+","+jaconv.hira2kata(i.split(",")[0]) for i in lines3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-833ae1f6055b> in <module>
# ----> 1 c=[i.split(",")[1]+",-1,-1,10000,名詞,固有名詞,医療機関名,,*,*,*"+i.split(",")[0]+","+jaconv.hira2kata(i.split(",")[0])+","+jaconv.hira2kata(i.split(",")[0]) for i in lines3]
#       2
#       3
#       4
#
# NameError: name 'lines3' is not defined

# %%
c=[i+",-1,-1,10000,名詞,固有名詞,*,*,*,*,*,*,*" for i in df_hospital.keys()]


#ポリフェノール,-1,-1,1000,名詞,固有名詞,一般,*,*,*,ポリフェノール,ポリフェノール,ポリフェノール

# %%
c[0]
# Out:
# '千葉県がんセンター,-1,-1,10000,名詞,固有名詞,*,*,*,*,*,*,*'

# %%
with open('hospital.csv', 'w', encoding='utf-8') as f:
#     f.write('ロスマリン,-1,-1,1000,名詞,固有名詞,一般,*,*,*,ロスマリン,ロスマリン,ロスマリン\n')
#     f.write('ポリフェノール,-1,-1,1000,名詞,固有名詞,一般,*,*,*,ポリフェノール,ポリフェノール,ポリフェノール\n')
#     f.write('機序,-1,-1,1000,名詞,サ変接続,*,*,*,*,機序,キジョ,キジョ\n')
    for i in c:
        f.write(i+"\n")

# %%
from janome.tokenizer import Tokenizer
t = Tokenizer("hospital.csv", udic_enc="utf-8")

line = '藍磯 飯田橋小池クリニック小原大智ロスマリン酸摂取後の脳内ドーパミンがアルツハイマー病を予防する  ポリフェノールの新たな作用機序'

for token in t.tokenize(line):
    print(token)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-d5634188e602> in <module>
#       1 from janome.tokenizer import Tokenizer
# ----> 2 t = Tokenizer("hospital.csv", udic_enc="utf-8")
#       3
#       4 line = '藍磯 飯田橋小池クリニック小原大智ロスマリン酸摂取後の脳内ドーパミンがアルツハイマー病を予防する  ポリフェノールの新たな作用機序'
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/janome/tokenizer.py in __init__(self, udic, udic_enc, udic_type, max_unknown_length, wakati, mmap, dotfile)
#     166             if udic.endswith('.csv'):
#     167                 # build user dictionary from CSV
# --> 168                 self.user_dic = UserDictionary(udic, udic_enc, udic_type, connections)
#     169             elif os.path.isdir(udic):
#     170                 # load compiled user dictionary
#
# ~/anaconda3/lib/python3.6/site-packages/janome/dic.py in __init__(self, user_dict, enc, type, connections)
#     404         """
#     405         build_method = getattr(self, 'build' + type)
# --> 406         compiledFST, entries = build_method(user_dict, enc)
#     407         Dictionary.__init__(self, [compiledFST], entries, connections)
#     408
#
# ~/anaconda3/lib/python3.6/site-packages/janome/dic.py in buildipadic(self, user_dict, enc)
#     416                 pos_major, pos_minor1, pos_minor2, pos_minor3, \
#     417                 infl_type, infl_form, base_form, reading, phonetic = \
# --> 418                     line.split(',')
#     419                 part_of_speech = ','.join([pos_major, pos_minor1, pos_minor2, pos_minor3])
#     420                 morph_id = len(surfaces)
#
# ValueError: too many values to unpack (expected 13)

# %%
text_list=list(df["result(10,0,10)"])
text_list=word_check_list_before(text_list,"所在地")
text_list=word_check_list_before(text_list,"電話番号")
text_list=word_check_list_before(text_list,"保険医療")
text_list=word_check_list_before(text_list,"医療機")
text_list=word_check_list_before(text_list,"〒")
text_list=word_check_list_before(text_list,"東京都")
text_list=word_check_list_before(text_list,"町")
text_list=word_check_list_before(text_list,"区")
text_list=word_check_list(text_list,"険者番号")
text_list=word_check_list2(text_list,"被保険")
# # text_list=word_check_list_before(text_list,"所在地")
# text_list=word_check_list_before(text_list,"電話番号")

info_list=[]
sum_=0
for i in text_list:
    print(sum_)
    #print(i)
    word_list=["-".join(s) for s in i]#.replace("・","-").replace(".","-")
    word_list2=("-".join(word_list))
    print(word_list2)
    word_list3=word_list2.replace("・","-").replace(".","-").replace("•","-")
    word_list4=word_list3.split("-")
    word_list5=[]
    for word in word_list4:
        if word.count(' ')==1:
            word_list5.append(word.split(" ")[0])
            word_list5.append(word.split(" ")[1])
        else:
            word_list5.append(word)
    print(word_list5)
    sum_+=1
#     for word in word_list5:
        
#         print(re.sub('[^0-9]','',word))
    word_list6=[re.sub('[^0-9]','',word) for word in word_list5]
    #print("-".join(word_list6))
    print(re.sub('-+', '-', "-".join(word_list6).strip("-")))
    info_list.append(re.sub('-+', '-', "-".join(word_list6).strip("-")))
    #print([re.sub('[^0-9]','', ("-".join(s)).replace("・","").replace(".",""))for s in i])
    #print("-".join([re.sub('[^0-9]','', ("-".join(s)))for s in i]))
    #print("".join(["-".join(s) for s in i]))
#     print(re.sub('[^0-9]','', ("".join(["-".join(s) for s in i]))))
    #print("".join(i))
    #print( re.sub('[0-9]','', i))
    print("----------------")
# Out:
# 0
# 被保険者証・被保険-1080912 347-・-者手帳の記号・番号
# ['被保険者証', '被保険', '1080912', '347', '', '', '者手帳の記号', '番号']
# 1080912-347
# ----------------
# 1
# Date-IKE-tre-A
# ['Date', 'IKE', 'tre', 'A']
#
# ----------------
# 2
# 被保険者証・被保険|1910-者手帳の記号・番号|1336373
# ['被保険者証', '被保険|1910', '者手帳の記号', '番号|1336373']
# 1910-1336373
# ----------------
# 3
# 被保険者証・被保険-者手帳の記号・番号-12.5900516
# ['被保険者証', '被保険', '者手帳の記号', '番号', '12', '5900516']
# 12-5900516
# ----------------
# 4
# 被保険者証・被保険-50000013-109420-者手帳の記号・番号
# ['被保険者証', '被保険', '50000013', '109420', '者手帳の記号', '番号']
# 50000013-109420
# ----------------
# 5
# 被保険者証・被保険-9 2 4 2 0 7 09.97 5-者手帳の記号・番号
# ['被保険者証', '被保険', '9 2 4 2 0 7 09', '97', '5', '者手帳の記号', '番号']
# 92420709-97-5
# ----------------
# 6
# 18.-被保険者証・被保険-者手帳の記号・番号
# ['18', '', '被保険者証', '被保険', '者手帳の記号', '番号']
# 18
# ----------------
# 7
# 被保険者証・被保険-3230・6408-者手帳の記号・番号
# ['被保険者証', '被保険', '3230', '6408', '者手帳の記号', '番号']
# 3230-6408
# ----------------
# 8
# 概険者証・被保険 4851-手帳の記号・番号|267
# ['概険者証', '被保険', '4851', '手帳の記号', '番号|267']
# 4851-267
# ----------------
# 9
# 被保険者証・被験7410435-手帳の記号・番号12
# ['被保険者証', '被験7410435', '手帳の記号', '番号12']
# 7410435-12
# ----------------
# 10
# 被保険者証・被保険 13580774-③提出を希望されない方-|者手帳の記号・番号
# ['被保険者証', '被保険', '13580774', '③提出を希望されない方', '|者手帳の記号', '番号']
# 13580774
# ----------------
# 11
# 被保険者証・被保険 26-38. 5209-者手帳の記号・番号
# ['被保険者証', '被保険', '26', '38', '', '5209', '者手帳の記号', '番号']
# 26-38-5209
# ----------------
# 12
# 被保険者証・械-者手帳の記号・927-16-• 0 3 7 5
# ['被保険者証', '械', '者手帳の記号', '927', '16', '', ' 0 3 7 5']
# 927-16-0375
# ----------------
# 13
# 険者証・被保険-1 3 2 4 • 5 0 8-三帳の記号・番号
# ['険者証', '被保険', '1 3 2 4 ', ' 5 0 8', '三帳の記号', '番号']
# 1324-508
# ----------------
# 14
# |被保険者証・被保険-36 · 536-者手帳の記号・番号
# ['|被保険者証', '被保険', '36 · 536', '者手帳の記号', '番号']
# 36536
# ----------------
# 15
# 被保険者証・被保険10403475-者手帳の記号・番号---③提出を希望されない方は処方せ
# ['被保険者証', '被保険10403475', '者手帳の記号', '番号', '', '', '③提出を希望されない方は処方せ']
# 10403475
# ----------------
# 16
# 被保険者証・被保険 | 59160232・7-者手帳の記号・番号
# ['被保険者証', '被保険 | 59160232', '7', '者手帳の記号', '番号']
# 59160232-7
# ----------------
# 17
# 被保険者証・被保険-4 2 3 6 2 4 1 2 • 18-者手帳の記号・番号
# ['被保険者証', '被保険', '4 2 3 6 2 4 1 2 ', '', '18', '者手帳の記号', '番号']
# 42362412-18
# ----------------
# 18
# 被保険者証・被保険者-03-・-335-2943-9-手帳の記号・番号
# ['被保険者証', '被保険者', '03', '', '', '335', '2943', '9', '手帳の記号', '番号']
# 03-335-2943-9
# ----------------
# 19
# 被保険者証・被保険-100-99744-者手帳の記号・番号
# ['被保険者証', '被保険', '100', '99744', '者手帳の記号', '番号']
# 100-99744
# ----------------
# 20
# 保険者証・被保険-・01964204-手帳の記号・番号
# ['保険者証', '被保険', '', '01964204', '手帳の記号', '番号']
# 01964204
# ----------------
# 21
# 被保険者証・被保険-1 3 2 2 3 1 6.5-者手帳の記号・番号
# ['被保険者証', '被保険', '1 3 2 2 3 1 6', '5', '者手帳の記号', '番号']
# 1322316-5
# ----------------
# 22
# 被保険者証・被保険-手帳の記号・番号|3226851
# ['被保険者証', '被保険', '手帳の記号', '番号|3226851']
# 3226851
# ----------------
# 23
# 被保険者証・被保険 10428159-者手帳の記号・番号
# ['被保険者証', '被保険', '10428159', '者手帳の記号', '番号']
# 10428159
# ----------------
# 24
# 被保険者証・被保険|11843562-者手帳の記号・番号
# ['被保険者証', '被保険|11843562', '者手帳の記号', '番号']
# 11843562
# ----------------
# 25
# 被保険者証・被保険-5 3 2.61 7 5-者手帳の記号・番号
# ['被保険者証', '被保険', '5 3 2', '61 7 5', '者手帳の記号', '番号']
# 532-6175
# ----------------
# 26
# Copy Guar/-被保険者証・被保険-B-572802041-者手帳の記号・番号 1750-vard per-ger-opy-Copy Guard Pascopy Guard Paper Cor-Cor
# ['Copy', 'Guar/', '被保険者証', '被保険', 'B', '572802041', '者手帳の記号', '番号', '1750', 'vard', 'per', 'ger', 'opy', 'Copy Guard Pascopy Guard Paper Cor', 'Cor']
# 572802041-1750
# ----------------
# 27
# 保険者証・被保険」-手帳の記号・番号-2 1 3 5 0 7 2 6 • 2 1 2
# ['保険者証', '被保険」', '手帳の記号', '番号', '2 1 3 5 0 7 2 6 ', ' 2 1 2']
# 21350726-212
# ----------------
# 28
# 手帳の記号・番号-被保険者証・被保険者-.-・04354858
# ['手帳の記号', '番号', '被保険者証', '被保険者', '', '', '', '04354858']
# 04354858
# ----------------
# 29
# 被保険者証・被保険-者手帳の記号・番号-01-48.5039
# ['被保険者証', '被保険', '者手帳の記号', '番号', '01', '48', '5039']
# 01-48-5039
# ----------------

# %%
"---------".replace("--","-")
re.sub('-+', '-', "---------")
# Out:
# '-'

# %%
info_list
# Out:
# ['1080912-347',
#  '',
#  '1910-1336373',
#  '12-5900516',
#  '50000013-109420',
#  '92420709-97-5',
#  '18',
#  '3230-6408',
#  '4851-267',
#  '7410435-12',
#  '13580774',
#  '26-38-5209',
#  '927-16-0375',
#  '1324-508',
#  '30-6137087-36536',
#  '39272125-10403475',
#  '59160232-7',
#  '42362412-18',
#  '03-335-2943-9',
#  '100-99744',
#  '01964204',
#  '1322316-5',
#  '3226851',
#  '10428159',
#  '11843562',
#  '532-6175',
#  '572802041-1750',
#  '21350726-212',
#  '04354858',
#  '01-48-5039']

# %%
a = 'lkdfhisoe78347834 (())&/&745  '
result = re.sub('[^0-9]','', a)
result
# Out:
# '78347834745'

# %%
#答え合わせ
f = open('result.txt',encoding="shift-jis")
lines2 = f.readlines() # 1行毎にファイル終端まで全て読む(改行文字も含まれる)
f.close()

# %%
for i in range(len(lines2)):
    print(i)
    if lines2[i].replace("\n","")==info_list[i]:
        print("あってる")
    else:
        print("間違ってる")
        print("正解:"+str(lines2[i].replace("\n","")))
        print("予想:"+str(info_list[i]))
    print("--------------")
# Out:
# 0
# あってる
# --------------
# 1
# あってる
# --------------
# 2
# あってる
# --------------
# 3
# あってる
# --------------
# 4
# あってる
# --------------
# 5
# 間違ってる
# 正解:92420709-975
# 予想:92420709-97-5
# --------------
# 6
# 間違ってる
# 正解:
# 予想:18
# --------------
# 7
# あってる
# --------------
# 8
# あってる
# --------------
# 9
# 間違ってる
# 正解:7410435-2
# 予想:7410435-12
# --------------
# 10
# あってる
# --------------
# 11
# あってる
# --------------
# 12
# 間違ってる
# 正解:27-16-0375
# 予想:927-16-0375
# --------------
# 13
# あってる
# --------------
# 14
# 間違ってる
# 正解:36-536
# 予想:36536
# --------------
# 15
# あってる
# --------------
# 16
# あってる
# --------------
# 17
# あってる
# --------------
# 18
# あってる
# --------------
# 19
# あってる
# --------------
# 20
# あってる
# --------------
# 21
# あってる
# --------------
# 22
# あってる
# --------------
# 23
# あってる
# --------------
# 24
# あってる
# --------------
# 25
# あってる
# --------------
# 26
# 間違ってる
# 正解:57280204-1750
# 予想:572802041-1750
# --------------
# 27
# あってる
# --------------
# 28
# あってる
# --------------
# 29
# あってる
# --------------

# %% [markdown]
# # 関数置き場

# %%
# 基本は最頻値をとる。最頻値がない時は平均をとる。numsが空の時は0にする。
def mode_average(nums):
    try:
        return mode(nums)
    except:
        if len(nums)!=0:
            return round(sum(nums) / len(nums))
        else:
            try:
                return nums[0]
            except:
                return 0  #これは危ないかも

# %%
#一部のみしか選択しないタイプ 画像を表示しない場合
def recognize5(url,n_part,start,goal):
    start_time = time.time()
    #pathからbase64にする場合
    def pil_image_to_base64(img_path):###ここは最後に消す
        pil_image = Image.open(img_path)
        buffered = BytesIO()
        pil_image.save(buffered, format="PNG")
        str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
        return str_encode_file

    #arrayからbase64にする場合
    def array_to_base64(img_array):
        pil_image = Image.fromarray(np.uint8(img_array))
        buffered = BytesIO()
        pil_image.save(buffered, format="PNG")
        str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
        return str_encode_file 

    def get_fullTextAnnotation(json_data):
        text_dict = json.loads(json_data)
        try:
            text = text_dict["responses"][0]["fullTextAnnotation"]["text"]
            return text
        except:
            print(None)
            return None

    #str_encode_file = pil_image_to_base64(url)  
    
    img = cv2.imread(url)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    input_image=img[start*img.shape[0]//n_part:goal*img.shape[0]//n_part ,0::]
#     plt.figure(figsize=[50,50])
#     plt.imshow(input_image)
    
    str_encode_file = array_to_base64(input_image)# input_imageがarrayの時
    str_url = "https://vision.googleapis.com/v1/images:annotate?key="
    str_api_key = "AIzaSyDlRRYrHEdjParsfRmh96_3xfafOo1crWY"
    str_headers = {'Content-Type': 'application/json'}
    str_json_data = {
        'requests': [
            {
                'image': {
                    'content': str_encode_file
                },
                'features': [
                    {
                        'type': "DOCUMENT_TEXT_DETECTION",
                        'maxResults': 1
                    }
                ],"imageContext": {
        "languageHints": ["ja"]
      },
            }
        ]
    }

    obj_session = Session()
    obj_request = Request("POST",
                            str_url + str_api_key,
                            data=json.dumps(str_json_data),
                            headers=str_headers
                            )
    obj_prepped = obj_session.prepare_request(obj_request)
    obj_response = obj_session.send(obj_prepped,
                                    verify=True,
                                    timeout=60
                                    )
    #もとの出力
    if obj_response.status_code == 200:
        text = get_fullTextAnnotation(obj_response.text)
        
    elapsed_time = time.time() - start_time
    print ("API終了までにかかった時間:{0}".format(elapsed_time) + "[sec]")
    #行ごとの出力    
    text_dict = json.loads(obj_response.text)
    word_list=text_dict["responses"][0]["textAnnotations"][0]["description"].split("\n")

    len_sum=0
    now_num=0
    left=[]
    right=[]
    top=[]
    bottom=[]
    dic_list=[]

    for i in range(1,len(text_dict["responses"][0]["textAnnotations"])):
        len_sum+=len(text_dict["responses"][0]["textAnnotations"][i]["description"].replace(" ",""))
        try:
            left.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["x"])
        except:
            pass
        try:
            right.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][1]["x"])
        except:
            pass
        try:
            right.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][2]["x"])
        except:
            pass
        try:
            left.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][3]["x"])
        except:
            pass

        try:
            bottom.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][0]["y"])
        except:
            pass
        try:
            bottom.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][1]["y"])
        except:
            pass
        try:
            top.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][2]["y"])
        except:
            pass
        try:
            top.append(text_dict["responses"][0]["textAnnotations"][i]["boundingPoly"]["vertices"][3]["y"])
        except:
            pass

        if len_sum==len(word_list[now_num].replace(" ","")):
            len_sum=0
            #print("word:   "+word_list[now_num])
            dic={"word":word_list[now_num],"文字の縦幅":mode_average(top)-mode_average(bottom),"x":round(mode_average(left)+mode_average(right)),"y":round(mode_average(top)+mode_average(bottom))}
            dic_list.append(dic)
            now_num+=1
            left=[]
            right=[]
            top=[]
            bottom=[]
    elapsed_time = time.time() - start_time
    print ("for文を回し終わるまでにかかった時間:{0}".format(elapsed_time) + "[sec]")
    df = pd.DataFrame(dic_list)
    df=df.sort_values('y')
    df.reset_index()
    tate_mean=df["文字の縦幅"].mean()

    diff_list=df["y"].diff()
    a_=0
    y_list=[]
    for a,b in zip(df["y"],diff_list):
        #print(a,b)
        if b<tate_mean:
            a=a_
        a_=a
        y_list.append(a)

    df["diff"]=diff_list
    df.loc[0,"diff"]=0
    df["y"]=y_list
    df=df.sort_values(["y","x"])
    grouped_df = df.groupby('y')
    grouped_list = [list(grouped_df["word"].get_group(word)) for word in grouped_df.groups]
    elapsed_time = time.time() - start_time
    print ("elapsed_time:{0}".format(elapsed_time) + "[sec]")
    return grouped_list
