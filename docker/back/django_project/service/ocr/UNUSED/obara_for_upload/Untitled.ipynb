# %%
def recognize_image1(input_image):#最後にstr_encode_fileに変える
    #pathからbase64にする場合
    # def pil_image_to_base64(img_path):###ここは最後に消す
    #     pil_image = Image.open(img_path)
    #     buffered = BytesIO()
    #     pil_image.save(buffered, format="PNG")
    #     str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
    #     return str_encode_file

    #arrayからbase64にする場合
    def array_to_base64(img_array):
        pil_image = Image.fromarray(np.uint8(img_array))
        buffered = BytesIO()
        pil_image.save(buffered, format="PNG")
        str_encode_file = base64.b64encode(buffered.getvalue()).decode("utf-8")
        return str_encode_file 
    
    def get_fullTextAnnotation(json_data):
        text_dict = json.loads(json_data)
        print(text_dict)
        try:
            text = text_dict["responses"][0]["fullTextAnnotation"]["text"]
            return text
        except:
            print(None)
            return None

    #str_encode_file = pil_image_to_base64(input_image)  
    str_encode_file = array_to_base64(input_image)# input_imageがarrayの時
    str_url = "https://vision.googleapis.com/v1/images:annotate?key="
    str_api_key = "AIzaSyDlRRYrHEdjParsfRmh96_3xfafOo1crWY"
    str_headers = {'Content-Type': 'application/json'}
    str_json_data = {
        'requests': [
            {
                'image': {
                    'content': str_encode_file
                },
                'features': [
                    {
                        'type': "DOCUMENT_TEXT_DETECTION",
                        'maxResults': 1
                    }
                ]
            }
        ]
    }

    obj_session = Session()
    obj_request = Request("POST",
                            str_url + str_api_key,
                            data=json.dumps(str_json_data),
                            headers=str_headers
                            )
    obj_prepped = obj_session.prepare_request(obj_request)
    obj_response = obj_session.send(obj_prepped,
                                    verify=True,
                                    timeout=60
                                    )

    if obj_response.status_code == 200:
        text = get_fullTextAnnotation(obj_response.text)
        
        return text
    else:
        return "error"

# %%
def path_to_array(img_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

# %%
recognize_image1(path_to_array("/Users/obara/PHCのコピー3.png"))
# Out:
# {'responses': [{'textAnnotations': [{'locale': 'ja', 'description': '0627134\n340\n処\n方\nせ\nん\n10004\n(この処方せんは、どの保険局でも有効です。)\n負担割合 3割\nP.1\n公費負担者番号\n保険者番号\n公費負担医療\n被保険者証・保険\nの受給者番号\n予報の記号番号\n1234.5678\nカンジャジロウ\n映像 東京都新宿区四ッ谷1-2-5\n患\n氏名\n患者次郎\nの田中クリニック\n及び名称\n45才\n者生年月日\n2ヶ月の女 電話番号03-5408-7751\n44年 9月 6日生\n保險代名医師太郎\n印\n区分 被保険者 被扶養者 F1317|1|2|3|4|5|6|7\n処方せんの\nにのある場合を、\n交付年月日 平成 26年 12月\n使用期間 平成26年12月4日 12312!!\n保に出すること。\n| 変更不可しには、「変更不可にカラはザメ」を記載し、行保険医著名」に著名又は記名押印すること、\n個々の方薬について、後発医薬品(ジェネリック医部品の変更にしぶえがあると判断した場合】\n*【般】カルボシステイン錠\n250mg\n3 錠\n処\n【般】アンブロキソール塩酸塩錠\n15mg\n3 錠\nフスコデ配合錠」\n3 錠\n【般】セフカペンピボキシル塩酸塩錠\n100mg\n3 錠\n分3毎食後服用し\n14日分\n*【般】ニフェジピン徐放錠\n20mg(24時間持続)\n2 錠\n分2朝・夕食後服用\n28日分\n【般】ケトプロフェンテープ\n40mg(10×14cm非温感) 14 枚\n方\n1日1回貼付\n【
'y': 167}, {'x': 499, 'y': 167}, {'x': 499, 'y': 181}, {'x': 497, 'y': 181}]}}, {'description': 'で', 'boundingPoly': {'vertices': [{'x': 508, 'y': 167}, {'x': 510, 'y': 167}, {'x': 510, 'y': 181}, {'x': 508, 'y': 181}]}}, {'description': 'も', 'boundingPoly': {'vertices': [{'x': 517, 'y': 167}, {'x': 519, 'y': 167}, {'x': 519, 'y': 181}, {'x': 517, 'y': 181}]}}, {'description': '有効', 'boundingPoly': {'vertices': [{'x': 523, 'y': 167}, {'x': 540, 'y': 167}, {'x': 540, 'y': 181}, {'x': 523, 'y': 181}]}}, {'description': 'です', 'boundingPoly': {'vertices': [{'x': 543, 'y': 167}, {'x': 555, 'y': 167}, {'x': 555, 'y': 181}, {'x': 543, 'y': 181}]}}, {'description': '。', 'boundingPoly': {'vertices': [{'x': 557, 'y': 167}, {'x': 559, 'y': 167}, {'x': 559, 'y': 181}, {'x': 557, 'y': 181}]}}, {'description': ')', 'boundingPoly': {'vertices': [{'x': 569, 'y': 167}, {'x': 571, 'y': 167}, {'x': 571, 'y': 181}, {'x': 569, 'y': 181}]}}, {'description':  ...
# '0627134\n340\n処\n方\nせ\nん\n10004\n(この処方せんは、どの保険局でも有効です。)\n負担割合 3割\nP.1\n公費負担者番号\n保険者番号\n公費負担医療\n被保険者証・保険\nの受給者番号\n予報の記号番号\n1234.5678\nカンジャジロウ\n映像 東京都新宿区四ッ谷1-2-5\n患\n氏名\n患者次郎\nの田中クリニック\n及び名称\n45才\n者生年月日\n2ヶ月の女 電話番号03-5408-7751\n44年 9月 6日生\n保險代名医師太郎\n印\n区分 被保険者 被扶養者 F1317|1|2|3|4|5|6|7\n処方せんの\nにのある場合を、\n交付年月日 平成 26年 12月\n使用期間 平成26年12月4日 12312!!\n保に出すること。\n| 変更不可しには、「変更不可にカラはザメ」を記載し、行保険医著名」に著名又は記名押印すること、\n個々の方薬について、後発医薬品(ジェネリック医部品の変更にしぶえがあると判断した場合】\n*【般】カルボシステイン錠\n250mg\n3 錠\n処\n【般】アンブロキソール塩酸塩錠\n15mg\n3 錠\nフスコデ配合錠」\n3 錠\n【般】セフカペンピボキシル塩酸塩錠\n100mg\n3 錠\n分3毎食後服用し\n14日分\n*【般】ニフェジピン徐放錠\n20mg(24時間持続)\n2 錠\n分2朝・夕食後服用\n28日分\n【般】ケトプロフェンテープ\n40mg(10×14cm非温感) 14 枚\n方\n1日1回貼付\n【以下余白】\n」\n保険医等名(\nしんきん:もしも!\n備\n医師 太郎\n処方せん情報のみを記録しています\n考\n公費負担者番号\n公費負担医療\nの受給者番号\n済年月日\n保薬局の所在\n地及び名称\n平成\n年\n月\n'

# %%
#coding:utf-8
#必要なもののimport 
import base64
import json
from requests import Request, Session
from io import BytesIO
from PIL import Image
import pandas as pd
import jaconv
import re
import cv2
import numpy as np
from symspellpy.symspellpy import SymSpell, Verbosity
import pickle
from pykakasi import kakasi
import Levenshtein
from collections import OrderedDict
import itertools

# %%
def pickle_file_open(pickle_file_name):
    with open(pickle_file_name, 'rb') as web:
        df = pickle.load(web)
    return df

# %%
df=pickle_file_open("ocr_result_name.pickle")

# %%
from others import pickle_file_open
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-ebd08096d016> in <module>
# ----> 1 from others import pickle_file_open
#
# ModuleNotFoundError: No module named 'others'

# %%
s = '自然言語処理による日本国憲法の形態素解析'

for token in t.tokenize(s):
    print(token)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-049d1ec6e161> in <module>
#       1 s = '自然言語処理による日本国憲法の形態素解析'
#       2
# ----> 3 for token in t.tokenize(s):
#       4     print(token)
#
# NameError: name 't' is not defined

# %%
text = 'すもももももももものうち'
from janome.tokenizer import Tokenizer
t = Tokenizer("merge.csv", udic_enc="utf-8")
token_filters = [POSKeepFilter(['名詞'])]
analyzer = Analyzer([],t ,token_filters)
for token in analyzer.analyze(text):
    print(token)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e0bf07d13bdf> in <module>
#       2 from janome.tokenizer import Tokenizer
#       3 t = Tokenizer("merge.csv", udic_enc="utf-8")
# ----> 4 token_filters = [POSKeepFilter(['名詞'])]
#       5 analyzer = Analyzer([],t ,token_filters)
#       6 for token in analyzer.analyze(text):
#
# NameError: name 'POSKeepFilter' is not defined

# %%
from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer
from janome.tokenfilter import POSKeepFilter

# %%
token_filters = [POSKeepFilter(['名詞'])]
analyzer = Analyzer([],t ,token_filters)
for token in analyzer.analyze(text):
    print(token)
# Out:
# すもも	名詞,一般,*,*,*,*,すもも,スモモ,スモモ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# うち	名詞,非自立,副詞可能,*,*,*,うち,ウチ,ウチ

# %%
def symbol_number(text_list):
    text_list=[text_list]
    text_list=word_check_list_before(text_list,"所在地")
    text_list=word_check_list_before(text_list,"電話番号")
    text_list=word_check_list_before(text_list,"保険医療")
    text_list=word_check_list_before(text_list,"医療機")
    text_list=word_check_list_before(text_list,"〒")
    text_list=word_check_list_before(text_list,"東京都")
    text_list=word_check_list_before(text_list,"町")
    text_list=word_check_list_before(text_list,"区")
    text_list=word_check_list(text_list,"険者番号")
    text_list=word_check_list2(text_list,"被保険")

    #info_list=[]
    sum_=0
    for i in text_list:
        #print(i)
        word_list=["-".join(s) for s in i]#.replace("・","-").replace(".","-")
        word_list2=("-".join(word_list))
        word_list3=word_list2.replace("・","-").replace(".","-").replace("•","-")
        word_list4=word_list3.split("-")
        word_list5=[]
        for word in word_list4:
            if word.count(' ')==1:
                word_list5.append(word.split(" ")[0])
                word_list5.append(word.split(" ")[1])
            else:
                word_list5.append(word)
        #print(word_list5)
        sum_+=1
    #     for word in word_list5:
            
    #         print(re.sub('[^0-9]','',word))
        word_list6=[re.sub('[^0-9]','',word) for word in word_list5]
        #print("-".join(word_list6))
        return re.sub('-+', '-', "-".join(word_list6).strip("-"))
        


    
def word_check_list_before(text_list, check_word):
    '''
    ある単語を含んでいたら、それより前を全てを取得（その単語は含まない）
    input:リスト内包リスト,検索単語
    output:リスト内包リスト
    '''
    word=check_word
    candidate_list=[]
    for num in range(len(text_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][:s])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)


def word_check_list2(text_list, check_word):
    '''
    ある単語を含んでいたら、それ以降全てを取得（その単語は含む）
    （含まないversionはword_check_list)
    input:リスト内包リスト,検索単語
    output:リスト内包リスト
    '''
    word=check_word
    candidate_list=[]
    for num in range(len(text_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):
            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1

                    candidate_list.append(text_list[num][s:])


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)

# %%
text_list=[['O'], ['P. 1'], ['薬局でも有効です。)'], ['保険者番号 O1 1 300112'], ['被保険者証・被保険', '50000013', '109420'], ['者手帳の記号・番号'], ['保険医療機 東京都千代田区飯田橋4-4-7'], ['及び名称 医療法人社団慈仁会 飯田橋小池クリニック'], ['電話番号 03-3221-8858'], ['保険医氏名 小池 美由紀'], ['|都道府県', '番号', '1', '3', '番号', '1', '点数表 医療機関', 'O', '1', '1', '314 5 5 1', '特に記載のある場合を除き、', '1'], ['使用期間', '処方箋の', '年月日', '保険薬局に提出すること。', '交付の日を含めて4日以内に'], ['ネリック医薬品)への変更に差し支えがあると判断した場合'], ['記載し、「保険医署名」欄に署名又は記名・押印すること。'], ['錠'], ['3', '錠'], ['30日分'], ['3', '錠'], ['mg'], ['30日分'], ['湯エキス顆粒(']]
symbol_number(text_list)
# Out:
# '50000013-109420'

# %%
def word_check_list(text_list, check_word):
    '''
    ある単語を含んでいたら、それ以降全てを取得（その単語は含まない）
    input: リスト内包リスト
    output:リスト内包リスト
    '''
    word=check_word
    candidate_list=[]
    for num in range(len(text_list)):
        #num=1
        num_sum=0
        for s in range(len(text_list[num])):

            texts=text_list[num][s]#たんごリスト
            #print(texts)
            if num_sum==0:
                #print(texts[s])
                #print("".join(texts).replace(" ",""))
                #print("-----------------")
                if (word in "".join(texts).replace(" ","")) :
                    num_sum=1
                    try:
                        candidate_list.append(text_list[num][s+1:])
                    except:
                        pass


        if num_sum==0:
            candidate_list.append(text_list[num])
            
    return (candidate_list)
