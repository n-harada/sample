# %%
import pandas as pd

# %%
df = pd.read_csv('202004-1DInews_hand_crafted_utf8.csv')

# %%
df
# Out:
#            区分                       商品名                  会社名           一般名   \
# 0      全科・院内外           アブストラル舌下錠 100μg             協和キリン＝久光   フェンタニルクエン酸塩
# 1   患者限定・院外のみ                    アヘンチンキ               武田薬品工業        アヘンチンキ
# 2     歯科・院内のみ           イーフェンバッカル錠 50μg            帝國製薬＝大鵬薬品   フェンタニルクエン酸塩
# 3      全科・院内外          コカイン塩酸塩  「タケダ」原末               武田薬品工業       コカイン塩酸塩
# 4    医師限定・院内外           メサペイン錠 5mg、10mg           帝国＝テルモ＝塩野義       メサドン塩酸塩
# ..         ...                       ...                  ...           ...
# 58    全科・院外のみ             セルシンシロップ 0.1％              武田＝武田テバ         ジアゼパム
# 59     全科・院内外   フェノバール散 10％、エリキシル\n0.4％              第一三共＝藤永     フェノバルビタール
# 60     全科・院内外          ベンザリン細粒 1％、錠 5mg                 共和薬品        ニトラゼパム
# 61     全科・院内外          マイスタン細粒 1％、錠 5mg   大日本住友＝アルフレ\nッサファーマ         クロバザム
# 62     全科・院内外      ランドセン細粒 0.1％、錠 0.5mg              大日本住友製薬        クロナゼパム
#
#             薬効分類   type  投薬期間
# 0             NaN    麻薬    14
# ...
