# %%
import os

# %% [markdown]
# ### リクエスト数

# %% [markdown]
# #### オゾン薬局

# %%
dict_total_papers = {
    '20201124':1,
    '20201125':1,
    '20201126':5,
    '20201127':0,
    '20201128':5,
    '20201129':0,
    '20201130':7,
    '20201201':5,
    '20201202':1,
    '20201203':2,
    '20201204':2,
    '20201205':5,
}

dict_total_QRs = {
    '20201124':1,
    '20201125':1,
    '20201126':5,
    '20201127':0,
    '20201128':4,
    '20201129':0,
    '20201130':5,
    '20201201':3,
    '20201202':1,
    '20201203':2,
    '20201204':2,
    '20201205':5,    
}

LOG_DIR = './ozon'

# %%
for log in sorted(os.listdir(LOG_DIR)):
    fd = open(os.path.join(LOG_DIR,log), mode='r')
    data = fd.read().splitlines()
    fd.close()
    print(log)
    for val in data:
        print(val)
    print('')
# Out:
# 20201201.log
# INFO:root:new session
# INFO:werkzeug:126.156.87.150 - - [01/Dec/2020 16:19:16] "POST /result1 HTTP/1.1" 200 -
# INFO:werkzeug:126.156.87.150 - - [01/Dec/2020 16:19:18] "GET /static/18266.jpg HTTP/1.1" 304 -
# INFO:werkzeug:126.156.87.150 - - [01/Dec/2020 16:19:18] "GET /uploads/QR_images/1_OZONE_2020-12-01-16-18-59-991629_for_main_qrcode.jpeg?1606807156.9187658 HTTP/1.1" 200 -
# INFO:werkzeug:126.156.87.150 - - [01/Dec/2020 16:19:18] "GET /uploads/prescription_images/1_OZONE_2020-12-01-16-18-59-991629_1.jpeg HTTP/1.1" 200 -
# INFO:werkzeug:126.156.87.150 - - [01/Dec/2020 16:19:19] "GET /uploads/prescription_images/1_OZONE_2020-12-01-16-18-59-991629_0.jpeg HTTP/1.1" 200 -
# INFO:root:【error-report】birthday
# INFO:werkzeug:126.156.87.150 - - [01/Dec/2020 16:20:09] "GET /report-birth HTTP/1.1" 200 -
# INFO:root:new session
# INFO:werkzeug:126.156.87.150 - - [01/Dec/2020 16:21:21] "POST /result1 HTTP/1.1" 200 -
# ...
