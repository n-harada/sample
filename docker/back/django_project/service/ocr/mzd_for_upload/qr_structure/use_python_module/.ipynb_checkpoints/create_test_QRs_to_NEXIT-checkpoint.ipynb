# %%
import os

os.chdir(r'/home/yukim/Desktop/prescription/')
import make_qr
# Out:
# loading med symspells...
# loading medicine DB...
# loading hospital info in med_info.py...should optimize...
# loading l_units_med_stable...

# %% [markdown]
# ### base vals

# %%
basic_result_base={"id_1_hospital_name":"","_1_hospital_code_type":"","_1_hospital_code":"","_1_hospital_place_code":"",
'_5_doctor_name_kana':'','_5_doctor_name_kanji':'',
"id_11_patient_name_kanji":"","id_11_patient_name_kana":"",
"id_12_patient_sex":"",
'_13_patient_birthday':"",
"id_22_insurance_patient_num":"",
"id_23_insurance_card_id":"","id_23_insurance_card_num":"","_23_insurance_type":"",
'_51_prescription_date':""}

# %%
#SAVE

basic_result_base["id_1_hospital_name"] = "仙川駅前すずきクリニック"
basic_result_base["_1_hospital_code_type"] ='1'
basic_result_base["_1_hospital_code"] = '4224481'
basic_result_base["_1_hospital_place_code"] = '13'

basic_result_base['_5_doctor_name_kanji'] = "鈴木　次郎"
basic_result_base['_5_doctor_name_kana']="ｽｽﾞｷ ｼﾞﾛｳ"

basic_result_base["id_11_patient_name_kanji"] = "松田　悠希"
basic_result_base["id_11_patient_name_kana"] = "ﾏﾂﾀﾞ ﾕｳｷ"

basic_result_base["id_12_patient_sex"] ='1'

basic_result_base['_13_patient_birthday'] = "4070306"

basic_result_base["id_22_insurance_patient_num"] = "138271"

basic_result_base["id_23_insurance_card_id"] = "27-18"
basic_result_base["id_23_insurance_card_num"] = '9796'
basic_result_base["_23_insurance_type"] = '1'

basic_result_base["_51_prescription_date"] = "5020729"

# %%
#SAVE

l_keys_med = ['RP番号','PR番号内連番','剤形区分','調剤数量','用法名称','薬品名称','用量','単位名']

l_1 = [1, 1,'-100','-1','用法未取得',['カルボシステイン錠 250mg'],'3','錠']
l_2 = [1, 2,'-100','-1','用法未取得',['アンブロキソール塩酸塩錠 15mg'],'3','錠']
l_3 = [1, 3,'-100','-1','用法未取得',['フスコデ配合錠'],'3','錠']
l_4 = [1, 4,'-100','14','分3 毎食後服用',['セフカペンピボキシル塩酸塩錠 100mg'],'3','錠']

l_5 = [2, 1,'-100','28','分2 朝・夕食後服用',['ニフェジピン徐放錠 20mg(24時間持続)'],'2','錠']

l_6 = [3, 1,'-100','1','1日1回 貼付',['ケトプロフェンテープ 40mg(10×14cm非温感)'],'14','枚']

l_tail = ['']*len(l_keys_med)

ls = [l_1,l_2,l_3,l_4,l_5,l_6,l_tail]

med_result_base = []
for l in ls:
    med_dict=dict(zip(l_keys_med,l))
    med_result_base.append(med_dict)

# %%
make_qr.make_qrcode(basic_result_base, med_result_base, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,鈴木　次郎
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,1
# 13,4070306
# 22,138271
# 23,27-18,9796,1,
# 51,5020729
# 101,1,1,,14
# 111,1,1,,分3 毎食後服用,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,1\r\n13,4070306\r\n22,138271\r\n23,27-18,9796,1,\r\n51,5020729\r\n101,1,1,,14\r\n111,1,1,,\x95\xaa3 \x96\x88\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 医療機関dummy

# %%
basic_result = basic_result_base.copy()
basic_result["id_1_hospital_name"] = "テスト医療機関"
basic_result["_1_hospital_code_type"] ='1'
basic_result["_1_hospital_code"] = '0000000'
basic_result["_1_hospital_place_code"] = '13'

# %%
make_qr.make_qrcode(basic_result, med_result_base, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,0000000,13,テスト医療機関
# 5,,,鈴木　次郎
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,1
# 13,4070306
# 22,138271
# 23,27-18,9796,1,
# 51,5020729
# 101,1,1,,14
# 111,1,1,,分3 毎食後服用,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,0000000,13,\x83e\x83X\x83g\x88\xe3\x97\xc3\x8b@\x8a\xd6\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,1\r\n13,4070306\r\n22,138271\r\n23,27-18,9796,1,\r\n51,5020729\r\n101,1,1,,14\r\n111,1,1,,\x95\xaa3 \x96\x88\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 医師氏名 dummy

# %%
basic_result = basic_result_base.copy()
basic_result['_5_doctor_name_kanji'] = "テスト医師"
basic_result['_5_doctor_name_kana']=""

# %%
make_qr.make_qrcode(basic_result, med_result_base, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,テスト医師
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,1
# 13,4070306
# 22,138271
# 23,27-18,9796,1,
# 51,5020729
# 101,1,1,,14
# 111,1,1,,分3 毎食後服用,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x83e\x83X\x83g\x88\xe3\x8et\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,1\r\n13,4070306\r\n22,138271\r\n23,27-18,9796,1,\r\n51,5020729\r\n101,1,1,,14\r\n111,1,1,,\x95\xaa3 \x96\x88\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 患者氏名 dummy

# %%
basic_result = basic_result_base.copy()
basic_result["id_11_patient_name_kanji"] = "テスト患者"
basic_result["id_11_patient_name_kana"] = "テストカンジャ"

# %%
make_qr.make_qrcode(basic_result, med_result_base, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,鈴木　次郎
# 11,,テスト患者,テストカンジャ
# 12,1
# 13,4070306
# 22,138271
# 23,27-18,9796,1,
# 51,5020729
# 101,1,1,,14
# 111,1,1,,分3 毎食後服用,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x83e\x83X\x83g\x8a\xb3\x8e\xd2,\x83e\x83X\x83g\x83J\x83\x93\x83W\x83\x83\r\n12,1\r\n13,4070306\r\n22,138271\r\n23,27-18,9796,1,\r\n51,5020729\r\n101,1,1,,14\r\n111,1,1,,\x95\xaa3 \x96\x88\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 患者性別 dummy

# %%
basic_result = basic_result_base.copy()
basic_result["id_12_patient_sex"] ='0'

# %%
make_qr.make_qrcode(basic_result, med_result_base, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,鈴木　次郎
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,0
# 13,4070306
# 22,138271
# 23,27-18,9796,1,
# 51,5020729
# 101,1,1,,14
# 111,1,1,,分3 毎食後服用,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,0\r\n13,4070306\r\n22,138271\r\n23,27-18,9796,1,\r\n51,5020729\r\n101,1,1,,14\r\n111,1,1,,\x95\xaa3 \x96\x88\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 患者生年月日dummy

# %%
basic_result = basic_result_base.copy()
basic_result['_13_patient_birthday'] = "1360101"

# %%
make_qr.make_qrcode(basic_result, med_result_base, return_image=True)
# Out:
# /home/yukim/Desktop/prescription/make_qr.py:228: UserWarning: カルボシステイン錠 250mgwas not in DB and was changed to カルボシステイン錠250mg
#   warn(med_name+'was not in DB and was changed to '+changed_med_name)
# /home/yukim/Desktop/prescription/make_qr.py:228: UserWarning: アンブロキソール塩酸塩錠 15mgwas not in DB and was changed to アンブロキソール塩酸塩錠15mg
#   warn(med_name+'was not in DB and was changed to '+changed_med_name)
# /home/yukim/Desktop/prescription/make_qr.py:228: UserWarning: セフカペンピボキシル塩酸塩錠 100mgwas not in DB and was changed to セフカペンピボキシル塩酸塩錠100mg
#   warn(med_name+'was not in DB and was changed to '+changed_med_name)
# /home/yukim/Desktop/prescription/make_qr.py:228: UserWarning: ニフェジピン徐放錠 20mg(24時間持続)was not in DB and was changed to ニフェジピン徐放錠20mg(24時間持続)
#   warn(med_name+'was not in DB and was changed to '+changed_med_name)
# /home/yukim/Desktop/prescription/make_qr.py:228: UserWarning: ケトプロフェンテープ 40mg(10×14cm非温感)was not in DB and was changed to ケトプロフェンテープ40mg(10×14cm非温感)
#   warn(med_name+'was not in DB and was changed to '+changed_med_name)
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,鈴木　次郎
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,1
# 13,1360101
# 22,138271
# 23,27-18,9796,1,
# 51,5020729
# 101,1,1,,14
# 111,1,1,,分3 毎食後服用,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,1\r\n13,1360101\r\n22,138271\r\n23,27-18,9796,1,\r\n51,5020729\r\n101,1,1,,14\r\n111,1,1,,\x95\xaa3 \x96\x88\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 保険者番号 dummy

# %%
basic_result = basic_result_base.copy()
basic_result["id_22_insurance_patient_num"] = "00000000"

# %%
make_qr.make_qrcode(basic_result, med_result_base, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,鈴木　次郎
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,1
# 13,4070306
# 22,00000000
# 23,27-18,9796,1,
# 51,5020729
# 101,1,1,,14
# 111,1,1,,分3 毎食後服用,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,1\r\n13,4070306\r\n22,00000000\r\n23,27-18,9796,1,\r\n51,5020729\r\n101,1,1,,14\r\n111,1,1,,\x95\xaa3 \x96\x88\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 記号番号dummy

# %%
basic_result = basic_result_base.copy()
basic_result["id_23_insurance_card_id"] = "XX"
basic_result["id_23_insurance_card_num"] = 'XX'
basic_result["_23_insurance_type"] = '0'

# %%
make_qr.make_qrcode(basic_result, med_result_base, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,鈴木　次郎
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,1
# 13,4070306
# 22,138271
# 23,XX,XX,0,
# 51,5020729
# 101,1,1,,14
# 111,1,1,,分3 毎食後服用,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,1\r\n13,4070306\r\n22,138271\r\n23,XX,XX,0,\r\n51,5020729\r\n101,1,1,,14\r\n111,1,1,,\x95\xaa3 \x96\x88\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 交付年月日dummy

# %%
basic_result = basic_result_base.copy()
basic_result["_51_prescription_date"] = "5010319"

# %%
make_qr.make_qrcode(basic_result, med_result_base, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,鈴木　次郎
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,1
# 13,4070306
# 22,138271
# 23,27-18,9796,1,
# 51,5010319
# 101,1,1,,14
# 111,1,1,,分3 毎食後服用,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,1\r\n13,4070306\r\n22,138271\r\n23,27-18,9796,1,\r\n51,5010319\r\n101,1,1,,14\r\n111,1,1,,\x95\xaa3 \x96\x88\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 剤形dummy

# %%
l_keys_med = ['RP番号','PR番号内連番','剤形区分','調剤数量','用法名称','薬品名称','用量','単位名']

l_1 = [1, 1,'-100','-1','用法未取得',['カルボシステイン錠 250mg'],'3','錠']
l_2 = [1, 2,'-100','-1','用法未取得',['アンブロキソール塩酸塩錠 15mg'],'3','錠']
l_3 = [1, 3,'-100','-1','用法未取得',['フスコデ配合錠'],'3','錠']
l_4 = [1, 4,'-100','0','分3 毎食後服用',['セフカペンピボキシル塩酸塩錠 100mg'],'3','錠']

l_5 = [2, 1,'-100','28','分2 朝・夕食後服用',['ニフェジピン徐放錠 20mg(24時間持続)'],'2','錠']

l_6 = [3, 1,'-100','1','1日1回 貼付',['ケトプロフェンテープ 40mg(10×14cm非温感)'],'14','枚']

l_tail = ['']*len(l_keys_med)

ls = [l_1,l_2,l_3,l_4,l_5,l_6,l_tail]

med_result = []
for l in ls:
    med_dict=dict(zip(l_keys_med,l))
    med_result.append(med_dict)

# %%
make_qr.make_qrcode(basic_result_base, med_result, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,鈴木　次郎
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,1
# 13,4070306
# 22,138271
# 23,27-18,9796,1,
# 51,5020729
# 101,1,1,,0
# 111,1,1,,分3 毎食後服用,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,1\r\n13,4070306\r\n22,138271\r\n23,27-18,9796,1,\r\n51,5020729\r\n101,1,1,,0\r\n111,1,1,,\x95\xaa3 \x96\x88\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 用法dummy

# %%
l_keys_med = ['RP番号','PR番号内連番','剤形区分','調剤数量','用法名称','薬品名称','用量','単位名']

l_1 = [1, 1,'-100','-1','用法未取得',['カルボシステイン錠 250mg'],'3','錠']
l_2 = [1, 2,'-100','-1','用法未取得',['アンブロキソール塩酸塩錠 15mg'],'3','錠']
l_3 = [1, 3,'-100','-1','用法未取得',['フスコデ配合錠'],'3','錠']
l_4 = [1, 4,'-100','14','ダミー用法',['セフカペンピボキシル塩酸塩錠 100mg'],'3','錠']
#l_4 = [1, 4,'-100','14','分3 毎食後服用',['セフカペンピボキシル塩酸塩錠 100mg'],'3','錠']

l_5 = [2, 1,'-100','28','分2 朝・夕食後服用',['ニフェジピン徐放錠 20mg(24時間持続)'],'2','錠']

l_6 = [3, 1,'-100','1','1日1回 貼付',['ケトプロフェンテープ 40mg(10×14cm非温感)'],'14','枚']

l_tail = ['']*len(l_keys_med)

ls = [l_1,l_2,l_3,l_4,l_5,l_6,l_tail]

med_result = []
for l in ls:
    med_dict=dict(zip(l_keys_med,l))
    med_result.append(med_dict)

# %%
make_qr.make_qrcode(basic_result_base, med_result, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,鈴木　次郎
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,1
# 13,4070306
# 22,138271
# 23,27-18,9796,1,
# 51,5020729
# 101,1,1,,14
# 111,1,1,,ダミー用法,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,3,1,錠
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,1\r\n13,4070306\r\n22,138271\r\n23,27-18,9796,1,\r\n51,5020729\r\n101,1,1,,14\r\n111,1,1,,\x83_\x83~\x81[\x97p\x96@,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,3,1,\x8f\xf9\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'

# %% [markdown]
# ### 医薬品dummy

# %%
l_keys_med = ['RP番号','PR番号内連番','剤形区分','調剤数量','用法名称','薬品名称','用量','単位名']

l_1 = [1, 1,'-100','-1','用法未取得',['カルボシステイン錠 250mg'],'0','錠']
l_2 = [1, 2,'-100','-1','用法未取得',['アンブロキソール塩酸塩錠 15mg'],'3','']
l_3 = [1, 3,'-100','-1','用法未取得',['フスコデ配合錠'],'3','錠']
l_4 = [1, 4,'-100','14','ダミー用法',['セフカペンピボキシル塩酸塩錠 100mg'],'3','錠']
#l_4 = [1, 4,'-100','14','分3 毎食後服用',['セフカペンピボキシル塩酸塩錠 100mg'],'3','錠']

l_5 = [2, 1,'-100','28','分2 朝・夕食後服用',['ニフェジピン徐放錠 20mg(24時間持続)'],'2','錠']

l_6 = [3, 1,'-100','1','1日1回 貼付',['ケトプロフェンテープ 40mg(10×14cm非温感)'],'14','枚']

l_tail = ['']*len(l_keys_med)

ls = [l_1,l_2,l_3,l_4,l_5,l_6,l_tail]

med_result = []
for l in ls:
    med_dict=dict(zip(l_keys_med,l))
    med_result.append(med_dict)

# %%
make_qr.make_qrcode(basic_result_base, med_result, return_image=True)
# Out:
# result
# JAHIS7
# 1,1,4224481,13,仙川駅前すずきクリニック
# 5,,,鈴木　次郎
# 11,,松田　悠希,ﾏﾂﾀﾞ ﾕｳｷ
# 12,1
# 13,4070306
# 22,138271
# 23,27-18,9796,1,
# 51,5020729
# 101,1,1,,14
# 111,1,1,,ダミー用法,
# 201,1,1,,7,2233002F1ZZZ,カルボシステイン錠250mg,0,1,
# 201,1,2,,7,2239001F1ZZZ,アンブロキソール塩酸塩錠15mg,3,1,錠
# 201,1,3,,2,620379601,フスコデ配合錠,3,1,錠
# 201,1,4,,7,6132016F2ZZZ,セフカペンピボキシル塩酸塩錠100mg,3,1,錠
# 101,2,1,,28
# 111,2,1,,分2 朝・夕食後服用,
# 201,2,1,,7,2171014G4ZZZ,ニフェジピン徐放錠20mg(24時間持続),2,1,錠
# 101,3,3,,1
# 111,3,1,,1日1回 貼付,
# 201,3,1,,7,2649729S3ZZZ,ケトプロフェンテープ40mg(10×14cm非温感),14,1,枚
#
# ----------------
# b'JAHIS7\r\n1,1,4224481,13,\x90\xe5\x90\xec\x89w\x91O\x82\xb7\x82\xb8\x82\xab\x83N\x83\x8a\x83j\x83b\x83N\r\n5,,,\x97\xe9\x96\xd8\x81@\x8e\x9f\x98Y\r\n11,,\x8f\xbc\x93c\x81@\x97I\x8a\xf3,\xcf\xc2\xc0\xde \xd5\xb3\xb7\r\n12,1\r\n13,4070306\r\n22,138271\r\n23,27-18,9796,1,\r\n51,5020729\r\n101,1,1,,14\r\n111,1,1,,\x83_\x83~\x81[\x97p\x96@,\r\n201,1,1,,7,2233002F1ZZZ,\x83J\x83\x8b\x83{\x83V\x83X\x83e\x83C\x83\x93\x8f\xf9250mg,0,1,\r\n201,1,2,,7,2239001F1ZZZ,\x83A\x83\x93\x83u\x83\x8d\x83L\x83\\\x81[\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf915mg,3,1,\x8f\xf9\r\n201,1,3,,2,620379601,\x83t\x83X\x83R\x83f\x94z\x8d\x87\x8f\xf9,3,1,\x8f\xf9\r\n201,1,4,,7,6132016F2ZZZ,\x83Z\x83t\x83J\x83y\x83\x93\x83s\x83{\x83L\x83V\x83\x8b\x89\x96\x8e_\x89\x96\x8f\xf9100mg,3,1,\x8f\xf9\r\n101,2,1,,28\r\n111,2,1,,\x95\xaa2 \x92\xa9\x81E\x97[\x90H\x8c\xe3\x95\x9e\x97p,\r\n201,2,1,,7,2171014G4ZZZ,\x83j\x83t\x83F\x83W\x83s\x83\x93\x8f\x99\x95\xfa\x8f\xf920mg(24\x8e\x9e\x8a\xd4\x8e\x9d\x91\xb1),2,1,\x8f\xf9\r\n101,3,3,,1\r\n111,3,1,,1\x93\xfa1\x89\xf1 \x93\\\x95t,\r\n201,3,1,,7,2649729S3ZZZ,\x83P\x83g\x83v\x83\x8d\x83t\x83F\x83\x93\x83e\x81[\x83v40mg(10\x81~14cm\x94\xf1\x89\xb7\x8a\xb4),14,1,\x96\x87\r\n'
